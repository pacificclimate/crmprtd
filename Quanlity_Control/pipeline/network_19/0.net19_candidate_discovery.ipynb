# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Automatically discover candidate mappings for any network
#
# This notebook creates provisional candidate mappings for `NETWORK_ID` from `meta_vars`. It uses variable names, standard names, descriptions, and units to find likely candidates for the six canonical variables.
#
# Automatic discovery is a screening step, not final semantic validation. Review the candidates and their aggregation meaning before marking mappings as accepted.

# %% [markdown]
# ## 1. Setup

# %%
import sys
function_path = '../func/'
sys.path.append(function_path)

# %%
from IPython.display import display
import sqlalchemy as sa
import pandas as pd
import numpy as np
import re
import os
from pathlib import Path
from func_network_2_variable_mapping import (
    CANONICAL_VARIABLES, CANONICAL_RULES, save_candidate_mappings,
)


HERE = Path.cwd()
OUTPUT_DIR = HERE / 'outfile'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
sys.path.insert(0, str(HERE.parent / 'func'))

DB_URL = os.getenv(
    'CRMP_DB_URL',
    'postgresql://tongli1997@proddb01.pcic.uvic.ca,proddb02.pcic.uvic.ca/crmp'
    '?keepalives=1&keepalives_idle=300&keepalives_interval=300'
    '&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass',
)
engine = sa.create_engine(DB_URL, pool_pre_ping=True)
NETWORK_ID = 19
MIN_SCORE = 3

# %% [markdown]
# ## 2. Load the selected network's variable catalog

# %%
catalog_query = sa.text("""
SELECT vars_id, network_id, net_var_name::text AS net_var_name, unit,
       standard_name, cell_method, display_name, short_name,
       long_description
FROM meta_vars
WHERE network_id = :network_id
ORDER BY standard_name
""")

network_catalog = pd.read_sql(
    catalog_query, engine, params={'network_id': NETWORK_ID}
)
display(network_catalog)
# Out:
#     vars_id  network_id                    net_var_name     unit  \
# 0       542          19                 air_temperature  Celsius
# 1       545          19   air_temperature_yesterday_low  Celsius
# 2       544          19  air_temperature_yesterday_high  Celsius
# 3       613          19                  Tx_Climatology  celsius
# 4       614          19                  Tn_Climatology  celsius
# 5       615          19              T_mean_Climatology  celsius
# 6       554          19               total_cloud_cover  percent
# 7       551          19                       dew_point  Celsius
# 8       616          19              Precip_Climatology       mm
# 9       546          19             total_precipitation       mm
# 10      549          19                  mean_sea_level      kPa
# 11      552          19               relative_humidity  percent
# 12      555          19                 tendency_amount  kPa s-1
# 13      837          19                     rain_amount       mm
# 14      547          19                      total_rain       mm
# 15      548          19                     snow_amount       cm
# 16      553          19                  wind_direction   degree
# 17      550          19                      wind_speed     km/h
# 18      543          19                 wind_gust_speed     km/h
#
#                             standard_name  \
# 0                         air_temperature
# 1                         air_temperature
# 2                         air_temperature
# 3                         air_temperature
# 4                         air_temperature
# 5                         air_temperature
# 6                     cloud_area_fraction
# 7                   dew_point_temperature
# 8   lwe_thickness_of_precipitation_amount
# 9   lwe_thickness_of_precipitation_amount
# 10                mean_sea_level_pressure
# 11                      relative_humidity
# 12               tendency_of_air_pressure
# 13           thickness_of_rainfall_amount
# 14           thickness_of_rainfall_amount
# 15           thickness_of_snowfall_amount
# 16                    wind_from_direction
# 17                             wind_speed
# 18                     wind_speed_of_gust
#
#                                           cell_method  \
# 0                                         time: point
# 1                                       time: minimum
# 2                                       time: maximum
# 3   t: maximum within days t: mean within months t...
# 4   t: minimum within days t: mean within months t...
# 5   t: mean within days t: mean within months t: m...
# 6                                         time: point
# 7                                         time: point
# 8             t: sum within months t: mean over years
# 9                                           time: sum
# 10                                        time: point
# 11                                        time: point
# 12                                          time: sum
# 13                                          time: sum
# 14                                          time: sum
# 15                                          time: sum
# 16                                         time: mean
# 17                                        time: point
# 18                                      time: maximum
#
#                       display_name  \
# 0              Temperature (Point)
# 1               Temperature (Min.)
# 2               Temperature (Max.)
# 3   Temperature Climatology (Max.)
# 4   Temperature Climatology (Min.)
# 5   Temperature Climatology (Mean)
# 6             Cloud Cover Fraction
# 7    Dew Point Temperature (Point)
# 8        Precipitation Climatology
# 9             Precipitation Amount
# 10         Mean Sea Level Pressure
# 11       Relative Humidity (Point)
# 12           Air Pressure Tendency
# 13                        Rainfall
# 14                 Rainfall Amount
# 15                 Snowfall Amount
# 16           Wind Direction (Mean)
# 17              Wind Speed (Point)
# 18                Wind Gust (Max.)
#
#                                            short_name  \
# 0                               air_temperature_point
# 1                             air_temperature_minimum
# 2                             air_temperature_maximum
# 3   air_temperaturet: maximum within days t: mean ...
# 4   air_temperaturet: minimum within days t: mean ...
# 5   air_temperaturet: mean within days t: mean wit...
# 6                           cloud_area_fraction_point
# 7                         dew_point_temperature_point
# 8   lwe_thickness_of_precipitation_amountt: sum wi...
# 9           lwe_thickness_of_precipitation_amount_sum
# 10                     mean_seal_level_pressure_point
# 11                            relative_humidity_point
# 12                       tendency_of_air_pressure_sum
# 13                   thickness_of_rainfall_amount_sum
# 14                   thickness_of_rainfall_amount_sum
# 15                   thickness_of_snowfall_amount_sum
# 16                           wind_from_direction_mean
# 17                                   wind_speed_point
# 18                         wind_speed_of_gust_maximum
#
#                                      long_description
# 0                              Hourly air temperature
# 1                       Minimum daily air temperature
# 2                       Maximum daily air temperature
# 3   Climatological mean of monthly mean maximum da...
# 4   Climatological mean of monthly mean minimum da...
# 5   Climatological mean of monthly mean of mean da...
# 6                                   Total cloud cover
# 7                                           Dew point
# 8   Climatological mean of monthly total precipita...
# 9                          Daily precipitation amount
# 10                    Hourly mean seas level pressure
# 11                                  Relative humidity
# 12                              Air pressure tendency
# 13                                     Daily rainfall
# 14                              Daily rainfall amount
# 15                                     Daily snowfall
# 16                             Wind direction octants
# 17                           Instantaneous wind speed
# 18                         Maximum speed of wind gust

# %% [markdown]
# ## 3. Define transparent discovery rules
#
# Positive patterns add evidence; exclusion patterns prevent common false matches. Adjust these expressions if the selected network uses unusual abbreviations.

# %%
DISCOVERY_RULES = {
    'air_temperature': {
        'include': [r'air.*temp', r'temp.*air', r'(^|_)temperature($|_)'],
        'exclude': [r'min', r'max', r'dew', r'soil', r'water', r'road', r'surface', r'climatology'],
        'daily_aggregation': 'mean',
    },
    'daily_min_temperature': {
        'include': [r'min(imum)?.*temp', r'temp.*min(imum)?'],
        'exclude': [r'soil', r'water', r'road', r'surface', r'climatology'],
        'daily_aggregation': 'min',
    },
    'daily_max_temperature': {
        'include': [r'max(imum)?.*temp', r'temp.*max(imum)?'],
        'exclude': [r'soil', r'water', r'road', r'surface', r'climatology'],
        'daily_aggregation': 'max',
    },
    'precipitation_amount': {
        'include': [r'precip', r'pcpn', r'(^|_)rain($|_)', r'rainfall'],
        'exclude': [r'snow', r'snw', r'climatology'],
        'daily_aggregation': 'sum',
    },
    'snowfall_amount': {
        'include': [r'snow.*fall', r'snwfl', r'standard.*snow'],
        'exclude': [r'depth', r'dpth', r'height', r'climatology'],
        'daily_aggregation': 'sum',
    },
    'snow_depth': {
        'include': [r'snow.*depth', r'depth.*snow', r'snw.*dpth', r'height.*snow'],
        'exclude': [r'fall', r'amount', r'climatology'],
        'daily_aggregation': 'fixed_hour',
    },
}

# %% [markdown]
# ## 4. Score and rank candidates

# %%
def normalized_text(row, columns):
    return ' '.join(str(row.get(column) or '') for column in columns).lower()


def score_candidate(row, canonical_name):
    rule = DISCOVERY_RULES[canonical_name]
    name_text = normalized_text(
        row, ['net_var_name', 'short_name', 'display_name'])
    metadata_text = normalized_text(
        row, ['standard_name', 'long_description', 'cell_method'])
    all_text = name_text + ' ' + metadata_text

    if any(re.search(pattern, all_text) for pattern in rule['exclude']):
        return 0, 'excluded keyword'

    name_hits = sum(bool(re.search(pattern, name_text))
                    for pattern in rule['include'])
    metadata_hits = sum(bool(re.search(pattern, metadata_text))
                        for pattern in rule['include'])
    score = 3 * name_hits + 3 * metadata_hits

    expected_unit = CANONICAL_RULES[canonical_name].unit.lower()
    actual_unit = str(row.get('unit') or '').lower()
    unit_tokens = {
        'celsius': ['celsius', 'degc', 'degree_c', 'degrees_c', '°c'],
        'mm': ['mm', 'millimet'],
        'cm': ['cm', 'centimet'],
    }[expected_unit]
    unit_match = any(token in actual_unit for token in unit_tokens)
    if unit_match:
        score += 1

    evidence = f'name hits={name_hits}; metadata hits={metadata_hits}; unit match={unit_match}'
    return score, evidence


rows = []
for _, variable in network_catalog.iterrows():
    for canonical_name in CANONICAL_VARIABLES:
        score, evidence = score_candidate(variable, canonical_name)
        if score >= MIN_SCORE:
            rule = DISCOVERY_RULES[canonical_name]
            rows.append({
                'vars_id': int(variable['vars_id']),
                'net_var_name': variable['net_var_name'],
                'canonical_variable': canonical_name,
                'unit': variable['unit'],
                'daily_aggregation': rule['daily_aggregation'],
                'source_family': f'network{NETWORK_ID}_auto',
                'discovery_score': score,
                'discovery_evidence': evidence,
                'mapping_status': 'needs_review',
            })

discovered_candidates = pd.DataFrame(rows)
if not discovered_candidates.empty:
    discovered_candidates = discovered_candidates.sort_values(
        ['canonical_variable', 'discovery_score', 'vars_id'],
        ascending=[True, False, True],
    )
    discovered_candidates['priority'] = (
        discovered_candidates.groupby('canonical_variable').cumcount() + 1
    )
display(discovered_candidates)
# Out:
#    vars_id                    net_var_name     canonical_variable     unit  \
# 0      542                 air_temperature        air_temperature  Celsius
# 2      544  air_temperature_yesterday_high  daily_max_temperature  Celsius
# 1      545   air_temperature_yesterday_low  daily_min_temperature  Celsius
# 4      837                     rain_amount   precipitation_amount       mm
# 3      546             total_precipitation   precipitation_amount       mm
# 5      547                      total_rain   precipitation_amount       mm
# 6      548                     snow_amount        snowfall_amount       cm
#
#   daily_aggregation   source_family  discovery_score  \
# 0              mean  network19_auto               16
# 2               max  network19_auto               13
# 1               min  network19_auto               13
# 4               sum  network19_auto               10
# 3               sum  network19_auto                7
# 5               sum  network19_auto                7
# 6               sum  network19_auto                7
#
#                               discovery_evidence mapping_status  priority
# 0  name hits=3; metadata hits=2; unit match=True   needs_review         1
# 2  name hits=2; metadata hits=2; unit match=True   needs_review         1
# 1  name hits=2; metadata hits=2; unit match=True   needs_review         1
# 4  name hits=2; metadata hits=1; unit match=True   needs_review         1
# 3  name hits=1; metadata hits=1; unit match=True   needs_review         2
# 5  name hits=1; metadata hits=1; unit match=True   needs_review         3
# 6  name hits=1; metadata hits=1; unit match=True   needs_review         1

# %% [markdown]
# ## 5. Review and override
#
# List false-positive IDs under `EXCLUDE`. Use `MANUAL_CANDIDATES` for variables missed by the patterns or to override inferred semantics. Re-run this cell after editing the lists.

# %%
# Exclusions are (vars_id, canonical_variable) pairs.
EXCLUDE = {
    # (732, 'precipitation_amount')
}

# Add or replace reviewed candidates here.
MANUAL_CANDIDATES = [
    # {
    #     'vars_id': 123,
    #     'net_var_name': 'NETWORK_1_VARIABLE_NAME',
    #     'canonical_variable': 'air_temperature',
    #     'unit': 'celsius',
    #     'daily_aggregation': 'mean',
    #     'source_family': f'network{NETWORK_ID}_reviewed',
    #     'priority': 1,
    #     'mapping_status': 'candidate',
    # },
]

reviewed = discovered_candidates.copy()
if not reviewed.empty and EXCLUDE:
    excluded = pd.MultiIndex.from_tuples(EXCLUDE)
    row_keys = pd.MultiIndex.from_frame(
        reviewed[['vars_id', 'canonical_variable']])
    reviewed = reviewed.loc[~row_keys.isin(excluded)].copy()

if MANUAL_CANDIDATES:
    manual = pd.DataFrame(MANUAL_CANDIDATES)
    manual_keys = set(zip(manual['vars_id'], manual['canonical_variable']))
    if not reviewed.empty:
        keep = [
            (row.vars_id, row.canonical_variable) not in manual_keys
            for row in reviewed.itertuples()
        ]
        reviewed = reviewed.loc[keep]
    reviewed = pd.concat([reviewed, manual], ignore_index=True)

display(reviewed.sort_values(['canonical_variable', 'priority']))
# Out:
#    vars_id                    net_var_name     canonical_variable     unit  \
# 0      542                 air_temperature        air_temperature  Celsius
# 2      544  air_temperature_yesterday_high  daily_max_temperature  Celsius
# 1      545   air_temperature_yesterday_low  daily_min_temperature  Celsius
# 4      837                     rain_amount   precipitation_amount       mm
# 3      546             total_precipitation   precipitation_amount       mm
# 5      547                      total_rain   precipitation_amount       mm
# 6      548                     snow_amount        snowfall_amount       cm
#
#   daily_aggregation   source_family  discovery_score  \
# 0              mean  network19_auto               16
# 2               max  network19_auto               13
# 1               min  network19_auto               13
# 4               sum  network19_auto               10
# 3               sum  network19_auto                7
# 5               sum  network19_auto                7
# 6               sum  network19_auto                7
#
#                               discovery_evidence mapping_status  priority
# 0  name hits=3; metadata hits=2; unit match=True   needs_review         1
# 2  name hits=2; metadata hits=2; unit match=True   needs_review         1
# 1  name hits=2; metadata hits=2; unit match=True   needs_review         1
# 4  name hits=2; metadata hits=1; unit match=True   needs_review         1
# 3  name hits=1; metadata hits=1; unit match=True   needs_review         2
# 5  name hits=1; metadata hits=1; unit match=True   needs_review         3
# 6  name hits=1; metadata hits=1; unit match=True   needs_review         1

# %% [markdown]
# ## 6. Build and save this network's candidate mappings
#
# The diagnostic columns remain in `discovered_candidates`; the final registry contains the same operational columns as the network-2 registry. The output filename includes the network ID.

# %%
mapping_columns = [
    'vars_id', 'net_var_name', 'canonical_variable',
    'daily_aggregation', 'priority', 'source_family', 'mapping_status',
]
candidate_mappings = (
    reviewed[mapping_columns]
    .sort_values(['canonical_variable', 'priority', 'vars_id'])
    .reset_index(drop=True)
)
# display(candidate_mappings)

# Include the network ID in the output filename.
candidate_mapping_path = (
    OUTPUT_DIR / f'0.net{NETWORK_ID}_candidate_mappings.csv'
)
all_saved_mappings = save_candidate_mappings(
    NETWORK_ID, candidate_mappings, candidate_mapping_path
)
print(f'Saved network {NETWORK_ID} mappings to {candidate_mapping_path}')
display(all_saved_mappings)
# Out:
# Saved network 19 mappings to /workspaces/crmprtd/Quanlity_Control/pipeline/network_19/outfile/0.net19_candidate_mappings.csv
#   network_id vars_id                    net_var_name     canonical_variable  \
# 0         19     542                 air_temperature        air_temperature
# 1         19     544  air_temperature_yesterday_high  daily_max_temperature
# 2         19     545   air_temperature_yesterday_low  daily_min_temperature
# 3         19     837                     rain_amount   precipitation_amount
# 4         19     546             total_precipitation   precipitation_amount
# 5         19     547                      total_rain   precipitation_amount
# 6         19     548                     snow_amount        snowfall_amount
#
#   daily_aggregation priority   source_family mapping_status
# 0              mean        1  network19_auto   needs_review
# 1               max        1  network19_auto   needs_review
# 2               min        1  network19_auto   needs_review
# 3               sum        1  network19_auto   needs_review
# 4               sum        2  network19_auto   needs_review
# 5               sum        3  network19_auto   needs_review
# 6               sum        1  network19_auto   needs_review

# %% [markdown]
# ## 7. Use the registry in the canonical-variable notebook

# %%
# Example
CANONICAL_VARIABLE = 'precipitation_amount'
candidate_rows = candidate_mappings[
    candidate_mappings['canonical_variable'] == CANONICAL_VARIABLE
]
candidate_ids = candidate_rows['vars_id'].tolist()
display(candidate_rows)
# Out:
#    vars_id         net_var_name    canonical_variable daily_aggregation  \
# 3      837          rain_amount  precipitation_amount               sum
# 4      546  total_precipitation  precipitation_amount               sum
# 5      547           total_rain  precipitation_amount               sum
#
#    priority   source_family mapping_status
# 3         1  network19_auto   needs_review
# 4         2  network19_auto   needs_review
# 5         3  network19_auto   needs_review
