# %% [markdown]
# # Canonical variable candidate check
#
# Select any of the six canonical variables, inspect candidate coverage, apply its plausible-value rule, and draw time-series and ECDF figures.

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sqlalchemy as sa
from IPython.display import display

HERE = Path.cwd()
OUTPUT_DIR = HERE / 'outfile'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
sys.path.insert(0, str(HERE.parent / 'func'))
from func_variable_mapping import *

DB_URL = os.getenv(
    'CRMP_DB_URL',
    'postgresql://tongli1997@proddb01.pcic.uvic.ca,proddb02.pcic.uvic.ca/crmp'
    '?keepalives=1&keepalives_idle=300&keepalives_interval=300'
    '&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass',
)
engine = sa.create_engine(DB_URL, pool_pre_ping=True)
plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.max_columns', 50)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Parameters
#
# Change `CANONICAL_VARIABLE` to any value shown in `CANONICAL_VARIABLES`. Use `STATION_OFFSET=0` for the first group, `5` for the next group, and so on.

# %%
# Change only these two values when reviewing the next variable.
CANONICAL_VARIABLE = 'snow_depth'
FINAL_SOURCE_IDS = []  # Fill this after reviewing the plots.
PLOT_VARIABLE_IDS = None  # For example: [434, 721]; None plots all candidates.
NETWORK_ID = 5
STATION_LIMIT = 5
STATION_OFFSET = 5
FIGURE_DIR = HERE / 'variable_mapping_figures'
FIGURE_DIR.mkdir(parents=True, exist_ok=True)
print('Current variable:', CANONICAL_VARIABLE, sep='\n* ')

print('-----' * 5)
print('Available variables:')
print(*CANONICAL_VARIABLES, sep='\n')

if CANONICAL_VARIABLE not in CANONICAL_VARIABLES:
    raise ValueError(f'Choose one of: {CANONICAL_VARIABLES}')
# Out:
# Current variable:
# * snow_depth
# -------------------------
# Available variables:
# air_temperature
# daily_min_temperature
# daily_max_temperature
# precipitation_amount
# snowfall_amount
# snow_depth

# %% [markdown]
# ## 2. Select stations and load data

# %%
# Load the persistent registry directly from CSV.
REGISTRY_PATH = OUTPUT_DIR / f'0.net{NETWORK_ID}_candidate_mappings.csv'
all_candidate_mappings = pd.read_csv(REGISTRY_PATH)
candidate_mappings = all_candidate_mappings[
    all_candidate_mappings['network_id'] == NETWORK_ID
].copy()
if candidate_mappings.empty:
    raise ValueError(
        f'No saved mappings for network {NETWORK_ID} in {REGISTRY_PATH}')

candidate_rows = candidate_mappings[
    candidate_mappings['canonical_variable'] == CANONICAL_VARIABLE
]
if candidate_rows.empty:
    raise ValueError(
        f'No {CANONICAL_VARIABLE} candidates saved for network {NETWORK_ID}'
    )
registry_candidate_ids = candidate_rows['vars_id'].astype(int).tolist()

# Use a lightweight existence check for each candidate. A full-network
# profile is expensive for high-volume variables such as air temperature.
representative_station_frames = []
observed_candidate_ids = []
unobserved_candidate_ids = []
for candidate_id in registry_candidate_ids:
    candidate_station = select_candidate_stations(
        engine, [candidate_id], network_id=NETWORK_ID,
        limit=STATION_LIMIT, offset=0,
    )
    if candidate_station.empty:
        unobserved_candidate_ids.append(candidate_id)
    else:
        observed_candidate_ids.append(candidate_id)
        representative_station_frames.append(candidate_station)

if unobserved_candidate_ids:
    print(
        'Ignoring candidate variables with no network observations:',
        unobserved_candidate_ids,
    )

candidate_rows = candidate_rows[
    candidate_rows['vars_id'].isin(observed_candidate_ids)
].copy()
candidate_ids = candidate_rows['vars_id'].astype(int).tolist()
if not candidate_ids:
    raise ValueError(
        f'None of the saved {CANONICAL_VARIABLE} candidates has '
        f'observations in network {NETWORK_ID}.'
    )
display(candidate_rows)

# Summarize station coverage across the entire network. This is separate
# from comparison_stations, which is only a small plotting sample.
network_station_summary = summarize_variable_station_presence(
    engine, candidate_ids, network_id=NETWORK_ID
)
print(f'Network {NETWORK_ID} station coverage (all stations):')
display(network_station_summary)

comparison_stations = select_candidate_stations(
    engine, candidate_ids, network_id=NETWORK_ID,
    limit=STATION_LIMIT, offset=STATION_OFFSET
)

if comparison_stations.empty:
    print(
        'No station contains every observed candidate; selecting the '
        'best-covered station for each candidate instead.'
    )
    comparison_stations = (
        pd.concat(representative_station_frames, ignore_index=True)
        [['station_id', 'station_name']]
        .drop_duplicates(subset='station_id')
        .sort_values('station_id')
        .reset_index(drop=True)
    )

comparison_station_ids = comparison_stations['station_id'].tolist()
display(comparison_stations)

candidate_profile = profile_candidate_variables(
    engine, candidate_ids, network_id=NETWORK_ID,
    station_ids=comparison_station_ids
)
candidate_summary = summarize_candidate_profiles(candidate_profile)
display(candidate_summary.round(2))
display(candidate_profile)
# Out:
#     network_id  vars_id        net_var_name canonical_variable  \
# 11           5      468  SNOW_ON_THE_GROUND         snow_depth
# 12           5     1331            snw_dpth         snow_depth
#
#    daily_aggregation  priority      source_family mapping_status
# 11        fixed_hour         1  network5_reviewed      candidate
# 12        fixed_hour         2      network5_auto   needs_review
# Network 5 station coverage (all stations):
#    vars_id        net_var_name  station_count  \
# 0      468  SNOW_ON_THE_GROUND             61
# 1     1331            snw_dpth             26
#
#                                          station_ids  \
# 0  12388, 12389, 12395, 12400, 12414, 12415, 1308...
# 1  12497, 12498, 12499, 12500, 2513, 2515, 2517, ...
#
#                                        station_names
# 0  Aiken Lake; Blackwall Peak; Bluff Creek; Boss ...
# 1  Aiken Lake; Blackwall Peak; Boss Mountain Mine...
#    station_id station_name
# 0        2534   Mount Cook
# 1        2536  Kostal Lake
# 2        2538   Cook Creek
# 3        2540      Celista
# 4        2553  Grano Creek
# /tmp/ipykernel_37140/2709988342.py:87: UserWarning: obj.round has no effect with datetime, timedelta, or period dtypes. Use obj.dt.round(...) instead.
#   display(candidate_summary.round(2))
#    vars_id        net_var_name  station_count first_observation  \
# 1     1331            snw_dpth              5        2003-10-01
# 0      468  SNOW_ON_THE_GROUND              5        1997-07-24
#
#      last_observation  median_station_span_years  median_active_years
# 1 2024-05-28 10:00:00                      20.60                 19.0
# 0 2008-09-30 00:00:00                       8.95                 10.0
#    station_id station_name  vars_id        net_var_name  active_years  \
# 0        2534   Mount Cook      468  SNOW_ON_THE_GROUND            10
# 1        2534   Mount Cook     1331            snw_dpth            22
# 2        2536  Kostal Lake      468  SNOW_ON_THE_GROUND             2
# 3        2536  Kostal Lake     1331            snw_dpth            16
# 4        2538   Cook Creek      468  SNOW_ON_THE_GROUND            10
# 5        2538   Cook Creek     1331            snw_dpth            17
# 6        2540      Celista      468  SNOW_ON_THE_GROUND             5
# 7        2540      Celista     1331            snw_dpth            20
# 8        2553  Grano Creek      468  SNOW_ON_THE_GROUND            12
# 9        2553  Grano Creek     1331            snw_dpth            19
#
#    coverage_years   first_observation    last_observation  observed_min  \
# 0        8.947296 1999-10-21 00:00:00 2008-09-30 00:00:00           0.0
# 1       20.599133 2003-10-23 14:00:00 2024-05-28 10:00:00        -753.0
# 2        1.010267 2007-09-28 00:00:00 2008-09-30 00:00:00           0.0
# 3       15.967146 2007-09-30 02:00:00 2023-09-17 02:00:00        -246.0
# 4        9.034908 1999-09-19 00:00:00 2008-09-30 00:00:00           0.0
# 5       20.651723 2003-10-04 09:00:00 2024-05-28 10:00:00          -5.0
# 6        3.964408 2004-10-14 00:00:00 2008-09-30 00:00:00           0.0
# 7       18.629249 2005-10-12 01:00:00 2024-05-28 09:00:00        -144.0
# 8       11.189596 1997-07-24 00:00:00 2008-09-30 00:00:00           0.0
# 9       20.660849 2003-10-01 00:00:00 2024-05-28 09:00:00           0.0
#
#    observed_max
# 0         400.0
# 1         491.0
# 2         329.0
# 3         292.0
# 4         195.0
# 5         384.0
# 6         268.0
# 7         543.0
# 8         199.0
# 9         517.0

# %% [markdown]
# ## 3. Apply the canonical plausible-value rule

# %%
observations = fetch_candidate_observations(
    engine, candidate_ids, comparison_station_ids
)
clean_data, qc_summary = apply_canonical_rule(
    observations, CANONICAL_VARIABLE
)
display(qc_summary.round(2))
# Out:
#    station_id        net_var_name  row_count  removed_count  removed_pct
# 0        2534  SNOW_ON_THE_GROUND       2963              0         0.00
# 1        2534            snw_dpth     141378           2597         1.84
# 2        2536  SNOW_ON_THE_GROUND        265              0         0.00
# 3        2536            snw_dpth      94555           3592         3.80
# 4        2538  SNOW_ON_THE_GROUND       2668              0         0.00
# 5        2538            snw_dpth      94475           3898         4.13
# 6        2540  SNOW_ON_THE_GROUND       1244              0         0.00
# 7        2540            snw_dpth     136663           6005         4.39
# 8        2553  SNOW_ON_THE_GROUND       3818              0         0.00
# 9        2553            snw_dpth     115413              0         0.00

# %% [markdown]
# ## 4. Time series

# %%
# PLOT_VARIABLE_IDS = [442, 726]  # For example: [434, 721]; None plots all candidates.

# %%
unit_labels = {
    'celsius': 'Temperature (°C)', 'mm': 'Amount (mm)', 'cm': 'Amount (cm)'}
ylabel = unit_labels[CANONICAL_RULES[CANONICAL_VARIABLE].unit]
plot_data = clean_data
if PLOT_VARIABLE_IDS is not None:
    plot_data = clean_data[
        clean_data['vars_id'].isin(PLOT_VARIABLE_IDS)
    ].copy()
    if plot_data.empty:
        raise ValueError(
            'None of PLOT_VARIABLE_IDS has valid data for the selected stations.'
        )

stations = list(plot_data.groupby('station_id'))

fig, axes = plt.subplots(len(stations), 1, figsize=(14, 4 * len(stations)),
                         sharex=True, sharey=True, squeeze=False)
for ax, (station_id, station_data) in zip(axes.ravel(), stations):
    for (vars_id, variable_name), variable_data in station_data.groupby(
        ['vars_id', 'net_var_name']
    ):
        ax.plot(variable_data['obs_time'], variable_data['datum'],
                linewidth=1, alpha=0.8,
                label=f'{vars_id} — {variable_name}')
    ax.set_title(
        f"{station_data['station_name'].iloc[0]} (station {station_id})")
    ax.set_ylabel(ylabel)
    ax.legend()
axes[-1, 0].set_xlabel('Time')
fig.suptitle(f'{CANONICAL_VARIABLE}: candidate time series', y=1.002)
plt.tight_layout()
time_series_path = FIGURE_DIR / (
    f'network_{NETWORK_ID}_{CANONICAL_VARIABLE}_time_series.png'
)
fig.savefig(time_series_path, dpi=150, bbox_inches='tight')
print(f'Saved: {time_series_path}')
plt.show()
# Out:
# Saved: /workspaces/crmprtd/Quanlity_Control/pipeline/network_5/variable_mapping_figures/network_5_snow_depth_time_series.png

# %% [markdown]
# ## 5. Empirical cumulative distributions
#
# Precipitation and snowfall ECDFs use positive values only and a logarithmic amount axis. Temperature and snow-depth ECDFs retain all plausible values.

# %%
positive_only = CANONICAL_VARIABLE in {
    'precipitation_amount', 'snowfall_amount'}
log_x = positive_only
ncols = 2
nrows = int(np.ceil(len(stations) / ncols))
fig, axes = plt.subplots(nrows, ncols, figsize=(14, 4 * nrows),
                         sharex=True, sharey=True, squeeze=False)
axes = axes.ravel()

for ax, (station_id, station_data) in zip(axes, stations):
    for (vars_id, variable_name), variable_data in station_data.groupby(
        ['vars_id', 'net_var_name']
    ):
        values = variable_data['datum'].dropna()
        if positive_only:
            values = values[values > 0]
        values = np.sort(values.to_numpy())
        if len(values):
            cumulative = np.arange(1, len(values) + 1) / len(values)
            ax.step(values, cumulative, where='post',
                    label=f'{vars_id} — {variable_name}')
    if log_x:
        ax.set_xscale('log')
    ax.set_title(
        f"{station_data['station_name'].iloc[0]} (station {station_id})")
    ax.set_xlabel(
        ylabel + (' — positive values, log scale' if positive_only else ''))
    ax.set_ylabel('Cumulative proportion')
    ax.legend()

for ax in axes[len(stations):]:
    ax.set_visible(False)
fig.suptitle(f'{CANONICAL_VARIABLE}: candidate ECDFs', y=1.002)
plt.tight_layout()
cdf_path = FIGURE_DIR / (
    f'network_{NETWORK_ID}_{CANONICAL_VARIABLE}_cdf.png'
)
fig.savefig(cdf_path, dpi=150, bbox_inches='tight')
print(f'Saved: {cdf_path}')
plt.show()
# Out:
# Saved: /workspaces/crmprtd/Quanlity_Control/pipeline/network_5/variable_mapping_figures/network_5_snow_depth_cdf.png

# %%
# Record the reviewed selection and merge policy; do not combine data here.
import json
FINAL_SOURCE_IDS = [468, 1331]
FINAL_RULE_PATH = (
    OUTPUT_DIR / f'1.net{NETWORK_ID}_final_variable_rules.csv'
)

if not FINAL_SOURCE_IDS:
    print(
        f'No rule saved for {CANONICAL_VARIABLE}: review the figures, '
        'fill FINAL_SOURCE_IDS in the setup cell, then rerun this cell.'
    )
else:
    unknown_ids = set(FINAL_SOURCE_IDS) - set(candidate_ids)
    if unknown_ids:
        raise ValueError(
            f'FINAL_SOURCE_IDS are not candidates for '
            f'{CANONICAL_VARIABLE}: {sorted(unknown_ids)}'
        )

    # Infer cadence from the median positive interval at each station.
    selected_observations = observations[
        observations['vars_id'].isin(FINAL_SOURCE_IDS)
    ].copy()
    selected_observations['obs_time'] = pd.to_datetime(
        selected_observations['obs_time']
    )

    frequency_rows = []
    for source_id in FINAL_SOURCE_IDS:
        source_times = (
            selected_observations.loc[
                selected_observations['vars_id'] == source_id,
                ['station_id', 'obs_time'],
            ]
            .drop_duplicates()
            .sort_values(['station_id', 'obs_time'])
        )
        intervals = (
            source_times.groupby('station_id')['obs_time']
            .diff()
            .dt.total_seconds()
            .div(3600)
        )
        intervals = intervals[intervals > 0]
        if intervals.empty:
            raise ValueError(
                f'Cannot infer observation frequency for vars_id {source_id}'
            )

        median_interval_hours = float(intervals.median())
        if 0.75 <= median_interval_hours <= 1.25:
            frequency = 'hourly'
        elif 20 <= median_interval_hours <= 28:
            frequency = 'daily'
        else:
            frequency = f'irregular_{median_interval_hours:g}_hours'

        frequency_rows.append({
            'vars_id': source_id,
            'median_interval_hours': median_interval_hours,
            'time_match': frequency,
        })

    frequency_summary = pd.DataFrame(frequency_rows)
    unique_frequencies = frequency_summary['time_match'].unique()
    if len(unique_frequencies) == 1:
        time_match = unique_frequencies[0]
    else:
        time_match = 'mixed:' + ','.join(
            f"{row.vars_id}={row.time_match}"
            for row in frequency_summary.itertuples()
        )
    display(frequency_summary)

    final_rule = pd.DataFrame([{
        'network_id': NETWORK_ID,
        'canonical_variable': CANONICAL_VARIABLE,
        'source_vars_ids': json.dumps(FINAL_SOURCE_IDS),
        'time_match': time_match,
        'overlap_method': 'mean',
        'single_source_method': 'use_available',
    }])

    if FINAL_RULE_PATH.exists():
        saved_rules = pd.read_csv(FINAL_RULE_PATH)
        same_mapping = (
            (saved_rules['network_id'] == NETWORK_ID)
            & (saved_rules['canonical_variable'] == CANONICAL_VARIABLE)
        )
        saved_rules = saved_rules.loc[~same_mapping]
        final_rules = pd.concat(
            [saved_rules, final_rule], ignore_index=True
        )
    else:
        final_rules = final_rule

    final_rules = final_rules.sort_values(
        ['network_id', 'canonical_variable']
    ).reset_index(drop=True)
    final_rules.to_csv(FINAL_RULE_PATH, index=False)
    print(f'Saved rule: {NETWORK_ID} / {CANONICAL_VARIABLE}')
    display(final_rules)
# Out:
#    vars_id  median_interval_hours time_match
# 0      468                   24.0      daily
# 1     1331                    1.0     hourly
# Saved rule: 5 / snow_depth
#    network_id     canonical_variable source_vars_ids  \
# 0           5        air_temperature    [1328, 1329]
# 1           5  daily_max_temperature           [464]
# 2           5  daily_min_temperature           [463]
# 3           5   precipitation_amount           [465]
# 4           5             snow_depth     [468, 1331]
# 5           5        snowfall_amount           [467]
#
#                     time_match overlap_method single_source_method
# 0                       hourly           mean        use_available
# 1                        daily           mean        use_available
# 2                        daily           mean        use_available
# 3                        daily           mean        use_available
# 4  mixed:468=daily,1331=hourly           mean        use_available
# 5                        daily           mean        use_available

# %% [markdown]
# ## 6. Cadence diagnostics
#
# Inspect per-station timestamp intervals for the selected source variables. This uses the comparison stations loaded above.

# %%
if not FINAL_SOURCE_IDS:
    print('Set FINAL_SOURCE_IDS before running cadence diagnostics.')
else:
    cadence_detail = (
        observations.loc[
            observations['vars_id'].isin(FINAL_SOURCE_IDS),
            ['vars_id', 'net_var_name', 'station_id',
             'station_name', 'obs_time', 'datum'],
        ]
        .drop_duplicates(
            ['vars_id', 'station_id', 'obs_time']
        )
        .sort_values(['vars_id', 'station_id', 'obs_time'])
        .copy()
    )
    cadence_detail['obs_time'] = pd.to_datetime(
        cadence_detail['obs_time']
    )
    cadence_detail['interval_hours'] = (
        cadence_detail
        .groupby(['vars_id', 'station_id'])['obs_time']
        .diff()
        .dt.total_seconds()
        .div(3600)
    )

    cadence_summary = (
        cadence_detail
        .groupby(
            ['vars_id', 'net_var_name', 'station_id', 'station_name'],
            as_index=False,
        )
        .agg(
            observation_count=('obs_time', 'size'),
            first_observation=('obs_time', 'min'),
            last_observation=('obs_time', 'max'),
            median_interval_hours=('interval_hours', 'median'),
            minimum_interval_hours=('interval_hours', 'min'),
            maximum_interval_hours=('interval_hours', 'max'),
        )
    )
    print('Per-station cadence summary:')
    display(cadence_summary)

    print('First 12 timestamps and intervals per variable/station:')
    cadence_samples = (
        cadence_detail
        .groupby(['vars_id', 'station_id'], group_keys=False)
        .head(12)
        [[
            'vars_id', 'net_var_name', 'station_id', 'station_name',
            'obs_time', 'interval_hours', 'datum',
        ]]
    )
    display(cadence_samples)
# Out:
# Per-station cadence summary:
#    vars_id        net_var_name  station_id station_name  observation_count  \
# 0      468  SNOW_ON_THE_GROUND        2534   Mount Cook               2963
# 1      468  SNOW_ON_THE_GROUND        2536  Kostal Lake                265
# 2      468  SNOW_ON_THE_GROUND        2538   Cook Creek               2668
# 3      468  SNOW_ON_THE_GROUND        2540      Celista               1244
# 4      468  SNOW_ON_THE_GROUND        2553  Grano Creek               3818
#
#   first_observation last_observation  median_interval_hours  \
# 0        1999-10-21       2008-09-30                   24.0
# 1        2007-09-28       2008-09-30                   24.0
# 2        1999-09-19       2008-09-30                   24.0
# 3        2004-10-14       2008-09-30                   24.0
# 4        1997-07-24       2008-09-30                   24.0
#
#    minimum_interval_hours  maximum_interval_hours
# 0                    24.0                  2208.0
# 1                    24.0                  1872.0
# 2                    24.0                  3504.0
# 3                    24.0                  2016.0
# 4                    24.0                  2064.0
# First 12 timestamps and intervals per variable/station:
#         vars_id        net_var_name  station_id station_name   obs_time  \
# 0           468  SNOW_ON_THE_GROUND        2534   Mount Cook 1999-10-21
# 1           468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-21
# 2           468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-22
# 3           468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-23
# 4           468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-24
# 5           468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-25
# 6           468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-26
# 7           468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-27
# 8           468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-28
# 9           468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-29
# 10          468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-30
# 11          468  SNOW_ON_THE_GROUND        2534   Mount Cook 2000-01-31
# 144341      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-09-28
# 144342      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-09-29
# 144343      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-09-30
# 144365      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-10-01
# 144390      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-10-02
# 144412      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-10-03
# 144435      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-10-04
# 144454      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-10-05
# 144479      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-10-06
# 144504      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-10-07
# 144529      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-10-08
# 144554      468  SNOW_ON_THE_GROUND        2536  Kostal Lake 2007-10-09
# 239161      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-19
# 239162      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-20
# 239163      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-21
# 239164      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-22
# 239165      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-23
# 239166      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-24
# 239167      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-25
# 239168      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-26
# 239169      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-27
# 239170      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-28
# 239171      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-29
# 239172      468  SNOW_ON_THE_GROUND        2538   Cook Creek 1999-09-30
# 336304      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-14
# 336305      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-15
# 336306      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-16
# 336307      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-17
# 336308      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-18
# 336309      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-19
# 336310      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-20
# 336311      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-21
# 336312      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-22
# 336313      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-23
# 336314      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-24
# 336315      468  SNOW_ON_THE_GROUND        2540      Celista 2004-10-25
# 474211      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-07-24
# 474212      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-07-25
# 474213      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-07-26
# 474214      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-07-27
# 474215      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-07-28
# 474216      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-07-29
# 474217      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-07-30
# 474218      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-07-31
# 474219      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-08-01
# 474220      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-08-02
# 474221      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-08-03
# 474222      468  SNOW_ON_THE_GROUND        2553  Grano Creek 1997-08-04
#
#         interval_hours  datum
# 0                  NaN   29.0
# 1               2208.0  300.0
# 2                 24.0  300.0
# 3                 24.0  294.0
# 4                 24.0  290.0
# 5                 24.0  289.0
# 6                 24.0  290.0
# 7                 24.0  284.0
# 8                 24.0  283.0
# 9                 24.0  279.0
# 10                24.0  277.0
# 11                24.0  286.0
# 144341             NaN   24.0
# 144342            24.0   31.0
# 144343            24.0   44.0
# 144365            24.0   41.0
# 144390            24.0   48.0
# 144412            24.0   40.0
# 144435            24.0   41.0
# 144454            24.0   46.0
# 144479            24.0   35.0
# 144504            24.0   38.0
# 144529            24.0   32.0
# 144554            24.0   32.0
# 239161             NaN    0.0
# 239162            24.0    0.0
# 239163            24.0    0.0
# 239164            24.0    0.0
# 239165            24.0    0.0
# 239166            24.0    0.0
# 239167            24.0    0.0
# 239168            24.0    0.0
# 239169            24.0    0.0
# 239170            24.0    0.0
# 239171            24.0    0.0
# 239172            24.0    0.0
# 336304             NaN   13.0
# 336305            24.0   13.0
# 336306            24.0    9.0
# 336307            24.0   15.0
# 336308            24.0   25.0
# 336309            24.0   34.0
# 336310            24.0   34.0
# 336311            24.0   34.0
# 336312            24.0   24.0
# 336313            24.0   33.0
# 336314            24.0   35.0
# 336315            24.0   30.0
# 474211             NaN    0.0
# 474212            24.0    0.0
# 474213            24.0    0.0
# 474214            24.0    0.0
# 474215            24.0    0.0
# 474216            24.0    0.0
# 474217            24.0    0.0
# 474218            24.0    0.0
# 474219            24.0    0.0
# 474220            24.0    0.0
# 474221            24.0    0.0
# 474222            24.0    0.0
