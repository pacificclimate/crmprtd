# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# from saqc import SaQC
import metpyqc as qc
import sys

function_path = './func/'
sys.path.append(function_path)

sys.path.append(function_path)

# from qc_func import *
# from fake_data_design import *

# %%
from visualizaion_func import *

# %%
import sqlalchemy as sa
from sqlalchemy.orm import Session
import sys
function_path = '../'
sys.path.append(function_path)

save_path = './comparison_forms/'
db_url = "postgresql://tongli1997@proddb01.pcic.uvic.ca,proddb02.pcic.uvic.ca/crmp?keepalives=1&keepalives_idle=300&keepalives_interval=300&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass"
log_file_path = save_path

engine = sa.create_engine(db_url, echo=False)
session = Session(engine)

session

# %% [markdown]
# #### Find the stations under network 2, and have all the variables I want

# %%
sql_text = sa.text("""
SELECT s.station_id, h.station_name
FROM meta_history h
JOIN meta_station s
    ON h.station_id = s.station_id
WHERE s.network_id = 2

AND EXISTS (
    SELECT 1 FROM obs_raw o JOIN meta_vars v ON o.vars_id = v.vars_id
    WHERE o.history_id = h.history_id AND v.standard_name = 'lwe_thickness_of_precipitation_amount'
)
;

""")

with engine.begin() as conn:
    df = pd.read_sql(sql_text, conn)

df
# Out:
#      station_id         station_name
# 0          2654           Brandywine
# 1          2655             Tantalus
# 2          2657  Mt. Strachan Precip
# 3          2658         Mt. Strachan
# 4          2659      Mt. Harvey Raws
# ..          ...                  ...
# 193       14854             Highline
# 194       14858          Galena Road
# 195       14859          Slocan Lake
# 196       15108                  NaN
# 197       15110                  NaN
#
# [198 rows x 2 columns]

# %%
first_station_id = int(df.iloc[1]["station_id"])

sql_vars = sa.text("""
SELECT DISTINCT v.vars_id, v.standard_name, v.net_var_name
FROM meta_history h
JOIN obs_raw o 
    ON h.history_id = o.history_id
JOIN meta_vars v 
    ON o.vars_id = v.vars_id
WHERE h.station_id = :station_id
ORDER BY v.standard_name
""")

with engine.begin() as conn:
    vars_df = pd.read_sql(sql_vars, conn, params={
                          "station_id": first_station_id})


vars_df
# Out:
#     vars_id                          standard_name  \
# 0       725                           air_pressure
# 1       439                           air_pressure
# 2       733         air_pressure_at_mean_sea_level
# 3       721                        air_temperature
# 4       720                        air_temperature
# 5       435                        air_temperature
# 6       434                        air_temperature
# 7       722                        air_temperature
# 8       433                        air_temperature
# 9       436                        air_temperature
# 10      438                  dew_point_temperature
# 11      724                  dew_point_temperature
# 12      443                                foo_bar
# 13      726  lwe_thickness_of_precipitation_amount
# 14      441  lwe_thickness_of_precipitation_amount
# 15      440  lwe_thickness_of_precipitation_amount
# 16      442  lwe_thickness_of_precipitation_amount
# 17      732  lwe_thickness_of_precipitation_amount
# 18      437                      relative_humidity
# 19      723                      relative_humidity
# 20      728                        snowfall_amount
# 21      727                 surface_snow_thickness
# 22      450                 surface_snow_thickness
# 23      451           thickness_of_snowfall_amount
# 24      731                    wind_from_direction
# 25      445                    wind_from_direction
# 26      448                    wind_from_direction
# 27      447                    wind_from_direction
# 28      729                             wind_speed
# 29      444                             wind_speed
# 30      730                             wind_speed
# 31      449                             wind_speed
# 32      446                             wind_speed
#
#                      net_var_name
# 0                        stn_pres
# 1            ATMOSPHERIC_PRESSURE
# 2                            mslp
# 3                        air_temp
# 4     max_air_temp_snc_last_reset
# 5         MINIMUM_AIR_TEMPERATURE
# 6        CURRENT_AIR_TEMPERATURE1
# 7     min_air_temp_snc_last_reset
# 8         MAXIMUM_AIR_TEMPERATURE
# 9        CURRENT_AIR_TEMPERATURE2
# 10                      DEW_POINT
# 11                      dwpt_temp
# 12          PRECIP_DETECTOR_RATIO
# 13                pcpn_amt_pst1hr
# 14              PRECIPITATION_NEW
# 15      PRECIPITATION_GAUGE_TOTAL
# 16           HOURLY_PRECIPITATION
# 17              pcpn_amt_pst24hrs
# 18             RELATIVE_HUMIDITY1
# 19                        rel_hum
# 20               snwfl_amt_pst1hr
# 21                       snw_dpth
# 22                 HEIGHT_OF_SNOW
# 23                  STANDARD_SNOW
# 24       avg_wnd_dir_10m_pst10mts
# 25          ACTUAL_WIND_DIRECTION
# 26  WIND_DIRECTION_STD_DEVIATION1
# 27       MEASURED_WIND_DIRECTION1
# 28       avg_wnd_spd_10m_pst10mts
# 29              ACTUAL_WIND_SPEED
# 30         max_wnd_spd_10m_pst1hr
# 31   MAXIMUM_MEASURED_WIND_SPEED1
# 32           MEASURED_WIND_SPEED1

# %%
first_station_id = int(df.iloc[1]["station_id"])

sql_obs = sa.text("""
SELECT 
    o.obs_time,
    o.vars_id,
    v.net_var_name,
    o.datum
FROM meta_history h
JOIN obs_raw o 
    ON h.history_id = o.history_id
JOIN meta_vars v 
    ON o.vars_id = v.vars_id
WHERE h.station_id = :station_id
  AND v.standard_name = :std_name
ORDER BY o.vars_id
""")

with engine.begin() as conn:
    obs_df = pd.read_sql(
        sql_obs,
        conn,
        params={
            "station_id": first_station_id,
            "std_name": "lwe_thickness_of_precipitation_amount"
        }
    )

obs_df
# Out:
#                   obs_time  vars_id               net_var_name  datum
# 0      2009-06-25 16:00:00      440  PRECIPITATION_GAUGE_TOTAL  176.1
# 1      2009-06-25 17:00:00      440  PRECIPITATION_GAUGE_TOTAL  176.4
# 2      2009-06-25 18:00:00      440  PRECIPITATION_GAUGE_TOTAL  176.7
# 3      2009-06-25 19:00:00      440  PRECIPITATION_GAUGE_TOTAL  176.9
# 4      2009-06-25 20:00:00      440  PRECIPITATION_GAUGE_TOTAL  177.1
# ...                    ...      ...                        ...    ...
# 175661 2026-03-20 05:00:00      732          pcpn_amt_pst24hrs   48.5
# 175662 2026-03-20 06:00:00      732          pcpn_amt_pst24hrs   48.2
# 175663 2026-03-20 07:00:00      732          pcpn_amt_pst24hrs   48.1
# 175664 2026-03-20 08:00:00      732          pcpn_amt_pst24hrs   45.2
# 175665 2026-03-20 09:00:00      732          pcpn_amt_pst24hrs   43.9
#
# [175666 rows x 4 columns]

# %%
from visualizaion_func import *

df_sql_list = []


obs_df["obs_time"] = pd.to_datetime(obs_df["obs_time"])

df_sql = obs_df.pivot_table(
    index="obs_time",
    columns="net_var_name",
    values="datum"
).sort_index()


plot_weather_data(df_sql, title=f"Station {first_station_id}")

# %%
df_sql
# Out:
# net_var_name         HOURLY_PRECIPITATION  PRECIPITATION_GAUGE_TOTAL  \
# obs_time
# 2009-06-25 16:00:00                   NaN                      176.1
# 2009-06-25 17:00:00                   0.3                      176.4
# 2009-06-25 18:00:00                   0.3                      176.7
# 2009-06-25 19:00:00                   0.2                      176.9
# 2009-06-25 20:00:00                   0.2                      177.1
# ...                                   ...                        ...
# 2026-04-28 04:00:00                   NaN                        NaN
# 2026-04-28 05:00:00                   NaN                        NaN
# 2026-04-28 06:00:00                   NaN                        NaN
# 2026-04-28 07:00:00                   NaN                        NaN
# 2026-04-28 08:00:00                   NaN                        NaN
#
# net_var_name         PRECIPITATION_NEW  pcpn_amt_pst1hr  pcpn_amt_pst24hrs
# obs_time
# 2009-06-25 16:00:00                0.0              NaN                NaN
# 2009-06-25 17:00:00                0.3              NaN                NaN
# 2009-06-25 18:00:00                0.6              NaN                NaN
# 2009-06-25 19:00:00                0.2              NaN                NaN
# 2009-06-25 20:00:00                0.4              NaN                NaN
# ...                                ...              ...                ...
# 2026-04-28 04:00:00                NaN              0.0                NaN
# 2026-04-28 05:00:00                NaN              0.0                NaN
# 2026-04-28 06:00:00                NaN              0.0                NaN
# 2026-04-28 07:00:00                NaN              0.1                NaN
# 2026-04-28 08:00:00                NaN              0.0                NaN
#
# [114240 rows x 5 columns]

# %%
from func_2_naught_check import *

qc_result = qc_trace_values(df_sql, value_col='HOURLY_PRECIPITATION')

qc_result.sum()
# Out:
# flag_HOURLY_PRECIPITATION_trace    0
# dtype: int64
