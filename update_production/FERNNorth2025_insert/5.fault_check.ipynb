# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa
import os
from row_generate_func import *
from auto_insert_func import *

from sqlalchemy.orm import Session

engine = sa.create_engine("postgresql://tongli1997@db.pcic.uvic.ca:5433/crmp?keepalives=1&keepalives_idle=300&keepalives_interval=300&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass", echo=False)
session = Session(engine)

# %%
# --- Main workflow ---
output_folder = '/workspaces/crmprtd/fern/FERNNorth2025_insert/output/'
file_name = 'Fern_raw_db_station_matched.csv'

df_match = pd.read_csv(output_folder + file_name)

df_match
# Out:
#         station_name native_id_raw station_file_name        lat         lon  \
# 0       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 1       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 2       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 3       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 4       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# ..               ...           ...               ...        ...         ...
# 528  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 529  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 530  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 531  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 532  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
#
#      elev         variable unit_raw    earliest_time_raw      latest_time_raw  \
# 0     705            DewPt       °C  2011-07-28 09:00:00  2024-08-10 19:00:00
# 1     705       Gust Speed      m/s  2010-08-20 19:00:00  2024-08-10 19:00:00
# 2     705               RH        %  2011-07-28 09:00:00  2024-08-10 19:00:00
# 3     705             Rain       mm  2010-08-20 20:00:00  2024-08-10 19:00:00
# 4     705         Sfc Temp       °C  2010-08-20 19:00:00  2024-08-10 19:00:00
# ..    ...              ...      ...                  ...                  ...
# 528   596  Solar Radiation     W/m²  2007-07-31 15:00:00  2025-10-30 10:00:00
# 529   596             Temp       °C  2007-07-31 15:00:00  2025-10-30 10:00:00
# 530   596          Wetness        %  2008-06-12 13:00:00  2025-10-30 10:00:00
# 531   596   Wind Direction        ø  2007-07-31 15:00:00  2025-10-30 10:00:00
# 532   596       Wind Speed      m/s  2007-07-31 15:00:00  2025-10-30 10:00:00
#
#     unit_origin      db_var_match  unit_db     earliest_time_db  \
# 0            °C            DewPtC  celsius                  NaN
# 1           m/s       GustSpeedms    m s-1                  NaN
# 2             %                RH        %                  NaN
# 3            mm            Rainmm       mm                  NaN
# 4            °C      Surface_Temp  celsius                  NaN
# ..          ...               ...      ...                  ...
# 528        W/m²  SolarRadiationWm    W m-2  2007-07-31 15:00:00
# 529          °C             TempC  celsius  2007-07-31 15:00:00
# 530           %           Wetness        %  2008-06-12 13:00:00
# 531           ø     WindDirection   degree  2007-07-31 15:00:00
# 532         m/s       WindSpeedms    m s-1  2007-07-31 15:00:00
#
#           latest_time_db  earliest_diff_days  latest_diff_days   batch
# 0                    NaN                 NaN               NaN  batch2
# 1                    NaN                 NaN               NaN  batch2
# 2                    NaN                 NaN               NaN  batch2
# 3                    NaN                 NaN               NaN  batch2
# 4                    NaN                 NaN               NaN  batch4
# ..                   ...                 ...               ...     ...
# 528  2023-10-17 09:00:00                 0.0             744.0  batch1
# 529  2023-10-17 09:00:00                 0.0             744.0  batch1
# 530  2023-10-17 09:00:00                 0.0             744.0  batch1
# 531  2023-10-17 09:00:00                 0.0             744.0  batch1
# 532  2023-10-17 09:00:00                 0.0             744.0  batch1
#
# [533 rows x 18 columns]

# %%
station_names = df_match['station_name'].tolist()

query = sa.text("""
    SELECT DISTINCT m.station_name, s.native_id, m.lat, m.lon, m.elev
    FROM meta_history AS m
    JOIN meta_station AS s ON m.station_id = s.station_id
    WHERE s.network_id = 11
      AND m.station_name = ANY(:station_names)
""")

with engine.connect() as conn:
    db_stations = pd.read_sql(query, conn, params={"station_names": station_names})

# %%
merged = df_match.merge(
    db_stations,
    on='station_name',
    how='left'
)

match_info = merged.rename(
    columns={
        'native_id': 'native_id_db',
        'lat_y': 'lat_db',
        'lon_y': 'lon_db',
        'elev_y': 'elev_db'
    }
)

match_info = match_info.drop(columns=['native_id_raw', 'lat_x', 'lon_x', 'elev_x'])

match_info
# Out:
#         station_name station_file_name         variable unit_raw  \
# 0       Atlin School      Atlin School            DewPt       °C
# 1       Atlin School      Atlin School       Gust Speed      m/s
# 2       Atlin School      Atlin School               RH        %
# 3       Atlin School      Atlin School             Rain       mm
# 4       Atlin School      Atlin School         Sfc Temp       °C
# ..               ...               ...              ...      ...
# 528  Willow-BowronWx   Willow-BowronWx  Solar Radiation     W/m²
# 529  Willow-BowronWx   Willow-BowronWx             Temp       °C
# 530  Willow-BowronWx   Willow-BowronWx          Wetness        %
# 531  Willow-BowronWx   Willow-BowronWx   Wind Direction        ø
# 532  Willow-BowronWx   Willow-BowronWx       Wind Speed      m/s
#
#        earliest_time_raw      latest_time_raw unit_origin      db_var_match  \
# 0    2011-07-28 09:00:00  2024-08-10 19:00:00          °C            DewPtC
# 1    2010-08-20 19:00:00  2024-08-10 19:00:00         m/s       GustSpeedms
# 2    2011-07-28 09:00:00  2024-08-10 19:00:00           %                RH
# 3    2010-08-20 20:00:00  2024-08-10 19:00:00          mm            Rainmm
# 4    2010-08-20 19:00:00  2024-08-10 19:00:00          °C      Surface_Temp
# ..                   ...                  ...         ...               ...
# 528  2007-07-31 15:00:00  2025-10-30 10:00:00        W/m²  SolarRadiationWm
# 529  2007-07-31 15:00:00  2025-10-30 10:00:00          °C             TempC
# 530  2008-06-12 13:00:00  2025-10-30 10:00:00           %           Wetness
# 531  2007-07-31 15:00:00  2025-10-30 10:00:00           ø     WindDirection
# 532  2007-07-31 15:00:00  2025-10-30 10:00:00         m/s       WindSpeedms
#
#      unit_db     earliest_time_db       latest_time_db  earliest_diff_days  \
# 0    celsius                  NaN                  NaN                 NaN
# 1      m s-1                  NaN                  NaN                 NaN
# 2          %                  NaN                  NaN                 NaN
# 3         mm                  NaN                  NaN                 NaN
# 4    celsius                  NaN                  NaN                 NaN
# ..       ...                  ...                  ...                 ...
# 528    W m-2  2007-07-31 15:00:00  2023-10-17 09:00:00                 0.0
# 529  celsius  2007-07-31 15:00:00  2023-10-17 09:00:00                 0.0
# 530        %  2008-06-12 13:00:00  2023-10-17 09:00:00                 0.0
# 531   degree  2007-07-31 15:00:00  2023-10-17 09:00:00                 0.0
# 532    m s-1  2007-07-31 15:00:00  2023-10-17 09:00:00                 0.0
#
#      latest_diff_days   batch native_id_db     lat_db      lon_db  elev_db
# 0                 NaN  batch2       AtlSch  59.574000 -133.687000    705.0
# 1                 NaN  batch2       AtlSch  59.574000 -133.687000    705.0
# 2                 NaN  batch2       AtlSch  59.574000 -133.687000    705.0
# 3                 NaN  batch2       AtlSch  59.574000 -133.687000    705.0
# 4                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# ..                ...     ...          ...        ...         ...      ...
# 528             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 529             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 530             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 531             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 532             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
#
# [533 rows x 18 columns]

# %% [markdown]
# ### Batch 1, for the unique variables (only one sensor)

# %%
match_info_uniq_var = match_info[match_info['db_var_match'].notna()]
match_info_uniq_var
# Out:
#         station_name station_file_name         variable unit_raw  \
# 0       Atlin School      Atlin School            DewPt       °C
# 1       Atlin School      Atlin School       Gust Speed      m/s
# 2       Atlin School      Atlin School               RH        %
# 3       Atlin School      Atlin School             Rain       mm
# 4       Atlin School      Atlin School         Sfc Temp       °C
# ..               ...               ...              ...      ...
# 528  Willow-BowronWx   Willow-BowronWx  Solar Radiation     W/m²
# 529  Willow-BowronWx   Willow-BowronWx             Temp       °C
# 530  Willow-BowronWx   Willow-BowronWx          Wetness        %
# 531  Willow-BowronWx   Willow-BowronWx   Wind Direction        ø
# 532  Willow-BowronWx   Willow-BowronWx       Wind Speed      m/s
#
#        earliest_time_raw      latest_time_raw unit_origin      db_var_match  \
# 0    2011-07-28 09:00:00  2024-08-10 19:00:00          °C            DewPtC
# 1    2010-08-20 19:00:00  2024-08-10 19:00:00         m/s       GustSpeedms
# 2    2011-07-28 09:00:00  2024-08-10 19:00:00           %                RH
# 3    2010-08-20 20:00:00  2024-08-10 19:00:00          mm            Rainmm
# 4    2010-08-20 19:00:00  2024-08-10 19:00:00          °C      Surface_Temp
# ..                   ...                  ...         ...               ...
# 528  2007-07-31 15:00:00  2025-10-30 10:00:00        W/m²  SolarRadiationWm
# 529  2007-07-31 15:00:00  2025-10-30 10:00:00          °C             TempC
# 530  2008-06-12 13:00:00  2025-10-30 10:00:00           %           Wetness
# 531  2007-07-31 15:00:00  2025-10-30 10:00:00           ø     WindDirection
# 532  2007-07-31 15:00:00  2025-10-30 10:00:00         m/s       WindSpeedms
#
#      unit_db     earliest_time_db       latest_time_db  earliest_diff_days  \
# 0    celsius                  NaN                  NaN                 NaN
# 1      m s-1                  NaN                  NaN                 NaN
# 2          %                  NaN                  NaN                 NaN
# 3         mm                  NaN                  NaN                 NaN
# 4    celsius                  NaN                  NaN                 NaN
# ..       ...                  ...                  ...                 ...
# 528    W m-2  2007-07-31 15:00:00  2023-10-17 09:00:00                 0.0
# 529  celsius  2007-07-31 15:00:00  2023-10-17 09:00:00                 0.0
# 530        %  2008-06-12 13:00:00  2023-10-17 09:00:00                 0.0
# 531   degree  2007-07-31 15:00:00  2023-10-17 09:00:00                 0.0
# 532    m s-1  2007-07-31 15:00:00  2023-10-17 09:00:00                 0.0
#
#      latest_diff_days   batch native_id_db     lat_db      lon_db  elev_db
# 0                 NaN  batch2       AtlSch  59.574000 -133.687000    705.0
# 1                 NaN  batch2       AtlSch  59.574000 -133.687000    705.0
# 2                 NaN  batch2       AtlSch  59.574000 -133.687000    705.0
# 3                 NaN  batch2       AtlSch  59.574000 -133.687000    705.0
# 4                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# ..                ...     ...          ...        ...         ...      ...
# 528             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 529             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 530             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 531             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 532             744.0  batch1       PGTIS2  53.772577 -122.724634    596.0
#
# [476 rows x 18 columns]

# %%
subset
# Out:
#    station_name station_file_name variable unit_raw    earliest_time_raw  \
# 72    BowronPit         BowronPit     Rain       mm  2018-09-13 13:00:00
#
#         latest_time_raw unit_origin db_var_match unit_db     earliest_time_db  \
# 72  2026-01-05 10:00:00          mm       Rainmm      mm  2018-09-13 13:00:00
#
#          latest_time_db  earliest_diff_days  latest_diff_days   batch  \
# 72  2024-01-05 08:00:00                 0.0             731.0  batch1
#
#    native_id_db     lat_db      lon_db  elev_db
# 72    BowronPit  53.902111 -122.015389    722.0

# %%
data_path = '/workspaces/crmprtd/fern/FERNNorth2025_VF_data'

# Choose the variables you want
variables_to_extract = ['Rain']

# Filter the DataFrame for the station and selected variables
subset = match_info_uniq_var.loc[
    (match_info_uniq_var['station_name'] == 'BowronPit') &
    (match_info_uniq_var['variable'].isin(variables_to_extract))
]

all_rows = []

for i, row in subset.iterrows():
    station = row["station_name"]
    variable = row["variable"]

    print(f"\n🔍 [{i+1}/{len(subset)}] Processing {station} — {variable}")

    new_rows = extract_new_data_rows(row, data_path)
    all_rows.extend(new_rows)

    if len(new_rows) > 0:
        print(f"  ✅ {len(new_rows)} new records found outside DB time range.")
    else:
        print("  ⚠️ No new records found (matches DB time range exactly).")

# Remove rows where timestamp is NaN
all_rows = [r for r in all_rows if not pd.isna(r.time)]
# Out:
# 🔍 [73/1] Processing BowronPit — Rain
#   ✅ 17544 new records found outside DB time range.

# %%
all_rows[-20:]
# Out:
# [Row(time=Timestamp('2026-01-04 15:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-04 16:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-04 17:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-04 18:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-04 19:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-04 20:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-04 21:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-04 22:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-04 23:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 00:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 01:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 02:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 03:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 04:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 05:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 06:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 07:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 08:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 09:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389),
#  Row(time=Timestamp('2026-01-05 10:00:00'), val=0.0, variable_name='Rainmm', unit='mm', network_name='FLNRO-FERN', station_id='BowronPit', lat=53.902111, lon=-122.015389)]

# %%
### Have fixed 3.1 code by adding all_rows = [r for r in all_rows if not pd.isna(r.time)]

# %%
db_url = "postgresql://tongli1997@db.pcic.uvic.ca:5433/crmp?keepalives=1&keepalives_idle=300&keepalives_interval=300&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass"

safe_insert_rows(
    all_rows,
    log_file_path=output_folder + 'fern_all_station_insert.log',
    db_url=db_url,
    chunk_size=5000,        # SAFE starting point
    bulk_chunk_size=1000,   # internal DB bulk insert size
)
# Out:
# 🚀 Starting insert: 15629 rows in 4 chunks
# ➡️  Processing rows 0–4999
# {"asctime": "2026-02-27 17:32:37,299", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 17:32:38,666", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:39,907", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:41,169", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:42,435", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:43,666", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:43,667", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-27 17:32:43,667", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 0–4999
# ➡️  Processing rows 5000–9999
# {"asctime": "2026-02-27 17:32:43,703", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 17:32:45,048", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:46,350", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:47,782", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:49,591", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:50,606", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4558 inserted, 442 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:50,606", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 4558"}
# {"asctime": "2026-02-27 17:32:50,607", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 5000–9999
# ➡️  Processing rows 10000–14999
# {"asctime": "2026-02-27 17:32:50,648", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 17:32:50,839", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:50,910", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:50,984", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:51,728", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 437 inserted, 3563 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:53,286", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1437 inserted, 3563 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:53,288", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 1437"}
# {"asctime": "2026-02-27 17:32:53,290", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 10000–14999
# ➡️  Processing rows 15000–15628
# {"asctime": "2026-02-27 17:32:53,313", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 17:32:54,373", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 629 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-27 17:32:54,374", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 629"}
# {"asctime": "2026-02-27 17:32:54,375", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 15000–15628

# %% [markdown]
# ### Other issues recognized by 6.

# %%
data_path = '/workspaces/crmprtd/fern/FERNNorth2025_VF_data'

# Choose the variables you want
variables_to_extract = ['Soil Temp']

# Filter the DataFrame for the station and selected variables
subset = match_info_uniq_var.loc[
    (match_info_uniq_var['station_name'] == 'Atlin School') &
    (match_info_uniq_var['variable'].isin(variables_to_extract))
]
subset

all_rows = []

for i, row in subset.iterrows():
    station = row["station_name"]
    variable = row["variable"]

    print(f"\n🔍 [{i+1}/{len(subset)}] Processing {station} — {variable}")

    new_rows = extract_new_data_rows(row, data_path)
    all_rows.extend(new_rows)

    if len(new_rows) > 0:
        print(f"  ✅ {len(new_rows)} new records found outside DB time range.")
    else:
        print("  ⚠️ No new records found (matches DB time range exactly).")

# Remove rows where timestamp is NaN
all_rows = [r for r in all_rows if not pd.isna(r.time)]
# Out:
# 🔍 [6/1] Processing Atlin School — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).

# %%
all_rows
# Out:
# []
