# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa
import os
from row_generate_func import *
from auto_insert_func import *

from sqlalchemy.orm import Session

engine = sa.create_engine("postgresql://tongli1997@db.pcic.uvic.ca:5433/crmp?keepalives=1&keepalives_idle=300&keepalives_interval=300&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass", echo=False)
session = Session(engine)

# %%
# --- Main workflow ---
output_folder = '/workspaces/crmprtd/fern/FERNNorth2025_insert/output/'
file_name = 'Fern_raw_db_station_matched.csv'

df_match = pd.read_csv(output_folder + file_name)

df_match
# Out:
#         station_name native_id_raw station_file_name        lat         lon  \
# 0       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 1       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 2       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 3       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 4       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# ..               ...           ...               ...        ...         ...
# 528  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 529  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 530  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 531  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 532  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
#
#      elev         variable unit_raw    earliest_time_raw      latest_time_raw  \
# 0     705            DewPt       °C  2011-07-28 09:00:00  2024-08-10 19:00:00
# 1     705       Gust Speed      m/s  2010-08-20 19:00:00  2024-08-10 19:00:00
# 2     705               RH        %  2011-07-28 09:00:00  2024-08-10 19:00:00
# 3     705             Rain       mm  2010-08-20 20:00:00  2024-08-10 19:00:00
# 4     705         Sfc Temp       °C  2010-08-20 19:00:00  2024-08-10 19:00:00
# ..    ...              ...      ...                  ...                  ...
# 528   596  Solar Radiation     W/m²  2007-07-31 15:00:00  2025-10-30 10:00:00
# 529   596             Temp       °C  2007-07-31 15:00:00  2025-10-30 10:00:00
# 530   596          Wetness        %  2008-06-12 13:00:00  2025-10-30 10:00:00
# 531   596   Wind Direction        ø  2007-07-31 15:00:00  2025-10-30 10:00:00
# 532   596       Wind Speed      m/s  2007-07-31 15:00:00  2025-10-30 10:00:00
#
#     unit_origin      db_var_match  unit_db     earliest_time_db  \
# 0            °C            DewPtC  celsius  2011-07-28 09:00:00
# 1           m/s       GustSpeedms    m s-1  2010-08-20 19:00:00
# 2             %                RH        %  2011-07-28 09:00:00
# 3            mm            Rainmm       mm  2010-08-20 20:00:00
# 4            °C      Surface_Temp  celsius                  NaN
# ..          ...               ...      ...                  ...
# 528        W/m²  SolarRadiationWm    W m-2  2007-07-31 15:00:00
# 529          °C             TempC  celsius  2007-07-31 15:00:00
# 530           %           Wetness        %  2008-06-12 13:00:00
# 531           ø     WindDirection   degree  2007-07-31 15:00:00
# 532         m/s       WindSpeedms    m s-1  2007-07-31 15:00:00
#
#           latest_time_db  earliest_diff_days  latest_diff_days   batch
# 0    2024-08-10 19:00:00                 0.0               0.0  batch1
# 1    2024-08-10 19:00:00                 0.0               0.0  batch1
# 2    2024-08-10 19:00:00                 0.0               0.0  batch1
# 3    2024-08-10 19:00:00                 0.0               0.0  batch1
# 4                    NaN                 NaN               NaN  batch4
# ..                   ...                 ...               ...     ...
# 528  2024-10-24 09:00:00                 0.0             371.0  batch1
# 529  2024-10-24 09:00:00                 0.0             371.0  batch1
# 530  2024-10-24 09:00:00                 0.0             371.0  batch1
# 531  2024-10-24 09:00:00                 0.0             371.0  batch1
# 532  2024-10-24 09:00:00                 0.0             371.0  batch1
#
# [533 rows x 18 columns]

# %%
station_names = df_match['station_name'].tolist()

query = sa.text("""
    SELECT DISTINCT m.station_name, s.native_id, m.lat, m.lon, m.elev
    FROM meta_history AS m
    JOIN meta_station AS s ON m.station_id = s.station_id
    WHERE s.network_id = 11
      AND m.station_name = ANY(:station_names)
""")

with engine.connect() as conn:
    db_stations = pd.read_sql(query, conn, params={"station_names": station_names})

# %%
merged = df_match.merge(
    db_stations,
    on='station_name',
    how='left'
)

match_info = merged.rename(
    columns={
        'native_id': 'native_id_db',
        'lat_y': 'lat_db',
        'lon_y': 'lon_db',
        'elev_y': 'elev_db'
    }
)

match_info = match_info.drop(columns=['native_id_raw', 'lat_x', 'lon_x', 'elev_x'])

match_info
# Out:
#         station_name station_file_name         variable unit_raw  \
# 0       Atlin School      Atlin School            DewPt       °C
# 1       Atlin School      Atlin School       Gust Speed      m/s
# 2       Atlin School      Atlin School               RH        %
# 3       Atlin School      Atlin School             Rain       mm
# 4       Atlin School      Atlin School         Sfc Temp       °C
# ..               ...               ...              ...      ...
# 528  Willow-BowronWx   Willow-BowronWx  Solar Radiation     W/m²
# 529  Willow-BowronWx   Willow-BowronWx             Temp       °C
# 530  Willow-BowronWx   Willow-BowronWx          Wetness        %
# 531  Willow-BowronWx   Willow-BowronWx   Wind Direction        ø
# 532  Willow-BowronWx   Willow-BowronWx       Wind Speed      m/s
#
#        earliest_time_raw      latest_time_raw unit_origin      db_var_match  \
# 0    2011-07-28 09:00:00  2024-08-10 19:00:00          °C            DewPtC
# 1    2010-08-20 19:00:00  2024-08-10 19:00:00         m/s       GustSpeedms
# 2    2011-07-28 09:00:00  2024-08-10 19:00:00           %                RH
# 3    2010-08-20 20:00:00  2024-08-10 19:00:00          mm            Rainmm
# 4    2010-08-20 19:00:00  2024-08-10 19:00:00          °C      Surface_Temp
# ..                   ...                  ...         ...               ...
# 528  2007-07-31 15:00:00  2025-10-30 10:00:00        W/m²  SolarRadiationWm
# 529  2007-07-31 15:00:00  2025-10-30 10:00:00          °C             TempC
# 530  2008-06-12 13:00:00  2025-10-30 10:00:00           %           Wetness
# 531  2007-07-31 15:00:00  2025-10-30 10:00:00           ø     WindDirection
# 532  2007-07-31 15:00:00  2025-10-30 10:00:00         m/s       WindSpeedms
#
#      unit_db     earliest_time_db       latest_time_db  earliest_diff_days  \
# 0    celsius  2011-07-28 09:00:00  2024-08-10 19:00:00                 0.0
# 1      m s-1  2010-08-20 19:00:00  2024-08-10 19:00:00                 0.0
# 2          %  2011-07-28 09:00:00  2024-08-10 19:00:00                 0.0
# 3         mm  2010-08-20 20:00:00  2024-08-10 19:00:00                 0.0
# 4    celsius                  NaN                  NaN                 NaN
# ..       ...                  ...                  ...                 ...
# 528    W m-2  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 529  celsius  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 530        %  2008-06-12 13:00:00  2024-10-24 09:00:00                 0.0
# 531   degree  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 532    m s-1  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
#
#      latest_diff_days   batch native_id_db     lat_db      lon_db  elev_db
# 0                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 1                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 2                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 3                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 4                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# ..                ...     ...          ...        ...         ...      ...
# 528             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 529             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 530             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 531             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 532             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
#
# [533 rows x 18 columns]

# %% [markdown]
# ### Batch 1, for the unique variables (only one sensor)

# %%
match_info_uniq_var = match_info[match_info['db_var_match'].notna()]
match_info_uniq_var
# Out:
#         station_name station_file_name         variable unit_raw  \
# 0       Atlin School      Atlin School            DewPt       °C
# 1       Atlin School      Atlin School       Gust Speed      m/s
# 2       Atlin School      Atlin School               RH        %
# 3       Atlin School      Atlin School             Rain       mm
# 4       Atlin School      Atlin School         Sfc Temp       °C
# ..               ...               ...              ...      ...
# 528  Willow-BowronWx   Willow-BowronWx  Solar Radiation     W/m²
# 529  Willow-BowronWx   Willow-BowronWx             Temp       °C
# 530  Willow-BowronWx   Willow-BowronWx          Wetness        %
# 531  Willow-BowronWx   Willow-BowronWx   Wind Direction        ø
# 532  Willow-BowronWx   Willow-BowronWx       Wind Speed      m/s
#
#        earliest_time_raw      latest_time_raw unit_origin      db_var_match  \
# 0    2011-07-28 09:00:00  2024-08-10 19:00:00          °C            DewPtC
# 1    2010-08-20 19:00:00  2024-08-10 19:00:00         m/s       GustSpeedms
# 2    2011-07-28 09:00:00  2024-08-10 19:00:00           %                RH
# 3    2010-08-20 20:00:00  2024-08-10 19:00:00          mm            Rainmm
# 4    2010-08-20 19:00:00  2024-08-10 19:00:00          °C      Surface_Temp
# ..                   ...                  ...         ...               ...
# 528  2007-07-31 15:00:00  2025-10-30 10:00:00        W/m²  SolarRadiationWm
# 529  2007-07-31 15:00:00  2025-10-30 10:00:00          °C             TempC
# 530  2008-06-12 13:00:00  2025-10-30 10:00:00           %           Wetness
# 531  2007-07-31 15:00:00  2025-10-30 10:00:00           ø     WindDirection
# 532  2007-07-31 15:00:00  2025-10-30 10:00:00         m/s       WindSpeedms
#
#      unit_db     earliest_time_db       latest_time_db  earliest_diff_days  \
# 0    celsius  2011-07-28 09:00:00  2024-08-10 19:00:00                 0.0
# 1      m s-1  2010-08-20 19:00:00  2024-08-10 19:00:00                 0.0
# 2          %  2011-07-28 09:00:00  2024-08-10 19:00:00                 0.0
# 3         mm  2010-08-20 20:00:00  2024-08-10 19:00:00                 0.0
# 4    celsius                  NaN                  NaN                 NaN
# ..       ...                  ...                  ...                 ...
# 528    W m-2  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 529  celsius  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 530        %  2008-06-12 13:00:00  2024-10-24 09:00:00                 0.0
# 531   degree  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 532    m s-1  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
#
#      latest_diff_days   batch native_id_db     lat_db      lon_db  elev_db
# 0                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 1                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 2                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 3                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 4                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# ..                ...     ...          ...        ...         ...      ...
# 528             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 529             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 530             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 531             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 532             371.0  batch1       PGTIS2  53.772577 -122.724634    596.0
#
# [472 rows x 18 columns]

# %%
subset
# Out:
#     station_name station_file_name     variable unit_raw    earliest_time_raw  \
# 506   ThompsonWx        ThompsonWx  DewPt 30 cm       °C  2007-09-12 18:00:00
#
#          latest_time_raw unit_origin db_var_match  unit_db earliest_time_db  \
# 506  2025-09-22 10:00:00          °C   DewPt_30cm  celsius              NaN
#
#     latest_time_db  earliest_diff_days  latest_diff_days   batch native_id_db  \
# 506            NaN                 NaN               NaN  batch4     Thompson
#
#         lat_db      lon_db  elev_db
# 506  54.333115 -126.099445    869.0

# %%
data_path = '/workspaces/crmprtd/fern/FERNNorth2025_VF_data'

# Choose the variables you want
variables_to_extract = ['DewPt 30 cm', 'Temp 30 cm', 'RH 30 cm']

# Filter the DataFrame for the station and selected variables
subset = match_info_uniq_var.loc[
    (match_info_uniq_var['station_name'] == 'ThompsonWx') &
    (match_info_uniq_var['variable'].isin(variables_to_extract))
]

all_rows = []

for i, row in subset.iterrows():
    station = row["station_name"]
    variable = row["variable"]

    print(f"\n🔍 [{i+1}/{len(subset)}] Processing {station} — {variable}")

    new_rows = extract_new_data_rows(row, data_path)
    all_rows.extend(new_rows)

    if len(new_rows) > 0:
        print(f"  ✅ {len(new_rows)} new records found outside DB time range.")
    else:
        print("  ⚠️ No new records found (matches DB time range exactly).")

# Remove rows where timestamp is NaN
all_rows = [r for r in all_rows if not pd.isna(r.time)]
# Out:
# 🔍 [507/3] Processing ThompsonWx — DewPt 30 cm
#   ✅ 135734 new records found outside DB time range.
#
# 🔍 [512/3] Processing ThompsonWx — RH 30 cm
#   ✅ 135734 new records found outside DB time range.
#
# 🔍 [518/3] Processing ThompsonWx — Temp 30 cm
#   ✅ 136196 new records found outside DB time range.

# %%
### Have fixed 3.1 code by adding all_rows = [r for r in all_rows if not pd.isna(r.time)]

# %%
db_url = "postgresql://tongli1997@db.pcic.uvic.ca:5433/crmp?keepalives=1&keepalives_idle=300&keepalives_interval=300&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass"

safe_insert_rows(
    all_rows,
    log_file_path=output_folder + 'fern_all_station_insert.log',
    db_url=db_url,
    chunk_size=5000,        # SAFE starting point
    bulk_chunk_size=1000,   # internal DB bulk insert size
)
# Out:
# 🚀 Starting insert: 407661 rows in 82 chunks
# ➡️  Processing rows 0–4999
# {"asctime": "2026-02-12 21:12:44,348", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:44,437", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:44,505", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:44,569", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:44,632", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:44,694", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:44,695", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:44,695", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 0–4999
# ➡️  Processing rows 5000–9999
# {"asctime": "2026-02-12 21:12:44,733", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:44,853", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:44,918", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:44,981", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,047", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,112", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,113", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:45,113", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 5000–9999
# ➡️  Processing rows 10000–14999
# {"asctime": "2026-02-12 21:12:45,153", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:45,299", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,363", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,425", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,489", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,550", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,551", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:45,551", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 10000–14999
# ➡️  Processing rows 15000–19999
# {"asctime": "2026-02-12 21:12:45,717", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:45,831", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,896", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:45,958", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,019", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,080", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,080", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:46,081", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 15000–19999
# ➡️  Processing rows 20000–24999
# {"asctime": "2026-02-12 21:12:46,119", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:46,233", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,298", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,359", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,426", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,490", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,491", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:46,491", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 20000–24999
# ➡️  Processing rows 25000–29999
# {"asctime": "2026-02-12 21:12:46,529", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:46,651", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,716", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,779", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,840", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,902", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:46,902", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:46,902", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 25000–29999
# ➡️  Processing rows 30000–34999
# {"asctime": "2026-02-12 21:12:46,943", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:47,056", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,139", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,202", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,262", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,322", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,323", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:47,323", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 30000–34999
# ➡️  Processing rows 35000–39999
# {"asctime": "2026-02-12 21:12:47,353", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:47,457", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,520", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,581", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,643", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,704", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:47,705", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:47,705", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 35000–39999
# ➡️  Processing rows 40000–44999
# {"asctime": "2026-02-12 21:12:47,750", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:47,989", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,049", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,109", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,170", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,229", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,230", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:48,230", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 40000–44999
# ➡️  Processing rows 45000–49999
# {"asctime": "2026-02-12 21:12:48,269", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:48,388", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,453", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,514", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,574", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,636", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,637", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:48,637", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 45000–49999
# ➡️  Processing rows 50000–54999
# {"asctime": "2026-02-12 21:12:48,675", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:48,795", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,858", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,920", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:48,981", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,041", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,042", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:49,042", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 50000–54999
# ➡️  Processing rows 55000–59999
# {"asctime": "2026-02-12 21:12:49,082", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:49,203", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,268", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,330", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,391", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,455", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,455", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:49,455", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 55000–59999
# ➡️  Processing rows 60000–64999
# {"asctime": "2026-02-12 21:12:49,501", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:49,623", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,686", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,750", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,812", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,875", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:49,876", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:49,876", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 60000–64999
# ➡️  Processing rows 65000–69999
# {"asctime": "2026-02-12 21:12:49,918", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:50,043", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,218", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,279", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,340", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,402", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,403", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:50,403", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 65000–69999
# ➡️  Processing rows 70000–74999
# {"asctime": "2026-02-12 21:12:50,442", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:50,569", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,633", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,696", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,758", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,819", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:50,819", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:50,820", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 70000–74999
# ➡️  Processing rows 75000–79999
# {"asctime": "2026-02-12 21:12:50,858", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:50,980", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,043", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,105", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,167", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,231", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,232", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:51,232", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 75000–79999
# ➡️  Processing rows 80000–84999
# {"asctime": "2026-02-12 21:12:51,273", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:51,399", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,463", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,527", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,590", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,653", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,653", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:51,654", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 80000–84999
# ➡️  Processing rows 85000–89999
# {"asctime": "2026-02-12 21:12:51,696", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:51,817", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,881", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:51,943", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,003", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,065", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,065", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:52,066", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 85000–89999
# ➡️  Processing rows 90000–94999
# {"asctime": "2026-02-12 21:12:52,106", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:52,228", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,293", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,354", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,416", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,610", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,610", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:52,610", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 90000–94999
# ➡️  Processing rows 95000–99999
# {"asctime": "2026-02-12 21:12:52,653", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:52,780", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,845", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,908", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:52,968", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,027", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,027", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:53,028", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 95000–99999
# ➡️  Processing rows 100000–104999
# {"asctime": "2026-02-12 21:12:53,067", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:53,190", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,254", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,315", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,378", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,439", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,440", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:53,440", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 100000–104999
# ➡️  Processing rows 105000–109999
# {"asctime": "2026-02-12 21:12:53,480", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:53,610", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,675", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,739", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,802", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,867", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:53,868", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:53,868", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 105000–109999
# ➡️  Processing rows 110000–114999
# {"asctime": "2026-02-12 21:12:53,912", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:54,035", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,100", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,163", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,224", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,284", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,284", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:54,284", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 110000–114999
# ➡️  Processing rows 115000–119999
# {"asctime": "2026-02-12 21:12:54,324", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:54,449", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,513", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,575", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,636", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,698", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:54,699", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:54,699", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 115000–119999
# ➡️  Processing rows 120000–124999
# {"asctime": "2026-02-12 21:12:54,736", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:54,964", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,029", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,103", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,165", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,226", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,226", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:55,227", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 120000–124999
# ➡️  Processing rows 125000–129999
# {"asctime": "2026-02-12 21:12:55,267", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:55,391", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,455", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,519", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,582", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,644", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,645", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:55,645", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 125000–129999
# ➡️  Processing rows 130000–134999
# {"asctime": "2026-02-12 21:12:55,681", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:55,795", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,857", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,919", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:55,981", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:56,044", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:56,044", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:56,045", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 130000–134999
# ➡️  Processing rows 135000–139999
# {"asctime": "2026-02-12 21:12:56,148", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:56,485", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 349 inserted, 651 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:56,578", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 349 inserted, 1651 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:56,647", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 349 inserted, 2651 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:56,710", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 349 inserted, 3651 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:56,772", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 349 inserted, 4651 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:56,772", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 349"}
# {"asctime": "2026-02-12 21:12:56,773", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 135000–139999
# ➡️  Processing rows 140000–144999
# {"asctime": "2026-02-12 21:12:56,811", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:56,935", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,000", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,063", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,125", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,186", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,187", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:57,187", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 140000–144999
# ➡️  Processing rows 145000–149999
# {"asctime": "2026-02-12 21:12:57,228", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:57,348", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,413", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,585", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,647", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,706", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,706", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:57,707", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 145000–149999
# ➡️  Processing rows 150000–154999
# {"asctime": "2026-02-12 21:12:57,751", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:57,879", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:57,945", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,008", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,072", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,135", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,135", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:58,135", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 150000–154999
# ➡️  Processing rows 155000–159999
# {"asctime": "2026-02-12 21:12:58,174", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:58,296", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,360", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,422", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,486", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,570", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,570", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:58,571", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 155000–159999
# ➡️  Processing rows 160000–164999
# {"asctime": "2026-02-12 21:12:58,609", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:58,734", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,800", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,865", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,929", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,992", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:58,992", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:58,992", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 160000–164999
# ➡️  Processing rows 165000–169999
# {"asctime": "2026-02-12 21:12:59,033", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:59,155", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,218", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,279", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,341", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,401", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,401", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:59,401", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 165000–169999
# ➡️  Processing rows 170000–174999
# {"asctime": "2026-02-12 21:12:59,450", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:12:59,575", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,643", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,710", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,774", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,837", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:12:59,837", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:12:59,837", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 170000–174999
# ➡️  Processing rows 175000–179999
# {"asctime": "2026-02-12 21:12:59,981", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:00,104", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,169", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,234", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,298", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,361", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,362", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:00,362", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 175000–179999
# ➡️  Processing rows 180000–184999
# {"asctime": "2026-02-12 21:13:00,402", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:00,524", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,590", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,655", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,719", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,784", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:00,784", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:00,785", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 180000–184999
# ➡️  Processing rows 185000–189999
# {"asctime": "2026-02-12 21:13:00,824", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:00,950", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:01,016", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:01,081", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:01,145", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:01,210", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:01,210", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:01,211", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 185000–189999
# ➡️  Processing rows 190000–194999
# {"asctime": "2026-02-12 21:13:01,252", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:01,376", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:01,441", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:01,502", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:01,564", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:01,625", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# ...
# {"asctime": "2026-02-12 21:13:15,112", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 340000–344999
# ➡️  Processing rows 345000–349999
# {"asctime": "2026-02-12 21:13:15,151", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:15,273", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:15,338", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:15,400", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:15,465", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:15,527", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:15,528", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:15,528", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 345000–349999
# ➡️  Processing rows 350000–354999
# {"asctime": "2026-02-12 21:13:15,568", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:15,692", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:15,758", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:15,926", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:15,991", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,053", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,053", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:16,054", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 350000–354999
# ➡️  Processing rows 355000–359999
# {"asctime": "2026-02-12 21:13:16,091", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:16,214", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,278", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,352", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,414", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,475", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,476", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:16,476", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 355000–359999
# ➡️  Processing rows 360000–364999
# {"asctime": "2026-02-12 21:13:16,511", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:16,633", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,696", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,759", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,822", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,886", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:16,887", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:16,887", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 360000–364999
# ➡️  Processing rows 365000–369999
# {"asctime": "2026-02-12 21:13:16,931", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:17,056", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,141", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,205", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,266", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,327", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,327", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:17,327", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 365000–369999
# ➡️  Processing rows 370000–374999
# {"asctime": "2026-02-12 21:13:17,358", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:17,478", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,542", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,606", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,668", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,731", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,731", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:17,732", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 370000–374999
# ➡️  Processing rows 375000–379999
# {"asctime": "2026-02-12 21:13:17,762", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:17,880", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:17,955", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,130", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,192", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,257", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,258", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:18,258", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 375000–379999
# ➡️  Processing rows 380000–384999
# {"asctime": "2026-02-12 21:13:18,298", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:18,419", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,482", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,542", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,605", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,667", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,667", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:18,668", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 380000–384999
# ➡️  Processing rows 385000–389999
# {"asctime": "2026-02-12 21:13:18,702", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:18,818", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,881", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:18,942", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,005", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,068", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,068", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:19,069", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 385000–389999
# ➡️  Processing rows 390000–394999
# {"asctime": "2026-02-12 21:13:19,105", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:19,223", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,289", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,350", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,411", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,475", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,476", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:19,476", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 390000–394999
# ➡️  Processing rows 395000–399999
# {"asctime": "2026-02-12 21:13:19,524", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:19,643", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,710", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,776", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,843", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,907", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:19,908", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:19,908", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 395000–399999
# ➡️  Processing rows 400000–404999
# {"asctime": "2026-02-12 21:13:19,947", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:20,070", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:20,133", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:20,302", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:20,363", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:20,423", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:20,423", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-12 21:13:20,424", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 400000–404999
# ➡️  Processing rows 405000–407660
# {"asctime": "2026-02-12 21:13:20,451", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-12 21:13:20,574", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:20,642", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:20,707", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 14 inserted, 2647 skipped, 0 failed"}
# {"asctime": "2026-02-12 21:13:20,708", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 14"}
# {"asctime": "2026-02-12 21:13:20,709", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 405000–407660

# %% [markdown]
# ### Other issues recognized by 6.

# %%
data_path = '/workspaces/crmprtd/fern/FERNNorth2025_VF_data'

# Choose the variables you want
variables_to_extract = ['Soil Temp']

# Filter the DataFrame for the station and selected variables
subset = match_info_uniq_var.loc[
    (match_info_uniq_var['station_name'] == 'Atlin School') &
    (match_info_uniq_var['variable'].isin(variables_to_extract))
]
subset

all_rows = []

for i, row in subset.iterrows():
    station = row["station_name"]
    variable = row["variable"]

    print(f"\n🔍 [{i+1}/{len(subset)}] Processing {station} — {variable}")

    new_rows = extract_new_data_rows(row, data_path)
    all_rows.extend(new_rows)

    if len(new_rows) > 0:
        print(f"  ✅ {len(new_rows)} new records found outside DB time range.")
    else:
        print("  ⚠️ No new records found (matches DB time range exactly).")

# Remove rows where timestamp is NaN
all_rows = [r for r in all_rows if not pd.isna(r.time)]
# Out:
# 🔍 [6/1] Processing Atlin School — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).

# %%
all_rows
# Out:
# []
