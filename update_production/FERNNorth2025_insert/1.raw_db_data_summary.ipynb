# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Match stations, using station name, lat, lon. The name matching in Raw data meta_data form, in the folder and in the database

# %%
from crmprtd import Row
import logging
import os
import pickle
import pandas as pd
import numpy as np
from natsort import natsorted
from natsort import natsort_keygen
from pprint import pprint
from collections import Counter
from collections import defaultdict

import re
from rapidfuzz import fuzz
from crmprtd import infer
import sqlalchemy as sa
from ftfy import fix_text

from fern_func import *
# from sql_func import *
from fern_raw_db_dompare import *

# %%
# --- Main workflow ---
# --- read data ---
meta_path = '/workspaces/crmprtd/fern/FERNNorth2025_insert/tables/20241125 MeteorologicalNetworks-FERN-VF-shared.xlsx'

df_station = pd.read_excel(meta_path)
df_station = df_station.sort_values(by='station_name', key=natsort_keygen())


# --- output folder ---
output_folder = '/workspaces/crmprtd/fern/FERNNorth2025_insert/output/'
os.makedirs(output_folder, exist_ok=True)

# %%
# !pip install ftfy

# %% [markdown]
# ### Fern raw data condition summary

# %%
data_path = '/workspaces/crmprtd/fern/FERNNorth2025_VF_data'
csv_files = [f for f in os.listdir(data_path) if f.endswith('.csv')]
# Sort in natural order
csv_files = natsorted(csv_files)

station_names = [os.path.splitext(f)[0] for f in csv_files]

df_stations = pd.DataFrame(
    {"station_name": station_names}
)

df_stations


summary_fern_raw_records = []

for station_i, csv_file in enumerate(csv_files):
    station_row = df_station.iloc[station_i]
    station_name = station_row[ 'station_name']

    print(station_name)

    ### summarize raw data
    records = summarize_raw_station(csv_file, station_row, data_path)
    summary_fern_raw_records.extend(records)  # add to the master list

raw_summary = pd.DataFrame(summary_fern_raw_records)

raw_summary['unit_origin'] = raw_summary['unit']
raw_summary['unit'] = raw_summary['unit'].astype(str).apply(fix_text)

raw_summary_path = os.path.join(output_folder, "Fern_raw_station_variable_summary.csv")
raw_summary.to_csv(raw_summary_path, index=False)
print(f"✅ Summary saved to {raw_summary_path}")
# Out:
# Atlin School
# ['Date', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Soil Temp 75 cm, °C', 'Soil Temp 50 cm, °C', 'Flags', 'Comments']
# 📍 Station: Atlin School (File: Atlin School)
# ⚠️ Variable 'Pressure' is all NaN, skipping
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# BarrenWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: BarrenWx (File: BarrenWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# BlackhawkWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: BlackhawkWx (File: BlackhawkWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# BoulderWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: BoulderWx (File: BoulderWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# BowronPit
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Snow sensor Temp, ░C', 'Flags', 'Comments']
# 📍 Station: BowronPit (File: BowronPit)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# BulkleyWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: BulkleyWx (File: BulkleyWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# CPFWx
# ['DateTime, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: CPFWx (File: CPFWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# Canoe Mountain Stn
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: Canoe Mountain Stn (File: Canoe Mountain Stn)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# Caribou Pass
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: Caribou Pass (File: Caribou Pass)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# ChapmanWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: ChapmanWx (File: ChapmanWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ChiefLakeWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: ChiefLakeWx (File: ChiefLakeWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# CoalmineWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29']
# 📍 Station: CoalmineWx (File: CoalmineWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# CrookedLk
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: CrookedLk (File: CrookedLk)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# CrystalWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: CrystalWx (File: CrystalWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# Dennis
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments', 'Unnamed: 27', 'Unnamed: 28']
# 📍 Station: Dennis (File: Dennis)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# DunsterWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Rain2, mm', 'Flags', 'Comments']
# 📍 Station: DunsterWx (File: DunsterWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# EndakoWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: EndakoWx (File: EndakoWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# GeorgeWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: GeorgeWx (File: GeorgeWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# GunnelWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth raw, cm', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Flags', 'Comments']
# 📍 Station: GunnelWx (File: Gunnel3)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth raw' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# HourglassWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: HourglassWx (File: HourglassWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# Hudson Bay Mtn2
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: Hudson Bay Mtn2 (File: Hudson Bay Mtn2)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# IBB1Wx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: IBB1Wx (File: IBB1Wx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# IBB2Wx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: IBB2Wx (File: IBB2Wx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# IBB3Wx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Comments']
# 📍 Station: IBB3Wx (File: IBB3Wx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# Inklin
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: Inklin (File: Inklin)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# Kluskus
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: Kluskus (File: Kluskus)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# MacJxnWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: MacJxnWx (File: MacJxnWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# MiddleforkWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: MiddleforkWx (File: MiddleforkWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# NondaWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: NondaWx (File: NondaWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# PinkWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil temp, °C', 'Sfc temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Rain raw, mm', 'Flags', 'Comments']
# 📍 Station: PinkWx (File: PinkWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# SaxtonWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: SaxtonWx (File: SaxtonWx)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# SeebachWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: SeebachWx (File: SeebachWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# Sunbeam
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: Sunbeam (File: Sunbeam)
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# Tamarac
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: Tamarac (File: Tamarac)
# ⚠️ Variable 'Pressure' is all NaN, skipping
# ⚠️ Variable 'Wind Direction' is all NaN, skipping
# ⚠️ Variable 'Solar Radiation' is all NaN, skipping
# ⚠️ Variable 'Wetness' is all NaN, skipping
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ThompsonWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: ThompsonWx (File: ThompsonWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# Willow-BowronWx
# ['Date Time, PST', 'Day', 'Rain, mm', 'Pressure, mbar', 'Temp, °C', 'RH, %', 'DewPt, °C', 'Wind Speed, m/s', 'Gust Speed, m/s', 'Wind Direction, ø', 'Solar Radiation, W/m²', 'Wetness, %', 'Snow depth, cm', 'Water Content, m³/m³ 15 cm', 'WC_cal, m³/m³', 'Soil Temp, °C', 'Sfc Temp, °C', 'Water Content, m³/m³ 5 cm', 'Water Content, m³/m³ 30 cm', 'Temp 2, °C', 'RH 2, %', 'DewPt 2, °C', 'Temp 30 cm, °C', 'RH 30 cm, %', 'DewPt 30 cm, °C', 'Flags', 'Comments']
# 📍 Station: Willow-BowronWx (File: Willow-BowronWx)
# ⚠️ Variable 'Snow depth' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'WC_cal' is all NaN, skipping
# ⚠️ Variable 'Soil Temp' is all NaN, skipping
# ⚠️ Variable 'Sfc Temp' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Water Content' is all NaN, skipping
# ⚠️ Variable 'Temp 2' is all NaN, skipping
# ⚠️ Variable 'RH 2' is all NaN, skipping
# ⚠️ Variable 'DewPt 2' is all NaN, skipping
# ⚠️ Variable 'Temp 30 cm' is all NaN, skipping
# ⚠️ Variable 'RH 30 cm' is all NaN, skipping
# ⚠️ Variable 'DewPt 30 cm' is all NaN, skipping
# ✅ Summary saved to /workspaces/crmprtd/fern/FERNNorth2025_insert/output/Fern_raw_station_variable_summary.csv

# %%
raw_summary
# Out:
#         station_name native_id station_file_name        lat         lon  elev  \
# 0       Atlin School    AtlSch      Atlin School  59.574000 -133.687000   705
# 1       Atlin School    AtlSch      Atlin School  59.574000 -133.687000   705
# 2       Atlin School    AtlSch      Atlin School  59.574000 -133.687000   705
# 3       Atlin School    AtlSch      Atlin School  59.574000 -133.687000   705
# 4       Atlin School    AtlSch      Atlin School  59.574000 -133.687000   705
# ..               ...       ...               ...        ...         ...   ...
# 529  Willow-BowronWx    PGTIS2   Willow-BowronWx  53.772577 -122.724634   596
# 530  Willow-BowronWx    PGTIS2   Willow-BowronWx  53.772577 -122.724634   596
# 531  Willow-BowronWx    PGTIS2   Willow-BowronWx  53.772577 -122.724634   596
# 532  Willow-BowronWx    PGTIS2   Willow-BowronWx  53.772577 -122.724634   596
# 533  Willow-BowronWx    PGTIS2   Willow-BowronWx  53.772577 -122.724634   596
#
#             variable  unit       earliest_time         latest_time unit_origin
# 0               Rain    mm 2010-08-20 20:00:00 2024-08-10 19:00:00          mm
# 1               Temp    °C 2010-08-20 19:00:00 2024-08-10 19:00:00          °C
# 2                 RH     % 2011-07-28 09:00:00 2024-08-10 19:00:00           %
# 3              DewPt    °C 2011-07-28 09:00:00 2024-08-10 19:00:00          °C
# 4         Wind Speed   m/s 2010-08-20 19:00:00 2024-08-10 19:00:00         m/s
# ..               ...   ...                 ...                 ...         ...
# 529       Wind Speed   m/s 2007-07-31 15:00:00 2025-10-30 10:00:00         m/s
# 530       Gust Speed   m/s 2007-07-31 15:00:00 2025-10-30 10:00:00         m/s
# 531   Wind Direction     ø 2007-07-31 15:00:00 2025-10-30 10:00:00           ø
# 532  Solar Radiation  W/m² 2007-07-31 15:00:00 2025-10-30 10:00:00        W/m²
# 533          Wetness     % 2008-06-12 13:00:00 2025-10-30 10:00:00           %
#
# [534 rows x 11 columns]

# %% [markdown]
# ### Database summary

# %%
import sqlalchemy as sa
from sqlalchemy.orm import Session

engine = sa.create_engine("postgresql://tongli1997@db.pcic.uvic.ca:5433/crmp?keepalives=1&keepalives_idle=300&keepalives_interval=300&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass", echo=False)
session = Session(engine)

# %%
station_name_id = df_station[['native_id', 'station_name']]
native_ids = station_name_id['native_id'].tolist()
station_names = station_name_id['station_name'].tolist()

query = sa.text("""
    SELECT DISTINCT m.station_name, s.native_id
    FROM meta_history AS m
    JOIN meta_station AS s ON m.station_id = s.station_id
    WHERE s.network_id = 11
      AND m.station_name = ANY(:station_names)
""")

with engine.connect() as conn:
    existing_stations = pd.read_sql(query, conn, params={"station_names": station_names})

print("Stations found in DB:")
existing_stations
# Out:
# Stations found in DB:
#           station_name             native_id
# 0         Atlin School                AtlSch
# 1             BarrenWx                Barren
# 2          BlackhawkWx             Blackhawk
# 3            BoulderWx         Boulder Creek
# 4            BowronPit             BowronPit
# 5            BulkleyWx                PGTIS1
# 6   Canoe Mountain Stn    Canoe Mountain Stn
# 7         Caribou Pass           CaribouPass
# 8            ChapmanWx               Chapman
# 9          ChiefLakeWx               ChiefWx
# 10          CoalmineWx            CoalmineWx
# 11               CPFWx                PGTIS3
# 12           CrookedLk             CrookedLk
# 13           CrystalWx          Crystal Lake
# 14              Dennis                Dennis
# 15           DunsterWx               Dunster
# 16            EndakoWx                Endako
# 17            GeorgeWx                George
# 18            GunnelWx               Gunnel1
# 19         HourglassWx            Hourglass
# 20     Hudson Bay Mtn2                HBMtn2
# 21              IBB1Wx                  IBB1
# 22              IBB2Wx                  IBB2
# 23              IBB3Wx                  IBB3
# 24              Inklin                Inklin
# 25             Kluskus            BednestiWx
# 26            MacJxnWx         Mackenzie Jxn
# 27        MiddleforkWx                   MF1
# 28             NondaWx                Nonda1
# 29              PinkWx                 Pink1
# 30            SaxtonWx                Saxton
# 31           SeebachWx               Seebach
# 32             Sunbeam  Mcbride Mountain Stn
# 33             Tamarac              Bednesti
# 34          ThompsonWx              Thompson
# 35     Willow-BowronWx                PGTIS2

# %% [markdown]
# - Station `Kluskus`
#     - `native_id` in Ted's sheet: `BednestiWx`
#     - `native_id` in Vanessa's sheet: `SBSmc3Wx`
#
# I update the `native_id` in Vanessa's sheet to `BednestiWx`
#
# And we didn't update it according to Vanessa's sheet, so we based on station_name to match stations. All stations can be matched

# %%
existing_native_ids = existing_stations['native_id'].tolist()

query = sa.text("""
    SELECT 
        m.station_name,
        s.native_id,
        m.lat,
        m.lon,
        m.elev,
        v.net_var_name, 
        v.unit,
        MIN(o.obs_time) AS earliest_time,
        MAX(o.obs_time) AS latest_time
    FROM obs_raw AS o
    JOIN meta_history AS m ON o.history_id = m.history_id
    JOIN meta_vars AS v ON o.vars_id = v.vars_id
    JOIN meta_station AS s ON m.station_id = s.station_id
    WHERE s.network_id = 11
      AND s.native_id = ANY(:native_ids)
    GROUP BY v.net_var_name, v.unit, m.station_name, m.lat, m.lon, s.native_id, m.elev
    ORDER BY v.net_var_name;
""")

with engine.connect() as conn:
    df_obs = pd.read_sql(query, conn, params={"native_ids": existing_native_ids})

df_obs
# Out:
#         station_name             native_id        lat         lon    elev  \
# 0           BarrenWx                Barren  54.510444 -126.614341  1051.0
# 1        BlackhawkWx             Blackhawk  55.078885 -120.352171   962.0
# 2          BoulderWx         Boulder Creek  55.108173 -127.374740   385.0
# 3          BowronPit             BowronPit  53.902111 -122.015389   722.0
# 4          BulkleyWx                PGTIS1  53.772183 -122.720729   594.0
# ..               ...                   ...        ...         ...     ...
# 293           PinkWx                 Pink1  57.061630 -122.864910  1756.0
# 294         SaxtonWx                Saxton  54.027523 -123.300774   718.0
# 295          Sunbeam  Mcbride Mountain Stn  53.338690 -120.121080  2000.0
# 296       ThompsonWx              Thompson  54.333115 -126.099445   869.0
# 297  Willow-BowronWx                PGTIS2  53.772577 -122.724634   596.0
#
#     net_var_name     unit       earliest_time         latest_time
# 0         DewPtC  celsius 2021-07-09 12:00:00 2023-09-18 12:00:00
# 1         DewPtC  celsius 2012-05-24 13:00:00 2024-01-05 08:00:00
# 2         DewPtC  celsius 2010-06-07 13:00:00 2023-09-21 14:00:00
# 3         DewPtC  celsius 2018-09-13 12:00:00 2024-01-05 08:00:00
# 4         DewPtC  celsius 2007-07-31 12:00:03 2023-10-17 10:00:00
# ..           ...      ...                 ...                 ...
# 293  WindSpeedms    m s-1 2008-09-08 16:00:00 2024-01-08 10:00:00
# 294  WindSpeedms    m s-1 2007-07-04 10:00:00 2023-10-05 11:00:00
# 295  WindSpeedms    m s-1 2009-09-09 16:00:00 2024-01-08 12:00:00
# 296  WindSpeedms    m s-1 2007-09-12 16:00:00 2023-09-13 11:00:00
# 297  WindSpeedms    m s-1 2007-07-31 15:00:00 2023-10-17 09:00:00
#
# [298 rows x 9 columns]

# %%
db_summary_path = os.path.join(output_folder, "Fern_db_station_variable_summary.csv")
df_obs.to_csv(db_summary_path, index=False)
print(f"✅ Summary saved to {db_summary_path}")

df_obs
# Out:
# ✅ Summary saved to /workspaces/crmprtd/fern/FERNNorth2025_insert/output/Fern_db_station_variable_summary.csv
#         station_name             native_id        lat         lon    elev  \
# 0           BarrenWx                Barren  54.510444 -126.614341  1051.0
# 1        BlackhawkWx             Blackhawk  55.078885 -120.352171   962.0
# 2          BoulderWx         Boulder Creek  55.108173 -127.374740   385.0
# 3          BowronPit             BowronPit  53.902111 -122.015389   722.0
# 4          BulkleyWx                PGTIS1  53.772183 -122.720729   594.0
# ..               ...                   ...        ...         ...     ...
# 293           PinkWx                 Pink1  57.061630 -122.864910  1756.0
# 294         SaxtonWx                Saxton  54.027523 -123.300774   718.0
# 295          Sunbeam  Mcbride Mountain Stn  53.338690 -120.121080  2000.0
# 296       ThompsonWx              Thompson  54.333115 -126.099445   869.0
# 297  Willow-BowronWx                PGTIS2  53.772577 -122.724634   596.0
#
#     net_var_name     unit       earliest_time         latest_time
# 0         DewPtC  celsius 2021-07-09 12:00:00 2023-09-18 12:00:00
# 1         DewPtC  celsius 2012-05-24 13:00:00 2024-01-05 08:00:00
# 2         DewPtC  celsius 2010-06-07 13:00:00 2023-09-21 14:00:00
# 3         DewPtC  celsius 2018-09-13 12:00:00 2024-01-05 08:00:00
# 4         DewPtC  celsius 2007-07-31 12:00:03 2023-10-17 10:00:00
# ..           ...      ...                 ...                 ...
# 293  WindSpeedms    m s-1 2008-09-08 16:00:00 2024-01-08 10:00:00
# 294  WindSpeedms    m s-1 2007-07-04 10:00:00 2023-10-05 11:00:00
# 295  WindSpeedms    m s-1 2009-09-09 16:00:00 2024-01-08 12:00:00
# 296  WindSpeedms    m s-1 2007-09-12 16:00:00 2023-09-13 11:00:00
# 297  WindSpeedms    m s-1 2007-07-31 15:00:00 2023-10-17 09:00:00
#
# [298 rows x 9 columns]
