# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa
import os
from row_generate_func import *
from auto_insert_func import *
from sqlalchemy.orm import Session

engine = sa.create_engine("postgresql://tongli1997@db.pcic.uvic.ca:5433/crmp?keepalives=1&keepalives_idle=300&keepalives_interval=300&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass", echo=False)
session = Session(engine)

# %%
# --- Main workflow ---
output_folder = '/workspaces/crmprtd/fern/FERNNorth2025_insert/output/'
file_name = 'Fern_raw_db_station_matched.csv'
df_match = pd.read_csv(output_folder + file_name)

df_match
# Out:
#         station_name native_id_raw station_file_name        lat         lon  \
# 0       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 1       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 2       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 3       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# 4       Atlin School        AtlSch      Atlin School  59.574000 -133.687000
# ..               ...           ...               ...        ...         ...
# 528  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 529  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 530  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 531  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
# 532  Willow-BowronWx        PGTIS2   Willow-BowronWx  53.772577 -122.724634
#
#      elev         variable unit_raw    earliest_time_raw      latest_time_raw  \
# 0     705            DewPt       °C  2011-07-28 09:00:00  2024-08-10 19:00:00
# 1     705       Gust Speed      m/s  2010-08-20 19:00:00  2024-08-10 19:00:00
# 2     705               RH        %  2011-07-28 09:00:00  2024-08-10 19:00:00
# 3     705             Rain       mm  2010-08-20 20:00:00  2024-08-10 19:00:00
# 4     705         Sfc Temp       °C  2010-08-20 19:00:00  2024-08-10 19:00:00
# ..    ...              ...      ...                  ...                  ...
# 528   596  Solar Radiation     W/m²  2007-07-31 15:00:00  2025-10-30 10:00:00
# 529   596             Temp       °C  2007-07-31 15:00:00  2025-10-30 10:00:00
# 530   596          Wetness        %  2008-06-12 13:00:00  2025-10-30 10:00:00
# 531   596   Wind Direction        ø  2007-07-31 15:00:00  2025-10-30 10:00:00
# 532   596       Wind Speed      m/s  2007-07-31 15:00:00  2025-10-30 10:00:00
#
#     unit_origin      db_var_match  unit_db     earliest_time_db  \
# 0            °C            DewPtC  celsius                  NaN
# 1           m/s       GustSpeedms    m s-1                  NaN
# 2             %                RH        %                  NaN
# 3            mm            Rainmm       mm                  NaN
# 4            °C      Surface_Temp  celsius                  NaN
# ..          ...               ...      ...                  ...
# 528        W/m²  SolarRadiationWm    W m-2  2007-07-31 15:00:00
# 529          °C             TempC  celsius  2007-07-31 15:00:00
# 530           %           Wetness        %  2008-06-12 13:00:00
# 531           ø     WindDirection   degree  2007-07-31 15:00:00
# 532         m/s       WindSpeedms    m s-1  2007-07-31 15:00:00
#
#           latest_time_db  earliest_diff_days  latest_diff_days   batch
# 0                    NaN                 NaN               NaN  batch2
# 1                    NaN                 NaN               NaN  batch2
# 2                    NaN                 NaN               NaN  batch2
# 3                    NaN                 NaN               NaN  batch2
# 4                    NaN                 NaN               NaN  batch4
# ..                   ...                 ...               ...     ...
# 528  2023-10-17 09:00:00                 0.0             744.0  batch1
# 529  2023-10-17 09:00:00                 0.0             744.0  batch1
# 530  2023-10-17 09:00:00                 0.0             744.0  batch1
# 531  2023-10-17 09:00:00                 0.0             744.0  batch1
# 532  2023-10-17 09:00:00                 0.0             744.0  batch1
#
# [533 rows x 18 columns]

# %%
station_names = df_match['station_name'].tolist()

query = sa.text("""
    SELECT DISTINCT m.station_name, s.native_id, m.lat, m.lon, m.elev
    FROM meta_history AS m
    JOIN meta_station AS s ON m.station_id = s.station_id
    WHERE s.network_id = 11
      AND m.station_name = ANY(:station_names)
""")

with engine.connect() as conn:
    db_stations = pd.read_sql(query, conn, params={"station_names": station_names})

# %%
merged = df_match.merge(
    db_stations,
    on='station_name',
    how='left'
)

match_info = merged.rename(
    columns={
        'native_id': 'native_id_db',
        'lat_y': 'lat_db',
        'lon_y': 'lon_db',
        'elev_y': 'elev_db'
    }
)

match_info = match_info.drop(columns=['native_id_raw', 'lat_x', 'lon_x', 'elev_x'])

# %%
match_info[['station_name', 'variable']]
# Out:
#         station_name         variable
# 0       Atlin School            DewPt
# 1       Atlin School       Gust Speed
# 2       Atlin School               RH
# 3       Atlin School             Rain
# 4       Atlin School         Sfc Temp
# ..               ...              ...
# 528  Willow-BowronWx  Solar Radiation
# 529  Willow-BowronWx             Temp
# 530  Willow-BowronWx          Wetness
# 531  Willow-BowronWx   Wind Direction
# 532  Willow-BowronWx       Wind Speed
#
# [533 rows x 2 columns]

# %%
import re

# 1️⃣ Define base variable
def base_variable(var):
    return re.sub(r'\s*\d+$', '', var).strip()

match_info['base_variable'] = match_info['variable'].apply(base_variable)

# 2️⃣ Filter rows with duplicates per station + base_variable + unit_raw
dup_items = (
    match_info
    .groupby(['station_name', 'base_variable', 'unit_raw'])
    .filter(lambda x: len(x) > 1)
    .reset_index(drop=True)
)

dup_items
# Out:
#      station_name station_file_name variable unit_raw    earliest_time_raw  \
# 0    Atlin School      Atlin School     Temp       °C  2010-08-20 19:00:00
# 1    Atlin School      Atlin School   Temp 2       °C  2011-07-28 09:00:00
# 2     BlackhawkWx       BlackhawkWx    DewPt       °C  2012-05-24 13:00:00
# 3     BlackhawkWx       BlackhawkWx  DewPt 2       °C  2024-07-18 10:00:00
# 4     BlackhawkWx       BlackhawkWx       RH        %  2012-05-24 13:00:00
# ..            ...               ...      ...      ...                  ...
# 109    ThompsonWx        ThompsonWx  DewPt 2       °C  2024-09-24 12:00:00
# 110    ThompsonWx        ThompsonWx       RH        %  2007-09-12 17:00:00
# 111    ThompsonWx        ThompsonWx     RH 2        %  2024-09-24 12:00:00
# 112    ThompsonWx        ThompsonWx     Temp       °C  2007-09-12 17:00:00
# 113    ThompsonWx        ThompsonWx   Temp 2       °C  2024-09-24 12:00:00
#
#          latest_time_raw unit_origin db_var_match  unit_db  \
# 0    2024-08-10 19:00:00          °C        TempC  celsius
# 1    2024-08-10 19:00:00          °C          NaN      NaN
# 2    2026-01-05 10:00:00          °C       DewPtC  celsius
# 3    2025-07-24 09:00:00          °C          NaN      NaN
# 4    2026-01-05 10:00:00           %           RH        %
# ..                   ...         ...          ...      ...
# 109  2025-09-22 10:00:00          °C          NaN      NaN
# 110  2025-09-22 10:00:00           %           RH        %
# 111  2025-09-22 10:00:00           %          NaN      NaN
# 112  2025-09-22 10:00:00          °C        TempC  celsius
# 113  2025-09-22 10:00:00          °C          NaN      NaN
#
#         earliest_time_db       latest_time_db  earliest_diff_days  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2    2012-05-24 13:00:00  2024-01-05 08:00:00                 0.0
# 3                    NaN                  NaN                 NaN
# 4    2012-05-24 13:00:00  2024-01-05 08:00:00                 0.0
# ..                   ...                  ...                 ...
# 109                  NaN                  NaN                 NaN
# 110  2007-09-12 16:00:00  2023-09-13 11:00:00                 0.0
# 111                  NaN                  NaN                 NaN
# 112  2007-09-12 16:00:00  2023-09-13 11:00:00                 0.0
# 113                  NaN                  NaN                 NaN
#
#      latest_diff_days   batch native_id_db     lat_db      lon_db  elev_db  \
# 0                 NaN  batch2       AtlSch  59.574000 -133.687000    705.0
# 1                 NaN  batch5       AtlSch  59.574000 -133.687000    705.0
# 2               731.0  batch1    Blackhawk  55.078885 -120.352171    962.0
# 3                 NaN  batch5    Blackhawk  55.078885 -120.352171    962.0
# 4               731.0  batch1    Blackhawk  55.078885 -120.352171    962.0
# ..                ...     ...          ...        ...         ...      ...
# 109               NaN  batch5     Thompson  54.333115 -126.099445    869.0
# 110             739.0  batch1     Thompson  54.333115 -126.099445    869.0
# 111               NaN  batch5     Thompson  54.333115 -126.099445    869.0
# 112             739.0  batch1     Thompson  54.333115 -126.099445    869.0
# 113               NaN  batch5     Thompson  54.333115 -126.099445    869.0
#
#     base_variable
# 0            Temp
# 1            Temp
# 2           DewPt
# 3           DewPt
# 4              RH
# ..            ...
# 109         DewPt
# 110            RH
# 111            RH
# 112          Temp
# 113          Temp
#
# [114 rows x 19 columns]

# %% [markdown]
# 2 sensors for the same station variable, the first sensors value has been inserted. Now for more records have only the second sensor or both, I insert them or update them. For the item with only the second sensor, seemes insert successufully. So need to update the values only from one sensor to the mean of two sensors. So I need to update the values of that obs_raw values. Right now I just need to update the obs_raw.

# %%
all_rows = []
data_path = '/workspaces/crmprtd/fern/FERNNorth2025_VF_data'
network_name = "FLNRO-FERN"

stations = dup_items.groupby(['station_name', 'base_variable'])

for (station_name, base_var), group in stations:
    
    print(f"Processing station: {station_name}, variable: {base_var}")

    csv_file_name = group['station_file_name'].iloc[0] + '.csv'
    csv_path = os.path.join(data_path, csv_file_name)
    df_data = pd.read_csv(csv_path, encoding='latin1', low_memory=False)

    time_col = 'Date' if 'Date' in df_data.columns else df_data.columns[0]
    df_data[time_col] = pd.to_datetime(df_data[time_col], errors='coerce')

    unit_raw = group['unit_raw'].iloc[0]
    variable_cols = [f"{v}, {unit_raw}" for v in group['variable'] if f"{v}, {unit_raw}" in df_data.columns]

    if not variable_cols or len(variable_cols) < 2:
        # Skip if only one sensor exists
        print(f"  ⚠ Only one sensor for {base_var}, skipping.")
        continue

    # Compute row-wise mean across sensors
    df_data[variable_cols] = df_data[variable_cols].apply(
        pd.to_numeric,
        errors='coerce'   # non-numeric → NaN
    )
    
    df_data['value'] = df_data[variable_cols].mean(axis=1, skipna=True)

    # Create a column showing which sensors contributed
    def contributing_sensors(row):
        sensors = [col for col in variable_cols if pd.notna(row[col])]
        if len(sensors) > 1:
            return f"mean of {', '.join(sensors)}"
        elif sensors:
            return sensors[0]
        else:
            return None

    df_data['sensor_source'] = df_data.apply(contributing_sensors, axis=1)

    # --- Filter: skip rows that only come from the first sensor ---
    # Assume the first sensor column is variable_cols[0]
    df_data = df_data[~(df_data['sensor_source'] == variable_cols[0])]
    df_data = df_data.dropna(subset=['value']).reset_index(drop=True)

    # --- Check for differences between sensors ---
    # Only consider rows where both sensor values exist
    sensor_diff_rows = df_data.dropna(subset=variable_cols)
    
    # Count how many rows have different values across sensors
    # Use `nunique` row-wise
    sensor_diff_count = (sensor_diff_rows[variable_cols].nunique(axis=1) > 1).sum()
    
    print(f"  🔹 Rows with differing sensor values: {sensor_diff_count} out of {len(sensor_diff_rows)}")

    print(f"{len(df_data)} values from {df_data['sensor_source'].unique()}")

    if df_data.empty:
        print(f"  ⚠ No rows left after skipping first sensor for {base_var}")
        continue

    # --- Build Row objects ---
    for _, row_i in df_data.iterrows():
        all_rows.append(Row(
            time=row_i[time_col],
            val=row_i['value'],
            variable_name=group['db_var_match'].iloc[0],
            unit=group['unit_db'].iloc[0],
            network_name=network_name,
            station_id=group['native_id_db'].iloc[0],
            lat=float(group['lat_db'].iloc[0]),
            lon=float(group['lon_db'].iloc[0])
        ))

all_rows = [r for r in all_rows if not pd.isna(r.time)]
# Out:
# Processing station: Atlin School, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: BlackhawkWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: BlackhawkWx, variable: RH
#   🔹 Rows with differing sensor values: 8900 out of 8903
# 8904 values from ['mean of RH, %, RH 2, %' 'RH 2, %']
# Processing station: BlackhawkWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: BowronPit, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: BowronPit, variable: RH
#   🔹 Rows with differing sensor values: 7770 out of 7774
# 7774 values from ['mean of RH, %, RH 2, %']
# Processing station: BowronPit, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: Canoe Mountain Stn, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: Canoe Mountain Stn, variable: RH
#   🔹 Rows with differing sensor values: 17482 out of 17495
# 17495 values from ['mean of RH, %, RH 2, %']
# Processing station: Canoe Mountain Stn, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: Caribou Pass, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: Caribou Pass, variable: RH
#   🔹 Rows with differing sensor values: 15516 out of 21240
# 21240 values from ['mean of RH, %, RH 2, %']
# Processing station: Caribou Pass, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: ChapmanWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: ChiefLakeWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: ChiefLakeWx, variable: RH
#   🔹 Rows with differing sensor values: 8202 out of 8208
# 8208 values from ['mean of RH, %, RH 2, %']
# Processing station: ChiefLakeWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: CrookedLk, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: CrookedLk, variable: RH
#   🔹 Rows with differing sensor values: 3526 out of 4005
# 4005 values from ['mean of RH, %, RH 2, %']
# Processing station: CrookedLk, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: DunsterWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: DunsterWx, variable: RH
#   🔹 Rows with differing sensor values: 12156 out of 12166
# 12166 values from ['mean of RH, %, RH 2, %']
# Processing station: DunsterWx, variable: Rain
#   🔹 Rows with differing sensor values: 0 out of 0
# 0 values from []
#   ⚠ No rows left after skipping first sensor for Rain
# Processing station: DunsterWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: EndakoWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: EndakoWx, variable: RH
#   🔹 Rows with differing sensor values: 8708 out of 8710
# 8710 values from ['mean of RH, %, RH 2, %']
# Processing station: EndakoWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: GeorgeWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: GeorgeWx, variable: RH
#   🔹 Rows with differing sensor values: 9399 out of 9407
# 9407 values from ['mean of RH, %, RH 2, %']
# Processing station: GeorgeWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: HourglassWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: HourglassWx, variable: RH
#   🔹 Rows with differing sensor values: 8896 out of 8901
# 8902 values from ['mean of RH, %, RH 2, %' 'RH 2, %']
# Processing station: HourglassWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: Hudson Bay Mtn2, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: Hudson Bay Mtn2, variable: RH
#   🔹 Rows with differing sensor values: 8679 out of 8686
# 8686 values from ['mean of RH, %, RH 2, %']
# Processing station: Hudson Bay Mtn2, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: Kluskus, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: Kluskus, variable: RH
#   🔹 Rows with differing sensor values: 15115 out of 16942
# 16944 values from ['mean of RH, %, RH 2, %' 'RH 2, %']
# Processing station: Kluskus, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: NondaWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: NondaWx, variable: RH
#   🔹 Rows with differing sensor values: 24188 out of 32273
# 32280 values from ['mean of RH, %, RH 2, %' 'RH 2, %']
# Processing station: NondaWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: PinkWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: PinkWx, variable: RH
#   🔹 Rows with differing sensor values: 12191 out of 12198
# 12198 values from ['mean of RH, %, RH 2, %']
# Processing station: PinkWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: SaxtonWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: SaxtonWx, variable: RH
#   🔹 Rows with differing sensor values: 49035 out of 60648
# 60648 values from ['mean of RH, %, RH 2, %']
# Processing station: SaxtonWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: SeebachWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: SeebachWx, variable: RH
#   🔹 Rows with differing sensor values: 1125 out of 1631
# 1631 values from ['mean of RH, %, RH 2, %']
# Processing station: SeebachWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: Sunbeam, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: Sunbeam, variable: RH
#   🔹 Rows with differing sensor values: 20129 out of 20254
# 20254 values from ['mean of RH, %, RH 2, %']
# Processing station: Sunbeam, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.
# Processing station: ThompsonWx, variable: DewPt
#   ⚠ Only one sensor for DewPt, skipping.
# Processing station: ThompsonWx, variable: RH
#   🔹 Rows with differing sensor values: 8702 out of 8711
# 8711 values from ['mean of RH, %, RH 2, %']
# Processing station: ThompsonWx, variable: Temp
#   ⚠ Only one sensor for Temp, skipping.

# %%
all_rows
# Out:
# [Row(time=Timestamp('2024-07-18 10:00:00'), val=5.8385, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 11:00:00'), val=6.317, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 12:00:00'), val=6.413, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 13:00:00'), val=7.232, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 14:00:00'), val=6.4125, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 15:00:00'), val=7.4925, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 16:00:00'), val=7.1495, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 17:00:00'), val=7.346500000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 18:00:00'), val=7.473000000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 19:00:00'), val=8.397, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 20:00:00'), val=9.422, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 21:00:00'), val=9.166, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 22:00:00'), val=8.8515, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-18 23:00:00'), val=8.7745, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 00:00:00'), val=8.076, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 01:00:00'), val=7.885999999999999, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 02:00:00'), val=7.895999999999999, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 03:00:00'), val=8.3875, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 04:00:00'), val=8.7555, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 05:00:00'), val=9.994, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 06:00:00'), val=12.334499999999998, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 07:00:00'), val=13.2735, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 08:00:00'), val=12.836500000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 09:00:00'), val=13.3045, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 10:00:00'), val=12.7275, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 11:00:00'), val=13.2685, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 12:00:00'), val=13.5085, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 13:00:00'), val=13.872, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 14:00:00'), val=13.9085, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 15:00:00'), val=13.621500000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 16:00:00'), val=13.592, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 17:00:00'), val=13.663499999999999, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 18:00:00'), val=13.0855, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 19:00:00'), val=13.921, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19 20:00:00'), val=12.529, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-07-19
variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 05:00:00'), val=6.9915, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 06:00:00'), val=5.765000000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 07:00:00'), val=7.473, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 08:00:00'), val=6.9605, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 09:00:00'), val=6.6905, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 10:00:00'), val=6.5085, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 11:00:00'), val=8.511, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 12:00:00'), val=7.885, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 13:00:00'), val=7.771000000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 14:00:00'), val=8.784500000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 15:00:00'), val=8.8295, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 16:00:00'), val=8.762, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 17:00:00'), val=8.2015, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 18:00:00'), val=7.5655, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 19:00:00'), val=7.912, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 20:00:00'), val=7.7515, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 21:00:00'), val=7.604, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 22:00:00'), val=6.058, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-27 23:00:00'), val=7.4675, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 00:00:00'), val=7.728, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 01:00:00'), val=7.592, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 02:00:00'), val=7.525, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 03:00:00'), val=6.099, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 04:00:00'), val=5.298500000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 05:00:00'), val=3.7145, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 06:00:00'), val=2.795, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 07:00:00'), val=8.209, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 08:00:00'), val=7.916, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 09:00:00'), val=7.5605, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 10:00:00'), val=6.9115, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 11:00:00'), val=6.9885, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 12:00:00'), val=7.1930000000000005, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 13:00:00'), val=7.0665, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 14:00:00'), val=6.877000000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 15:00:00'), val=6.758, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 16:00:00'), val=6.503, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 17:00:00'), val=5.898999999999999, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 18:00:00'), val=6.2065, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 19:00:00'), val=6.2835, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 20:00:00'), val=6.877000000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 21:00:00'), val=6.9350000000000005, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 22:00:00'), val=7.319000000000001, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-28 23:00:00'), val=7.619, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-29 00:00:00'), val=7.4719999999999995, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  Row(time=Timestamp('2024-08-29 01:00:00'), val=7.5225, variable_name='RH', unit='%', network_name='FLNRO-FERN', station_id='Blackhawk', lat=55.078885, lon=-120.352171),
#  ...]

# %%
len(all_rows)
# Out:
# 268163

# %%
import math

all_valid = all(
    (r.val is not None) and (not math.isnan(r.val))
    for r in all_rows
)

print(all_valid)
# Out:
# True

# %%
db_url = "postgresql://tongli1997@db.pcic.uvic.ca:5433/crmp?keepalives=1&keepalives_idle=300&keepalives_interval=300&keepalives_count=9&passfile=/workspaces/crmprtd/.pgpass"

safe_insert_rows(
    all_rows,
    log_file_path=output_folder + 'fern_all_station_insert.log',
    db_url=db_url,
    chunk_size=5000,        # SAFE starting point
    bulk_chunk_size=1000,   # internal DB bulk insert size
)
# Out:
# 🚀 Starting insert: 268163 rows in 54 chunks
# ➡️  Processing rows 0–4999
# {"asctime": "2026-02-27 00:39:25,767", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:25,886", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:25,989", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:26,070", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:26,140", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:26,334", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:26,334", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:26,335", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 0–4999
# ➡️  Processing rows 5000–9999
# {"asctime": "2026-02-27 00:39:26,466", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:26,543", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:26,623", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:26,698", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:26,768", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:26,845", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:26,845", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:26,846", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 5000–9999
# ➡️  Processing rows 10000–14999
# {"asctime": "2026-02-27 00:39:26,882", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:26,982", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,066", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,135", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,204", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,273", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,274", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:27,274", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 10000–14999
# ➡️  Processing rows 15000–19999
# {"asctime": "2026-02-27 00:39:27,422", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:27,583", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,673", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,744", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,815", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,885", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:27,885", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:27,886", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 15000–19999
# ➡️  Processing rows 20000–24999
# {"asctime": "2026-02-27 00:39:27,925", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:28,037", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,127", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,200", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,272", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,346", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,346", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:28,347", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 20000–24999
# ➡️  Processing rows 25000–29999
# {"asctime": "2026-02-27 00:39:28,387", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:28,489", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,559", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,631", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,703", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,773", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:28,773", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:28,774", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 25000–29999
# ➡️  Processing rows 30000–34999
# {"asctime": "2026-02-27 00:39:28,987", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:29,064", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,152", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,226", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,293", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,362", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,362", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:29,362", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 30000–34999
# ➡️  Processing rows 35000–39999
# {"asctime": "2026-02-27 00:39:29,400", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:29,507", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,578", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,650", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,721", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,788", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:29,789", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:29,789", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 35000–39999
# ➡️  Processing rows 40000–44999
# {"asctime": "2026-02-27 00:39:29,910", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:30,009", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,097", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,164", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,235", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,302", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,302", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:30,303", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 40000–44999
# ➡️  Processing rows 45000–49999
# {"asctime": "2026-02-27 00:39:30,340", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:30,443", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,525", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,598", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,669", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,741", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,742", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:30,742", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 45000–49999
# ➡️  Processing rows 50000–54999
# {"asctime": "2026-02-27 00:39:30,783", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:30,883", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:30,953", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:31,021", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:31,091", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:31,159", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:31,160", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:31,160", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 50000–54999
# ➡️  Processing rows 55000–59999
# {"asctime": "2026-02-27 00:39:31,363", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:31,433", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:31,522", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:31,590", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:31,662", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:31,733", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:31,733", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:31,734", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 55000–59999
# ➡️  Processing rows 60000–64999
# {"asctime": "2026-02-27 00:39:31,861", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:31,950", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,022", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,101", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,166", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,251", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,252", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:32,252", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 60000–64999
# ➡️  Processing rows 65000–69999
# {"asctime": "2026-02-27 00:39:32,380", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:32,450", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,645", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,733", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,799", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,865", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:32,866", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:32,866", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 65000–69999
# ➡️  Processing rows 70000–74999
# {"asctime": "2026-02-27 00:39:32,896", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:32,996", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:33,088", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:33,154", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:33
"levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:49,647", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:49,720", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:49,789", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:49,856", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:49,857", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:49,857", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 240000–244999
# ➡️  Processing rows 245000–249999
# {"asctime": "2026-02-27 00:39:49,895", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:49,995", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,064", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,132", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,203", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,274", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,275", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:50,275", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 245000–249999
# ➡️  Processing rows 250000–254999
# {"asctime": "2026-02-27 00:39:50,310", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:50,422", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,591", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,657", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,725", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,798", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:50,798", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:50,799", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 250000–254999
# ➡️  Processing rows 255000–259999
# {"asctime": "2026-02-27 00:39:50,917", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:51,005", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,079", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,150", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,222", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,292", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,292", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:51,293", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 255000–259999
# ➡️  Processing rows 260000–264999
# {"asctime": "2026-02-27 00:39:51,331", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:51,443", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,518", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,588", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,656", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,726", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:51,726", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:51,727", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 260000–264999
# ➡️  Processing rows 265000–268162
# {"asctime": "2026-02-27 00:39:51,757", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-27 00:39:51,939", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:52,017", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:52,085", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:52,109", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3163 skipped, 0 failed"}
# {"asctime": "2026-02-27 00:39:52,110", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-27 00:39:52,110", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 265000–268162

# %% [markdown]
# #### batch update

# %%
update_sql = sa.text("""
UPDATE obs_raw AS o
SET datum = :val
FROM meta_history AS m,
     meta_station AS s,
     meta_vars AS v
WHERE o.history_id = m.history_id
  AND m.station_id = s.station_id
  AND o.vars_id = v.vars_id
  AND s.native_id = :station_id
  AND v.net_var_name = :variable_name
  AND o.obs_time = :obs_time
  AND o.datum IS DISTINCT FROM :val
""")

def chunked(lst, size):
    for i in range(0, len(lst), size):
        yield i, lst[i:i + size]

BATCH_SIZE = 3000
total = len(all_rows)

for start, chunk in chunked(all_rows, BATCH_SIZE):
    params = [
        {
            "val": float(r.val),
            "station_id": r.station_id,
            "variable_name": r.variable_name,
            "obs_time": r.time,
        }
        for r in chunk
    ]

    with engine.begin() as conn:
        result = conn.execute(update_sql, params)

    end = min(start + BATCH_SIZE, total)
    print(
        f"Updated batch {start}-{end - 1} "
        f"({result.rowcount} rows updated)"
    )
# Out:
# Updated batch 0-2999 (2976 rows updated)
# Updated batch 3000-5999 (2970 rows updated)
# Updated batch 6000-8999 (2980 rows updated)
# Updated batch 9000-11999 (2973 rows updated)
# Updated batch 12000-14999 (2981 rows updated)
# Updated batch 15000-17999 (2985 rows updated)
# Updated batch 18000-20999 (2986 rows updated)
# Updated batch 21000-23999 (2967 rows updated)
# Updated batch 24000-26999 (2975 rows updated)
# Updated batch 27000-29999 (2966 rows updated)
# Updated batch 30000-32999 (2979 rows updated)
# Updated batch 33000-35999 (2991 rows updated)
# Updated batch 36000-38999 (2989 rows updated)
# Updated batch 39000-41999 (2973 rows updated)
# Updated batch 42000-44999 (2975 rows updated)
# Updated batch 45000-47999 (2963 rows updated)
# Updated batch 48000-50999 (2971 rows updated)
# Updated batch 51000-53999 (2970 rows updated)
# Updated batch 54000-56999 (2966 rows updated)
# Updated batch 57000-59999 (2971 rows updated)
# Updated batch 60000-62999 (2977 rows updated)
# Updated batch 63000-65999 (2975 rows updated)
# Updated batch 66000-68999 (2973 rows updated)
# Updated batch 69000-71999 (2968 rows updated)
