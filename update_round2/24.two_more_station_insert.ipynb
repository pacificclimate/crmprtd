# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sqlalchemy as sa
from sqlalchemy.orm import Session
from crmprtd import setup_logging
from pycds import Station, History
import pandas as pd
import numpy as np

save_path = './comparison_forms/'

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"
log_file_path = save_path

engine = sa.create_engine(db_url, echo=False)
session = Session(engine)

session

# %%
station_name = ['Judge Creek', 'Rithet Creek']

import pandas as pd
from sqlalchemy import text

stations = ['Judge Creek', 'Rithet Creek']

SQL = text("""
    SELECT 
        m.station_name,
        COUNT(o.obs_time) AS n_obs,
        MIN(o.obs_time) AS oldest,
        MAX(o.obs_time) AS newest
    FROM meta_history m
    LEFT JOIN obs_raw o ON o.history_id = m.history_id
    WHERE m.station_name = ANY(:stations)
    GROUP BY m.station_name
""")

with engine.connect() as conn:
    df = pd.read_sql(SQL, conn, params={"stations": stations})

print(df)
# Out:
#    station_name    n_obs              oldest     newest
# 0   Judge Creek  1782308 1994-10-28 15:00:00 2025-01-01
# 1  Rithet Creek  1672856 1995-11-22 00:00:00 2014-03-21

# %%
import pandas as pd
from sqlalchemy import text

stations = ['Judge Creek', 'Rithet Creek']

SQL_network = text("""
    SELECT 
        h.station_name,
        s.native_id,
        s.station_id,
        s.network_id,
        n.network_name,
        h.lat,
        h.lon
    FROM meta_station s
    JOIN meta_history h ON s.station_id = h.station_id
    JOIN meta_network n ON s.network_id = n.network_id
    WHERE h.station_name = ANY(:stations)
""")

with engine.connect() as conn:
    df_station_network = pd.read_sql(
        SQL_network,
        conn,
        params={"stations": stations}
    )

print(df_station_network)

network_ids = df_station_network["network_id"].unique().tolist()

SQL_vars = text("""
    SELECT DISTINCT
        v.*,
        s.network_id
    FROM meta_vars v
    JOIN meta_station s ON v.network_id = s.network_id
    WHERE v.network_id = ANY(:network_ids)
    ORDER BY s.network_id, v.net_var_name
""")

with engine.connect() as conn:
    df_vars = pd.read_sql(
        SQL_vars,
        conn,
        params={"network_ids": network_ids}
    )

    df_vars
# Out:
#    station_name native_id  station_id  network_id network_name        lat  \
# 0  Rithet Creek     FW002       12625          36       CRD-WS  48.567500
# 1   Judge Creek     HY002       12626          36       CRD-WS  48.585278
#
#           lon
# 0 -123.714167
# 1 -123.673611

# %%
SQL_vars = text("""
    SELECT DISTINCT
        v.*
    FROM meta_vars v
    WHERE v.net_var_name = 'WindSpeed'
""")

with engine.connect() as conn:
    df_vars = pd.read_sql(
        SQL_vars,
        conn,
        params={"network_ids": network_ids}
    )

df_vars
# Out:
#    vars_id  network_id   unit precision standard_name  cell_method  \
# 0      745          36    kph      None    wind_speed  time: point
# 1      819           5  m s-1      None    wind_speed   time: mean
#
#   long_description net_var_name       display_name  short_name  \
# 0             None    WindSpeed         Wind Speed        Wspd
# 1       Wind Speed    WindSpeed  Wind Speed (Mean)  Wind Speed
#
#                     mod_time mod_user
# 0 2025-02-11 16:03:39.747374     crmp
# 1 2025-02-11 16:03:39.747374     crmp

# %% [markdown]
# #### Insert variable first

# %%
TMax = dict(
    network_id=36,
    unit='celsius',
    standard_name='air_temperature',
    cell_method='time: maximum',
    description= 'Maximum hourly temperature',
    name='MAX_TEMP_h',
    display_name='Temperature (Max. h)',
    short_name='air_temperature_maximum_h',
)

TMin = dict(
    network_id=36,
    unit='celsius',
    standard_name='air_temperature',
    cell_method='time: minimum',
    description= 'Minimum hourly temperature',
    name='MIN_TEMP_h',
    display_name='Temperature (Min. h)',
    short_name='air_temperature_minimum_h',
)

RhMax = dict(
    network_id=36,
    unit='percent',
    standard_name='relative_humidity',
    cell_method='time: maximum',
    description=None,
    name='RelativeHumidity_Max',
    display_name='Relative Humidity (Max. h)',
    short_name='Rh_Max',
)

RhMin = dict(
    network_id=36,
    unit='percent',
    standard_name='relative_humidity',
    cell_method='time: minimum',
    description=None,
    name='RelativeHumidity_Min',
    display_name='Relative Humidity (Min. h)',
    short_name='Rh_Min',
)

Rn_1 = dict(
    network_id=36,
    unit='mm',
    standard_name='rainfall_amount',
    cell_method='time: sum',
    description= 'Hourly accumulated rainfall',
    name='Rain_h',
    display_name='Hourly Rainfall',
    short_name='Rn_1',
)

WSpd_1 = dict(
    network_id=36,
    unit='kph',
    standard_name='wind_speed',
    cell_method='time: mean',
    description= 'Hourly average wind speed',
    name='WindSpeed_mean',
    display_name='Wind Speed (mean)',
    short_name='Wspd_mean',
)

WSpd_Max = dict(
    network_id=36,
    unit='kph',
    standard_name='wind_speed',
    cell_method='time: maximum',
    description= 'maximum wind speed (gusts) over the last hour',
    name='WindSpeed_Max',
    display_name='Wind Speed (Max. h)',
    short_name='WSpd_Max',
)

variables_data = [TMax, TMin, RhMax, RhMin, Rn_1, WSpd_1, WSpd_Max]

# %%
# from pycds import Variable
# from sqlalchemy.inspection import inspect

# existing = (
#     session.query(Variable)
#     .filter(
#         Variable.network_id == 36,
#         Variable.name.in_([v["name"] for v in variables_data]),
#     )
#     .all()
# )

# existing_names = {v.name for v in existing}

# # Create only the missing ones
# to_insert = [
#     Variable(**v)
#     for v in variables_data
#     if v["name"] not in existing_names
# ]

# session.add_all(to_insert)
# session.commit()

# %% [markdown]
# ### Then insert all the obs records

# %%
df_station_network
# Out:
#    station_name native_id  station_id  network_id network_name        lat  \
# 0  Rithet Creek     FW002       12625          36       CRD-WS  48.567500
# 1   Judge Creek     HY002       12626          36       CRD-WS  48.585278
#
#           lon
# 0 -123.714167
# 1 -123.673611

# %% [markdown]
# ### generate rows

# %%
meta_path = '/workspaces/crmprtd/SSpencerFiles/'

file_names = ['JudgeCreek_raw_MetData_1994-2024.csv', 'RithetCreek_raw_MetData_1995-2014.csv']

import os
import pandas as pd

meta_path = '/workspaces/crmprtd/SSpencerFiles/'
file_names = [
    'JudgeCreek_raw_MetData_1994-2024.csv',
    'RithetCreek_raw_MetData_1995-2014.csv'
]

dfs = []

for file in file_names:
    path = os.path.join(meta_path, file)

    df = pd.read_csv(
        path,
        header=[0, 1]   # read two header rows
    )

    # ---- Combine header levels (e.g. Temp + C → Temp_C)
    df.columns = [
        f"{c1}_{c2}".strip("_")
        for c1, c2 in df.columns
    ]

    df['DateTime_DateTime'] = pd.to_datetime(
        df['DateTime_DateTime'],
        format='%d/%m/%Y %H:%M',
        errors='coerce'
    )


    dfs.append(df)

df_judge = dfs[0]
df_rithet = dfs[1]

# %%
df_judge
# Out:
#        StationName_Unnamed: 0_level_1   DateTime_DateTime  Prec_1_mm   Rh_%  \
# 0                         Judge Creek 1994-10-28 15:00:00        0.0   76.0
# 1                         Judge Creek 1994-10-28 16:00:00        0.0   76.0
# 2                         Judge Creek 1994-10-28 17:00:00        0.0   99.0
# 3                         Judge Creek 1994-10-28 18:00:00        0.0  100.0
# 4                         Judge Creek 1994-10-28 19:00:00        0.0  100.0
# ...                               ...                 ...        ...    ...
# 262970                    Judge Creek 2024-12-31 20:00:00        0.0   98.0
# 262971                    Judge Creek 2024-12-31 21:00:00        0.0   98.0
# 262972                    Judge Creek 2024-12-31 22:00:00        0.0   98.0
# 262973                    Judge Creek 2024-12-31 23:00:00        0.0   98.0
# 262974                    Judge Creek 2025-01-01 00:00:00        0.0   98.0
#
#         RhMax_%  RhMin_%  TMax_C  TMin_C  Temp_C
# 0           NaN      NaN     NaN     NaN     9.5
# 1           NaN      NaN     NaN     NaN     8.1
# 2           NaN      NaN     NaN     NaN     4.1
# 3           NaN      NaN     NaN     NaN     1.6
# 4           NaN      NaN     NaN     NaN     0.6
# ...         ...      ...     ...     ...     ...
# 262970     98.0     98.0     2.5     2.4     2.4
# 262971     98.0     98.0     2.4     2.2     2.2
# 262972     98.0     98.0     2.5     2.2     2.5
# 262973     98.0     98.0     2.6     2.5     2.6
# 262974     98.0     98.0     2.8     2.6     2.8
#
# [262975 rows x 9 columns]

# %%
mapping_id = {
    'Prec_1_mm': 738,
    'Rh_%': 740,
    'RhMax_%': 1397,
    'RhMin_%': 1398,
    'TMax_C': 1395,
    'TMin_C': 1396,
    'Temp_C': 739,
    'Rn_1_mm': 1399,
    'WSpd_Unnamed: 9_level_1': 745,
    'WSpd_1_kph': 1400,
    'Dir_deg': 746,
    'Mx_Spd_kph': 1401
}


from sqlalchemy import text

SQL_vars = text("""
    SELECT v.vars_id, v.net_var_name, v.unit
    FROM meta_vars v
    WHERE v.vars_id IN :vars_ids
""")

vars_ids = tuple(mapping_id.values())

with engine.connect() as conn:
    df_vars = pd.read_sql(
        SQL_vars,
        conn,
        params={"vars_ids": vars_ids}
    )

df_mapping = pd.DataFrame(
    list(mapping_id.items()),
    columns=["var_name_raw", "vars_id"]
)

df_var = df_mapping.merge(df_vars, on="vars_id", how="left")

df_var
# Out:
#                var_name_raw  vars_id          net_var_name     unit
# 0                 Prec_1_mm      738         Precipitation       mm
# 1                      Rh_%      740      RelativeHumidity  percent
# 2                   RhMax_%     1397  RelativeHumidity_Max  percent
# 3                   RhMin_%     1398  RelativeHumidity_Min  percent
# 4                    TMax_C     1395            MAX_TEMP_h  celsius
# 5                    TMin_C     1396            MIN_TEMP_h  celsius
# 6                    Temp_C      739        AirTemperature  celsius
# 7                   Rn_1_mm     1399                Rain_h       mm
# 8   WSpd_Unnamed: 9_level_1      745             WindSpeed      kph
# 9                WSpd_1_kph     1400        WindSpeed_mean      kph
# 10                  Dir_deg      746         WindDirection  degrees
# 11               Mx_Spd_kph     1401         WindSpeed_Max      kph

# %%
# Out:
#    station_name native_id  station_id  network_id network_name      lat  \
# 0  Rithet Creek     FW002       12625          36       CRD-WS  48.5675
#
#           lon
# 0 -123.714167

# %%
df_rithet
# Out:
#        StationName_Unnamed: 0_level_1   DateTime_DateTime  TMax_C  TMin_C  \
# 0                    FWx Rithet Creek 1995-11-22 00:00:00     NaN     NaN
# 1                    FWx Rithet Creek 1995-11-22 01:00:00     NaN     NaN
# 2                    FWx Rithet Creek 1995-11-22 02:00:00     NaN     NaN
# 3                    FWx Rithet Creek 1995-11-22 03:00:00     NaN     NaN
# 4                    FWx Rithet Creek 1995-11-22 04:00:00     NaN     NaN
# ...                               ...                 ...     ...     ...
# 160630               FWx Rithet Creek 2014-03-20 20:00:00     2.4     1.4
# 160631               FWx Rithet Creek 2014-03-20 21:00:00     1.4     0.6
# 160632               FWx Rithet Creek 2014-03-20 22:00:00     0.6    -0.5
# 160633               FWx Rithet Creek 2014-03-20 23:00:00    -0.5    -1.4
# 160634               FWx Rithet Creek 2014-03-21 00:00:00    -1.3    -1.6
#
#         Temp_C  RhMax_%  RhMin_%  Rh_%  Rn_1_mm  WSpd_Unnamed: 9_level_1  \
# 0          NaN      0.0      0.0   0.0      0.0                      1.8
# 1          NaN      0.0      0.0   0.0      0.0                      1.8
# 2          NaN      0.0      0.0   0.0      0.3                      3.2
# 3          NaN      0.0      0.0   0.0      0.0                      5.3
# 4          NaN      0.0      0.0   0.0      0.0                      3.4
# ...        ...      ...      ...   ...      ...                      ...
# 160630     1.4     94.0     89.0  94.0      0.0                      0.0
# 160631     0.6     94.0     93.0  94.0      0.0                      0.0
# 160632    -0.5     95.0     94.0  95.0      0.0                      0.0
# 160633    -1.4     95.0     95.0  95.0      0.0                      0.0
# 160634    -1.3     96.0     95.0  96.0      0.0                      0.0
#
#         WSpd_1_kph  Dir_deg  Mx_Spd_kph
# 0              NaN    333.0         5.0
# 1              NaN    323.0         3.3
# 2              NaN    164.0         5.6
# 3              NaN    356.0         9.0
# 4              NaN      6.0         5.0
# ...            ...      ...         ...
# 160630         0.0      2.0         0.0
# 160631         0.0     23.0         0.0
# 160632         0.0     16.0         0.0
# 160633         0.0      4.0         0.0
# 160634         0.0    353.0         0.0
#
# [160635 rows x 13 columns]

# %%
df_var
# Out:
#                var_name_raw  vars_id          net_var_name     unit
# 0                 Prec_1_mm      738         Precipitation       mm
# 1                      Rh_%      740      RelativeHumidity  percent
# 2                   RhMax_%     1397  RelativeHumidity_Max  percent
# 3                   RhMin_%     1398  RelativeHumidity_Min  percent
# 4                    TMax_C     1395            MAX_TEMP_h  celsius
# 5                    TMin_C     1396            MIN_TEMP_h  celsius
# 6                    Temp_C      739        AirTemperature  celsius
# 7                   Rn_1_mm     1399                Rain_h       mm
# 8   WSpd_Unnamed: 9_level_1      745             WindSpeed      kph
# 9                WSpd_1_kph     1400        WindSpeed_mean      kph
# 10                  Dir_deg      746         WindDirection  degrees
# 11               Mx_Spd_kph     1401         WindSpeed_Max      kph

# %%
from crmprtd import Row

### for the station Rithet Creek

df_station_1 = df_station_network.loc[
    df_station_network['station_name'] == 'Rithet Creek'
]

time_col = df_rithet['DateTime_DateTime']
variable_name = df_var['var_name_raw']
variable_name_db = df_var['net_var_name']
unit_db = df_var['unit']
network_name = df_station_1['network_name']
native_id = df_station_1['native_id']
lat = float(df_station_1['lat'].iloc[0])
lon = float(df_station_1['lon'].iloc[0])

time_col
variable_name


all_rows = []

# station metadata (extract scalar values!)
network_name = df_station_1['network_name'].iloc[0]
native_id = df_station_1['native_id'].iloc[0]
lat = df_station_1['lat'].iloc[0]
lon = df_station_1['lon'].iloc[0]

# loop over each time row
for _, row_i in df_rithet.iterrows():
    
    time_value = row_i['DateTime_DateTime']
    
    # loop over each variable mapping
    for _, var_row in df_var.iterrows():
        
        raw_name = var_row['var_name_raw']
        db_name = var_row['net_var_name']
        unit_db = var_row['unit']
        
        val = row_i.get(raw_name)
        
        if pd.notna(val):   # optional: skip NaNs
            all_rows.append(
                Row(
                    time=time_value,
                    val=val,
                    variable_name=db_name,
                    unit=unit_db,
                    network_name=network_name,
                    station_id=native_id,
                    lat=lat,
                    lon=lon
                )
            )

# %%
import sys
sys.path.append("/workspaces/crmprtd/fern/FERNNorth2025_insert")

from auto_insert_func import *

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"

output_folder = '/workspaces/crmprtd/update_round2/output_tables/'

statin_name = df_station_1['station_name']


safe_insert_rows(
    all_rows,
    log_file_path=output_folder + str(statin_name) +'insert.log',
    db_url=db_url,
    chunk_size=5000,        # SAFE starting point
    bulk_chunk_size=1000,   # internal DB bulk insert size
)
# Out:
# 🚀 Starting insert: 1672856 rows in 335 chunks
# ➡️  Processing rows 0–4999
# {"asctime": "2026-02-20 19:11:20,154", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:20,468", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 965 inserted, 35 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:20,793", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1965 inserted, 35 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:21,108", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2965 inserted, 35 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:21,426", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3965 inserted, 35 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:21,743", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4965 inserted, 35 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:21,744", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 4965"}
# {"asctime": "2026-02-20 19:11:21,745", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 0–4999
# ➡️  Processing rows 5000–9999
# {"asctime": "2026-02-20 19:11:21,800", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:22,131", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:22,444", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:22,776", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:23,090", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:23,407", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:23,409", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:23,410", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 5000–9999
# ➡️  Processing rows 10000–14999
# {"asctime": "2026-02-20 19:11:23,474", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:23,798", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:24,111", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:24,424", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:24,739", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:25,057", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:25,059", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:25,060", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 10000–14999
# ➡️  Processing rows 15000–19999
# {"asctime": "2026-02-20 19:11:25,121", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:25,490", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:25,811", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:26,127", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:26,443", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:26,761", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:26,764", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:26,765", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 15000–19999
# ➡️  Processing rows 20000–24999
# {"asctime": "2026-02-20 19:11:26,834", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:27,164", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:27,487", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:27,807", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:28,108", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:28,454", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:28,460", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:28,466", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 20000–24999
# ➡️  Processing rows 25000–29999
# {"asctime": "2026-02-20 19:11:28,533", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:28,863", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:29,178", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:29,472", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:29,775", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:30,090", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:30,091", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:30,092", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 25000–29999
# ➡️  Processing rows 30000–34999
# {"asctime": "2026-02-20 19:11:30,152", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:30,767", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:31,093", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:31,413", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:31,765", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:32,085", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:32,086", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:32,087", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 30000–34999
# ➡️  Processing rows 35000–39999
# {"asctime": "2026-02-20 19:11:32,149", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:32,488", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:32,799", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:33,113", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:33,425", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:33,733", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:33,734", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:33,735", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 35000–39999
# ➡️  Processing rows 40000–44999
# {"asctime": "2026-02-20 19:11:33,792", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:34,119", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:34,470", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:34,785", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:35,098", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:35,409", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:35,410", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:35,411", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 40000–44999
# ➡️  Processing rows 45000–49999
# {"asctime": "2026-02-20 19:11:35,472", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:35,794", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:36,087", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:36,393", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:36,727", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:37,029", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:37,030", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:37,032", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 45000–49999
# ➡️  Processing rows 50000–54999
# {"asctime": "2026-02-20 19:11:37,087", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:37,419", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:37,721", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:38,030", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:38,342", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:38,660", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:38,662", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:38,663", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 50000–54999
# ➡️  Processing rows 55000–59999
# {"asctime": "2026-02-20 19:11:38,721", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:39,045", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:39,386", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:39,706", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:40,025", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:40,338", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:40,339", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:40,340", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 55000–59999
# ➡️  Processing rows 60000–64999
# {"asctime": "2026-02-20 19:11:40,399", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:40,726", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:41,048", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:41,379", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:41,707", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:42,061", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:42,062", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:42,062", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 60000–64999
# ➡️  Processing rows 65000–69999
# {"asctime": "2026-02-20 19:11:42,113", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:42,451", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:42,787", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:43,112", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:43,440", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:43,768", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:43,769", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:43,770", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 65000–69999
# ➡️  Processing rows 70000–74999
# {"asctime": "2026-02-20 19:11:43,827", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:44,357", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:44,723", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:45,026", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:45,315", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:45,616", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:45,618", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:45,619", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 70000–74999
# ➡️  Processing rows 75000–79999
# {"asctime": "2026-02-20 19:11:45,675", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:46,005", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:46,315", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:46,620", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:46,934", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:47,315", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:47,317", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:47,319", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 75000–79999
# ➡️  Processing rows 80000–84999
# {"asctime": "2026-02-20 19:11:47,385", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:47,701", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:48,011", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:48,321", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:48,643", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:48,951", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:48,952", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:48,953", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 80000–84999
# ➡️  Processing rows 85000–89999
# {"asctime": "2026-02-20 19:11:49,015", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:49,344", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:49,655", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:50,042", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:50,354", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:50,647", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:50,648", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:50,649", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 85000–89999
# ➡️  Processing rows 90000–94999
# {"asctime": "2026-02-20 19:11:50,712", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:51,036", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:51,361", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:51,675", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:51,986", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:52,296", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:52,298", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:52,300", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 90000–94999
# ➡️  Processing rows 95000–99999
# {"asctime": "2026-02-20 19:11:52,361", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:52,684", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:53,069", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:53,387", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:53,696", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:54,005", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:54,006", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:54,007", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 95000–99999
# ➡️  Processing rows 100000–104999
# {"asctime": "2026-02-20 19:11:54,071", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:54,396", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:54,710", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:55,022", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:55,330", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:55,639", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:55,640", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:55,641", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 100000–104999
# ➡️  Processing rows 105000–109999
# {"asctime": "2026-02-20 19:11:55,698", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:56,017", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:56,322", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:56,635", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:56,952", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:57,265", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:57,267", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:57,268", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 105000–109999
# ➡️  Processing rows 110000–114999
# {"asctime": "2026-02-20 19:11:57,493", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:57,815", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:58,128", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:58,439", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:58,799", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:59,093", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:59,094", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:11:59,095", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 110000–114999
# ➡️  Processing rows 115000–119999
# {"asctime": "2026-02-20 19:11:59,130", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:11:59,448", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:11:59,733", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:00,033", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:00,340", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:00,636", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:00,637", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:00,637", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 115000–119999
# ➡️  Processing rows 120000–124999
# {"asctime": "2026-02-20 19:12:00,700", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:01,029", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:01,324", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:01,688", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:01,990", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:02,294", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:02,295", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:02,296", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 120000–124999
# ➡️  Processing rows 125000–129999
# {"asctime": "2026-02-20 19:12:02,340", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:02,667", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:02,976", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:03,285", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:03,593", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:03,954", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:03,957", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:03,958", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 125000–129999
# ➡️  Processing rows 130000–134999
# {"asctime": "2026-02-20 19:12:04,010", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:04,323", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:04,630", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:04,933", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:05,230", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:05,554", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:05,556", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:05,557", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 130000–134999
# ➡️  Processing rows 135000–139999
# {"asctime": "2026-02-20 19:12:05,622", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:05,970", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:06,279", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:06,645", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:06,963", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:07,273", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:07,275", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:07,276", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 135000–139999
# ➡️  Processing rows 140000–144999
# {"asctime": "2026-02-20 19:12:07,344", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:07,669", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:07,987", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:08,303", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:08,622", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:08,941", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:08,942", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:08,943", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 140000–144999
# ➡️  Processing rows 145000–149999
# {"asctime": "2026-02-20 19:12:09,002", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:09,382", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:09,706", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:10,015", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:10,329", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:10,642", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:10,643", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:10,644", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 145000–149999
# ➡️  Processing rows 150000–154999
# {"asctime": "2026-02-20 19:12:10,905", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:11,219", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:11,542", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:11,901", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:12,219", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:12,538", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:12,539", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:12,540", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 150000–154999
# ➡️  Processing rows 155000–159999
# {"asctime": "2026-02-20 19:12:12,604", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:12,931", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:13,248", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:13,567", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:13,889", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:14,196", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:14,198", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:14,198", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 155000–159999
# ➡️  Processing rows 160000–164999
# {"asctime": "2026-02-20 19:12:14,237", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:14,613", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:14,909", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:15,215", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:15,521", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:15,819", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:15,820", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:15,821", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 160000–164999
# ➡️  Processing rows 165000–169999
# {"asctime": "2026-02-20 19:12:15,880", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:16,203", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:16,525", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:16,832", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:17,204", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:17,522", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:17,524", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:17,525", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 165000–169999
# ➡️  Processing rows 170000–174999
# {"asctime": "2026-02-20 19:12:17,583", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:17,912", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:18,224", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:18,533", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:18,843", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:19,163", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:19,165", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:19,167", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 170000–174999
# ➡️  Processing rows 175000–179999
# {"asctime": "2026-02-20 19:12:19,228", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:19,608", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:19,935", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:20,250", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:20,566", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:20,877", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:20,879", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:20,880", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 175000–179999
# ➡️  Processing rows 180000–184999
# {"asctime": "2026-02-20 19:12:20,941", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:21,264", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:21,585", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:21,896", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:22,272", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:22,595", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:22,596", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:22,597", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 180000–184999
# ➡️  Processing rows 185000–189999
# {"asctime": "2026-02-20 19:12:22,670", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:23,001", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:23,306", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:23,615", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:23,911", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:24,217", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:24,219", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:12:24,220", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 185000–189999
# ➡️  Processing rows 190000–194999
# {"asctime": "2026-02-20 19:12:24,452", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:12:24,767", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:25,136", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:25,448", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:12:25,766", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# ...
# ✅ Inserted rows 1605000–1609999
# ➡️  Processing rows 1610000–1614999
# {"asctime": "2026-02-20 19:20:39,528", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:39,902", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:40,274", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:40,626", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:40,958", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:41,279", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:41,281", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:41,282", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1610000–1614999
# ➡️  Processing rows 1615000–1619999
# {"asctime": "2026-02-20 19:20:41,333", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:41,687", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:42,016", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:42,378", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:42,717", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:43,083", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:43,086", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:43,087", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1615000–1619999
# ➡️  Processing rows 1620000–1624999
# {"asctime": "2026-02-20 19:20:43,153", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:43,517", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:43,865", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:44,198", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:44,541", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:44,886", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:44,887", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:44,888", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1620000–1624999
# ➡️  Processing rows 1625000–1629999
# {"asctime": "2026-02-20 19:20:44,947", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:45,562", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:45,879", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:46,249", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:46,596", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:46,939", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:46,941", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:46,942", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1625000–1629999
# ➡️  Processing rows 1630000–1634999
# {"asctime": "2026-02-20 19:20:47,003", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:47,349", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:47,686", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:48,017", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:48,378", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:48,703", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:48,704", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:48,705", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1630000–1634999
# ➡️  Processing rows 1635000–1639999
# {"asctime": "2026-02-20 19:20:48,767", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:49,134", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:49,483", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:49,836", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:50,179", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:50,524", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:50,525", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:50,526", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1635000–1639999
# ➡️  Processing rows 1640000–1644999
# {"asctime": "2026-02-20 19:20:50,586", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:50,943", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:51,298", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:51,649", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:51,988", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:52,363", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:52,366", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:52,367", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1640000–1644999
# ➡️  Processing rows 1645000–1649999
# {"asctime": "2026-02-20 19:20:52,429", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:52,788", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:53,126", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:53,459", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:53,780", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:54,107", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:54,108", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:54,109", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1645000–1649999
# ➡️  Processing rows 1650000–1654999
# {"asctime": "2026-02-20 19:20:54,148", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:54,510", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:54,852", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:55,241", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:55,566", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:55,897", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:55,899", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:55,900", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1650000–1654999
# ➡️  Processing rows 1655000–1659999
# {"asctime": "2026-02-20 19:20:55,964", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:56,298", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:56,614", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:56,939", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:57,296", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:57,658", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:57,660", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:57,661", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1655000–1659999
# ➡️  Processing rows 1660000–1664999
# {"asctime": "2026-02-20 19:20:57,722", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:58,082", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:58,480", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:58,805", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:59,129", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:59,445", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:20:59,447", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:20:59,448", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1660000–1664999
# ➡️  Processing rows 1665000–1669999
# {"asctime": "2026-02-20 19:20:59,512", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:20:59,857", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:21:00,364", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:21:00,683", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:21:00,978", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:21:01,335", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:21:01,338", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:21:01,339", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1665000–1669999
# ➡️  Processing rows 1670000–1672855
# {"asctime": "2026-02-20 19:21:01,376", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:21:01,753", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:21:02,114", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:21:02,400", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2856 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:21:02,400", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 2856"}
# {"asctime": "2026-02-20 19:21:02,401", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1670000–1672855

# %% [markdown]
# ### For the second station

# %%
from crmprtd import Row

### for the station Rithet Creek

df_station_2 = df_station_network.loc[
    df_station_network['station_name'] == 'Judge Creek'
]

time_col = df_judge['DateTime_DateTime']
variable_name = df_var['var_name_raw']
variable_name_db = df_var['net_var_name']
unit_db = df_var['unit']
network_name = df_station_2['network_name']
native_id = df_station_2['native_id']
lat = float(df_station_2['lat'].iloc[0])
lon = float(df_station_2['lon'].iloc[0])

time_col
variable_name


all_rows = []

# station metadata (extract scalar values!)
network_name = df_station_2['network_name'].iloc[0]
native_id = df_station_2['native_id'].iloc[0]
lat = df_station_2['lat'].iloc[0]
lon = df_station_2['lon'].iloc[0]

# loop over each time row
for _, row_i in df_judge.iterrows():
    
    time_value = row_i['DateTime_DateTime']
    
    # loop over each variable mapping
    for _, var_row in df_var.iterrows():
        
        raw_name = var_row['var_name_raw']
        db_name = var_row['net_var_name']
        unit_db = var_row['unit']
        
        val = row_i.get(raw_name)
        
        if pd.notna(val):   # optional: skip NaNs
            all_rows.append(
                Row(
                    time=time_value,
                    val=val,
                    variable_name=db_name,
                    unit=unit_db,
                    network_name=network_name,
                    station_id=native_id,
                    lat=lat,
                    lon=lon
                )
            )

# %%
all_rows
# Out:
# [Row(time=Timestamp('1994-10-28 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 15:00:00'), val=76.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 15:00:00'), val=9.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 16:00:00'), val=76.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 16:00:00'), val=8.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 17:00:00'), val=99.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 17:00:00'), val=4.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 18:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 18:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 18:00:00'), val=1.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 19:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 19:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 19:00:00'), val=0.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 20:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 20:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 20:00:00'), val=1.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 21:00:00'), val=1.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 22:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 22:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 22:00:00'), val=0.4, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 23:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 23:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 23:00:00'), val=-0.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 00:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 00:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 00:00:00'), val=-0.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 01:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 01:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 01:00:00'), val=-1.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 02:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 02:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 02:00:00'), val=-1.3, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 03:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 03:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 03:00:00'), val=-0.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 04:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 04:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 04:00:00'), val=-0.3, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 05:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 05:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 05:00:00'), val=-0.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 06:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 06:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 06:00:00'), val=-0.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 07:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 07:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 07:00:00'), val=-0.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 08:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 08:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 08:00:00'), val=0.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 09:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 09:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 09:00:00'), val=2.0, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 10:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 10:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 10:00:00'), val=5.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 11:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 11:00:00'), val=96.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 11:00:00'), val=7.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 12:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 12:00:00'), val=80.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 12:00:00'), val=9.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 13:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 13:00:00'), val=77.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 13:00:00'), val=9.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 14:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 14:00:00'), val=77.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 14:00:00'), val=9.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 15:00:00'), val=80.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 15:00:00'), val=8.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 16:00:00'), val=85.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 16:00:00'), val=7.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 17:00:00'), val=97.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 17:00:00'), val=6.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 18:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 18:00:00'), val=99.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 18:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 19:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 19:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 19:00:00'), val=5.4, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 20:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 20:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 20:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 21:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 21:00:00'), val=5.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 22:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 22:00:00'), val=99.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 22:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 23:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 23:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 23:00:00'), val=5.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 00:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 00:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 00:00:00'), val=5.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 01:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 01:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 01:00:00'), val=5.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 02:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 02:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 02:00:00'), val=3.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 03:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 03:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 03:00:00'), val=2.3, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 04:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 04:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 04:00:00'), val=1.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 05:00:00'), val=-1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 05:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 05:00:00'), val=-0.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 06:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 06:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 06:00:00'), val=-0.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 07:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 07:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 07:00:00'), val=-0.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 08:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 08:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 08:00:00'), val=0.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 09:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 09:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 09:00:00'), val=2.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 10:00:00'), val=-1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 10:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 10:00:00'), val=5.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 11:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 11:00:00'), val=91.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 11:00:00'), val=8.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 12:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 12:00:00'), val=95.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 12:00:00'), val=7.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 13:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 13:00:00'), val=88.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 13:00:00'), val=8.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 14:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 14:00:00'), val=88.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 14:00:00'), val=8.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 15:00:00'), val=88.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 15:00:00'), val=8.3, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 16:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 16:00:00'), val=7.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 17:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 17:00:00'), val=6.0, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 18:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 18:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 18:00:00'), val=5.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 19:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 19:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 19:00:00'), val=4.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 20:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 20:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 20:00:00'), val=4.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 21:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 21:00:00'), val=5.0, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 22:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 22:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 22:00:00'), val=5.3, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 23:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 23:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 23:00:00'), val=6.0, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 00:00:00'), val=4.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 00:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 00:00:00'), val=5.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 01:00:00'), val=3.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 01:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 01:00:00'), val=5.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 02:00:00'), val=5.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 02:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 02:00:00'), val=5.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 03:00:00'), val=5.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 03:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 03:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 04:00:00'), val=5.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 04:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 04:00:00'), val=5.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 05:00:00'), val=6.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 05:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 05:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 06:00:00'), val=4.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 06:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 06:00:00'), val=5.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 07:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 07:00:00'), val=91.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 07:00:00'), val=10.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 08:00:00'), val=-1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 08:00:00'), val=90.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 08:00:00'), val=9.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 09:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 09:00:00'), val=90.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 09:00:00'), val=8.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 10:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 10:00:00'), val=87.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 10:00:00'), val=8.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 11:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 11:00:00'), val=86.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 11:00:00'), val=8.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 12:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 12:00:00'), val=93.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 12:00:00'), val=7.5, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 13:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 13:00:00'), val=85.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 13:00:00'), val=8.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 14:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 14:00:00'), val=93.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 14:00:00'), val=7.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 15:00:00'), val=94.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 15:00:00'), val=7.4, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 16:00:00'), val=84.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 16:00:00'), val=7.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 17:00:00'), val=77.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 17:00:00'), val=7.3, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 18:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 18:00:00'), val=77.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 18:00:00'), val=7.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 19:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 19:00:00'), val=86.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 19:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 20:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 20:00:00'), val=89.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 20:00:00'), val=5.3, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 21:00:00'), val=-1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 21:00:00'), val=3.0, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 22:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 22:00:00'), val=83.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 22:00:00'), val=5.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
# ...
#  Row(time=Timestamp('1994-11-10 10:00:00'), val=87.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 10:00:00'), val=3.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 11:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 11:00:00'), val=97.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 11:00:00'), val=7.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 12:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 12:00:00'), val=91.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 12:00:00'), val=7.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 13:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 13:00:00'), val=80.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 13:00:00'), val=9.7, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 14:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 14:00:00'), val=93.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 14:00:00'), val=8.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 15:00:00'), val=99.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 15:00:00'), val=7.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 16:00:00'), val=97.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 16:00:00'), val=6.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 17:00:00'), val=98.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 17:00:00'), val=6.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 18:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 18:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 18:00:00'), val=5.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 19:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 19:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 19:00:00'), val=5.3, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 20:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 20:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 20:00:00'), val=5.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 21:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 21:00:00'), val=4.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 22:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 22:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 22:00:00'), val=5.0, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 23:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 23:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 23:00:00'), val=5.0, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 00:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 00:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 00:00:00'), val=4.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 01:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 01:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 01:00:00'), val=4.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 02:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 02:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 02:00:00'), val=4.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 03:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 03:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 03:00:00'), val=4.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 04:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 04:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 04:00:00'), val=4.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 05:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 05:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 05:00:00'), val=4.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 06:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 06:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 06:00:00'), val=4.9, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 07:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 07:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 07:00:00'), val=5.0, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 08:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 08:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 08:00:00'), val=5.1, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 09:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 09:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 09:00:00'), val=5.8, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 10:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 10:00:00'), val=96.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 10:00:00'), val=6.3, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 11:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 11:00:00'), val=96.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 11:00:00'), val=6.2, variable_name='AirTemperature', unit='celsius', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 12:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 12:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD-WS', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  ...]

# %%
import sys
sys.path.append("/workspaces/crmprtd/fern/FERNNorth2025_insert")

from auto_insert_func import *

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"

output_folder = '/workspaces/crmprtd/update_round2/output_tables/'

statin_name = df_station_2['station_name']


safe_insert_rows(
    all_rows,
    log_file_path=output_folder + str(statin_name) +'insert.log',
    db_url=db_url,
    chunk_size=5000,        # SAFE starting point
    bulk_chunk_size=1000,   # internal DB bulk insert size
)
# Out:
# 🚀 Starting insert: 1782308 rows in 357 chunks
# ➡️  Processing rows 0–4999
# {"asctime": "2026-02-20 19:24:22,607", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:22,927", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:23,278", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:23,599", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:23,917", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:24,234", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:24,235", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:24,236", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 0–4999
# ➡️  Processing rows 5000–9999
# {"asctime": "2026-02-20 19:24:24,295", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:24,624", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:24,973", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:25,289", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:25,592", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:25,916", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:25,918", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:25,919", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 5000–9999
# ➡️  Processing rows 10000–14999
# {"asctime": "2026-02-20 19:24:25,977", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:26,315", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:26,667", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:26,990", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:27,306", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:27,640", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:27,641", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:27,642", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 10000–14999
# ➡️  Processing rows 15000–19999
# {"asctime": "2026-02-20 19:24:27,699", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:28,058", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:28,596", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:28,921", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:29,249", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:29,561", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:29,563", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:29,564", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 15000–19999
# ➡️  Processing rows 20000–24999
# {"asctime": "2026-02-20 19:24:29,624", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:30,000", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:30,335", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:30,650", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:30,965", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:31,308", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:31,310", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:31,311", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 20000–24999
# ➡️  Processing rows 25000–29999
# {"asctime": "2026-02-20 19:24:31,347", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:31,680", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:31,997", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:32,309", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:32,623", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:32,971", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:32,974", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:32,975", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 25000–29999
# ➡️  Processing rows 30000–34999
# {"asctime": "2026-02-20 19:24:33,032", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:33,364", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:33,678", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:34,001", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:34,311", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:34,627", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:34,628", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:34,628", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 30000–34999
# ➡️  Processing rows 35000–39999
# {"asctime": "2026-02-20 19:24:34,670", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:34,993", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:35,373", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:35,680", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:35,994", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:36,314", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:36,316", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:36,317", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 35000–39999
# ➡️  Processing rows 40000–44999
# {"asctime": "2026-02-20 19:24:36,376", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:36,706", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:37,021", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:37,339", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:37,642", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:37,978", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:37,981", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:37,982", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 40000–44999
# ➡️  Processing rows 45000–49999
# {"asctime": "2026-02-20 19:24:38,045", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:38,366", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:38,694", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:39,005", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:39,319", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:39,626", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:39,627", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:39,628", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 45000–49999
# ➡️  Processing rows 50000–54999
# {"asctime": "2026-02-20 19:24:39,684", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:40,011", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:40,326", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:40,658", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:40,977", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:41,291", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:41,294", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:41,295", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 50000–54999
# ➡️  Processing rows 55000–59999
# {"asctime": "2026-02-20 19:24:41,351", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:41,671", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:41,989", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:42,305", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:42,616", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:42,958", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:42,961", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:42,962", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 55000–59999
# ➡️  Processing rows 60000–64999
# {"asctime": "2026-02-20 19:24:43,024", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:43,353", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:43,669", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:43,988", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:44,300", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:44,614", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:44,616", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:44,617", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 60000–64999
# ➡️  Processing rows 65000–69999
# {"asctime": "2026-02-20 19:24:44,876", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:45,195", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:45,541", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:45,845", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:46,142", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:46,459", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:46,460", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:46,461", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 65000–69999
# ➡️  Processing rows 70000–74999
# {"asctime": "2026-02-20 19:24:46,520", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:46,854", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:47,176", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:47,518", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:47,844", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:48,161", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:48,164", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:48,166", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 70000–74999
# ➡️  Processing rows 75000–79999
# {"asctime": "2026-02-20 19:24:48,226", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:48,546", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:48,865", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:49,174", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:49,490", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:49,824", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:49,825", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:49,825", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 75000–79999
# ➡️  Processing rows 80000–84999
# {"asctime": "2026-02-20 19:24:49,872", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:50,196", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:50,514", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:50,818", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:51,122", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:51,435", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:51,435", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:51,436", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 80000–84999
# ➡️  Processing rows 85000–89999
# {"asctime": "2026-02-20 19:24:51,480", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:51,798", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:52,141", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:52,457", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:52,763", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:53,078", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:53,080", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:53,081", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 85000–89999
# ➡️  Processing rows 90000–94999
# {"asctime": "2026-02-20 19:24:53,139", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:53,465", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:53,772", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:54,079", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:54,415", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:54,728", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:54,730", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:54,731", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 90000–94999
# ➡️  Processing rows 95000–99999
# {"asctime": "2026-02-20 19:24:54,790", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:55,103", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:55,398", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:55,710", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:56,030", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:56,339", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:56,340", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:56,341", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 95000–99999
# ➡️  Processing rows 100000–104999
# {"asctime": "2026-02-20 19:24:56,391", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:56,721", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:57,056", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:57,370", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:57,680", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:57,987", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:57,989", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:57,990", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 100000–104999
# ➡️  Processing rows 105000–109999
# {"asctime": "2026-02-20 19:24:58,048", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:24:58,367", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:58,668", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:58,981", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:59,293", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:59,640", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:24:59,642", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:24:59,644", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 105000–109999
# ➡️  Processing rows 110000–114999
# {"asctime": "2026-02-20 19:24:59,705", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:00,253", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:00,568", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:00,863", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:01,160", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:01,481", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:01,483", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:01,484", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 110000–114999
# ➡️  Processing rows 115000–119999
# {"asctime": "2026-02-20 19:25:01,544", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:01,876", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:02,221", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:02,536", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:02,845", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:03,171", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:03,173", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:03,174", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 115000–119999
# ➡️  Processing rows 120000–124999
# {"asctime": "2026-02-20 19:25:03,234", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:03,558", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:03,866", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:04,211", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:04,530", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:04,848", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:04,849", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:04,850", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 120000–124999
# ➡️  Processing rows 125000–129999
# {"asctime": "2026-02-20 19:25:04,889", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:05,200", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:05,484", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:05,807", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:06,118", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:06,461", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:06,464", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:06,465", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 125000–129999
# ➡️  Processing rows 130000–134999
# {"asctime": "2026-02-20 19:25:06,527", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:06,855", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:07,171", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:07,485", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:07,794", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:08,099", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:08,100", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:08,101", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 130000–134999
# ➡️  Processing rows 135000–139999
# {"asctime": "2026-02-20 19:25:08,156", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:08,487", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:08,831", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:09,154", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:09,468", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:09,788", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:09,790", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:09,791", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 135000–139999
# ➡️  Processing rows 140000–144999
# {"asctime": "2026-02-20 19:25:09,849", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:10,176", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:10,494", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:10,825", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:11,129", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:11,442", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:11,443", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:11,444", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 140000–144999
# ➡️  Processing rows 145000–149999
# {"asctime": "2026-02-20 19:25:11,510", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:11,835", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:12,152", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:12,467", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:12,767", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:13,109", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:13,112", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:13,113", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 145000–149999
# ➡️  Processing rows 150000–154999
# {"asctime": "2026-02-20 19:25:13,172", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:13,501", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:13,819", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:14,138", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:14,453", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:14,765", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:14,767", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:14,768", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 150000–154999
# ➡️  Processing rows 155000–159999
# {"asctime": "2026-02-20 19:25:14,827", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:15,181", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:15,508", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:15,817", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:16,111", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:16,611", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:16,612", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:16,613", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 155000–159999
# ➡️  Processing rows 160000–164999
# {"asctime": "2026-02-20 19:25:16,671", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:16,998", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:17,312", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:17,656", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:17,965", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:18,271", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:18,275", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:18,277", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 160000–164999
# ➡️  Processing rows 165000–169999
# {"asctime": "2026-02-20 19:25:18,334", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:18,658", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:18,979", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:19,296", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:19,623", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:19,933", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:19,935", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:19,936", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 165000–169999
# ➡️  Processing rows 170000–174999
# {"asctime": "2026-02-20 19:25:19,994", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:20,353", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:20,671", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:20,988", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:21,306", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:21,624", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:21,626", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:21,627", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 170000–174999
# ➡️  Processing rows 175000–179999
# {"asctime": "2026-02-20 19:25:21,683", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:22,020", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:22,356", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:22,673", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:22,980", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:23,290", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:23,293", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:23,294", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 175000–179999
# ➡️  Processing rows 180000–184999
# {"asctime": "2026-02-20 19:25:23,353", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:23,682", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:23,996", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:24,308", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:24,640", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:24,938", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:24,939", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:24,941", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 180000–184999
# ➡️  Processing rows 185000–189999
# {"asctime": "2026-02-20 19:25:24,982", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:25,316", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:25,630", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:25,945", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:26,255", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:26,559", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:26,561", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:25:26,562", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 185000–189999
# ➡️  Processing rows 190000–194999
# {"asctime": "2026-02-20 19:25:26,621", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:25:26,975", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:27,289", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:27,606", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:25:27,914", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# ...
# ✅ Inserted rows 1715000–1719999
# ➡️  Processing rows 1720000–1724999
# {"asctime": "2026-02-20 19:34:37,355", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:37,761", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:38,125", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:38,509", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:38,877", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:39,230", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:39,231", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:39,232", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1720000–1724999
# ➡️  Processing rows 1725000–1729999
# {"asctime": "2026-02-20 19:34:39,298", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:39,984", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:40,349", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:40,730", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:41,092", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:41,473", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:41,475", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:41,476", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1725000–1729999
# ➡️  Processing rows 1730000–1734999
# {"asctime": "2026-02-20 19:34:41,540", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:41,928", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:42,290", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:42,647", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:42,992", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:43,336", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:43,337", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:43,338", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1730000–1734999
# ➡️  Processing rows 1735000–1739999
# {"asctime": "2026-02-20 19:34:43,399", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:43,768", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:44,116", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:44,478", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:44,834", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:45,190", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:45,191", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:45,193", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1735000–1739999
# ➡️  Processing rows 1740000–1744999
# {"asctime": "2026-02-20 19:34:45,257", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:45,621", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:45,973", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:46,323", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:46,663", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:47,049", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:47,052", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:47,054", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1740000–1744999
# ➡️  Processing rows 1745000–1749999
# {"asctime": "2026-02-20 19:34:47,117", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:47,473", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:47,832", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:48,188", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:48,543", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:48,885", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:48,887", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:48,887", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1745000–1749999
# ➡️  Processing rows 1750000–1754999
# {"asctime": "2026-02-20 19:34:48,948", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:49,309", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:49,694", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:50,054", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:50,417", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:50,776", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:50,777", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:50,778", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1750000–1754999
# ➡️  Processing rows 1755000–1759999
# {"asctime": "2026-02-20 19:34:50,832", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:51,197", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:51,553", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:51,895", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:52,255", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:52,631", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:52,634", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:52,636", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1755000–1759999
# ➡️  Processing rows 1760000–1764999
# {"asctime": "2026-02-20 19:34:52,707", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:53,102", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:53,472", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:53,845", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:54,210", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:54,574", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:54,576", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:54,577", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1760000–1764999
# ➡️  Processing rows 1765000–1769999
# {"asctime": "2026-02-20 19:34:54,635", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:55,014", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:55,396", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:55,760", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:56,119", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:56,468", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:56,469", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:56,470", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1765000–1769999
# ➡️  Processing rows 1770000–1774999
# {"asctime": "2026-02-20 19:34:56,532", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:56,896", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:57,249", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:57,601", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:57,994", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:58,347", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:58,347", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:34:58,348", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1770000–1774999
# ➡️  Processing rows 1775000–1779999
# {"asctime": "2026-02-20 19:34:58,573", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:34:58,940", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:59,307", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:59,651", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:34:59,996", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:35:00,353", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:35:00,354", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-20 19:35:00,355", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1775000–1779999
# ➡️  Processing rows 1780000–1782307
# {"asctime": "2026-02-20 19:35:00,399", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-20 19:35:00,769", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:35:01,144", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:35:01,268", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2308 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-20 19:35:01,270", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 2308"}
# {"asctime": "2026-02-20 19:35:01,271", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1780000–1782307
