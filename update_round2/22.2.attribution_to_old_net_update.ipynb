# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

# %%
import sqlalchemy as sa
from sqlalchemy.orm import Session
from crmprtd import setup_logging
from pycds import Station, History

save_path = './comparison_forms/'

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"
log_file_path = save_path

engine = sa.create_engine(db_url, echo=False)
session = Session(engine)

session

# %%
path = '/workspaces/crmprtd/update_round2/input_tables/'
df = pd.read_excel(path + '20251223-Metadata-AllRequiredChanges_round2.xlsx', header = 1)   # pandas automatically uses openpyxl

# Select rows where ISSUE contains "Attribution" (case-sensitive)
df_attribution = df[df["ISSUE"].str.contains("Attribution", na=False)]

len(df_attribution)

df_attribution =  df_attribution[['ISSUE','Station ID', 'Network ID', 'Network Name', 'Native ID', 'Unique Names', 'Unique Location (String)']].reset_index(drop=True)
df_attribution["Network ID"] = pd.to_numeric(df_attribution["Network ID"], errors="coerce").astype("Int64")
df_attribution["Station ID"] = pd.to_numeric(df_attribution["Station ID"], errors="coerce").astype("Int64")
df_attribution
# Out:
#            ISSUE  Station ID  Network ID            Network Name  \
# 0    Attribution        2322          12          BC-FWx-> BC-TS
# 1    Attribution        2633           9      BC-Air -> MVRD-AIR
# 2    Attribution       12610           9      BC-Air -> MVRD-AIR
# 3    Attribution       12608           9      BC-Air -> MVRD-AIR
# 4    Attribution       12529           9      BC-Air -> MVRD-AIR
# ..           ...         ...         ...                     ...
# 132  Attribution        2571          14  BC-Snow -> BCH-GSO-HMP
# 133  Attribution        2513          14  BC-Snow -> BCH-GSO-HMP
# 134  Attribution        2554          14  BC-Snow -> BCH-GSO-HMP
# 135  Attribution        2543          14  BC-Snow -> BCH-GSO-HMP
# 136  Attribution        2534          14  BC-Snow -> BCH-GSO-HMP
#
#                                   Native ID  \
# 0                                       945
# 1                           E246240 -> T034
# 2    New Westminster Sapperton Park -> T046
# 3                       Surrey East -> T015
# 4      Abbotsford A Columbia Street -> T045
# ..                                      ...
# 132                                   4B15P
# 133                                   1A02P
# 134                                   2F05P
# 135                                   2A21P
# 136                                   1E02P
#
#                             Unique Names  \
# 0                          TS NAKA CREEK
# 1    Abbotsford Airport -  Walmsley Road
# 2                 NA -> New Westminister
# 3                      NA -> Surrey East
# 4               NA -> Abbotsford Airport
# ..                                   ...
# 132                              Lu Lake
# 133                      McBride (Upper)
# 134                        Mission Creek
# 135                         Molson Creek
# 136                           Mount Cook
#
#                               Unique Location (String)
# 0    115.2144 W, 49.6673 N, Elev. 1051 m -> 126.433...
# 1                     122.343 W, 49.0235 N, Elev. 65 m
# 2    122.894487 W, 49.227045 N, Elev. null m -> 122...
# 3    122.6942 W, 49.1328 N, Elev. null m -> 122.695...
# 4    122.3266 W, 49.0215 N, Elev. null m -> 122.326...
# ..                                                 ...
# 132                      126.3 W, 54.2 N, Elev. 1310 m
# 133                    120.333 W, 53.3 N, Elev. 1620 m
# 134                    118.95 W, 49.95 N, Elev. 1780 m
# 135                 118.233 W, 52.2333 N, Elev. 1980 m
# 136                   121.65 W, 49.667 N, Elev. 1550 m
#
# [137 rows x 7 columns]

# %%
df_attribution = df_attribution[['ISSUE','Station ID', 'Network ID', 'Network Name']]
df_attribution

def split_network_name(name):
    if pd.isna(name):
        return pd.Series([None, None, 0])

    parts = [p.strip() for p in name.split("->")]

    if len(parts) == 2:
        old_name, new_name = parts
        n_names = 2
    else:
        old_name = new_name = parts[0]
        n_names = 1

    return pd.Series([old_name, new_name, n_names])
    

df_attribution[['old_net_name', 'new_net_name', 'n_net_names']] = (
    df_attribution['Network Name'].apply(split_network_name)
)

df_attribution['new_net_name'] = (
    df_attribution['new_net_name']
    .replace(['MVRD-AIR', 'MVRD'], 'MVRD-AQ')
)


df_attribution
# Out:
# /tmp/ipykernel_17547/811755646.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution[['old_net_name', 'new_net_name', 'n_net_names']] = (
# /tmp/ipykernel_17547/811755646.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution[['old_net_name', 'new_net_name', 'n_net_names']] = (
#            ISSUE  Station ID  Network ID            Network Name old_net_name  \
# 0    Attribution        2322          12          BC-FWx-> BC-TS       BC-FWx
# 1    Attribution        2633           9      BC-Air -> MVRD-AIR       BC-Air
# 2    Attribution       12610           9      BC-Air -> MVRD-AIR       BC-Air
# 3    Attribution       12608           9      BC-Air -> MVRD-AIR       BC-Air
# 4    Attribution       12529           9      BC-Air -> MVRD-AIR       BC-Air
# ..           ...         ...         ...                     ...          ...
# 132  Attribution        2571          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 133  Attribution        2513          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 134  Attribution        2554          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 135  Attribution        2543          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 136  Attribution        2534          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
#
#     new_net_name  n_net_names
# 0          BC-TS            2
# 1        MVRD-AQ            2
# 2        MVRD-AQ            2
# 3        MVRD-AQ            2
# 4        MVRD-AQ            2
# ..           ...          ...
# 132  BCH-GSO-HMP            2
# 133  BCH-GSO-HMP            2
# 134  BCH-GSO-HMP            2
# 135  BCH-GSO-HMP            2
# 136  BCH-GSO-HMP            2
#
# [137 rows x 7 columns]

# %% [markdown]
# ### select the netwok_id based on new_net_name, summarize back to the table

# %%
# Create an empty column first
df_attribution['new_network_id'] = None

with engine.connect() as conn:
    for idx, row in df_attribution.iterrows():
        # Query network_id for this row's new_net_name
        res = conn.execute(
            sa.text("""
                SELECT network_id
                FROM meta_network
                WHERE network_name = :network_name
            """),
            {"network_name": row['new_net_name']}
        ).mappings().fetchone()

        if res is not None:
            df_attribution.at[idx, 'new_network_id'] = res['network_id']
        else:
            print(f"❌ Network '{row['new_net_name']}' not found for station {row['Station ID']}")

df_attribution
# Out:
#            ISSUE  Station ID  Network ID            Network Name old_net_name  \
# 0    Attribution        2322          12          BC-FWx-> BC-TS       BC-FWx
# 1    Attribution        2633           9      BC-Air -> MVRD-AIR       BC-Air
# 2    Attribution       12610           9      BC-Air -> MVRD-AIR       BC-Air
# 3    Attribution       12608           9      BC-Air -> MVRD-AIR       BC-Air
# 4    Attribution       12529           9      BC-Air -> MVRD-AIR       BC-Air
# ..           ...         ...         ...                     ...          ...
# 132  Attribution        2571          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 133  Attribution        2513          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 134  Attribution        2554          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 135  Attribution        2543          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 136  Attribution        2534          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
#
#     new_net_name  n_net_names new_network_id
# 0          BC-TS            2             71
# 1        MVRD-AQ            2             72
# 2        MVRD-AQ            2             72
# 3        MVRD-AQ            2             72
# 4        MVRD-AQ            2             72
# ..           ...          ...            ...
# 132  BCH-GSO-HMP            2              5
# 133  BCH-GSO-HMP            2              5
# 134  BCH-GSO-HMP            2              5
# 135  BCH-GSO-HMP            2              5
# 136  BCH-GSO-HMP            2              5
#
# [137 rows x 8 columns]

# %%
df_attribution['new_network'] = df_attribution['new_network_id']> 50
df_attri_new_net = df_attribution[df_attribution['new_network'] == True]
df_attri_old_net = df_attribution[df_attribution['new_network'] == False]
df_attri_old_net = df_attri_old_net.drop(columns=['n_net_names'])
df_attri_old_net = df_attri_old_net.rename(columns={'Network ID': 'old_network_id'})

df_attri_new_net = df_attri_new_net.reset_index(drop=True)
df_attri_old_net
# Out:
#                                ISSUE  Station ID  old_network_id  \
# 12                       Attribution        2569              14
# 13                       Attribution        2532              14
# 14                       Attribution        2551              14
# 15                       Attribution        2521              14
# 16                       Attribution        2567              14
# 17                       Attribution        2522              14
# 18                       Attribution        2548              14
# 19                       Attribution        2547              14
# 20                       Attribution        2541              14
# 21                       Attribution        2565              14
# 22                       Attribution        2526              14
# 55   Attribution, ID, Name, Location       13011              12
# 56   Attribution, ID, Name, Location       13012              12
# 57   Attribution, ID, Name, Location       13013              12
# 78             Attribution, Location       11017              12
# 79             Attribution, Location       12464              12
# 88          Concatenate, Attribution       12560               9
# 102                      Attribution        2556              14
# 103                      Attribution        2576              14
# 104                      Attribution        2523              14
# 105                      Attribution        2528              14
# 106                      Attribution        2527              14
# 107                      Attribution        2555              14
# 108                      Attribution        2564              14
# 109                      Attribution        2574              14
# 110                      Attribution        2540              14
# 111                      Attribution        2531              14
# 112                      Attribution        2538              14
# 113                      Attribution        2575              14
# 114                      Attribution        2517              14
# 115                      Attribution        2544              14
# 116                      Attribution       12498              14
# 117                      Attribution        2542              14
# 118                      Attribution        2559              14
# 119                      Attribution        2550              14
# 120                      Attribution        2578              14
# 121                      Attribution        2577              14
# 122                      Attribution        2570              14
# 123                      Attribution        2553              14
# 124                      Attribution        2530              14
# 125                      Attribution       12499              14
# 126                      Attribution       12500              14
# 127                      Attribution        2515              14
# 128                      Attribution        2563              14
# 129                      Attribution        2580              14
# 130                      Attribution       12497              14
# 131                      Attribution        2536              14
# 132                      Attribution        2571              14
# 133                      Attribution        2513              14
# 134                      Attribution        2554              14
# 135                      Attribution        2543              14
# 136                      Attribution        2534              14
#
#                Network Name old_net_name new_net_name new_network_id  \
# 12   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 13   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 14   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 15   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 16   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 17   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 18   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 19   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 20   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 21   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 22   BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 55        BC-FWx -> MVRD-WS       BC-FWx      MVRD-WS             15
# 56        BC-FWx -> MVRD-WS       BC-FWx      MVRD-WS             15
# 57        BC-FWx -> MVRD-WS       BC-FWx      MVRD-WS             15
# 78        BC-FWx -> BC-FERN       BC-FWx      BC-FERN             11
# 79        BC-FWx -> BC-FERN       BC-FWx      BC-FERN             11
# 88                   BC-Air       BC-Air       BC-Air              9
# 102  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 103  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 104  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 105  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 106  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 107  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 108  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 109  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 110  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 111  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 112  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 113  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 114  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 115  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 116  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 117  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 118  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 119  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 120  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 121  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 122  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 123  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 124  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 125  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 126  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 127  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 128  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 129  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 130  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 131  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 132  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 133  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 134  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 135  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
# 136  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP              5
#
#      new_network
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 55         False
# 56         False
# 57         False
# 78         False
# 79         False
# 88         False
# 102        False
# 103        False
# 104        False
# 105        False
# 106        False
# 107        False
# 108        False
# 109        False
# 110        False
# 111        False
# 112        False
# 113        False
# 114        False
# 115        False
# 116        False
# 117        False
# 118        False
# 119        False
# 120        False
# 121        False
# 122        False
# 123        False
# 124        False
# 125        False
# 126        False
# 127        False
# 128        False
# 129        False
# 130        False
# 131        False
# 132        False
# 133        False
# 134        False
# 135        False
# 136        False

# %%
from sqlalchemy import text
import pandas as pd
from sqlalchemy.engine import Engine
from typing import Optional, List

def compare_network_vars(
    engine: Engine,
    df_attri_old_net: pd.DataFrame,
    old_network_id: int,
    new_network_id: int,
    station_ids: Optional[List[int]] = None
) -> pd.DataFrame:
    """
    Compare variables used by stations in an old network to variables in a new network.

    Parameters
    ----------
    engine : Engine
        SQLAlchemy engine connected to the database.
    df_attri_old_net : pd.DataFrame
        DataFrame containing at least 'Station ID' and 'old_network_id'.
    old_network_id : int
        old_network_id of the old network whose stations we want to check.
    new_network_id : int
        old_network_id of the target network to compare variables against.
    station_ids : Optional[List[int]]
        List of station IDs to check. If None, all stations in the old network are used.

    Returns
    -------
    pd.DataFrame
        DataFrame showing old station variables, matching new network vars, 
        and a boolean column 'exists_in_new_net'.
    """
    # Get station IDs if not provided
    if station_ids is None:
        station_ids = df_attri_old_net.loc[
            (df_attri_old_net['old_network_id'] == old_network_id) &
            (df_attri_old_net['new_network_id'] == new_network_id),
            'Station ID'
        ].dropna().tolist()

    if not station_ids:
        print("⚠️ No stations found for the old network.")
        return pd.DataFrame()

    print(station_ids)

    # --- Load variables used by the old stations ---
    SQL_STATION_VARS = text("""
    SELECT DISTINCT
           v.vars_id,
           v.unit,
           v.precision,
           v.standard_name,
           v.cell_method,
           v.long_description,
           v.net_var_name,
           v.display_name,
           v.short_name
    FROM obs_raw o
    JOIN meta_history h ON o.history_id = h.history_id
    JOIN meta_station s ON h.station_id = s.station_id
    JOIN meta_vars v ON o.vars_id = v.vars_id
    WHERE s.station_id = ANY(:station_ids)
    ORDER BY v.vars_id
    """)

    with engine.connect() as conn:
        df_vars_old_stations = pd.read_sql(SQL_STATION_VARS, conn, params={"station_ids": station_ids})

    if df_vars_old_stations.empty:
        print("⚠️ No variables found for the old stations.")
        return pd.DataFrame()

    # --- Load variables in the new network ---
    SQL_VARS_NEW = text("""
    SELECT DISTINCT
           v.vars_id,
           v.unit,
           v.precision,
           v.standard_name,
           v.cell_method,
           v.long_description,
           v.net_var_name,
           v.display_name,
           v.short_name
    FROM meta_vars v
    JOIN meta_network n ON v.network_id = n.network_id
    WHERE n.network_id = :network_id
    ORDER BY v.vars_id

    """)

    new_net_vars = pd.read_sql(SQL_VARS_NEW, engine, params={"network_id": new_network_id})

    # --- Compare variables ---
    VAR_MATCH_COLS = [
        "unit",
        "precision",
        "standard_name",
        "cell_method",
        "long_description",
        "net_var_name",
        "display_name",
        "short_name",
    ]

    df_compare = df_vars_old_stations.merge(
        new_net_vars[VAR_MATCH_COLS + ["vars_id"]],
        on=VAR_MATCH_COLS,
        how="left",
        suffixes=("", "_new_net"),
        indicator=True
    )

    # Mark existence in new network
    df_compare["exists_in_new_net"] = df_compare["_merge"] == "both"
    df_compare["vars_id_new_net"] = df_compare["vars_id_new_net"]

    return df_compare, df_vars_old_stations, new_net_vars

# %%
from pycds import Variable
from sqlalchemy.orm import Session
from typing import Tuple, Dict, List

def create_vars_for_network(
    df_vars: pd.DataFrame,
    network_id: int,
    session: Session
) -> Tuple[List[int], Dict[int, int]]:
    """
    Create variables in meta_vars for a given network based on a DataFrame,
    and return the list of new variable IDs and a mapping from old_vars_id -> new_vars_id.
    
    Parameters
    ----------
    df_vars : pd.DataFrame
        DataFrame containing the variable info with columns:
        ['vars_id', 'unit', 'precision', 'standard_name', 'cell_method',
         'long_description', 'net_var_name', 'display_name', 'short_name']
    network_id : int
        The network_id to which these variables will belong.
    session : sqlalchemy.orm.Session
        The active SQLAlchemy session.
    
    Returns
    -------
    vars_created : List[int]
        List of newly created variable IDs.
    vars_map : Dict[int, int]
        Mapping from old_vars_id to new_vars_id.
    """
    vars_created = []
    vars_map = {}

    for _, row in df_vars.iterrows():
        v = Variable(
            network_id=network_id,
            unit=row["unit"],
            precision=row["precision"],
            standard_name=row["standard_name"],
            cell_method=row["cell_method"],
            description=row["long_description"],
            name=row["net_var_name"],
            display_name=row["display_name"],
            short_name=row["short_name"],
        )

        session.add(v)
        session.flush()  # assigns vars_id immediately

        vars_created.append(v.id)
        vars_map[row["vars_id"]] = v.id

    session.commit()
    print(f"✅ Created {len(vars_created)} variables for network {network_id}")

    return vars_created, vars_map

# %%
import json
from sqlalchemy import text
from sqlalchemy.engine import Engine
from typing import Dict


SQL_UPDATE_VARS_BULK = text("""
UPDATE obs_raw o
SET vars_id = m.new_vars_id
FROM meta_history h
JOIN meta_station s
  ON h.station_id = s.station_id
CROSS JOIN json_to_recordset(:pairs_json)
     AS m(old_vars_id INT, new_vars_id INT)
WHERE o.history_id = h.history_id
  AND s.station_id = :station_id
  AND o.vars_id = m.old_vars_id
""")


def remap_obs_vars_for_station(
    engine: Engine,
    station_id: int,
    vars_map: Dict[int, int],
) -> int:
    """
    Bulk-remap obs_raw.vars_id for a given station using an old→new vars_id map.

    Parameters
    ----------
    engine : sqlalchemy.engine.Engine
        SQLAlchemy engine.
    station_id : int
        Station ID whose observations will be updated.
    vars_map : dict[int, int]
        Mapping of old_vars_id → new_vars_id.

    Returns
    -------
    int
        Number of rows updated.
    """
    if not vars_map:
        print("⚠️ vars_map is empty — nothing to update.")
        return 0


    # Only include old_vars_id that differ from current obs_raw
    rows_to_update = [
        (old, new) for old, new in vars_map.items()
        if old != new
    ]

    if not rows_to_update:
        print("🔹 All vars already mapped — nothing to update")
        return 0

    rows_to_update_json = json.dumps(
        [{"old_vars_id": old, "new_vars_id": new} for old, new in rows_to_update]
    )


    # Ensure plain Python int (avoid numpy.int64 issues)
    station_id = int(station_id)

    with engine.begin() as conn:
        res = conn.execute(
            SQL_UPDATE_VARS_BULK,
            {
                "pairs_json": rows_to_update_json,
                "station_id": station_id,
            }
        )

    print(
        f"✅ vars_id remap completed | "
        f"station={station_id} | "
        f"mappings={len(vars_map)} | "
        f"rows_updated={res.rowcount}"
    )

    return res.rowcount

# %%
def migrate_network_vars_and_remap_obs(
    engine,
    session,
    df_attri_old_net,
    old_network_id: int,
    new_network_id: int,
    dry_run: bool = False,
):
    """
    1. Compare vars between old and new network
    2. Create missing vars in new network (if needed)
    3. Build vars_id mapping
    4. Remap obs_raw vars_id station by station

    Parameters
    ----------
    dry_run : bool
        If True, do NOT update database — only print what would happen.
    """

    print(f"\n=== Migrating vars {old_network_id} → {new_network_id} ===")

    # -------------------------------------------------
    # Step 1: Compare network vars
    # -------------------------------------------------
    df_compare, _, _ = compare_network_vars(
        engine=engine,
        df_attri_old_net=df_attri_old_net,
        old_network_id=old_network_id,
        new_network_id=new_network_id,
    )

    df_compare["vars_id_new_net"] = (
        pd.to_numeric(df_compare["vars_id_new_net"], errors="coerce")
        .astype("Int64")
    )

    # -------------------------------------------------
    # Step 2: Create missing vars if needed
    # -------------------------------------------------
    df_missing = df_compare[df_compare["_merge"] != "both"].copy()

    vars_map_created = {}

    if not df_missing.empty:
        print(f"Creating {len(df_missing)} missing vars in new network...")

        if not dry_run:
            vars_created, vars_map_created = create_vars_for_network(
                df_missing,
                network_id=new_network_id,
                session=session,
            )
            print("Created vars:", vars_map_created)
        else:
            print("Dry run: vars would be created here.")

    # -------------------------------------------------
    # Step 3: Fill new vars_id safely
    # -------------------------------------------------
    if vars_map_created:
        df_compare["vars_id_new_net"] = (
            df_compare["vars_id_new_net"]
            .fillna(df_compare["vars_id"].map(vars_map_created))
        )

    # Safety check
    if df_compare["vars_id_new_net"].isna().any():
        raise ValueError("Some vars_id_new_net are still NaN. Aborting.")

    # Final mapping
    vars_map = {
        int(r["vars_id"]): int(r["vars_id_new_net"])
        for _, r in df_compare.iterrows()
    }

    print(f"Total vars mapped: {len(vars_map)}")

    # -------------------------------------------------
    # Step 4: Get stations
    # -------------------------------------------------
    subset = (
        df_attri_old_net.loc[
            (df_attri_old_net["old_network_id"] == old_network_id)
            & (df_attri_old_net["new_network_id"] == new_network_id)
        ]
        .reset_index(drop=True)
    )

    station_ids = subset["Station ID"].dropna().unique()

    print(f"Total stations to update: {len(station_ids)}")

    # -------------------------------------------------
    # Step 5: Remap obs station by station
    # -------------------------------------------------
    total_rows_updated = 0

    for station_id in station_ids:
        if dry_run:
            print(f"[Dry Run] Would update station {station_id}")
            continue

        rows_updated = remap_obs_vars_for_station(
            engine=engine,
            station_id=station_id,
            vars_map=vars_map,
        )

        print(f"Station {station_id}: {rows_updated} rows updated")
        total_rows_updated += rows_updated

    print(f"\nTotal rows updated: {total_rows_updated}")

    return {
        "vars_map": vars_map,
        "stations_updated": len(station_ids),
        "rows_updated": total_rows_updated,
    }

# %%
pair_1 = migrate_network_vars_and_remap_obs(
    engine=engine,
    session=session,
    df_attri_old_net=df_attri_old_net,
    old_network_id=14,
    new_network_id=5,
    dry_run=False,  # change to True for safety check
)

print(pair_1)
# Out:
# === Migrating vars 14 → 5 ===
# Total vars mapped: 17
# Total stations to update: 46
# ✅ vars_id remap completed | station=2569 | mappings=17 | rows_updated=481225
# Station 2569: 481225 rows updated
# ✅ vars_id remap completed | station=2532 | mappings=17 | rows_updated=88845
# Station 2532: 88845 rows updated
# ✅ vars_id remap completed | station=2551 | mappings=17 | rows_updated=441941
# Station 2551: 441941 rows updated
# ✅ vars_id remap completed | station=2521 | mappings=17 | rows_updated=449419
# Station 2521: 449419 rows updated
# ✅ vars_id remap completed | station=2567 | mappings=17 | rows_updated=442860
# Station 2567: 442860 rows updated
# ✅ vars_id remap completed | station=2522 | mappings=17 | rows_updated=423138
# Station 2522: 423138 rows updated
# ✅ vars_id remap completed | station=2548 | mappings=17 | rows_updated=437424
# Station 2548: 437424 rows updated
# ✅ vars_id remap completed | station=2547 | mappings=17 | rows_updated=532
# Station 2547: 532 rows updated
# ✅ vars_id remap completed | station=2541 | mappings=17 | rows_updated=402161
# Station 2541: 402161 rows updated
# ✅ vars_id remap completed | station=2565 | mappings=17 | rows_updated=459566
# Station 2565: 459566 rows updated
# ✅ vars_id remap completed | station=2526 | mappings=17 | rows_updated=238159
# Station 2526: 238159 rows updated
# ✅ vars_id remap completed | station=2556 | mappings=17 | rows_updated=804228
# Station 2556: 804228 rows updated
# ✅ vars_id remap completed | station=2576 | mappings=17 | rows_updated=10268
# Station 2576: 10268 rows updated
# ✅ vars_id remap completed | station=2523 | mappings=17 | rows_updated=614749
# Station 2523: 614749 rows updated
# ✅ vars_id remap completed | station=2528 | mappings=17 | rows_updated=244
# Station 2528: 244 rows updated
# ✅ vars_id remap completed | station=2527 | mappings=17 | rows_updated=6575
# Station 2527: 6575 rows updated
# ✅ vars_id remap completed | station=2555 | mappings=17 | rows_updated=353540
# Station 2555: 353540 rows updated
# ✅ vars_id remap completed | station=2564 | mappings=17 | rows_updated=722326
# Station 2564: 722326 rows updated
# ✅ vars_id remap completed | station=2574 | mappings=17 | rows_updated=674038
# Station 2574: 674038 rows updated
# ✅ vars_id remap completed | station=2540 | mappings=17 | rows_updated=655870
# Station 2540: 655870 rows updated
# ✅ vars_id remap completed | station=2531 | mappings=17 | rows_updated=678387
# Station 2531: 678387 rows updated
# ✅ vars_id remap completed | station=2538 | mappings=17 | rows_updated=457204
# Station 2538: 457204 rows updated
# ✅ vars_id remap completed | station=2575 | mappings=17 | rows_updated=105139
# Station 2575: 105139 rows updated
# ✅ vars_id remap completed | station=2517 | mappings=17 | rows_updated=243640
# Station 2517: 243640 rows updated
# ✅ vars_id remap completed | station=2544 | mappings=17 | rows_updated=133480
# Station 2544: 133480 rows updated
# ✅ vars_id remap completed | station=12498 | mappings=17 | rows_updated=213148
# Station 12498: 213148 rows updated
# ✅ vars_id remap completed | station=2542 | mappings=17 | rows_updated=1225
# Station 2542: 1225 rows updated
# ✅ vars_id remap completed | station=2559 | mappings=17 | rows_updated=4256
# Station 2559: 4256 rows updated
# ✅ vars_id remap completed | station=2550 | mappings=17 | rows_updated=437613
# Station 2550: 437613 rows updated
# ✅ vars_id remap completed | station=2578 | mappings=17 | rows_updated=10710
# Station 2578: 10710 rows updated
# ✅ vars_id remap completed | station=2577 | mappings=17 | rows_updated=5279
# Station 2577: 5279 rows updated
# ✅ vars_id remap completed | station=2570 | mappings=17 | rows_updated=206209
# Station 2570: 206209 rows updated
# ✅ vars_id remap completed | station=2553 | mappings=17 | rows_updated=558832
# Station 2553: 558832 rows updated
# ✅ vars_id remap completed | station=2530 | mappings=17 | rows_updated=172607
# Station 2530: 172607 rows updated
# ✅ vars_id remap completed | station=12499 | mappings=17 | rows_updated=116997
# Station 12499: 116997 rows updated
# ✅ vars_id remap completed | station=12500 | mappings=17 | rows_updated=218921
# Station 12500: 218921 rows updated
# ✅ vars_id remap completed | station=2515 | mappings=17 | rows_updated=204260
# Station 2515: 204260 rows updated
# ✅ vars_id remap completed | station=2563 | mappings=17 | rows_updated=710656
# Station 2563: 710656 rows updated
# ✅ vars_id remap completed | station=2580 | mappings=17 | rows_updated=282181
# Station 2580: 282181 rows updated
# ✅ vars_id remap completed | station=12497 | mappings=17 | rows_updated=200567
# Station 12497: 200567 rows updated
# ✅ vars_id remap completed | station=2536 | mappings=17 | rows_updated=680327
# Station 2536: 680327 rows updated
# ✅ vars_id remap completed | station=2571 | mappings=17 | rows_updated=725799
# Station 2571: 725799 rows updated
# ✅ vars_id remap completed | station=2513 | mappings=17 | rows_updated=269826
# Station 2513: 269826 rows updated
# ✅ vars_id remap completed | station=2554 | mappings=17 | rows_updated=787634
# Station 2554: 787634 rows updated
# ✅ vars_id remap completed | station=2543 | mappings=17 | rows_updated=436390
# Station 2543: 436390 rows updated
# ✅ vars_id remap completed | station=2534 | mappings=17 | rows_updated=610874
# Station 2534: 610874 rows updated
#
# Total rows updated: 16179269
# {'vars_map': {511: 463, 512: 464, 513: 465, 515: 467, 516: 468, 597: 569, 598: 570, 599: 571, 600: 572, 660: 1308, 701: 1309, 702: 1310, 703: 1311, 704: 1312, 705: 1313, 706: 1314, 710: 1315}, 'stations_updated': 46, 'rows_updated': 16179269}

# %%
pair_2 = migrate_network_vars_and_remap_obs(
    engine=engine,
    session=session,
    df_attri_old_net=df_attri_old_net,
    old_network_id=12,
    new_network_id=15,
    dry_run=False,  # change to True for safety check
)

print(pair_2)
# Out:
# === Migrating vars 12 → 15 ===
# Creating 13 missing vars in new network...
# ✅ Created 13 variables for network 15
# Created vars: {496: 1316, 497: 1317, 498: 1318, 499: 1319, 500: 1320, 711: 1321, 712: 1322, 713: 1323, 714: 1324, 715: 1325, 718: 1326, 719: 1327, 736: 1328}
# Total vars mapped: 13
# Total stations to update: 3
# ✅ vars_id remap completed | station=13011 | mappings=13 | rows_updated=126299
# Station 13011: 126299 rows updated
# ✅ vars_id remap completed | station=13012 | mappings=13 | rows_updated=136803
# Station 13012: 136803 rows updated
# ✅ vars_id remap completed | station=13013 | mappings=13 | rows_updated=126038
# Station 13013: 126038 rows updated
#
# Total rows updated: 389140
# {'vars_map': {496: 1316, 497: 1317, 498: 1318, 499: 1319, 500: 1320, 711: 1321, 712: 1322, 713: 1323, 714: 1324, 715: 1325, 718: 1326, 719: 1327, 736: 1328}, 'stations_updated': 3, 'rows_updated': 389140}

# %% [markdown]
# ### In the new run, need to double check the manually matched variable id

# %%
old_network_id=12
new_network_id=11

df_compare, df_vars_old_stations, new_net_vars = compare_network_vars(
    engine=engine,
    df_attri_old_net=df_attri_old_net,
    old_network_id=old_network_id,
    new_network_id=new_network_id,
)

### Manually mapping
manual_map = {
    496: 501,
    497: 503,
    498: 504,
    499: 506,
    500: 508,
    719: 505,
    736: 832,
}

mask = df_compare['vars_id'].isin(manual_map.keys())

df_compare.loc[mask, 'vars_id_new_net'] = (
    df_compare.loc[mask, 'vars_id'].map(manual_map)
)

df_compare['exists_in_new_net'] = df_compare['exists_in_new_net'].map({
    True: 'auto',
    False: 'missing'
}).astype('object')

df_compare.loc[mask, 'exists_in_new_net'] = 'manually'

df_compare["vars_id_new_net"] = (
    pd.to_numeric(df_compare["vars_id_new_net"], errors="coerce")
    .astype("Int64")
)
df_compare

# -------------------------------------------------
# Step 2: Create missing vars if needed
# -------------------------------------------------
df_missing = df_compare[df_compare["exists_in_new_net"] == False].copy()

dry_run = False
vars_map_created = {}

if not df_missing.empty:
    print(f"Creating {len(df_missing)} missing vars in new network...")

    if not dry_run:
        vars_created, vars_map_created = create_vars_for_network(
            df_missing,
            network_id=new_network_id,
            session=session,
        )
        print("Created vars:", vars_map_created)
    else:
        print("Dry run: vars would be created here.")
# Out:
# [11017, 12464]
# Creating 6 missing vars in new network...
# ✅ Created 6 variables for network 11
# Created vars: {711: 1357, 712: 1358, 713: 1359, 714: 1360, 715: 1361, 718: 1362}
# /tmp/ipykernel_17547/1171747177.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'manually' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df_compare.loc[mask, 'exists_in_new_net'] = 'manually'

# %%
# -------------------------------------------------
# Step 3: Fill new vars_id safely
# -------------------------------------------------
if vars_map_created:
    df_compare["vars_id_new_net"] = (
        df_compare["vars_id_new_net"]
        .fillna(df_compare["vars_id"].map(vars_map_created))
    )

# Safety check
if df_compare["vars_id_new_net"].isna().any():
    raise ValueError("Some vars_id_new_net are still NaN. Aborting.")

# Final mapping
vars_map = {
    int(r["vars_id"]): int(r["vars_id_new_net"])
    for _, r in df_compare.iterrows()
}

print(f"Total vars mapped: {len(vars_map)}")

# -------------------------------------------------
# Step 4: Get stations
# -------------------------------------------------
subset = (
    df_attri_old_net.loc[
        (df_attri_old_net["old_network_id"] == old_network_id)
        & (df_attri_old_net["new_network_id"] == new_network_id)
    ]
    .reset_index(drop=True)
)

station_ids = subset["Station ID"].dropna().unique()

print(f"Total stations to update: {len(station_ids)}")

# -------------------------------------------------
# Step 5: Remap obs station by station
# -------------------------------------------------
total_rows_updated = 0

for station_id in station_ids:
    if dry_run:
        print(f"[Dry Run] Would update station {station_id}")
        continue

    rows_updated = remap_obs_vars_for_station(
        engine=engine,
        station_id=station_id,
        vars_map=vars_map,
    )

    print(f"Station {station_id}: {rows_updated} rows updated")
    total_rows_updated += rows_updated

print(f"\nTotal rows updated: {total_rows_updated}")

return {
    "vars_map": vars_map,
    "stations_updated": len(station_ids),
    "rows_updated": total_rows_updated,
}
# Out:
# Total vars mapped: 13
# Total stations to update: 2
# ✅ vars_id remap completed | station=11017 | mappings=13 | rows_updated=450059
# Station 11017: 450059 rows updated
# ✅ vars_id remap completed | station=12464 | mappings=13 | rows_updated=543483
# Station 12464: 543483 rows updated
#
# Total rows updated: 993542
#   Cell In[44], line 58
#     return {
#     ^
# SyntaxError: 'return' outside function
