# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

# %%
import sqlalchemy as sa
from sqlalchemy.orm import Session
from crmprtd import setup_logging
from pycds import Station, History

save_path = './comparison_forms/'

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"
log_file_path = save_path

engine = sa.create_engine(db_url, echo=False)
session = Session(engine)

session

# %% [markdown]
# ### The Network Name in db and Ted's spread

# %%
path = '/workspaces/crmprtd/update_round2/input_tables/'
df = pd.read_excel(path + '20251223-Metadata-AllRequiredChanges_round2.xlsx', header = 1)   # pandas automatically uses openpyxl

df["Network ID"] = pd.to_numeric(df["Network ID"], errors="coerce").astype("Int64")

df[['Network ID', 'Network Name']].drop_duplicates()
# Out:
#       Network ID                 Network Name
# 0             10            -> BC AGRIWeather
# 48             2                   -> BC-TRAN
# 49            12                    -> BC-FWx
# 57            12                     -> BC-TS
# 62            76                   -> MVRD-AQ
# 63             5               -> BCH-GSO-HMP
# 65            14                   -> BC-Snow
# 83            15                   -> MVRD-WS
# 98          <NA>                   -> BC-FERN
# 130           74                    -> PC-FWx
# 131         <NA>                      BC-Snow
# 133         <NA>                      -> PRPA
# 219            9          BC-Air -> BCH-SiteC
# 221           12               BC-FWx-> BC-TS
# 222            9           BC-Air -> MVRD-AIR
# 233           14       BC-Snow -> BCH-GSO-HMP
# 249            9               BC-Air -> MVRD
# 259           12             BC-FWx -> PC-FWx
# 277           12            BC-FWx -> MVRD-WS
# 280            9               BC-Air -> PRPA
# 300           12            BC-FWx -> BC-FERN
# 302           11                      BC-FERN
# 314            9                       BC-Air
# 315           14                      BC-Snow
# 372           36                       CRD-WS
# 381            5                  BCH-GSO-HMP
# 384            9            BC-Air -> MVRD-AQ
# 391           10       BC AGRIWeather -> MVRD
# 403            2                      BC-TRAN
# 404           12               BC-FWx -> ECCC
# 405           12             BC-FWx -> NAVCAN
# 406           12      BC-FWx -> ECCC (NAVCN?)
# 407           12                       BC-FWx
# 411           12     BC-FWx -> ECCC (NAVCAN)?
# 412           12            BC-FWx -> ECCC???
# 415           12        BC-FWx -> ECCC/NAVCAN
# 431           12             BC-FWx -> CRD-WS
# 606           12  BC-FWx -> BCH-GSO-HMP-SiteC
# 727           14                BC-Snow -> RT
# 730            5        BCH-GSO-HMP -> PC-FWx
# 731           14                     BC-Snow
# 733            5       BCH-GSO-HMP -> ENV ASP
# 893            6                           RT
# 1226        <NA>                  ->BCH-SITEC
# 1237          10               BC AGRIWeather
# 2061        <NA>                          NaN

# %% [markdown]
# ### Fix problem

# %%
path = '/workspaces/crmprtd/update_round2/input_tables/'
df = pd.read_excel(path + '20251223-Metadata-AllRequiredChanges_round2.xlsx', header = 1)   # pandas automatically uses openpyxl

# Select rows where ISSUE contains "Attribution" (case-sensitive)
df_attribution = df[df["ISSUE"].str.contains("Attribution", na=False)]

len(df_attribution)

df_attribution =  df_attribution[['ISSUE','Station ID', 'Network ID', 'Network Name', 'Native ID', 'Unique Names', 'Unique Location (String)']].reset_index(drop=True)
df_attribution["Network ID"] = pd.to_numeric(df_attribution["Network ID"], errors="coerce").astype("Int64")
df_attribution["Station ID"] = pd.to_numeric(df_attribution["Station ID"], errors="coerce").astype("Int64")
df_attribution
# Out:
#            ISSUE  Station ID  Network ID            Network Name  \
# 0    Attribution        2322          12          BC-FWx-> BC-TS
# 1    Attribution        2633           9      BC-Air -> MVRD-AIR
# 2    Attribution       12610           9      BC-Air -> MVRD-AIR
# 3    Attribution       12608           9      BC-Air -> MVRD-AIR
# 4    Attribution       12529           9      BC-Air -> MVRD-AIR
# ..           ...         ...         ...                     ...
# 132  Attribution        2571          14  BC-Snow -> BCH-GSO-HMP
# 133  Attribution        2513          14  BC-Snow -> BCH-GSO-HMP
# 134  Attribution        2554          14  BC-Snow -> BCH-GSO-HMP
# 135  Attribution        2543          14  BC-Snow -> BCH-GSO-HMP
# 136  Attribution        2534          14  BC-Snow -> BCH-GSO-HMP
#
#                                   Native ID  \
# 0                                       945
# 1                           E246240 -> T034
# 2    New Westminster Sapperton Park -> T046
# 3                       Surrey East -> T015
# 4      Abbotsford A Columbia Street -> T045
# ..                                      ...
# 132                                   4B15P
# 133                                   1A02P
# 134                                   2F05P
# 135                                   2A21P
# 136                                   1E02P
#
#                             Unique Names  \
# 0                          TS NAKA CREEK
# 1    Abbotsford Airport -  Walmsley Road
# 2                 NA -> New Westminister
# 3                      NA -> Surrey East
# 4               NA -> Abbotsford Airport
# ..                                   ...
# 132                              Lu Lake
# 133                      McBride (Upper)
# 134                        Mission Creek
# 135                         Molson Creek
# 136                           Mount Cook
#
#                               Unique Location (String)
# 0    115.2144 W, 49.6673 N, Elev. 1051 m -> 126.433...
# 1                     122.343 W, 49.0235 N, Elev. 65 m
# 2    122.894487 W, 49.227045 N, Elev. null m -> 122...
# 3    122.6942 W, 49.1328 N, Elev. null m -> 122.695...
# 4    122.3266 W, 49.0215 N, Elev. null m -> 122.326...
# ..                                                 ...
# 132                      126.3 W, 54.2 N, Elev. 1310 m
# 133                    120.333 W, 53.3 N, Elev. 1620 m
# 134                    118.95 W, 49.95 N, Elev. 1780 m
# 135                 118.233 W, 52.2333 N, Elev. 1980 m
# 136                   121.65 W, 49.667 N, Elev. 1550 m
#
# [137 rows x 7 columns]

# %% [markdown]
# ### update native_id

# %%
df_attribution_id = df_attribution[['ISSUE','Station ID', 'Network ID', 'Native ID',]]

split_ids = df_attribution_id['Native ID'].astype(str).str.split('->', expand=True)

df_attribution_id['old_native_id'] = split_ids[0].str.strip()
df_attribution_id['new_native_id'] = split_ids[1].str.strip()


df_id_update = df_attribution_id[df_attribution_id['new_native_id'].notna()]

df_id_update_filtered = df_id_update[
    df_attribution_id['new_native_id'].notna() &
    ~df_attribution_id['ISSUE'].str.contains("Concatenate", na=False) &
    ~df_attribution_id['ISSUE'].str.contains("Delete", na=False)
]

len(df_id_update_filtered)
df_id_update_filtered
# Out:
# /tmp/ipykernel_55237/4235452717.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution_id['old_native_id'] = split_ids[0].str.strip()
# /tmp/ipykernel_55237/4235452717.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution_id['new_native_id'] = split_ids[1].str.strip()
# /tmp/ipykernel_55237/4235452717.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_id_update_filtered = df_id_update[
#                                                 ISSUE  Station ID  Network ID  \
# 1                                         Attribution        2633           9
# 2                                         Attribution       12610           9
# 3                                         Attribution       12608           9
# 4                                         Attribution       12529           9
# 5                                         Attribution       12538           9
# 6                                         Attribution       12602           9
# 7                                         Attribution       12607           9
# 8                                         Attribution       12583           9
# 21                                        Attribution        2565          14
# 36                                    Attribution, ID       12951           9
# 37                          Attribution, ID, Location       12960          12
# 38                          Attribution, ID, Location       11433          12
# 39                          Attribution, ID, Location       11431          12
# 40                          Attribution, ID, Location       11430          12
# 41                          Attribution, ID, Location       11432          12
# 42                          Attribution, ID, Location       12037          12
# 43                          Attribution, ID, Location       12036          12
# 44                          Attribution, ID, Location       12051          12
# 45                          Attribution, ID, Location       12038          12
# 46                          Attribution, ID, Location       12039          12
# 47                          Attribution, ID, Location       12042          12
# 48                          Attribution, ID, Location       12089           9
# 49            Attribution, ID, Location, Missing Data        2628           9
# 50  Attribution, ID, Location, Missing Data (Diffe...       12220           9
# 51                      Attribution, ID, Missing Data       12092           9
# 52                      Attribution, ID, Missing Data        2634           9
# 53                      Attribution, ID, Missing Data       12269           9
# 54                              Attribution, ID, Name       12232           9
# 55                    Attribution, ID, Name, Location       13011          12
# 56                    Attribution, ID, Name, Location       13012          12
# 57                    Attribution, ID, Name, Location       13013          12
# 58                    Attribution, ID, Name, Location       13014           9
# 59                    Attribution, ID, Name, Location        2647           9
# 62      Attribution, ID, Name, Location, missing data       12530           9
# 63      Attribution, ID, Name, Location, Missing Data       12589           9
# 64      Attribution, ID, Name, Location, Missing Data       12532           9
# 65      Attribution, ID, Name, Location, Missing Data       12593           9
# 66      Attribution, ID, Name, Location, Missing Data       12533           9
# 67      Attribution, ID, Name, Location, Missing Data       12601           9
# 68      Attribution, ID, Name, Location, Missing Data       12591           9
# 69      Attribution, ID, Name, Location, Missing Data       12536           9
# 70      Attribution, ID, Name, Location, Missing Data       12549           9
# 71      Attribution, ID, Name, Location, Missing Data       12556           9
# 72      Attribution, ID, Name, Location, Missing Data       12603           9
# 73      Attribution, ID, Name, Location, Missing Data       12600           9
# 74      Attribution, ID, Name, Location, Missing Data       12558           9
# 75  Attribution, ID, Name, Location, Missing Data ...       12562           9
# 76                Attribution, ID, Name, Missing Data       12311           9
# 77                   Attribution, ID, Reference 12538       12104           9
# 80                          Attribution, Missing Data       12291           9
# 84                                     Attribution,ID        1581           9
# 86                       Attribution,ID, Missing Data       12074           9
# 89                    Attribution, ID, Name, Location       12208           9
#
#                                      Native ID  \
# 1                              E246240 -> T034
# 2       New Westminster Sapperton Park -> T046
# 3                          Surrey East -> T015
# 4         Abbotsford A Columbia Street -> T045
# 5            Coquitlam Douglas College -> T032
# 6                          North Delta -> T013
# 7                       Richmond South -> T017
# 8   Vancouver International Airport #2 -> T031
# 21                                4A02P -> PYN
# 36                               E304550 ->85A
# 37                               1 -> C2B10A78
# 38                            1239 -> CBA24550
# 39                            1240 -> CBA47004
# 40                            1241 -> CBA4A66C
# 41                            1242 -> CBA48080
# 42                            1260 -> CBA572FE
# 43                            1261 -> CBA1E2A6
# 44                            1262 -> CBA18740
# 45                            1263 -> CBA1F1D0
# 46                             1264-> CBA19436
# 47                            1265 -> CBA1B2DA
# 48                             0310177 -> T004
# 49                             M110514 -> T038
# 50                             E232244 -> T020
# 51                             E207418 -> T018
# 52                             M104271 -> T035
# 53                              E207417 -> T17
# 54                             0310162 -> T009
# 55                               554 -> 01FW01
# 56                               555 -> 02FW02
# 57                               556 -> 04FW01
# 58                              E327924 -> 589
# 59                             M110510 -> T016
# 62               Agassiz Municipal Hall ->T044
# 63                  Abbotsford Central -> T033
# 64                    Burnaby Mountain -> T014
# 65                  Burnaby North Eton -> T024
# 66                       Burnaby South -> T018
# 67          North Burnaby Capitol Hill -> T023
# 68                    Burnaby Burmount -> T022
# 69                  Chilliwack Airport -> T012
# 70                        Hope Airport -> T029
# 71                     Langley Central -> T027
# 72          North Vancouver Mahon Park -> T026
# 73      Maple Ridge Golden Ears School -> T028
# 74            Mission School Works Yard ->T043
# 75     Pitt Meadows Meadowlands School -> T020
# 76                             E232246 -> T031
# 77                             E242892 -> T032
# 80                             E206271 -> T015
# 84                              M110515 -> 324
# 86                             E289309 -> T045
# 89                             0310179 -> T006
#
#                          old_native_id new_native_id
# 1                              E246240          T034
# 2       New Westminster Sapperton Park          T046
# 3                          Surrey East          T015
# 4         Abbotsford A Columbia Street          T045
# 5            Coquitlam Douglas College          T032
# 6                          North Delta          T013
# 7                       Richmond South          T017
# 8   Vancouver International Airport #2          T031
# 21                               4A02P           PYN
# 36                             E304550           85A
# 37                                   1      C2B10A78
# 38                                1239      CBA24550
# 39                                1240      CBA47004
# 40                                1241      CBA4A66C
# 41                                1242      CBA48080
# 42                                1260      CBA572FE
# 43                                1261      CBA1E2A6
# 44                                1262      CBA18740
# 45                                1263      CBA1F1D0
# 46                                1264      CBA19436
# 47                                1265      CBA1B2DA
# 48                             0310177          T004
# 49                             M110514          T038
# 50                             E232244          T020
# 51                             E207418          T018
# 52                             M104271          T035
# 53                             E207417           T17
# 54                             0310162          T009
# 55                                 554        01FW01
# 56                                 555        02FW02
# 57                                 556        04FW01
# 58                             E327924           589
# 59                             M110510          T016
# 62              Agassiz Municipal Hall          T044
# 63                  Abbotsford Central          T033
# 64                    Burnaby Mountain          T014
# 65                  Burnaby North Eton          T024
# 66                       Burnaby South          T018
# 67          North Burnaby Capitol Hill          T023
# 68                    Burnaby Burmount          T022
# 69                  Chilliwack Airport          T012
# 70                        Hope Airport          T029
# 71                     Langley Central          T027
# 72          North Vancouver Mahon Park          T026
# 73      Maple Ridge Golden Ears School          T028
# 74           Mission School Works Yard          T043
# 75     Pitt Meadows Meadowlands School          T020
# 76                             E232246          T031
# 77                             E242892          T032
# 80                             E206271          T015
# 84                             M110515           324
# 86                             E289309          T045
# 89                             0310179          T006

# %%
check_sql = sa.text("""
SELECT station_id, native_id
FROM meta_station
WHERE station_id = :station_id
""")

with engine.connect() as conn:
    for _, row in df_id_update_filtered.iterrows():
        res = conn.execute(
            check_sql,
            {"station_id": int(row["Station ID"])}
        ).fetchone()

        if res is None:
            print(f"❌ Station {row['Station ID']} not found")
            continue

        db_native_id = res.native_id

        if db_native_id == row["old_native_id"]:
            print(
                f"✅ OK to update station {res.station_id}: "
                f"{db_native_id} → {row['new_native_id']}"
            )
        else:
            print(
                f"⚠️ Mismatch for station {res.station_id}: "
                f"DB={db_native_id}, expected={row['old_native_id']}"
            )
# Out:
# ✅ OK to update station 2633: E246240 → T034
# ✅ OK to update station 12610: New Westminster Sapperton Park → T046
# ✅ OK to update station 12608: Surrey East → T015
# ✅ OK to update station 12529: Abbotsford A Columbia Street → T045
# ✅ OK to update station 12538: Coquitlam Douglas College → T032
# ✅ OK to update station 12602: North Delta → T013
# ✅ OK to update station 12607: Richmond South → T017
# ✅ OK to update station 12583: Vancouver International Airport #2 → T031
# ✅ OK to update station 2565: 4A02P → PYN
# ✅ OK to update station 12951: E304550 → 85A
# ✅ OK to update station 12960: 1 → C2B10A78
# ✅ OK to update station 11433: 1239 → CBA24550
# ✅ OK to update station 11431: 1240 → CBA47004
# ✅ OK to update station 11430: 1241 → CBA4A66C
# ✅ OK to update station 11432: 1242 → CBA48080
# ✅ OK to update station 12037: 1260 → CBA572FE
# ✅ OK to update station 12036: 1261 → CBA1E2A6
# ✅ OK to update station 12051: 1262 → CBA18740
# ✅ OK to update station 12038: 1263 → CBA1F1D0
# ✅ OK to update station 12039: 1264 → CBA19436
# ✅ OK to update station 12042: 1265 → CBA1B2DA
# ✅ OK to update station 12089: 0310177 → T004
# ✅ OK to update station 2628: M110514 → T038
# ✅ OK to update station 12220: E232244 → T020
# ✅ OK to update station 12092: E207418 → T018
# ✅ OK to update station 2634: M104271 → T035
# ✅ OK to update station 12269: E207417 → T17
# ✅ OK to update station 12232: 0310162 → T009
# ✅ OK to update station 13011: 554 → 01FW01
# ✅ OK to update station 13012: 555 → 02FW02
# ✅ OK to update station 13013: 556 → 04FW01
# ✅ OK to update station 13014: E327924 → 589
# ✅ OK to update station 2647: M110510 → T016
# ✅ OK to update station 12530: Agassiz Municipal Hall → T044
# ✅ OK to update station 12589: Abbotsford Central → T033
# ✅ OK to update station 12532: Burnaby Mountain → T014
# ✅ OK to update station 12593: Burnaby North Eton → T024
# ✅ OK to update station 12533: Burnaby South → T018
# ✅ OK to update station 12601: North Burnaby Capitol Hill → T023
# ✅ OK to update station 12591: Burnaby Burmount → T022
# ✅ OK to update station 12536: Chilliwack Airport → T012
# ✅ OK to update station 12549: Hope Airport → T029
# ✅ OK to update station 12556: Langley Central → T027
# ✅ OK to update station 12603: North Vancouver Mahon Park → T026
# ✅ OK to update station 12600: Maple Ridge Golden Ears School → T028
# ✅ OK to update station 12558: Mission School Works Yard → T043
# ✅ OK to update station 12562: Pitt Meadows Meadowlands School → T020
# ✅ OK to update station 12311: E232246 → T031
# ✅ OK to update station 12104: E242892 → T032
# ✅ OK to update station 12291: E206271 → T015
# ✅ OK to update station 1581: M110515 → 324
# ✅ OK to update station 12074: E289309 → T045
# ✅ OK to update station 12208: 0310179 → T006

# %%
update_station_sql = sa.text("""
UPDATE meta_station
SET native_id = :new_native_id
WHERE station_id = :station_id
  AND native_id = :old_native_id
""")

with engine.begin() as conn:
    for _, row in df_id_update_filtered.iterrows():
        result = conn.execute(
            update_station_sql,
            {
                "station_id": int(row["Station ID"]),
                "old_native_id": row["old_native_id"],
                "new_native_id": row["new_native_id"],
            }
        )

        if result.rowcount == 1:
            print(
                f"✅ Updated station {row['Station ID']}: "
                f"{row['old_native_id']} → {row['new_native_id']}"
            )
        else:
            # check why it failed
            res = conn.execute(
                check_sql,
                {"station_id": int(row["Station ID"])}
            ).fetchone()

            if res is None:
                print(f"❌ Station {row['Station ID']} not found")
            else:
                print(
                    f"⚠️ Skipped station {row['Station ID']}: "
                    f"DB={res.native_id}, expected={row['old_native_id']}"
                )
# Out:
# ✅ Updated station 2633: E246240 → T034
# ✅ Updated station 12610: New Westminster Sapperton Park → T046
# ✅ Updated station 12608: Surrey East → T015
# ✅ Updated station 12529: Abbotsford A Columbia Street → T045
# ✅ Updated station 12538: Coquitlam Douglas College → T032
# ✅ Updated station 12602: North Delta → T013
# ✅ Updated station 12607: Richmond South → T017
# ✅ Updated station 12583: Vancouver International Airport #2 → T031
# ✅ Updated station 2565: 4A02P → PYN
# ✅ Updated station 12951: E304550 → 85A
# ✅ Updated station 12960: 1 → C2B10A78
# ✅ Updated station 11433: 1239 → CBA24550
# ✅ Updated station 11431: 1240 → CBA47004
# ✅ Updated station 11430: 1241 → CBA4A66C
# ✅ Updated station 11432: 1242 → CBA48080
# ✅ Updated station 12037: 1260 → CBA572FE
# ✅ Updated station 12036: 1261 → CBA1E2A6
# ✅ Updated station 12051: 1262 → CBA18740
# ✅ Updated station 12038: 1263 → CBA1F1D0
# ✅ Updated station 12039: 1264 → CBA19436
# ✅ Updated station 12042: 1265 → CBA1B2DA
# ✅ Updated station 12089: 0310177 → T004
# ✅ Updated station 2628: M110514 → T038
# ✅ Updated station 12220: E232244 → T020
# ✅ Updated station 12092: E207418 → T018
# ✅ Updated station 2634: M104271 → T035
# ✅ Updated station 12269: E207417 → T17
# ✅ Updated station 12232: 0310162 → T009
# ✅ Updated station 13011: 554 → 01FW01
# ✅ Updated station 13012: 555 → 02FW02
# ✅ Updated station 13013: 556 → 04FW01
# ✅ Updated station 13014: E327924 → 589
# ✅ Updated station 2647: M110510 → T016
# ✅ Updated station 12530: Agassiz Municipal Hall → T044
# ✅ Updated station 12589: Abbotsford Central → T033
# ✅ Updated station 12532: Burnaby Mountain → T014
# ✅ Updated station 12593: Burnaby North Eton → T024
# ✅ Updated station 12533: Burnaby South → T018
# ✅ Updated station 12601: North Burnaby Capitol Hill → T023
# ✅ Updated station 12591: Burnaby Burmount → T022
# ✅ Updated station 12536: Chilliwack Airport → T012
# ✅ Updated station 12549: Hope Airport → T029
# ✅ Updated station 12556: Langley Central → T027
# ✅ Updated station 12603: North Vancouver Mahon Park → T026
# ✅ Updated station 12600: Maple Ridge Golden Ears School → T028
# ✅ Updated station 12558: Mission School Works Yard → T043
# ✅ Updated station 12562: Pitt Meadows Meadowlands School → T020
# ✅ Updated station 12311: E232246 → T031
# ✅ Updated station 12104: E242892 → T032
# ✅ Updated station 12291: E206271 → T015
# ✅ Updated station 1581: M110515 → 324
# ✅ Updated station 12074: E289309 → T045
# ✅ Updated station 12208: 0310179 → T006

# %%
verify_sql = sa.text("""
SELECT native_id
FROM meta_station
WHERE station_id = :station_id
""")

with engine.begin() as conn:
    for _, row in df_id_update_filtered.iterrows():
        # verify
        res = conn.execute(
            verify_sql,
            {"station_id": int(row["Station ID"])}
        ).fetchone()

        if res and res.native_id == row["new_native_id"]:
            print(
                f"✅ Verified: station {row['Station ID']} "
                f"native_id = {res.native_id}"
            )
        else:
            print(
                f"⚠️ Verification failed for station {row['Station ID']}: "
                f"DB={res.native_id if res else None}, "
                f"expected={row['new_native_id']}"
            )
# Out:
# ✅ Verified: station 2633 native_id = T034
# ✅ Verified: station 12610 native_id = T046
# ✅ Verified: station 12608 native_id = T015
# ✅ Verified: station 12529 native_id = T045
# ✅ Verified: station 12538 native_id = T032
# ✅ Verified: station 12602 native_id = T013
# ✅ Verified: station 12607 native_id = T017
# ✅ Verified: station 12583 native_id = T031
# ✅ Verified: station 2565 native_id = PYN
# ✅ Verified: station 12951 native_id = 85A
# ✅ Verified: station 12960 native_id = C2B10A78
# ✅ Verified: station 11433 native_id = CBA24550
# ✅ Verified: station 11431 native_id = CBA47004
# ✅ Verified: station 11430 native_id = CBA4A66C
# ✅ Verified: station 11432 native_id = CBA48080
# ✅ Verified: station 12037 native_id = CBA572FE
# ✅ Verified: station 12036 native_id = CBA1E2A6
# ✅ Verified: station 12051 native_id = CBA18740
# ✅ Verified: station 12038 native_id = CBA1F1D0
# ✅ Verified: station 12039 native_id = CBA19436
# ✅ Verified: station 12042 native_id = CBA1B2DA
# ✅ Verified: station 12089 native_id = T004
# ✅ Verified: station 2628 native_id = T038
# ✅ Verified: station 12220 native_id = T020
# ✅ Verified: station 12092 native_id = T018
# ✅ Verified: station 2634 native_id = T035
# ✅ Verified: station 12269 native_id = T17
# ✅ Verified: station 12232 native_id = T009
# ✅ Verified: station 13011 native_id = 01FW01
# ✅ Verified: station 13012 native_id = 02FW02
# ✅ Verified: station 13013 native_id = 04FW01
# ✅ Verified: station 13014 native_id = 589
# ✅ Verified: station 2647 native_id = T016
# ✅ Verified: station 12530 native_id = T044
# ✅ Verified: station 12589 native_id = T033
# ✅ Verified: station 12532 native_id = T014
# ✅ Verified: station 12593 native_id = T024
# ✅ Verified: station 12533 native_id = T018
# ✅ Verified: station 12601 native_id = T023
# ✅ Verified: station 12591 native_id = T022
# ✅ Verified: station 12536 native_id = T012
# ✅ Verified: station 12549 native_id = T029
# ✅ Verified: station 12556 native_id = T027
# ✅ Verified: station 12603 native_id = T026
# ✅ Verified: station 12600 native_id = T028
# ✅ Verified: station 12558 native_id = T043
# ✅ Verified: station 12562 native_id = T020
# ✅ Verified: station 12311 native_id = T031
# ✅ Verified: station 12104 native_id = T032
# ✅ Verified: station 12291 native_id = T015
# ✅ Verified: station 1581 native_id = 324
# ✅ Verified: station 12074 native_id = T045
# ✅ Verified: station 12208 native_id = T006

# %% [markdown]
# ### update station name

# %%
df_attribution_name = df_attribution[['ISSUE','Station ID', 'Network ID', 'Unique Names',]]
df_attribution_name

def split_station_name(name):
    if pd.isna(name):
        return pd.Series([None, None, 0])

    parts = [p.strip() for p in name.split("->")]

    if len(parts) == 2:
        old_name, new_name = parts
        n_names = 2
    else:
        old_name = new_name = parts[0]
        n_names = 1

    return pd.Series([old_name, new_name, n_names])
    

df_attribution_name[['old_name', 'new_name', 'n_names']] = (
    df_attribution_name['Unique Names'].apply(split_station_name)
)

df_attribution_name = df_attribution_name.drop(columns= 'Unique Names')
df_attribution_name
# split_ids = df_attribution_id['Native ID'].astype(str).str.split('->', expand=True)

# df_attribution_id['old_native_id'] = split_ids[0].str.strip()
# df_attribution_id['new_native_id'] = split_ids[1].str.strip()


# df_id_update = df_attribution_id[df_attribution_id['new_native_id'].notna()]

# df_id_update_filtered = df_id_update[
#     df_attribution_id['new_native_id'].notna() &
#     ~df_attribution_id['ISSUE'].str.contains("Concatenate", na=False) &
#     ~df_attribution_id['ISSUE'].str.contains("Delete", na=False)
# ]

# len(df_id_update_filtered)
# df_id_update_filtered
# Out:
# /tmp/ipykernel_55237/2547330766.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution_name[['old_name', 'new_name', 'n_names']] = (
# /tmp/ipykernel_55237/2547330766.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution_name[['old_name', 'new_name', 'n_names']] = (
#            ISSUE  Station ID  Network ID                             old_name  \
# 0    Attribution        2322          12                        TS NAKA CREEK
# 1    Attribution        2633           9  Abbotsford Airport -  Walmsley Road
# 2    Attribution       12610           9                                   NA
# 3    Attribution       12608           9                                   NA
# 4    Attribution       12529           9                                   NA
# ..           ...         ...         ...                                  ...
# 132  Attribution        2571          14                              Lu Lake
# 133  Attribution        2513          14                      McBride (Upper)
# 134  Attribution        2554          14                        Mission Creek
# 135  Attribution        2543          14                         Molson Creek
# 136  Attribution        2534          14                           Mount Cook
#
#                                 new_name  n_names
# 0                          TS NAKA CREEK      1.0
# 1    Abbotsford Airport -  Walmsley Road      1.0
# 2                       New Westminister      2.0
# 3                            Surrey East      2.0
# 4                     Abbotsford Airport      2.0
# ..                                   ...      ...
# 132                              Lu Lake      1.0
# 133                      McBride (Upper)      1.0
# 134                        Mission Creek      1.0
# 135                         Molson Creek      1.0
# 136                           Mount Cook      1.0
#
# [137 rows x 6 columns]

# %%
df_name_update = df_attribution_name[df_attribution_name['old_name'] != df_attribution_name['new_name'] ]

df_name_update = df_attribution_name[
    (df_attribution_name['old_name'] != df_attribution_name['new_name']) &
    (~df_attribution_name['ISSUE'].str.contains("delete", na=False))
]

df_name_update
# Out:
#                                                  ISSUE  Station ID  \
# 2                                          Attribution       12610
# 3                                          Attribution       12608
# 4                                          Attribution       12529
# 5                                          Attribution       12538
# 6                                          Attribution       12602
# 7                                          Attribution       12607
# 8                                          Attribution       12583
# 23                            Attribution, Concatenate       12559
# 33              Attribution, Delete Reference to 12601       12204
# 34              Attribution, Delete Reference to 12603       12207
# 36                                     Attribution, ID       12951
# 37                           Attribution, ID, Location       12960
# 54                               Attribution, ID, Name       12232
# 55                     Attribution, ID, Name, Location       13011
# 56                     Attribution, ID, Name, Location       13012
# 57                     Attribution, ID, Name, Location       13013
# 58                     Attribution, ID, Name, Location       13014
# 59                     Attribution, ID, Name, Location        2647
# 60   Attribution, ID, Name, Location, Concatenate w...       12582
# 62       Attribution, ID, Name, Location, missing data       12530
# 63       Attribution, ID, Name, Location, Missing Data       12589
# 64       Attribution, ID, Name, Location, Missing Data       12532
# 65       Attribution, ID, Name, Location, Missing Data       12593
# 66       Attribution, ID, Name, Location, Missing Data       12533
# 67       Attribution, ID, Name, Location, Missing Data       12601
# 68       Attribution, ID, Name, Location, Missing Data       12591
# 69       Attribution, ID, Name, Location, Missing Data       12536
# 70       Attribution, ID, Name, Location, Missing Data       12549
# 71       Attribution, ID, Name, Location, Missing Data       12556
# 72       Attribution, ID, Name, Location, Missing Data       12603
# 73       Attribution, ID, Name, Location, Missing Data       12600
# 74       Attribution, ID, Name, Location, Missing Data       12558
# 75   Attribution, ID, Name, Location, Missing Data ...       12562
# 76                 Attribution, ID, Name, Missing Data       12311
# 87                            Concatenate, Attribution       12551
# 88                            Concatenate, Attribution       12560
# 89                     Attribution, ID, Name, Location       12208
# 100                        Name, Location, Attribution       12957
# 101                                        Attribution       12545
# 110                                        Attribution        2540
#
#      Network ID                            old_name  \
# 2             9                                  NA
# 3             9                                  NA
# 4             9                                  NA
# 5             9                                  NA
# 6             9                                  NA
# 7             9                                  NA
# 8             9                                  NA
# 23            9                                  NA
# 33            9          North Burnaby Capitol Hill
# 34            9          North Vancouver Mahon Park
# 36            9              Fort St John 85 Avenue
# 37           12
# 54            9         Port Moody Rocky Point Park
# 55           12
# 56           12
# 57           12
# 58            9
# 59            9                        Pitt Meadows
# 60            9                                  NA
# 62            9                                  NA
# 63            9                                  NA
# 64            9                                  NA
# 65            9                                  NA
# 66            9                                  NA
# 67            9                                  NA
# 68            9                                  NA
# 69            9                                  NA
# 70            9                                  NA
# 71            9                                  NA
# 72            9                                  NA
# 73            9                                  NA
# 74            9                                  NA
# 75            9                                  NA
# 76            9  Vancouver International Airport #2
# 87            9                                 NaN
# 88            9                                  NA
# 89            9      North Vancouver Second Narrows
# 100          12
# 101           9                                  NA
# 110          14                    Celista Mountain
#
#                                      new_name  n_names
# 2                            New Westminister      2.0
# 3                                 Surrey East      2.0
# 4                          Abbotsford Airport      2.0
# 5                                   Coquitlam      2.0
# 6                                 North Delta      2.0
# 7                              Richmond South      2.0
# 8                                         YVR      2.0
# 23   Peace Valley Attachie Flat Upper Terrace      2.0
# 33                       Burnaby-Capitol Hill      2.0
# 34                    N. Vancouver-Mahon Park      2.0
# 36                                85th Avenue      2.0
# 37                                 TOFINO PCA      2.0
# 54                                 Port Moody      2.0
# 55                      Capilano Fire Weather      2.0
# 56                       Seymour Fire Weather      2.0
# 57                     Coquitlam Fire Weather      2.0
# 58                  Port Edwards Sunset Drive      2.0
# 59                       Pitt Meadows Airport      2.0
# 60                      Vancouver Clark Drive      2.0
# 62                     Agassiz Municiple Hall      2.0
# 63                       Abbotsford-Mill Lake      2.0
# 64                           Burnaby Mountain      2.0
# 65                              Burnaby North      2.0
# 66                              Burnaby South      2.0
# 67                       Burnaby-Capitol Hill      2.0
# 68                           Burnbay-Burmount      2.0
# 69                          Chilliwak Airport      2.0
# 70                                       Hope      2.0
# 71                                    Langley      2.0
# 72                                 Mahon Park      2.0
# 73                                Maple Ridge      2.0
# 74                                    Mission      2.0
# 75                       Pitt Meadows Airport      2.0
# 76                           Richmond Airport      2.0
# 87                                        NaN      0.0
# 88                                PG Marsulex      2.0
# 89                N. Vancouver Second Narrows      2.0
# 100                             TS BLACKWATER      2.0
# 101                 Fort St John North Camp C      2.0
# 110                                   Celista      2.0

# %%
check_sql = sa.text("""
SELECT
    station_id,
    station_name
FROM meta_history
WHERE station_id = :station_id
""")

import numpy as np

with engine.begin() as conn:
    for _, row in df_name_update.iterrows():

        station_id = int(row["Station ID"])

        old_name  = row["old_name"]
        new_name  = row["new_name"]

        # --- 1. Read current DB values ---
        db_row = conn.execute(
            check_sql,
            {"station_id": station_id}
        ).fetchone()

        if db_row is None:
            print(f"❌ Station {station_id} not found in DB")
            continue

        # --- 2. Compare with expected OLD values ---

        if db_row.station_name != old_name:
            print(
                f"⚠️ Station {station_id} (DB, XLS values differ)\n"
                f"   DB : station name is {db_row.station_name}\n"
                f"   XLS: station name is {old_name}"
            )
        else:
            print(
                f"✅ Station {station_id}, {db_row.station_name}, the names match "
            )
# Out:
# ✅ Station 12610, NA, the names match
# ✅ Station 12608, NA, the names match
# ✅ Station 12529, NA, the names match
# ✅ Station 12538, NA, the names match
# ✅ Station 12602, NA, the names match
# ✅ Station 12607, NA, the names match
# ✅ Station 12583, NA, the names match
# ⚠️ Station 12559 (DB, XLS values differ)
#    DB : station name is Peace Valley Attachie Flat Upper Terrace
#    XLS: station name is NA
# ✅ Station 12204, North Burnaby Capitol Hill, the names match
# ✅ Station 12207, North Vancouver Mahon Park, the names match
# ⚠️ Station 12951 (DB, XLS values differ)
#    DB : station name is None
#    XLS: station name is Fort St John 85 Avenue
# ⚠️ Station 12960 (DB, XLS values differ)
#    DB : station name is None
#    XLS: station name is
# ✅ Station 12232, Port Moody Rocky Point Park, the names match
# ⚠️ Station 13011 (DB, XLS values differ)
#    DB : station name is None
#    XLS: station name is
# ⚠️ Station 13012 (DB, XLS values differ)
#    DB : station name is None
#    XLS: station name is
# ⚠️ Station 13013 (DB, XLS values differ)
#    DB : station name is None
#    XLS: station name is
# ⚠️ Station 13014 (DB, XLS values differ)
#    DB : station name is None
#    XLS: station name is
# ✅ Station 2647, Pitt Meadows, the names match
# ✅ Station 12582, NA, the names match
# ✅ Station 12530, NA, the names match
# ✅ Station 12589, NA, the names match
# ✅ Station 12532, NA, the names match
# ✅ Station 12593, NA, the names match
# ✅ Station 12533, NA, the names match
# ✅ Station 12601, NA, the names match
# ✅ Station 12591, NA, the names match
# ✅ Station 12536, NA, the names match
# ✅ Station 12549, NA, the names match
# ✅ Station 12556, NA, the names match
# ✅ Station 12603, NA, the names match
# ✅ Station 12600, NA, the names match
# ✅ Station 12558, NA, the names match
# ✅ Station 12562, NA, the names match
# ✅ Station 12311, Vancouver International Airport #2, the names match
# ⚠️ Station 12551 (DB, XLS values differ)
#    DB : station name is NA
#    XLS: station name is nan
# ✅ Station 12560, NA, the names match
# ✅ Station 12208, North Vancouver Second Narrows, the names match
# ⚠️ Station 12957 (DB, XLS values differ)
#    DB : station name is None
#    XLS: station name is
# ✅ Station 12545, NA, the names match
# ✅ Station 2540, Celista Mountain, the names match

# %%
update_sql = sa.text("""
UPDATE meta_history
SET
    station_name  = :new_name
WHERE station_id = :station_id
""")

with engine.begin() as conn:
    for _, row in df_name_update.iterrows():

        station_id = int(row["Station ID"])

        old_name  = row["old_name"]
        new_name  = row["new_name"]

        # --- 1. Read current DB values ---
        db_row = conn.execute(
            check_sql,
            {"station_id": station_id}
        ).fetchone()

        if db_row is None:
            print(f"❌ Station {station_id} not found in DB")
            continue

        # --- 3. Perform update ---
        result = conn.execute(
            update_sql,
            {
                "station_id": station_id,
                "new_name": new_name,
            }
        )

        if result.rowcount == 1:
            print(
                f"✅ Updated station {station_id}: "
                f"({old_name}) → "
                f"({new_name})"
            )
        else:
            print(f"⚠️ Station {station_id}: no update applied")
# Out:
# ✅ Updated station 12610: (NA) → (New Westminister)
# ✅ Updated station 12608: (NA) → (Surrey East)
# ✅ Updated station 12529: (NA) → (Abbotsford Airport)
# ✅ Updated station 12538: (NA) → (Coquitlam)
# ✅ Updated station 12602: (NA) → (North Delta)
# ✅ Updated station 12607: (NA) → (Richmond South)
# ✅ Updated station 12583: (NA) → (YVR)
# ✅ Updated station 12559: (NA) → (Peace Valley Attachie Flat Upper Terrace)
# ✅ Updated station 12204: (North Burnaby Capitol Hill) → (Burnaby-Capitol Hill)
# ✅ Updated station 12207: (North Vancouver Mahon Park) → (N. Vancouver-Mahon Park)
# ✅ Updated station 12951: (Fort St John 85 Avenue) → (85th Avenue)
# ✅ Updated station 12960: () → (TOFINO PCA)
# ✅ Updated station 12232: (Port Moody Rocky Point Park) → (Port Moody)
# ✅ Updated station 13011: () → (Capilano Fire Weather)
# ✅ Updated station 13012: () → (Seymour Fire Weather)
# ✅ Updated station 13013: () → (Coquitlam Fire Weather)
# ✅ Updated station 13014: () → (Port Edwards Sunset Drive)
# ✅ Updated station 2647: (Pitt Meadows) → (Pitt Meadows Airport)
# ✅ Updated station 12582: (NA) → (Vancouver Clark Drive)
# ✅ Updated station 12530: (NA) → (Agassiz Municiple Hall)
# ✅ Updated station 12589: (NA) → (Abbotsford-Mill Lake)
# ✅ Updated station 12532: (NA) → (Burnaby Mountain)
# ✅ Updated station 12593: (NA) → (Burnaby North)
# ✅ Updated station 12533: (NA) → (Burnaby South)
# ✅ Updated station 12601: (NA) → (Burnaby-Capitol Hill)
# ✅ Updated station 12591: (NA) → (Burnbay-Burmount)
# ✅ Updated station 12536: (NA) → (Chilliwak Airport)
# ✅ Updated station 12549: (NA) → (Hope)
# ✅ Updated station 12556: (NA) → (Langley)
# ✅ Updated station 12603: (NA) → (Mahon Park)
# ✅ Updated station 12600: (NA) → (Maple Ridge)
# ✅ Updated station 12558: (NA) → (Mission)
# ✅ Updated station 12562: (NA) → (Pitt Meadows Airport)
# ✅ Updated station 12311: (Vancouver International Airport #2) → (Richmond Airport)
# ✅ Updated station 12551: (nan) → (nan)
# ✅ Updated station 12560: (NA) → (PG Marsulex)
# ✅ Updated station 12208: (North Vancouver Second Narrows) → (N. Vancouver Second Narrows)
# ✅ Updated station 12957: () → (TS BLACKWATER)
# ✅ Updated station 12545: (NA) → (Fort St John North Camp C)
# ✅ Updated station 2540: (Celista Mountain) → (Celista)

# %% [markdown]
# ### Update location

# %%
df_attribution_loc = df_attribution[['ISSUE','Station ID', 'Network ID', 'Unique Location (String)',]]

df_loc = df_attribution_loc.loc[df_attribution_loc['Unique Location (String)'].astype(str).str.contains('->', na=False)]


df_loc
# Out:
#                                                  ISSUE  Station ID  \
# 0                                          Attribution        2322
# 2                                          Attribution       12610
# 3                                          Attribution       12608
# 4                                          Attribution       12529
# 5                                          Attribution       12538
# 6                                          Attribution       12602
# 7                                          Attribution       12607
# 8                                          Attribution       12583
# 26                 Attribution, Concatenate and delete       12563
# 37                           Attribution, ID, Location       12960
# 38                           Attribution, ID, Location       11433
# 39                           Attribution, ID, Location       11431
# 40                           Attribution, ID, Location       11430
# 41                           Attribution, ID, Location       11432
# 43                           Attribution, ID, Location       12036
# 45                           Attribution, ID, Location       12038
# 46                           Attribution, ID, Location       12039
# 47                           Attribution, ID, Location       12042
# 48                           Attribution, ID, Location       12089
# 49             Attribution, ID, Location, Missing Data        2628
# 50   Attribution, ID, Location, Missing Data (Diffe...       12220
# 52                       Attribution, ID, Missing Data        2634
# 55                     Attribution, ID, Name, Location       13011
# 56                     Attribution, ID, Name, Location       13012
# 57                     Attribution, ID, Name, Location       13013
# 58                     Attribution, ID, Name, Location       13014
# 59                     Attribution, ID, Name, Location        2647
# 60   Attribution, ID, Name, Location, Concatenate w...       12582
# 61   Attribution, ID, Name, Location, Concatenate w...       12949
# 62       Attribution, ID, Name, Location, missing data       12530
# 63       Attribution, ID, Name, Location, Missing Data       12589
# 64       Attribution, ID, Name, Location, Missing Data       12532
# 65       Attribution, ID, Name, Location, Missing Data       12593
# 66       Attribution, ID, Name, Location, Missing Data       12533
# 67       Attribution, ID, Name, Location, Missing Data       12601
# 68       Attribution, ID, Name, Location, Missing Data       12591
# 69       Attribution, ID, Name, Location, Missing Data       12536
# 70       Attribution, ID, Name, Location, Missing Data       12549
# 71       Attribution, ID, Name, Location, Missing Data       12556
# 72       Attribution, ID, Name, Location, Missing Data       12603
# 73       Attribution, ID, Name, Location, Missing Data       12600
# 74       Attribution, ID, Name, Location, Missing Data       12558
# 75   Attribution, ID, Name, Location, Missing Data ...       12562
# 78                               Attribution, Location       11017
# 84                                      Attribution,ID        1581
# 89                     Attribution, ID, Name, Location       12208
# 90                               Location, Attribution        2321
# 92                               Location, Attribution        2338
# 93                               Location, Attribution        2339
# 94                               Location, Attribution        2350
# 95                               Location, Attribution        3300
# 96                               Location, Attribution        3301
# 97                               Location, Attribution       12453
# 98                         Name, Location, Attribution       12458
# 99                         Name, Location, Attribution       12526
# 100                        Name, Location, Attribution       12957
#
#      Network ID                           Unique Location (String)
# 0            12  115.2144 W, 49.6673 N, Elev. 1051 m -> 126.433...
# 2             9  122.894487 W, 49.227045 N, Elev. null m -> 122...
# 3             9  122.6942 W, 49.1328 N, Elev. null m -> 122.695...
# 4             9  122.3266 W, 49.0215 N, Elev. null m -> 122.326...
# 5             9  122.7914 W, 49.2881 N, Elev. null m -> 122.791...
# 6             9  122.9017 W, 49.1583 N, Elev. null m -> 122.901...
# 7             9  123.1083 W, 49.1414 N, Elev. null m -> 123.108...
# 8             9  123.1522 W, 49.1864 N, Elev. null m -> 123.152...
# 26            9  122.8492 W, 49.2808 N, Elev. null m -> 122.849...
# 37           12  0 W, null N, Elev. null m -> 125.7666 W, 49.07...
# 38           12  116.7148167 W, 51.96803333 N, Elev. 1442 m ->1...
# 39           12  116.5264333 W, 51.36643333 N, Elev. 1275 m -> ...
# 40           12  115.9789167 W, 51.02336667 N, Elev. 1277 m -> ...
# 41           12  115.9508167 W, 50.76911667 N, Elev. 1132 m -> ...
# 43           12  118.2072333 W, 51.02203333 N, Elev. 527 m -> 1...
# 45           12  117.68105 W, 51.23438333 N, Elev. 1308 m -> 11...
# 46           12  117.4740833 W, 51.41488333 N, Elev. 835 m -> 1...
# 47           12  117.3740833 W, 51.31453333 N, Elev. 1638 m -> ...
# 48            9  122.9711 W, 49.2794 N, Elev. 133 m -> 122.9707...
# 49            9  122.9422222 W, 49.15972222 N, Elev. 160 m -> 1...
# 50            9  122.7089 W, 49.2453 N, Elev. 20 m -> 122.7089 ...
# 52            9  123.2797222 W, 49.37277778 N, Elev. 60 m -> 12...
# 55           12  0 W, null N, Elev. null m -> 123.10394 W, 49.4...
# 56           12  0 W, null N, Elev. null m  ->'122.9463056 W, 4...
# 57           12  0 W, null N, Elev. null m -> 122.7536111 W, 49...
# 58            9  130.29045 W, 54.2231999 N, Elev. null m -> 130...
# 59            9  122.7166667 W, 49.21666667 N, Elev. 3 m -> 122...
# 60            9  123.077811 W, 49.26029 N, Elev. null m -> 123....
# 61            9  123.077811 W, 49.26029 N, Elev. null m -> 123....
# 62            9  121.762334 W, 49.238032 N, Elev. null m -> 121...
# 63            9  122.3097 W, 49.0428 N, Elev. null m -> 122.308...
# 64            9  122.9222 W, 49.2797 N, Elev. null m -> 122.922...
# 65            9  123.0078 W, 49.2875 N, Elev. null m -> 123.008...
# 66            9  122.9856 W, 49.2153 N, Elev. null m -> 122.985...
# 67            9  122.9856 W, 49.2878 N, Elev. null m -> 122.985...
# 68            9  122.9356 W, 49.2667 N, Elev. null m -> 122.935...
# 69            9  121.9406 W, 49.1561 N, Elev. null m -> 121.940...
# 70            9  121.4994 W, 49.3697 N, Elev. null m -> 121.499...
# 71            9  122.5669 W, 49.0956 N, Elev. null m -> 122.567...
# 72            9  123.0836 W, 49.3239 N, Elev. null m -> 123.083...
# 73            9  122.5819 W, 49.215 N, Elev. null m -> 122.5821...
# 74            9  122.311078 W, 49.14149 N, Elev. null m -> 122....
# 75            9  122.7089 W, 49.2453 N, Elev. null m -> 122.708...
# 78           12  126.890543 W, 52.279579 N, Elev. 1260 m -> 126...
# 84            9      122.5733333 W, 49.08722222 N, Elev. 110 m ->
# 89            9  123.0203 W, 49.3017 N, Elev. 15 m -> 123.0204 ...
# 90           12  124.2006 W, 48.5711 N, Elev. 296 m -> 124.2 W,...
# 92           12  126.92823 W, 50.13242 N, Elev. 130 m -> 126.92...
# 93           12  123.56484 W, 49.42805 N, Elev. 593 m -> 123.56...
# 94           12  124.61373 W, 50.10348 N, Elev. 91 m -> 124.614...
# 95           12  125.1309 W, 50.27092 N, Elev. 132 m -> 125.130...
# 96           12  123.38722 W, 49.5855 N, Elev. 154 m -> 123.387...
# 97           12  126.032697 W, 49.610222 N, Elev. 77 m -> 126.0...
# 98           12  127.0796111 W, 50.2678056 N, Elev. 462 m -> 12...
# 99           12  125.1218 W, 49.2074 N, Elev. 341 m -> 125.1218...
# 100          12  0 W, null N, Elev. null m -> 125.5757 W, 50.17...

# %%
import re


def _parse_single_location(loc_str):
    """
    Parse:
    '123.764438 W, 48.51616 N, Elev. 512.14 m'
    '123.764438 W, 48.51616 N, Elev. null m'

    Returns: (lat, lon, elev)
    """
    if pd.isna(loc_str):
        return np.nan, np.nan, np.nan

    pattern = (
        r"([\d\.]+)\s*([EW]),\s*"
        r"([\d\.]+)\s*([NS]),\s*"
        r"Elev\.\s*(null|[\d\.]+)\s*m"
    )

    m = re.search(pattern, loc_str, re.IGNORECASE)
    if not m:
        return np.nan, np.nan, np.nan

    lon_val, lon_dir, lat_val, lat_dir, elev_val = m.groups()

    lon = float(lon_val) * (-1 if lon_dir.upper() == "W" else 1)
    lat = float(lat_val) * (-1 if lat_dir.upper() == "S" else 1)

    elev = np.nan if elev_val.lower() == "null" else float(elev_val)

    return lat, lon, elev


def parse_old_new_lat_lon_elev(loc_str):
    """
    Returns:
    (old_lat, old_lon, old_elev, new_lat, new_lon, new_elev)
    """
    if pd.isna(loc_str):
        return (np.nan,) * 6

    if "->" in loc_str:
        old_str, new_str = map(str.strip, loc_str.split("->", 1))
    else:
        old_str = new_str = loc_str.strip()

    old_lat, old_lon, old_elev = _parse_single_location(old_str)
    new_lat, new_lon, new_elev = _parse_single_location(new_str)

    return (
        old_lat, old_lon, old_elev,
        new_lat, new_lon, new_elev
    )

cols = [
    'old_lat', 'old_lon', 'old_elev',
    'new_lat', 'new_lon', 'new_elev'
]

df_loc[cols] = df_loc['Unique Location (String)'].apply(
    lambda x: pd.Series(parse_old_new_lat_lon_elev(x))
)
# 
df_loc = df_loc.drop(columns=['Unique Location (String)'])


df_loc = df_loc.dropna(
    subset=['new_lat', 'new_lon', 'new_elev'],
    how='all'
)

df_loc
# Out:
# /tmp/ipykernel_55237/64680190.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loc[cols] = df_loc['Unique Location (String)'].apply(
# /tmp/ipykernel_55237/64680190.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loc[cols] = df_loc['Unique Location (String)'].apply(
# /tmp/ipykernel_55237/64680190.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loc[cols] = df_loc['Unique Location (String)'].apply(
# /tmp/ipykernel_55237/64680190.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loc[cols] = df_loc['Unique Location (String)'].apply(
# /tmp/ipykernel_55237/64680190.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loc[cols] = df_loc['Unique Location (String)'].apply(
# /tmp/ipykernel_55237/64680190.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loc[cols] = df_loc['Unique Location (String)'].apply(
#                                                  ISSUE  Station ID  \
# 0                                          Attribution        2322
# 2                                          Attribution       12610
# 3                                          Attribution       12608
# 4                                          Attribution       12529
# 5                                          Attribution       12538
# 6                                          Attribution       12602
# 7                                          Attribution       12607
# 8                                          Attribution       12583
# 26                 Attribution, Concatenate and delete       12563
# 37                           Attribution, ID, Location       12960
# 38                           Attribution, ID, Location       11433
# 39                           Attribution, ID, Location       11431
# 40                           Attribution, ID, Location       11430
# 41                           Attribution, ID, Location       11432
# 43                           Attribution, ID, Location       12036
# 45                           Attribution, ID, Location       12038
# 46                           Attribution, ID, Location       12039
# 47                           Attribution, ID, Location       12042
# 48                           Attribution, ID, Location       12089
# 49             Attribution, ID, Location, Missing Data        2628
# 50   Attribution, ID, Location, Missing Data (Diffe...       12220
# 52                       Attribution, ID, Missing Data        2634
# 55                     Attribution, ID, Name, Location       13011
# 56                     Attribution, ID, Name, Location       13012
# 57                     Attribution, ID, Name, Location       13013
# 58                     Attribution, ID, Name, Location       13014
# 59                     Attribution, ID, Name, Location        2647
# 60   Attribution, ID, Name, Location, Concatenate w...       12582
# 61   Attribution, ID, Name, Location, Concatenate w...       12949
# 62       Attribution, ID, Name, Location, missing data       12530
# 63       Attribution, ID, Name, Location, Missing Data       12589
# 64       Attribution, ID, Name, Location, Missing Data       12532
# 65       Attribution, ID, Name, Location, Missing Data       12593
# 67       Attribution, ID, Name, Location, Missing Data       12601
# 68       Attribution, ID, Name, Location, Missing Data       12591
# 69       Attribution, ID, Name, Location, Missing Data       12536
# 70       Attribution, ID, Name, Location, Missing Data       12549
# 71       Attribution, ID, Name, Location, Missing Data       12556
# 72       Attribution, ID, Name, Location, Missing Data       12603
# 73       Attribution, ID, Name, Location, Missing Data       12600
# 74       Attribution, ID, Name, Location, Missing Data       12558
# 75   Attribution, ID, Name, Location, Missing Data ...       12562
# 78                               Attribution, Location       11017
# 89                     Attribution, ID, Name, Location       12208
# 90                               Location, Attribution        2321
# 92                               Location, Attribution        2338
# 93                               Location, Attribution        2339
# 94                               Location, Attribution        2350
# 95                               Location, Attribution        3300
# 96                               Location, Attribution        3301
# 97                               Location, Attribution       12453
# 98                         Name, Location, Attribution       12458
# 99                         Name, Location, Attribution       12526
# 100                        Name, Location, Attribution       12957
#
#      Network ID    old_lat     old_lon  old_elev    new_lat     new_lon  \
# 0            12  49.667300 -115.214400    1051.0  50.370100 -126.433900
# 2             9  49.227045 -122.894487       NaN  49.227045 -122.894487
# 3             9  49.132800 -122.694200       NaN  49.134235 -122.695491
# 4             9  49.021500 -122.326600       NaN  49.021500 -122.326500
# 5             9  49.288100 -122.791400       NaN  49.288300 -122.791600
# 6             9  49.158300 -122.901700       NaN  49.158300 -122.901700
# 7             9  49.141400 -123.108300       NaN  49.141400 -123.108200
# 8             9  49.186400 -123.152200       NaN  49.186300 -123.152400
# 26            9  49.280800 -122.849200       NaN  49.280900 -122.849300
# 37           12        NaN         NaN       NaN  49.079600 -125.766600
# 38           12  51.968033 -116.714817    1442.0  51.968100 -116.714500
# 39           12  51.366433 -116.526433    1275.0  51.366500 -116.526400
# 40           12  51.023367 -115.978917    1277.0  51.019400 -115.976600
# 41           12  50.769117 -115.950817    1132.0  50.769100 -115.951000
# 43           12  51.022033 -118.207233     527.0  51.022000 -118.207400
# 45           12  51.234383 -117.681050    1308.0  51.234800 -117.680800
# 46           12  51.414883 -117.474083     835.0  51.414800 -117.474300
# 47           12  51.314533 -117.374083    1638.0  51.314500 -117.373900
# 48            9  49.279400 -122.971100     133.0  49.279200 -122.970700
# 49            9  49.159722 -122.942222     160.0  49.165700 -133.960700
# 50            9  49.245300 -122.708900      20.0  49.245300 -122.708900
# 52            9  49.372778 -123.279722      60.0  49.368600 -123.276700
# 55           12        NaN         NaN       NaN  49.444910 -123.103940
# 56           12        NaN         NaN       NaN  49.485889 -122.946306
# 57           12        NaN         NaN       NaN  49.363861 -122.753611
# 58            9  54.223200 -130.290450       NaN  54.223200 -130.290450
# 59            9  49.216667 -122.716667       3.0  49.209440 -122.706110
# 60            9  49.260290 -123.077811       NaN  49.260290 -123.077811
# 61            9  49.260290 -123.077811       NaN  49.260290 -123.077811
# 62            9  49.238032 -121.762334       NaN  49.238008 -121.762264
# 63            9  49.042800 -122.309700       NaN  49.042600 -122.308900
# 64            9  49.279700 -122.922200       NaN  49.279800 -122.922300
# 65            9  49.287500 -123.007800       NaN  49.287500 -123.008000
# 67            9  49.287800 -122.985600       NaN  49.287900 -122.985600
# 68            9  49.266700 -122.935600       NaN  49.266700 -122.935500
# 69            9  49.156100 -121.940600       NaN  49.155800 -121.940300
# 70            9  49.369700 -121.499400       NaN  49.369800 -121.499100
# 71            9  49.095600 -122.566900       NaN  49.095600 -122.567100
# 72            9  49.323900 -123.083600       NaN  49.323900 -123.083500
# 73            9  49.215000 -122.581900       NaN  49.214900 -122.582100
# 74            9  49.141490 -122.311078       NaN  49.141490 -122.310780
# 75            9  49.245300 -122.708900       NaN  49.245200 -122.708900
# 78           12  52.279579 -126.890543    1260.0  52.279900 -126.890200
# 89            9  49.301700 -123.020300      15.0  49.301500 -123.020400
# 90           12  48.571100 -124.200600     296.0  48.571300 -124.200000
# 92           12  50.132420 -126.928230     130.0  50.132420 -126.928230
# 93           12  49.428050 -123.564840     593.0  49.428000 -123.564900
# 94           12  50.103480 -124.613730      91.0  50.103480 -124.614600
# 95           12  50.270920 -125.130900     132.0  50.270920 -125.130900
# 96           12  49.585500 -123.387220     154.0  49.585500 -123.387300
# 97           12  49.610222 -126.032697      77.0  49.610222 -126.032697
# 98           12  50.267806 -127.079611     462.0  50.265100 -127.083500
# 99           12  49.207400 -125.121800     341.0  49.207500 -125.121800
# 100          12        NaN         NaN       NaN  50.171100 -125.575700
#
#      new_elev
# 0       515.0
# 2        45.0
# 3        79.0
# 4        65.0
# 5        38.0
# 6       113.0
# 7         4.0
# 8         1.0
# 26       13.0
# 37       24.0
# 38     1442.0
# 39     1276.0
# 40     1272.0
# 41     1120.0
# 43      533.0
# 45     1306.0
# 46      826.0
# 47     1636.0
# 48      104.0
# 49        6.0
# 50        4.0
# 52       65.0
# 55      295.0
# 56      375.0
# 57      352.0
# 58       39.0
# 59       15.0
# 60       29.0
# 61       29.0
# 62       23.0
# 63       58.0
# 64      360.0
# 65       70.0
# 67      200.0
# 68      101.0
# 69       12.0
# 70       40.0
# 71       88.0
# 72       71.0
# 73       50.0
# 74       74.0
# 75       10.0
# 78     1275.0
# 89        4.0
# 90      294.0
# 92      120.0
# 93      615.0
# 94      103.0
# 95      140.0
# 96      140.0
# 97       71.0
# 98      384.0
# 99      354.0
# 100     289.0

# %%
check_sql = sa.text("""
SELECT
    station_id,
    lat,
    lon,
    elev
FROM meta_history
WHERE station_id = :station_id
""")


with engine.begin() as conn:
    for _, row in df_loc.iterrows():

        station_id = int(row["Station ID"])

        old_lat  = row["old_lat"]
        old_lon  = row["old_lon"]
        old_elev = row["old_elev"]

        new_lat  = row["new_lat"]
        new_lon  = row["new_lon"]
        new_elev = row["new_elev"]

        # --- 1. Read current DB values ---
        db_row = conn.execute(
            check_sql,
            {"station_id": station_id}
        ).fetchone()

        if db_row is None:
            print(f"❌ Station {station_id} not found in DB")
            continue

        # --- 2. Compare with expected OLD values ---
        def norm(x):
            if pd.isna(x):
                return None
            return round(float(x), 6)

        def same(a, b):
            return norm(a) == norm(b)

        if not (
            same(db_row.lat,  old_lat) and
            same(db_row.lon,  old_lon) and
            same(db_row.elev, old_elev)
        ):
            print(
                f"⚠️ Station {station_id} skipped (DB values differ)\n"
                f"   DB : lat={db_row.lat}, lon={db_row.lon}, elev={db_row.elev}\n"
                f"   XLS: lat={old_lat}, lon={old_lon}, elev={old_elev}"
            )
            continue
# Out:
# ⚠️ Station 2322 skipped (DB values differ)
#    DB : lat=50.3689, lon=-126.4336, elev=510
#    XLS: lat=49.6673, lon=-115.2144, elev=1051.0

# %%
import numpy as np

update_sql = sa.text("""
UPDATE meta_history
SET
    lat  = :new_lat,
    lon  = :new_lon,
    elev = :new_elev
WHERE station_id = :station_id
""")

with engine.begin() as conn:
    for _, row in df_loc.iterrows():

        station_id = int(row["Station ID"])

        old_lat  = row["old_lat"]
        old_lon  = row["old_lon"]
        old_elev = row["old_elev"]

        new_lat  = row["new_lat"]
        new_lon  = row["new_lon"]
        new_elev = row["new_elev"]

        # --- 1. Read current DB values ---
        db_row = conn.execute(
            check_sql,
            {"station_id": station_id}
        ).fetchone()

        if db_row is None:
            print(f"❌ Station {station_id} not found in DB")
            continue

        # --- 3. Perform update ---
        result = conn.execute(
            update_sql,
            {
                "station_id": station_id,
                "new_lat": new_lat,
                "new_lon": new_lon,
                "new_elev": new_elev,
            }
        )

        if result.rowcount == 1:
            print(
                f"✅ Updated station {station_id}: "
                f"({old_lat}, {old_lon}, {old_elev}) → "
                f"({new_lat}, {new_lon}, {new_elev})"
            )
        else:
            print(f"⚠️ Station {station_id}: no update applied")
# Out:
# ✅ Updated station 2322: (49.6673, -115.2144, 1051.0) → (50.3701, -126.4339, 515.0)
# ✅ Updated station 12610: (49.227045, -122.894487, nan) → (49.227045, -122.894487, 45.0)
# ✅ Updated station 12608: (49.1328, -122.6942, nan) → (49.134235, -122.695491, 79.0)
# ✅ Updated station 12529: (49.0215, -122.3266, nan) → (49.0215, -122.3265, 65.0)
# ✅ Updated station 12538: (49.2881, -122.7914, nan) → (49.2883, -122.7916, 38.0)
# ✅ Updated station 12602: (49.1583, -122.9017, nan) → (49.1583, -122.9017, 113.0)
# ✅ Updated station 12607: (49.1414, -123.1083, nan) → (49.1414, -123.1082, 4.0)
# ✅ Updated station 12583: (49.1864, -123.1522, nan) → (49.1863, -123.1524, 1.0)
# ✅ Updated station 12563: (49.2808, -122.8492, nan) → (49.2809, -122.8493, 13.0)
# ✅ Updated station 12960: (nan, nan, nan) → (49.0796, -125.7666, 24.0)
# ✅ Updated station 11433: (51.96803333, -116.7148167, 1442.0) → (51.9681, -116.7145, 1442.0)
# ✅ Updated station 11431: (51.36643333, -116.5264333, 1275.0) → (51.3665, -116.5264, 1276.0)
# ✅ Updated station 11430: (51.02336667, -115.9789167, 1277.0) → (51.0194, -115.9766, 1272.0)
# ✅ Updated station 11432: (50.76911667, -115.9508167, 1132.0) → (50.7691, -115.951, 1120.0)
# ✅ Updated station 12036: (51.02203333, -118.2072333, 527.0) → (51.022, -118.2074, 533.0)
# ✅ Updated station 12038: (51.23438333, -117.68105, 1308.0) → (51.2348, -117.6808, 1306.0)
# ✅ Updated station 12039: (51.41488333, -117.4740833, 835.0) → (51.4148, -117.4743, 826.0)
# ✅ Updated station 12042: (51.31453333, -117.3740833, 1638.0) → (51.3145, -117.3739, 1636.0)
# ✅ Updated station 12089: (49.2794, -122.9711, 133.0) → (49.2792, -122.9707, 104.0)
# ✅ Updated station 2628: (49.15972222, -122.9422222, 160.0) → (49.1657, -133.9607, 6.0)
# ✅ Updated station 12220: (49.2453, -122.7089, 20.0) → (49.2453, -122.7089, 4.0)
# ✅ Updated station 2634: (49.37277778, -123.2797222, 60.0) → (49.3686, -123.2767, 65.0)
# ✅ Updated station 13011: (nan, nan, nan) → (49.44491, -123.10394, 295.0)
# ✅ Updated station 13012: (nan, nan, nan) → (49.48588889, -122.9463056, 375.0)
# ✅ Updated station 13013: (nan, nan, nan) → (49.36386111, -122.7536111, 352.0)
# ✅ Updated station 13014: (54.2231999, -130.29045, nan) → (54.2231999, -130.29045, 39.0)
# ✅ Updated station 2647: (49.21666667, -122.7166667, 3.0) → (49.20944, -122.70611, 15.0)
# ✅ Updated station 12582: (49.26029, -123.077811, nan) → (49.26029, -123.077811, 29.0)
# ✅ Updated station 12949: (49.26029, -123.077811, nan) → (49.26029, -123.077811, 29.0)
# ✅ Updated station 12530: (49.238032, -121.762334, nan) → (49.238008, -121.762264, 23.0)
# ✅ Updated station 12589: (49.0428, -122.3097, nan) → (49.0426, -122.3089, 58.0)
# ✅ Updated station 12532: (49.2797, -122.9222, nan) → (49.2798, -122.9223, 360.0)
# ✅ Updated station 12593: (49.2875, -123.0078, nan) → (49.2875, -123.008, 70.0)
# ✅ Updated station 12601: (49.2878, -122.9856, nan) → (49.2879, -122.9856, 200.0)
# ✅ Updated station 12591: (49.2667, -122.9356, nan) → (49.2667, -122.9355, 101.0)
# ✅ Updated station 12536: (49.1561, -121.9406, nan) → (49.1558, -121.9403, 12.0)
# ✅ Updated station 12549: (49.3697, -121.4994, nan) → (49.3698, -121.4991, 40.0)
# ✅ Updated station 12556: (49.0956, -122.5669, nan) → (49.0956, -122.5671, 88.0)
# ✅ Updated station 12603: (49.3239, -123.0836, nan) → (49.3239, -123.0835, 71.0)
# ✅ Updated station 12600: (49.215, -122.5819, nan) → (49.2149, -122.5821, 50.0)
# ✅ Updated station 12558: (49.14149, -122.311078, nan) → (49.14149, -122.31078, 74.0)
# ✅ Updated station 12562: (49.2453, -122.7089, nan) → (49.2452, -122.7089, 10.0)
# ✅ Updated station 11017: (52.279579, -126.890543, 1260.0) → (52.2799, -126.8902, 1275.0)
# ✅ Updated station 12208: (49.3017, -123.0203, 15.0) → (49.3015, -123.0204, 4.0)
# ✅ Updated station 2321: (48.5711, -124.2006, 296.0) → (48.5713, -124.2, 294.0)
# ✅ Updated station 2338: (50.13242, -126.92823, 130.0) → (50.13242, -126.92823, 120.0)
# ✅ Updated station 2339: (49.42805, -123.56484, 593.0) → (49.428, -123.5649, 615.0)
# ✅ Updated station 2350: (50.10348, -124.61373, 91.0) → (50.10348, -124.6146, 103.0)
# ✅ Updated station 3300: (50.27092, -125.1309, 132.0) → (50.27092, -125.1309, 140.0)
# ✅ Updated station 3301: (49.5855, -123.38722, 154.0) → (49.5855, -123.3873, 140.0)
# ✅ Updated station 12453: (49.610222, -126.032697, 77.0) → (49.610222, -126.032697, 71.0)
# ✅ Updated station 12458: (50.2678056, -127.0796111, 462.0) → (50.2651, -127.0835, 384.0)
# ✅ Updated station 12526: (49.2074, -125.1218, 341.0) → (49.2075, -125.1218, 354.0)
# ✅ Updated station 12957: (nan, nan, nan) → (50.1711, -125.5757, 289.0)

# %% [markdown]
# #### Attribution update

# %%
df_attribution = df_attribution[['ISSUE','Station ID', 'Network ID', 'Network Name']]
df_attribution

def split_network_name(name):
    if pd.isna(name):
        return pd.Series([None, None, 0])

    parts = [p.strip() for p in name.split("->")]

    if len(parts) == 2:
        old_name, new_name = parts
        n_names = 2
    else:
        old_name = new_name = parts[0]
        n_names = 1

    return pd.Series([old_name, new_name, n_names])
    

df_attribution[['old_net_name', 'new_net_name', 'n_net_names']] = (
    df_attribution['Network Name'].apply(split_network_name)
)

df_attribution
# Out:
# /tmp/ipykernel_55237/508565202.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution[['old_net_name', 'new_net_name', 'n_net_names']] = (
# /tmp/ipykernel_55237/508565202.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution[['old_net_name', 'new_net_name', 'n_net_names']] = (
#            ISSUE  Station ID  Network ID            Network Name old_net_name  \
# 0    Attribution        2322          12          BC-FWx-> BC-TS       BC-FWx
# 1    Attribution        2633           9      BC-Air -> MVRD-AIR       BC-Air
# 2    Attribution       12610           9      BC-Air -> MVRD-AIR       BC-Air
# 3    Attribution       12608           9      BC-Air -> MVRD-AIR       BC-Air
# 4    Attribution       12529           9      BC-Air -> MVRD-AIR       BC-Air
# ..           ...         ...         ...                     ...          ...
# 132  Attribution        2571          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 133  Attribution        2513          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 134  Attribution        2554          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 135  Attribution        2543          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 136  Attribution        2534          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
#
#     new_net_name  n_net_names
# 0          BC-TS            2
# 1       MVRD-AIR            2
# 2       MVRD-AIR            2
# 3       MVRD-AIR            2
# 4       MVRD-AIR            2
# ..           ...          ...
# 132  BCH-GSO-HMP            2
# 133  BCH-GSO-HMP            2
# 134  BCH-GSO-HMP            2
# 135  BCH-GSO-HMP            2
# 136  BCH-GSO-HMP            2
#
# [137 rows x 7 columns]

# %%
### Check if the new_net_name exist
from sqlalchemy import text

new_net_name = df_attribution['new_net_name'].unique()

exists_sql = text("""
SELECT EXISTS (
    SELECT network_id
    FROM meta_network 
    WHERE network_display_name = :network_name
)
""")


existing_networks = set()

for name in new_net_name:
    exists = session.execute(
        exists_sql,
        {"network_name": name}
    ).scalar()

    if exists:
        existing_networks.add(name)

existing_networks
# Out:
# {'BC-Air',
#  'BC-FERN',
#  'BC-TS',
#  'BCH-GSO-HMP',
#  'BCH-SiteC',
#  'MVRD-WS',
#  'PC-FWx',
#  'PRPA'}

# %%
df_attribution_2attri = df_attribution[df_attribution['n_net_names'] == 2]

df_attribution_2attri['new_net_name'] = (
    df_attribution_2attri['new_net_name']
    .replace(['MVRD-AIR', 'MVRD'], 'MVRD-AQ')
)

df_attribution_2attri
# Out:
# /tmp/ipykernel_55237/3822543348.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution_2attri['new_net_name'] = (
#            ISSUE  Station ID  Network ID            Network Name old_net_name  \
# 0    Attribution        2322          12          BC-FWx-> BC-TS       BC-FWx
# 1    Attribution        2633           9      BC-Air -> MVRD-AIR       BC-Air
# 2    Attribution       12610           9      BC-Air -> MVRD-AIR       BC-Air
# 3    Attribution       12608           9      BC-Air -> MVRD-AIR       BC-Air
# 4    Attribution       12529           9      BC-Air -> MVRD-AIR       BC-Air
# ..           ...         ...         ...                     ...          ...
# 132  Attribution        2571          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 133  Attribution        2513          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 134  Attribution        2554          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 135  Attribution        2543          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
# 136  Attribution        2534          14  BC-Snow -> BCH-GSO-HMP      BC-Snow
#
#     new_net_name  n_net_names
# 0          BC-TS            2
# 1        MVRD-AQ            2
# 2        MVRD-AQ            2
# 3        MVRD-AQ            2
# 4        MVRD-AQ            2
# ..           ...          ...
# 132  BCH-GSO-HMP            2
# 133  BCH-GSO-HMP            2
# 134  BCH-GSO-HMP            2
# 135  BCH-GSO-HMP            2
# 136  BCH-GSO-HMP            2
#
# [136 rows x 7 columns]

# %% [markdown]
# ### select the netwok_id based on new_net_name, summarize back to the table

# %%
# Create an empty column first
df_attribution_2attri['new_network_id'] = None

with engine.connect() as conn:
    for idx, row in df_attribution_2attri.iterrows():
        # Query network_id for this row's new_net_name
        res = conn.execute(
            sa.text("""
                SELECT network_id
                FROM meta_network
                WHERE network_display_name = :network_name
            """),
            {"network_name": row['new_net_name']}
        ).mappings().fetchone()

        if res is not None:
            df_attribution_2attri.at[idx, 'new_network_id'] = res['network_id']
        else:
            print(f"❌ Network '{row['new_net_name']}' not found for station {row['Station ID']}")

df_attribution_2attri[0:50]
# Out:
# /tmp/ipykernel_55237/3936967325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution_2attri['new_network_id'] = None
#                                       ISSUE  Station ID  Network ID  \
# 0                               Attribution        2322          12
# 1                               Attribution        2633           9
# 2                               Attribution       12610           9
# 3                               Attribution       12608           9
# 4                               Attribution       12529           9
# 5                               Attribution       12538           9
# 6                               Attribution       12602           9
# 7                               Attribution       12607           9
# 8                               Attribution       12583           9
# 9                               Attribution        2632           9
# 10                              Attribution        1591           9
# 11                              Attribution        1584           9
# 12                              Attribution        2569          14
# 13                              Attribution        2532          14
# 14                              Attribution        2551          14
# 15                              Attribution        2521          14
# 16                              Attribution        2567          14
# 17                              Attribution        2522          14
# 18                              Attribution        2548          14
# 19                              Attribution        2547          14
# 20                              Attribution        2541          14
# 21                              Attribution        2565          14
# 22                              Attribution        2526          14
# 23                 Attribution, Concatenate       12559           9
# 24      Attribution, Concatenate and delete       12592           9
# 25      Attribution, Concatenate and delete       12611           9
# 26      Attribution, Concatenate and delete       12563           9
# 27   Attribution, Delete Reference to 12532       12090           9
# 28   Attribution, Delete Reference to 12536        2644           9
# 29   Attribution, Delete Reference to 12549        1588           9
# 30   Attribution, Delete Reference to 12556       12191           9
# 31   Attribution, Delete Reference to 12558       12200           9
# 32   Attribution, Delete Reference to 12600       12196           9
# 33   Attribution, Delete Reference to 12601       12204           9
# 34   Attribution, Delete Reference to 12603       12207           9
# 35    Attribution, Delete Reference to 2634       12160           9
# 36                          Attribution, ID       12951           9
# 37                Attribution, ID, Location       12960          12
# 38                Attribution, ID, Location       11433          12
# 39                Attribution, ID, Location       11431          12
# 40                Attribution, ID, Location       11430          12
# 41                Attribution, ID, Location       11432          12
# 42                Attribution, ID, Location       12037          12
# 43                Attribution, ID, Location       12036          12
# 44                Attribution, ID, Location       12051          12
# 45                Attribution, ID, Location       12038          12
# 46                Attribution, ID, Location       12039          12
# 47                Attribution, ID, Location       12042          12
# 48                Attribution, ID, Location       12089           9
# 49  Attribution, ID, Location, Missing Data        2628           9
#
#               Network Name old_net_name new_net_name  n_net_names  \
# 0           BC-FWx-> BC-TS       BC-FWx        BC-TS            2
# 1       BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 2       BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 3       BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 4       BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 5       BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 6       BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 7       BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 8       BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 9       BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 10      BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 11      BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 12  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 13  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 14  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 15  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 16  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 17  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 18  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 19  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 20  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 21  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 22  BC-Snow -> BCH-GSO-HMP      BC-Snow  BCH-GSO-HMP            2
# 23     BC-Air -> BCH-SiteC       BC-Air    BCH-SiteC            2
# 24      BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 25      BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 26      BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 27          BC-Air -> MVRD       BC-Air      MVRD-AQ            2
# 28          BC-Air -> MVRD       BC-Air      MVRD-AQ            2
# 29          BC-Air -> MVRD       BC-Air      MVRD-AQ            2
# 30          BC-Air -> MVRD       BC-Air      MVRD-AQ            2
# 31          BC-Air -> MVRD       BC-Air      MVRD-AQ            2
# 32          BC-Air -> MVRD       BC-Air      MVRD-AQ            2
# 33      BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 34      BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 35          BC-Air -> MVRD       BC-Air      MVRD-AQ            2
# 36     BC-Air -> BCH-SiteC       BC-Air    BCH-SiteC            2
# 37        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 38        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 39        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 40        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 41        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 42        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 43        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 44        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 45        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 46        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 47        BC-FWx -> PC-FWx       BC-FWx       PC-FWx            2
# 48      BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
# 49      BC-Air -> MVRD-AIR       BC-Air      MVRD-AQ            2
#
#    new_network_id
# 0              71
# 1              72
# 2              72
# 3              72
# 4              72
# 5              72
# 6              72
# 7              72
# 8              72
# 9              72
# 10             72
# 11             72
# 12              5
# 13              5
# 14              5
# 15              5
# 16              5
# 17              5
# 18              5
# 19              5
# 20              5
# 21              5
# 22              5
# 23             70
# 24             72
# 25             72
# 26             72
# 27             72
# 28             72
# 29             72
# 30             72
# 31             72
# 32             72
# 33             72
# 34             72
# 35             72
# 36             70
# 37             75
# 38             75
# 39             75
# 40             75
# 41             75
# 42             75
# 43             75
# 44             75
# 45             75
# 46             75
# 47             75
# 48             72
# 49             72

# %%
check_sql = sa.text("""
SELECT
    s.station_id,
    n.network_id,
    n.network_display_name
FROM meta_network as n
JOIN meta_station as s ON n.network_id = s.network_id
WHERE s.station_id = :station_id
AND n.network_id = :network_id

""")


with engine.connect() as conn:
    for _, row in df_attribution_2attri.iterrows():

        res = conn.execute(
            check_sql,
            {
                "station_id": int(row["Station ID"]),
                "network_id": int(row["Network ID"]),
            }
        ).fetchone()

        if res is None:
            print(f"❌ Station {row['Station ID']} not found")
            continue

        db_network_name = res[2]

        if db_network_name == row["old_net_name"]:
            print(
                f"✅ OK to update station {res.station_id}: "
                f"{db_network_name} → {row['new_net_name']}"
            )
        else:
            print(
                f"⚠️ Mismatch for station {res.station_id}: "
                f"DB={db_network_name}, expected={row['old_net_name']}"
            )
# Out:
# ✅ OK to update station 2322: BC-FWx → BC-TS
# ✅ OK to update station 2633: BC-Air → MVRD-AQ
# ✅ OK to update station 12610: BC-Air → MVRD-AQ
# ✅ OK to update station 12608: BC-Air → MVRD-AQ
# ✅ OK to update station 12529: BC-Air → MVRD-AQ
# ✅ OK to update station 12538: BC-Air → MVRD-AQ
# ✅ OK to update station 12602: BC-Air → MVRD-AQ
# ✅ OK to update station 12607: BC-Air → MVRD-AQ
# ✅ OK to update station 12583: BC-Air → MVRD-AQ
# ✅ OK to update station 2632: BC-Air → MVRD-AQ
# ✅ OK to update station 1591: BC-Air → MVRD-AQ
# ✅ OK to update station 1584: BC-Air → MVRD-AQ
# ✅ OK to update station 2569: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2532: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2551: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2521: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2567: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2522: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2548: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2547: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2541: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2565: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2526: BC-Snow → BCH-GSO-HMP
# ❌ Station 12559 not found
# ✅ OK to update station 12592: BC-Air → MVRD-AQ
# ✅ OK to update station 12611: BC-Air → MVRD-AQ
# ✅ OK to update station 12563: BC-Air → MVRD-AQ
# ✅ OK to update station 12090: BC-Air → MVRD-AQ
# ✅ OK to update station 2644: BC-Air → MVRD-AQ
# ✅ OK to update station 1588: BC-Air → MVRD-AQ
# ✅ OK to update station 12191: BC-Air → MVRD-AQ
# ✅ OK to update station 12200: BC-Air → MVRD-AQ
# ✅ OK to update station 12196: BC-Air → MVRD-AQ
# ✅ OK to update station 12204: BC-Air → MVRD-AQ
# ✅ OK to update station 12207: BC-Air → MVRD-AQ
# ✅ OK to update station 12160: BC-Air → MVRD-AQ
# ✅ OK to update station 12951: BC-Air → BCH-SiteC
# ✅ OK to update station 12960: BC-FWx → PC-FWx
# ✅ OK to update station 11433: BC-FWx → PC-FWx
# ✅ OK to update station 11431: BC-FWx → PC-FWx
# ✅ OK to update station 11430: BC-FWx → PC-FWx
# ✅ OK to update station 11432: BC-FWx → PC-FWx
# ✅ OK to update station 12037: BC-FWx → PC-FWx
# ✅ OK to update station 12036: BC-FWx → PC-FWx
# ✅ OK to update station 12051: BC-FWx → PC-FWx
# ✅ OK to update station 12038: BC-FWx → PC-FWx
# ✅ OK to update station 12039: BC-FWx → PC-FWx
# ✅ OK to update station 12042: BC-FWx → PC-FWx
# ✅ OK to update station 12089: BC-Air → MVRD-AQ
# ✅ OK to update station 2628: BC-Air → MVRD-AQ
# ✅ OK to update station 12220: BC-Air → MVRD-AQ
# ✅ OK to update station 12092: BC-Air → MVRD-AQ
# ✅ OK to update station 2634: BC-Air → MVRD-AQ
# ✅ OK to update station 12269: BC-Air → MVRD-AQ
# ✅ OK to update station 12232: BC-Air → MVRD-AQ
# ✅ OK to update station 13011: BC-FWx → MVRD-WS
# ✅ OK to update station 13012: BC-FWx → MVRD-WS
# ✅ OK to update station 13013: BC-FWx → MVRD-WS
# ✅ OK to update station 13014: BC-Air → PRPA
# ✅ OK to update station 2647: BC-Air → MVRD-AQ
# ✅ OK to update station 12582: BC-Air → MVRD-AQ
# ✅ OK to update station 12949: BC-Air → MVRD-AQ
# ✅ OK to update station 12530: BC-Air → MVRD-AQ
# ✅ OK to update station 12589: BC-Air → MVRD-AQ
# ✅ OK to update station 12532: BC-Air → MVRD-AQ
# ✅ OK to update station 12593: BC-Air → MVRD-AQ
# ✅ OK to update station 12533: BC-Air → MVRD-AQ
# ✅ OK to update station 12601: BC-Air → MVRD-AQ
# ✅ OK to update station 12591: BC-Air → MVRD-AQ
# ✅ OK to update station 12536: BC-Air → MVRD-AQ
# ✅ OK to update station 12549: BC-Air → MVRD-AQ
# ✅ OK to update station 12556: BC-Air → MVRD-AQ
# ✅ OK to update station 12603: BC-Air → MVRD-AQ
# ✅ OK to update station 12600: BC-Air → MVRD-AQ
# ✅ OK to update station 12558: BC-Air → MVRD-AQ
# ✅ OK to update station 12562: BC-Air → MVRD-AQ
# ✅ OK to update station 12311: BC-Air → MVRD-AQ
# ✅ OK to update station 12104: BC-Air → MVRD-AQ
# ✅ OK to update station 11017: BC-FWx → BC-FERN
# ✅ OK to update station 12464: BC-FWx → BC-FERN
# ✅ OK to update station 12291: BC-Air → MVRD-AQ
# ✅ OK to update station 2641: BC-Air → MVRD-AQ
# ✅ OK to update station 2637: BC-Air → MVRD-AQ
# ✅ OK to update station 12091: BC-Air → MVRD-AQ
# ✅ OK to update station 1581: BC-Air → MVRD-AQ
# ✅ OK to update station 12086: BC-Air → MVRD-AQ
# ✅ OK to update station 12074: BC-Air → MVRD-AQ
# ✅ OK to update station 12551: BC-Air → MVRD-AQ
# ✅ OK to update station 12208: BC-Air → MVRD-AQ
# ✅ OK to update station 2321: BC-FWx → BC-TS
# ✅ OK to update station 2325: BC-FWx → BC-TS
# ✅ OK to update station 2338: BC-FWx → BC-TS
# ✅ OK to update station 2339: BC-FWx → BC-TS
# ✅ OK to update station 2350: BC-FWx → BC-TS
# ✅ OK to update station 3300: BC-FWx → BC-TS
# ✅ OK to update station 3301: BC-FWx → BC-TS
# ✅ OK to update station 12453: BC-FWx → BC-TS
# ✅ OK to update station 12458: BC-FWx → BC-TS
# ✅ OK to update station 12526: BC-FWx → BC-TS
# ✅ OK to update station 12957: BC-FWx → BC-TS
# ✅ OK to update station 12545: BC-Air → BCH-SiteC
# ✅ OK to update station 2556: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2576: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2523: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2528: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2527: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2555: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2564: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2574: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2540: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2531: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2538: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2575: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2517: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2544: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 12498: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2542: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2559: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2550: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2578: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2577: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2570: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2553: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2530: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 12499: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 12500: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2515: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2563: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2580: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 12497: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2536: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2571: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2513: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2554: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2543: BC-Snow → BCH-GSO-HMP
# ✅ OK to update station 2534: BC-Snow → BCH-GSO-HMP

# %%
Just select station_id, then update network_name (new_net_name) and network_id (new_network_id) to the new ones in the form

# %%
update_sql = sa.text("""
UPDATE meta_station
SET network_id = :new_network_id
FROM meta_network AS n
WHERE meta_station.station_id = :station_id
  AND meta_station.network_id = n.network_id
""")

update_network_sql = sa.text("""
UPDATE meta_network AS n
SET network_display_name = :new_network_name
WHERE n.network_id = :new_network_id
""")

with engine.begin() as conn:  # auto-commit / rollback
    for _, row in df_attribution_2attri.iterrows():

        # 1. Update the network_id in meta_station
        result_station = conn.execute(
            update_sql,
            {
                "station_id": int(row["Station ID"]),
                "new_network_id": int(row["new_network_id"])
            }
        )

        # 2. Update the network_display_name in meta_network
        result_network = conn.execute(
            update_network_sql,
            {
                "new_network_id": int(row["new_network_id"]),
                "new_network_name": row["new_net_name"]
            }
        )

        # ✅ Print checks
        if result_station.rowcount == 1 and result_network.rowcount == 1:
            print(
                f"✅ Station {row['Station ID']} updated: "
                f"network_id → {row['new_network_id']}, "
                f"network_display_name → {row['new_net_name']}"
            )
        else:
            print(f"⚠️ Check station {row['Station ID']}, updates may have failed")
# Out:
# ✅ Station 2322 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 2633 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12610 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12608 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12529 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12538 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12602 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12607 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12583 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 2632 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 1591 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 1584 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 2569 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2532 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2551 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2521 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2567 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2522 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2548 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2547 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2541 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2565 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2526 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 12559 updated: network_id → 70, network_display_name → BCH-SiteC
# ✅ Station 12592 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12611 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12563 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12090 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 2644 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 1588 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12191 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12200 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12196 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12204 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12207 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12160 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12951 updated: network_id → 70, network_display_name → BCH-SiteC
# ✅ Station 12960 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 11433 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 11431 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 11430 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 11432 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 12037 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 12036 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 12051 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 12038 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 12039 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 12042 updated: network_id → 75, network_display_name → PC-FWx
# ✅ Station 12089 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 2628 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12220 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12092 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 2634 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12269 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12232 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 13011 updated: network_id → 15, network_display_name → MVRD-WS
# ✅ Station 13012 updated: network_id → 15, network_display_name → MVRD-WS
# ✅ Station 13013 updated: network_id → 15, network_display_name → MVRD-WS
# ✅ Station 13014 updated: network_id → 76, network_display_name → PRPA
# ✅ Station 2647 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12582 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12949 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12530 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12589 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12532 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12593 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12533 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12601 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12591 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12536 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12549 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12556 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12603 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12600 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12558 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12562 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12311 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12104 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 11017 updated: network_id → 11, network_display_name → BC-FERN
# ✅ Station 12464 updated: network_id → 11, network_display_name → BC-FERN
# ✅ Station 12291 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 2641 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 2637 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12091 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 1581 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12086 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12074 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12551 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 12208 updated: network_id → 72, network_display_name → MVRD-AQ
# ✅ Station 2321 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 2325 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 2338 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 2339 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 2350 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 3300 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 3301 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 12453 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 12458 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 12526 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 12957 updated: network_id → 71, network_display_name → BC-TS
# ✅ Station 12545 updated: network_id → 70, network_display_name → BCH-SiteC
# ✅ Station 2556 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2576 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2523 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2528 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2527 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2555 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2564 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2574 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2540 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2531 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2538 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2575 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2517 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2544 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 12498 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2542 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2559 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2550 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2578 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2577 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2570 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2553 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2530 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 12499 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 12500 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2515 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2563 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2580 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 12497 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2536 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2571 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2513 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2554 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2543 updated: network_id → 5, network_display_name → BCH-GSO-HMP
# ✅ Station 2534 updated: network_id → 5, network_display_name → BCH-GSO-HMP

# %%
check_sql = sa.text("""
SELECT
    s.station_id,
    n.network_id,
    n.network_display_name
FROM meta_network as n
JOIN meta_station as s ON n.network_id = s.network_id
WHERE s.station_id = :station_id

""")


with engine.connect() as conn:
    for _, row in df_attribution_2attri.iterrows():

        res = conn.execute(
            check_sql,
            {
                "station_id": int(row["Station ID"]),
            }
        ).fetchone()

        if res is None:
            print(f"❌ Station {row['Station ID']} not found")
            continue
        db_network_id = res[1]
        db_network_name = res[2]

        if db_network_id == row["new_network_id"] and db_network_name == row["new_net_name"]:

            print(
                f"✅ Verified: station {res.station_id}: "
                f"{db_network_id} → {row['new_network_id']}, "
                f"{db_network_name} → {row['new_net_name']}"
            )
        else:
            print(
                f"⚠️ Verification failed for station {res.station_id}: "
                f"DB={db_network_name}, expected={row['new_net_name']}"
            )
# Out:
# ✅ Verified: station 2322: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 2633: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12610: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12608: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12529: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12538: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12602: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12607: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12583: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 2632: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 1591: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 1584: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 2569: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2532: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2551: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2521: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2567: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2522: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2548: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2547: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2541: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2565: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2526: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 12559: 70 → 70, BCH-SiteC → BCH-SiteC
# ✅ Verified: station 12592: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12611: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12563: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12090: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 2644: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 1588: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12191: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12200: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12196: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12204: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12207: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12160: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12951: 70 → 70, BCH-SiteC → BCH-SiteC
# ✅ Verified: station 12960: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 11433: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 11431: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 11430: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 11432: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 12037: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 12036: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 12051: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 12038: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 12039: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 12042: 75 → 75, PC-FWx → PC-FWx
# ✅ Verified: station 12089: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 2628: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12220: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12092: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 2634: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12269: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12232: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 13011: 15 → 15, MVRD-WS → MVRD-WS
# ✅ Verified: station 13012: 15 → 15, MVRD-WS → MVRD-WS
# ✅ Verified: station 13013: 15 → 15, MVRD-WS → MVRD-WS
# ✅ Verified: station 13014: 76 → 76, PRPA → PRPA
# ✅ Verified: station 2647: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12582: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12949: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12530: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12589: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12532: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12593: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12533: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12601: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12591: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12536: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12549: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12556: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12603: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12600: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12558: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12562: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12311: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12104: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 11017: 11 → 11, BC-FERN → BC-FERN
# ✅ Verified: station 12464: 11 → 11, BC-FERN → BC-FERN
# ✅ Verified: station 12291: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 2641: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 2637: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12091: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 1581: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12086: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12074: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12551: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 12208: 72 → 72, MVRD-AQ → MVRD-AQ
# ✅ Verified: station 2321: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 2325: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 2338: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 2339: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 2350: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 3300: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 3301: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 12453: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 12458: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 12526: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 12957: 71 → 71, BC-TS → BC-TS
# ✅ Verified: station 12545: 70 → 70, BCH-SiteC → BCH-SiteC
# ✅ Verified: station 2556: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2576: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2523: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2528: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2527: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2555: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2564: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2574: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2540: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2531: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2538: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2575: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2517: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2544: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 12498: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2542: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2559: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2550: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2578: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2577: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2570: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2553: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2530: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 12499: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 12500: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2515: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2563: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2580: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 12497: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2536: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2571: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2513: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2554: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2543: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP
# ✅ Verified: station 2534: 5 → 5, BCH-GSO-HMP → BCH-GSO-HMP

# %% [markdown]
# ### Only one attributes gives

# %%
df_attribution_1attri = df_attribution[df_attribution['n_net_names'] == 1]

df_attribution_1attri['new_net_name'] = (
    df_attribution_1attri['new_net_name']
    .replace(['MVRD-AIR', 'MVRD'], 'MVRD-AQ')
)

df_attribution_1attri
# Out:
# /tmp/ipykernel_55237/2229839121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution_1attri['new_net_name'] = (
#                        ISSUE  Station ID  Network ID Network Name  \
# 88  Concatenate, Attribution       12560           9       BC-Air
#
#    old_net_name new_net_name  n_net_names
# 88       BC-Air       BC-Air            1

# %%
check_sql = sa.text("""
SELECT
    s.station_id,
    n.network_id,
    n.network_display_name
FROM meta_network as n
JOIN meta_station as s ON n.network_id = s.network_id
WHERE s.station_id = :station_id

""")


with engine.connect() as conn:
    for _, row in df_attribution_1attri.iterrows():

        res = conn.execute(
            check_sql,
            {
                "station_id": int(row["Station ID"]),
            }
        ).fetchone()

        if res is None:
            print(f"❌ Station {row['Station ID']} not found")
            continue
        db_network_id = res[1]
        db_network_name = res[2]

        if db_network_name == row["old_net_name"]:
            print(
                f"✅ OK to update station {res.station_id}: "
                f"{db_network_name} → {row['new_net_name']}, "
                f"DB={db_network_id}, expected={row['Network ID']}"

            )
        else:
            print(
                f"⚠️ Mismatch for station {res.station_id}: "
                f"DB={db_network_name}, expected={row['old_net_name']}, "
                f"DB={db_network_id}, expected={row['Network ID']}"
            )
# Out:
# ✅ OK to update station 12560: BC-Air → BC-Air, DB=9, expected=9

# %%
### Don't need to run the left part

# %%
# Create an empty column first
df_attribution_1attri['new_network_id'] = None

with engine.connect() as conn:
    for idx, row in df_attribution_1attri.iterrows():
        # Query network_id for this row's new_net_name
        res = conn.execute(
            sa.text("""
                SELECT network_id
                FROM meta_network
                WHERE network_name = :network_name
            """),
            {"network_name": row['new_net_name']}
        ).mappings().fetchone()

        if res is not None:
            df_attribution_1attri.at[idx, 'new_network_id'] = res['network_id']
        else:
            print(f"❌ Network '{row['new_net_name']}' not found for station {row['Station ID']}")

df_attribution_1attri[0:50]
# Out:
# ❌ Network 'BC-Air' not found for station 12560
# /tmp/ipykernel_55237/1611397296.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attribution_1attri['new_network_id'] = None
#                        ISSUE  Station ID  Network ID Network Name  \
# 88  Concatenate, Attribution       12560           9       BC-Air
#
#    old_net_name new_net_name  n_net_names new_network_id
# 88       BC-Air       BC-Air            1           None

# %%
check_sql = sa.text("""
SELECT
    s.station_id,
    n.network_id,
    n.network_display_name
FROM meta_network as n
JOIN meta_station as s ON n.network_id = s.network_id
WHERE s.station_id = :station_id

""")


with engine.connect() as conn:
    for _, row in df_attribution_1attri.iterrows():

        res = conn.execute(
            check_sql,
            {
                "station_id": int(row["Station ID"]),
            }
        ).fetchone()

        if res is None:
            print(f"❌ Station {row['Station ID']} not found")
            continue

        db_network_id = res[1]
        db_network_name = res[2]

        if db_network_name == row["old_net_name"]:
            print(
                f"✅ OK to update station {res.station_id}: "
                f"{db_network_name} → {row['new_net_name']}"
            )
        else:
            print(
                f"⚠️ Mismatch for station {res.station_id}: "
                f"DB={db_network_id}, {db_network_name}; "
                f"Change to: {row['new_network_id']}, {row['new_net_name']}"

            )
# Out:
# ✅ OK to update station 12560: BC-Air → BC-Air
