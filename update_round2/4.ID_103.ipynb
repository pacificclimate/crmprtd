# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

# %%
import sqlalchemy as sa
from sqlalchemy.orm import Session
from crmprtd import setup_logging
from pycds import Station, History

save_path = './comparison_forms/'

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"
log_file_path = save_path

engine = sa.create_engine(db_url, echo=False)
session = Session(engine)

session

# %%
path = '/workspaces/crmprtd/update_round2/input_tables/'
df = pd.read_excel(path + '20251223-Metadata-AllRequiredChanges_round2.xlsx', header = 1)   # pandas automatically uses openpyxl
df_id = df[
    df["ISSUE"]
    .astype(str) == "ID"
]

df_id
# Out:
#     ISSUE  Network ID Network Name       Native ID  Station ID  \
# 740    ID         9.0       BC-Air  M116006 -> 347      2587.0
# 741    ID         9.0       BC-Air   E230617 -> 22      1560.0
# 742    ID         9.0       BC-Air  E238240 -> 310      2627.0
# 743    ID         9.0       BC-Air  M114017 -> 343      1556.0
# 744    ID         9.0       BC-Air  E225267 -> 104      1562.0
# ..    ...         ...          ...             ...         ...
# 838    ID         9.0       BC-Air  E248623 -> 199      2604.0
# 839    ID         9.0       BC-Air  0550502 -> 549     12324.0
# 841    ID         9.0       BC-Air   0500886 ->102     12170.0
# 861    ID         9.0       BC-Air  E295729 -> 450     12083.0
# 862    ID         9.0       BC-Air    E257435-> 97      2609.0
#
#                          Unique Names  \
# 740                    100 Mile House
# 741                Ainsworth 100 Mile
# 742           Boston Bar RCMP Station
# 743                         Brilliant
# 744            Burns Lake Fire Centre
# ..                                ...
# 838       Williams Lake Canadian Tire
# 839  Williams Lake Columneetza School
# 841                   Kelowna College
# 861              Bessborough 237 Road
# 862            Birch Bank Golf Course
#
#                       Unique Location (String)            Unique Records  \
# 740     121.375 W, 51.65416667 N, Elev. 1000 m  1992-11-11 to 1998-09-28
# 741     121.365 W, 51.65333333 N, Elev. 1063 m  1998-09-30 to 2018-06-16
# 742     121.4425 W, 49.86583333 N, Elev. 180 m  1999-07-08 to 2002-06-20
# 743  117.6402778 W, 49.32166667 N, Elev. 449 m  1993-05-14 to 2002-07-31
# 744  125.7644444 W, 54.23083333 N, Elev. 652 m  1997-03-08 to 2025-07-20
# ..                                         ...                       ...
# 838      122.1313889 W, 52.1175 N, Elev. 578 m  2002-06-13 to 2018-09-24
# 839      122.150391 W, 52.14428 N, Elev. 631 m  2018-08-01 to 2025-07-20
# 841     119.477367 W, 49.862336 N, Elev. 347 m  2009-01-01 to 2019-06-03
# 861     120.483611 W, 55.791944 N, Elev. 665 m  2015-09-22 to 2025-07-20
# 862  117.7330556 W, 49.15805556 N, Elev. 527 m  2004-11-08 to 2025-07-20
#
#     Uniq Obs Freqs                                          Variables  ...  \
# 740         Hourly  Temperature (Mean)|Wind Direction (Point)|Wind...  ...
# 741         Hourly  Precipitation Amount|Precipitation Climatology...  ...
# 742         Hourly  Relative Humidity (Point)|Temperature (Mean)|W...  ...
# 743         Hourly  Temperature (Mean)|Wind Direction (Point)|Wind...  ...
# 744         Hourly  Relative Humidity|Relative Humidity (Point)|Te...  ...
# ..             ...                                                ...  ...
# 838         Hourly  Precipitation Amount|Relative Humidity|Relativ...  ...
# 839         Hourly  Relative Humidity|Relative Humidity (Point)|Te...  ...
# 841         Hourly  Relative Humidity|Relative Humidity (Point)|Te...  ...
# 861         Hourly  Temperature (Mean)|Wind Direction (Point)|Wind...  ...
# 862         Hourly  Relative Humidity|Relative Humidity (Point)|Te...  ...
#
#      SITE TYPE OWNER FIRE CENTRE FIRE ZONE LATITUDE LONGITUDE  ELEVATION  \
# 740        NaN   NaN         NaN       NaN      NaN       NaN        NaN
# 741        NaN   NaN         NaN       NaN      NaN       NaN        NaN
# 742        NaN   NaN         NaN       NaN      NaN       NaN        NaN
# 743        NaN   NaN         NaN       NaN      NaN       NaN        NaN
# 744        NaN   NaN         NaN       NaN      NaN       NaN        NaN
# ..         ...   ...         ...       ...      ...       ...        ...
# 838        NaN   NaN         NaN       NaN      NaN       NaN        NaN
# 839        NaN   NaN         NaN       NaN      NaN       NaN        NaN
# 841        NaN   NaN         NaN       NaN      NaN       NaN        NaN
# 861        NaN   NaN         NaN       NaN      NaN       NaN        NaN
# 862        NaN   NaN         NaN       NaN      NaN       NaN        NaN
#
#     Unnamed: 50 Unnamed: 51 Unnamed: 52
# 740         NaN         NaN         NaN
# 741         NaN         NaN         NaN
# 742         NaN         NaN         NaN
# 743         NaN         NaN         NaN
# 744         NaN         NaN         NaN
# ..          ...         ...         ...
# 838         NaN         NaN         NaN
# 839         NaN         NaN         NaN
# 841         NaN         NaN         NaN
# 861         NaN         NaN         NaN
# 862         NaN         NaN         NaN
#
# [103 rows x 53 columns]

# %%
df_id
df_new = df_id[['Native ID', 'Station ID']].copy()


# Split on '->'
split_ids = df_new['Native ID'].astype(str).str.split('->', expand=True)

df_new['old_native_id'] = split_ids[0].str.strip()
df_new['new_native_id'] = split_ids[1].str.strip()

df_new = df_new.drop(columns=['Native ID'])
df_new["Station ID"] = pd.to_numeric(df_new["Station ID"], errors="coerce").astype("Int64")

df_new
# Out:
#      Station ID old_native_id new_native_id
# 740        2587       M116006           347
# 741        1560       E230617            22
# 742        2627       E238240           310
# 743        1556       M114017           343
# 744        1562       E225267           104
# ..          ...           ...           ...
# 838        2604       E248623           199
# 839       12324       0550502           549
# 841       12170       0500886           102
# 861       12083       E295729           450
# 862        2609       E257435            97
#
# [103 rows x 3 columns]

# %% [markdown]
# ### In the db

# %%
import sqlalchemy as sa
from sqlalchemy.orm import Session
from crmprtd import setup_logging
from pycds import Station, History

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"
log_file_path = save_path

engine = sa.create_engine(db_url, echo=False)
session = Session(engine)

session

# %%
check_sql = sa.text("""
SELECT station_id, native_id
FROM meta_station
WHERE station_id = :station_id
""")

with engine.connect() as conn:
    for _, row in df_new.iterrows():
        res = conn.execute(
            check_sql,
            {"station_id": int(row["Station ID"])}
        ).fetchone()

        if res is None:
            print(f"❌ Station {row['Station ID']} not found")
            continue

        db_native_id = res.native_id

        if db_native_id == row["old_native_id"]:
            print(
                f"✅ OK to update station {res.station_id}: "
                f"{db_native_id} → {row['new_native_id']}"
            )
        else:
            print(
                f"⚠️ Mismatch for station {res.station_id}: "
                f"DB={db_native_id}, expected={row['old_native_id']}"
            )
# Out:
# ✅ OK to update station 2587: M116006 → 347
# ✅ OK to update station 1560: E230617 → 22
# ✅ OK to update station 2627: E238240 → 310
# ✅ OK to update station 1556: M114017 → 343
# ✅ OK to update station 1562: E225267 → 104
# ✅ OK to update station 12093: E292669 → 439
# ✅ OK to update station 2616: M114009 → 98
# ✅ OK to update station 1585: E253229 → 166
# ✅ OK to update station 12103: E240337 → 553
# ✅ OK to update station 12105: E285829 → 526
# ✅ OK to update station 12427: E313510 → 551
# ✅ OK to update station 2608: E256215 → 99
# ✅ OK to update station 2599: M114018 → 31
# ✅ OK to update station 1571: E262799 → 354
# ✅ OK to update station 1590: M101004 → 37
# ✅ OK to update station 12116: E220217 → 39
# ✅ OK to update station 3280: E277329 → 523
# ✅ OK to update station 12428: E311128 → 537
# ✅ OK to update station 2642: E251329 → 44
# ✅ OK to update station 2639: E231478 → 47
# ✅ OK to update station 12129: E295892 → 464
# ✅ OK to update station 2611: E239298 → 396
# ✅ OK to update station 2620: E250350 → 50
# ✅ OK to update station 1577: 0770705 → 399
# ✅ OK to update station 1564: M111068 → 54
# ✅ OK to update station 2591: E256895 → 357
# ✅ OK to update station 2594: E243003 → 19
# ✅ OK to update station 1572: E262779 → 56
# ✅ OK to update station 2610: E223885 → 342
# ✅ OK to update station 2626: E254955 → 64
# ✅ OK to update station 2602: M107004 → 3
# ✅ OK to update station 12162: E303935 → 481
# ✅ OK to update station 1578: M116003 → 66
# ✅ OK to update station 12166: 0605008 → 267
# ✅ OK to update station 12462: E317850 → 571
# ✅ OK to update station 2617: E272963 → 70
# ✅ OK to update station 2645: M106008 → 72
# ✅ OK to update station 12176: E282711 → 271
# ✅ OK to update station 12177: E223616 → 75
# ✅ OK to update station 1592: M106009 → 73
# ✅ OK to update station 12182: E216670 → 279
# ✅ OK to update station 12185: E223615 → 80
# ✅ OK to update station 12186: E286269 → 418
# ✅ OK to update station 1579: E255714 → 82
# ✅ OK to update station 1561: E248774 → 85
# ✅ OK to update station 2643: M104273 → 88
# ✅ OK to update station 2631: E249735 → 295
# ✅ OK to update station 2629: E264882 → 14
# ✅ OK to update station 2584: E230577 → 385
# ✅ OK to update station 1566: E264682 → 94
# ✅ OK to update station 2607: M114216 → 361
# ✅ OK to update station 2621: E260397 → 96
# ✅ OK to update station 2622: E257415 → 120
# ✅ OK to update station 2624: E244775 → 345
# ✅ OK to update station 2586: 0770703 → 107
# ✅ OK to update station 2598: E237631 → 110
# ✅ OK to update station 12223: E273483 → 263
# ✅ OK to update station 2635: M103335 → 298
# ✅ OK to update station 1583: E234430 → 114
# ✅ OK to update station 2638: E243949 → 325
# ✅ OK to update station 3278: E226338 → 117
# ✅ OK to update station 12238: E271963 → 122
# ✅ OK to update station 1587: E238705 → 126
# ✅ OK to update station 12248: E293670 → 280
# ✅ OK to update station 1569: M109940 → 403
# ✅ OK to update station 2595: E224014 → 138
# ✅ OK to update station 2597: M109915 → 405
# ✅ OK to update station 1568: M109943 → 406
# ✅ OK to update station 2605: M109913 → 142
# ✅ OK to update station 12254: 0450307 → 144
# ✅ OK to update station 2600: M109914 → 146
# ✅ OK to update station 1567: M109946 → 408
# ✅ OK to update station 2636: M106037 → 326
# ✅ OK to update station 1586: M102039 → 300
# ✅ OK to update station 1582: E233625 → 150
# ✅ OK to update station 2612: E208096 → 158
# ✅ OK to update station 1559: E248021 → 162
# ✅ OK to update station 1576: M101110 → 302
# ✅ OK to update station 1575: M101005 → 303
# ✅ OK to update station 2593: M115024 → 366
# ✅ OK to update station 12441: E315110 → 563
# ✅ OK to update station 12283: E206589 → 171
# ✅ OK to update station 2646: M104270 → 173
# ✅ OK to update station 12285: E304570 → 493
# ✅ OK to update station 12293: E304685 → 499
# ✅ OK to update station 2596: E234230 → 176
# ✅ OK to update station 2614: 0770708 → 179
# ✅ OK to update station 1557: E230557 → 213
# ✅ OK to update station 1558: M107028 → 185
# ✅ OK to update station 12297: E300350 → 473
# ✅ OK to update station 12300: 0250009 → 189
# ✅ OK to update station 12309: E282169 → 266
# ✅ OK to update station 1563: E269223 → 207
# ✅ OK to update station 2619: E249492 → 194
# ✅ OK to update station 2648: E260701 → 203
# ✅ OK to update station 1593: 0110031 → 205
# ✅ OK to update station 1589: E231866 → 8
# ✅ OK to update station 2585: M109011 → 377
# ✅ OK to update station 2604: E248623 → 199
# ✅ OK to update station 12324: 0550502 → 549
# ✅ OK to update station 12170: 0500886 → 102
# ✅ OK to update station 12083: E295729 → 450
# ✅ OK to update station 2609: E257435 → 97

# %%
update_station_sql = sa.text("""
UPDATE meta_station
SET native_id = :new_native_id
WHERE station_id = :station_id
  AND native_id = :old_native_id
""")

with engine.begin() as conn:
    for _, row in df_new.iterrows():
        result = conn.execute(
            update_station_sql,
            {
                "station_id": int(row["Station ID"]),
                "old_native_id": row["old_native_id"],
                "new_native_id": row["new_native_id"],
            }
        )

        if result.rowcount == 1:
            print(
                f"✅ Updated station {row['Station ID']}: "
                f"{row['old_native_id']} → {row['new_native_id']}"
            )
        else:
            # check why it failed
            res = conn.execute(
                check_sql,
                {"station_id": int(row["Station ID"])}
            ).fetchone()

            if res is None:
                print(f"❌ Station {row['Station ID']} not found")
            else:
                print(
                    f"⚠️ Skipped station {row['Station ID']}: "
                    f"DB={res.native_id}, expected={row['old_native_id']}"
                )
# Out:
# ✅ Updated station 2587: M116006 → 347
# ✅ Updated station 1560: E230617 → 22
# ✅ Updated station 2627: E238240 → 310
# ✅ Updated station 1556: M114017 → 343
# ✅ Updated station 1562: E225267 → 104
# ✅ Updated station 12093: E292669 → 439
# ✅ Updated station 2616: M114009 → 98
# ✅ Updated station 1585: E253229 → 166
# ✅ Updated station 12103: E240337 → 553
# ✅ Updated station 12105: E285829 → 526
# ✅ Updated station 12427: E313510 → 551
# ✅ Updated station 2608: E256215 → 99
# ✅ Updated station 2599: M114018 → 31
# ✅ Updated station 1571: E262799 → 354
# ✅ Updated station 1590: M101004 → 37
# ✅ Updated station 12116: E220217 → 39
# ✅ Updated station 3280: E277329 → 523
# ✅ Updated station 12428: E311128 → 537
# ✅ Updated station 2642: E251329 → 44
# ✅ Updated station 2639: E231478 → 47
# ✅ Updated station 12129: E295892 → 464
# ✅ Updated station 2611: E239298 → 396
# ✅ Updated station 2620: E250350 → 50
# ✅ Updated station 1577: 0770705 → 399
# ✅ Updated station 1564: M111068 → 54
# ✅ Updated station 2591: E256895 → 357
# ✅ Updated station 2594: E243003 → 19
# ✅ Updated station 1572: E262779 → 56
# ✅ Updated station 2610: E223885 → 342
# ✅ Updated station 2626: E254955 → 64
# ✅ Updated station 2602: M107004 → 3
# ✅ Updated station 12162: E303935 → 481
# ✅ Updated station 1578: M116003 → 66
# ✅ Updated station 12166: 0605008 → 267
# ✅ Updated station 12462: E317850 → 571
# ✅ Updated station 2617: E272963 → 70
# ✅ Updated station 2645: M106008 → 72
# ✅ Updated station 12176: E282711 → 271
# ✅ Updated station 12177: E223616 → 75
# ✅ Updated station 1592: M106009 → 73
# ✅ Updated station 12182: E216670 → 279
# ✅ Updated station 12185: E223615 → 80
# ✅ Updated station 12186: E286269 → 418
# ✅ Updated station 1579: E255714 → 82
# ✅ Updated station 1561: E248774 → 85
# ✅ Updated station 2643: M104273 → 88
# ✅ Updated station 2631: E249735 → 295
# ✅ Updated station 2629: E264882 → 14
# ✅ Updated station 2584: E230577 → 385
# ✅ Updated station 1566: E264682 → 94
# ✅ Updated station 2607: M114216 → 361
# ✅ Updated station 2621: E260397 → 96
# ✅ Updated station 2622: E257415 → 120
# ✅ Updated station 2624: E244775 → 345
# ✅ Updated station 2586: 0770703 → 107
# ✅ Updated station 2598: E237631 → 110
# ✅ Updated station 12223: E273483 → 263
# ✅ Updated station 2635: M103335 → 298
# ✅ Updated station 1583: E234430 → 114
# ✅ Updated station 2638: E243949 → 325
# ✅ Updated station 3278: E226338 → 117
# ✅ Updated station 12238: E271963 → 122
# ✅ Updated station 1587: E238705 → 126
# ✅ Updated station 12248: E293670 → 280
# ✅ Updated station 1569: M109940 → 403
# ✅ Updated station 2595: E224014 → 138
# ✅ Updated station 2597: M109915 → 405
# ✅ Updated station 1568: M109943 → 406
# ✅ Updated station 2605: M109913 → 142
# ✅ Updated station 12254: 0450307 → 144
# ✅ Updated station 2600: M109914 → 146
# ✅ Updated station 1567: M109946 → 408
# ✅ Updated station 2636: M106037 → 326
# ✅ Updated station 1586: M102039 → 300
# ✅ Updated station 1582: E233625 → 150
# ✅ Updated station 2612: E208096 → 158
# ✅ Updated station 1559: E248021 → 162
# ✅ Updated station 1576: M101110 → 302
# ✅ Updated station 1575: M101005 → 303
# ✅ Updated station 2593: M115024 → 366
# ✅ Updated station 12441: E315110 → 563
# ✅ Updated station 12283: E206589 → 171
# ✅ Updated station 2646: M104270 → 173
# ✅ Updated station 12285: E304570 → 493
# ✅ Updated station 12293: E304685 → 499
# ✅ Updated station 2596: E234230 → 176
# ✅ Updated station 2614: 0770708 → 179
# ✅ Updated station 1557: E230557 → 213
# ✅ Updated station 1558: M107028 → 185
# ✅ Updated station 12297: E300350 → 473
# ✅ Updated station 12300: 0250009 → 189
# ✅ Updated station 12309: E282169 → 266
# ✅ Updated station 1563: E269223 → 207
# ✅ Updated station 2619: E249492 → 194
# ✅ Updated station 2648: E260701 → 203
# ✅ Updated station 1593: 0110031 → 205
# ✅ Updated station 1589: E231866 → 8
# ✅ Updated station 2585: M109011 → 377
# ✅ Updated station 2604: E248623 → 199
# ✅ Updated station 12324: 0550502 → 549
# ✅ Updated station 12170: 0500886 → 102
# ✅ Updated station 12083: E295729 → 450
# ✅ Updated station 2609: E257435 → 97

# %%
verify_sql = sa.text("""
SELECT native_id
FROM meta_station
WHERE station_id = :station_id
""")

with engine.begin() as conn:
    for _, row in df_new.iterrows():
        # verify
        res = conn.execute(
            verify_sql,
            {"station_id": int(row["Station ID"])}
        ).fetchone()

        if res and res.native_id == row["new_native_id"]:
            print(
                f"✅ Verified: station {row['Station ID']} "
                f"native_id = {res.native_id}"
            )
        else:
            print(
                f"⚠️ Verification failed for station {row['Station ID']}: "
                f"DB={res.native_id if res else None}, "
                f"expected={row['new_native_id']}"
            )
# Out:
# ✅ Verified: station 2587 native_id = 347
# ✅ Verified: station 1560 native_id = 22
# ✅ Verified: station 2627 native_id = 310
# ✅ Verified: station 1556 native_id = 343
# ✅ Verified: station 1562 native_id = 104
# ✅ Verified: station 12093 native_id = 439
# ✅ Verified: station 2616 native_id = 98
# ✅ Verified: station 1585 native_id = 166
# ✅ Verified: station 12103 native_id = 553
# ✅ Verified: station 12105 native_id = 526
# ✅ Verified: station 12427 native_id = 551
# ✅ Verified: station 2608 native_id = 99
# ✅ Verified: station 2599 native_id = 31
# ✅ Verified: station 1571 native_id = 354
# ✅ Verified: station 1590 native_id = 37
# ✅ Verified: station 12116 native_id = 39
# ✅ Verified: station 3280 native_id = 523
# ✅ Verified: station 12428 native_id = 537
# ✅ Verified: station 2642 native_id = 44
# ✅ Verified: station 2639 native_id = 47
# ✅ Verified: station 12129 native_id = 464
# ✅ Verified: station 2611 native_id = 396
# ✅ Verified: station 2620 native_id = 50
# ✅ Verified: station 1577 native_id = 399
# ✅ Verified: station 1564 native_id = 54
# ✅ Verified: station 2591 native_id = 357
# ✅ Verified: station 2594 native_id = 19
# ✅ Verified: station 1572 native_id = 56
# ✅ Verified: station 2610 native_id = 342
# ✅ Verified: station 2626 native_id = 64
# ✅ Verified: station 2602 native_id = 3
# ✅ Verified: station 12162 native_id = 481
# ✅ Verified: station 1578 native_id = 66
# ✅ Verified: station 12166 native_id = 267
# ✅ Verified: station 12462 native_id = 571
# ✅ Verified: station 2617 native_id = 70
# ✅ Verified: station 2645 native_id = 72
# ✅ Verified: station 12176 native_id = 271
# ✅ Verified: station 12177 native_id = 75
# ✅ Verified: station 1592 native_id = 73
# ✅ Verified: station 12182 native_id = 279
# ✅ Verified: station 12185 native_id = 80
# ✅ Verified: station 12186 native_id = 418
# ✅ Verified: station 1579 native_id = 82
# ✅ Verified: station 1561 native_id = 85
# ✅ Verified: station 2643 native_id = 88
# ✅ Verified: station 2631 native_id = 295
# ✅ Verified: station 2629 native_id = 14
# ✅ Verified: station 2584 native_id = 385
# ✅ Verified: station 1566 native_id = 94
# ✅ Verified: station 2607 native_id = 361
# ✅ Verified: station 2621 native_id = 96
# ✅ Verified: station 2622 native_id = 120
# ✅ Verified: station 2624 native_id = 345
# ✅ Verified: station 2586 native_id = 107
# ✅ Verified: station 2598 native_id = 110
# ✅ Verified: station 12223 native_id = 263
# ✅ Verified: station 2635 native_id = 298
# ✅ Verified: station 1583 native_id = 114
# ✅ Verified: station 2638 native_id = 325
# ✅ Verified: station 3278 native_id = 117
# ✅ Verified: station 12238 native_id = 122
# ✅ Verified: station 1587 native_id = 126
# ✅ Verified: station 12248 native_id = 280
# ✅ Verified: station 1569 native_id = 403
# ✅ Verified: station 2595 native_id = 138
# ✅ Verified: station 2597 native_id = 405
# ✅ Verified: station 1568 native_id = 406
# ✅ Verified: station 2605 native_id = 142
# ✅ Verified: station 12254 native_id = 144
# ✅ Verified: station 2600 native_id = 146
# ✅ Verified: station 1567 native_id = 408
# ✅ Verified: station 2636 native_id = 326
# ✅ Verified: station 1586 native_id = 300
# ✅ Verified: station 1582 native_id = 150
# ✅ Verified: station 2612 native_id = 158
# ✅ Verified: station 1559 native_id = 162
# ✅ Verified: station 1576 native_id = 302
# ✅ Verified: station 1575 native_id = 303
# ✅ Verified: station 2593 native_id = 366
# ✅ Verified: station 12441 native_id = 563
# ✅ Verified: station 12283 native_id = 171
# ✅ Verified: station 2646 native_id = 173
# ✅ Verified: station 12285 native_id = 493
# ✅ Verified: station 12293 native_id = 499
# ✅ Verified: station 2596 native_id = 176
# ✅ Verified: station 2614 native_id = 179
# ✅ Verified: station 1557 native_id = 213
# ✅ Verified: station 1558 native_id = 185
# ✅ Verified: station 12297 native_id = 473
# ✅ Verified: station 12300 native_id = 189
# ✅ Verified: station 12309 native_id = 266
# ✅ Verified: station 1563 native_id = 207
# ✅ Verified: station 2619 native_id = 194
# ✅ Verified: station 2648 native_id = 203
# ✅ Verified: station 1593 native_id = 205
# ✅ Verified: station 1589 native_id = 8
# ✅ Verified: station 2585 native_id = 377
# ✅ Verified: station 2604 native_id = 199
# ✅ Verified: station 12324 native_id = 549
# ✅ Verified: station 12170 native_id = 102
# ✅ Verified: station 12083 native_id = 450
# ✅ Verified: station 2609 native_id = 97
