# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sqlalchemy as sa
from sqlalchemy.orm import Session
from crmprtd import setup_logging
from pycds import Station, History
import pandas as pd
import numpy as np

save_path = './comparison_forms/'

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"
log_file_path = save_path

engine = sa.create_engine(db_url, echo=False)
session = Session(engine)

session

# %%
station_name = ['Judge Creek', 'Rithet Creek']

import pandas as pd
from sqlalchemy import text

stations = ['Judge Creek', 'Rithet Creek']

SQL = text("""
    SELECT 
        m.station_name,
        COUNT(o.obs_time) AS n_obs,
        MIN(o.obs_time) AS oldest,
        MAX(o.obs_time) AS newest
    FROM meta_history m
    LEFT JOIN obs_raw o ON o.history_id = m.history_id
    WHERE m.station_name = ANY(:stations)
    GROUP BY m.station_name
""")

with engine.connect() as conn:
    df = pd.read_sql(SQL, conn, params={"stations": stations})

print(df)
# Out:
#    station_name    n_obs              oldest     newest
# 0   Judge Creek  1782308 1994-10-28 15:00:00 2025-01-01
# 1  Rithet Creek  1672856 1995-11-22 00:00:00 2014-03-21

# %%
import pandas as pd
from sqlalchemy import text

stations = ['Judge Creek', 'Rithet Creek']

SQL_network = text("""
    SELECT 
        h.station_name,
        s.native_id,
        s.station_id,
        s.network_id,
        n.network_name,
        h.lat,
        h.lon
    FROM meta_station s
    JOIN meta_history h ON s.station_id = h.station_id
    JOIN meta_network n ON s.network_id = n.network_id
    WHERE h.station_name = ANY(:stations)
""")

with engine.connect() as conn:
    df_station_network = pd.read_sql(
        SQL_network,
        conn,
        params={"stations": stations}
    )

print(df_station_network)

network_ids = df_station_network["network_id"].unique().tolist()

SQL_vars = text("""
    SELECT DISTINCT
        v.*,
        s.network_id
    FROM meta_vars v
    JOIN meta_station s ON v.network_id = s.network_id
    WHERE v.network_id = ANY(:network_ids)
    ORDER BY s.network_id, v.net_var_name
""")

with engine.connect() as conn:
    df_vars = pd.read_sql(
        SQL_vars,
        conn,
        params={"network_ids": network_ids}
    )

    df_vars
# Out:
#    station_name native_id  station_id  network_id network_name        lat  \
# 0  Rithet Creek     FW002       12625          36          CRD  48.567500
# 1   Judge Creek     HY002       12626          36          CRD  48.585278
#
#           lon
# 0 -123.714167
# 1 -123.673611

# %%
SQL_vars = text("""
    SELECT DISTINCT
        v.*
    FROM meta_vars v
    WHERE v.net_var_name = 'WindSpeed'
""")

with engine.connect() as conn:
    df_vars = pd.read_sql(
        SQL_vars,
        conn,
        params={"network_ids": network_ids}
    )

df_vars
# Out:
#    vars_id  network_id   unit precision standard_name  cell_method  \
# 0      745          36    kph      None    wind_speed  time: point
# 1      819           5  m s-1      None    wind_speed   time: mean
#
#   long_description net_var_name       display_name  short_name  \
# 0             None    WindSpeed         Wind Speed        Wspd
# 1       Wind Speed    WindSpeed  Wind Speed (Mean)  Wind Speed
#
#                     mod_time mod_user
# 0 2025-02-11 16:03:39.747374     crmp
# 1 2025-02-11 16:03:39.747374     crmp

# %% [markdown]
# #### Insert variable first

# %%
TMax = dict(
    network_id=36,
    unit='celsius',
    standard_name='air_temperature',
    cell_method='time: maximum',
    description= 'Maximum hourly temperature',
    name='MAX_TEMP_h',
    display_name='Temperature (Max. h)',
    short_name='air_temperature_maximum_h',
)

TMin = dict(
    network_id=36,
    unit='celsius',
    standard_name='air_temperature',
    cell_method='time: minimum',
    description= 'Minimum hourly temperature',
    name='MIN_TEMP_h',
    display_name='Temperature (Min. h)',
    short_name='air_temperature_minimum_h',
)

RhMax = dict(
    network_id=36,
    unit='percent',
    standard_name='relative_humidity',
    cell_method='time: maximum',
    description=None,
    name='RelativeHumidity_Max',
    display_name='Relative Humidity (Max. h)',
    short_name='Rh_Max',
)

RhMin = dict(
    network_id=36,
    unit='percent',
    standard_name='relative_humidity',
    cell_method='time: minimum',
    description=None,
    name='RelativeHumidity_Min',
    display_name='Relative Humidity (Min. h)',
    short_name='Rh_Min',
)

Rn_1 = dict(
    network_id=36,
    unit='mm',
    standard_name='rainfall_amount',
    cell_method='time: sum',
    description= 'Hourly accumulated rainfall',
    name='Rain_h',
    display_name='Hourly Rainfall',
    short_name='Rn_1',
)

WSpd_1 = dict(
    network_id=36,
    unit='kph',
    standard_name='wind_speed',
    cell_method='time: mean',
    description= 'Hourly average wind speed',
    name='WindSpeed_mean',
    display_name='Wind Speed (mean)',
    short_name='Wspd_mean',
)

WSpd_Max = dict(
    network_id=36,
    unit='kph',
    standard_name='wind_speed',
    cell_method='time: maximum',
    description= 'maximum wind speed (gusts) over the last hour',
    name='WindSpeed_Max',
    display_name='Wind Speed (Max. h)',
    short_name='WSpd_Max',
)

variables_data = [TMax, TMin, RhMax, RhMin, Rn_1, WSpd_1, WSpd_Max]

# %%
from pycds import Variable
from sqlalchemy.inspection import inspect

existing = (
    session.query(Variable)
    .filter(
        Variable.network_id == 36,
        Variable.name.in_([v["name"] for v in variables_data]),
    )
    .all()
)

existing_names = {v.name for v in existing}

# Create only the missing ones
to_insert = [
    Variable(**v)
    for v in variables_data
    if v["name"] not in existing_names
]

session.add_all(to_insert)
session.commit()

# %% [markdown]
# ### Then insert all the obs records

# %%
df_station_network
# Out:
#    station_name native_id  station_id  network_id network_name        lat  \
# 0  Rithet Creek     FW002       12625          36          CRD  48.567500
# 1   Judge Creek     HY002       12626          36          CRD  48.585278
#
#           lon
# 0 -123.714167
# 1 -123.673611

# %% [markdown]
# ### generate rows

# %%
meta_path = '/workspaces/crmprtd/SSpencerFiles/'

file_names = ['JudgeCreek_raw_MetData_1994-2024.csv', 'RithetCreek_raw_MetData_1995-2014.csv']

import os
import pandas as pd

meta_path = '/workspaces/crmprtd/SSpencerFiles/'
file_names = [
    'JudgeCreek_raw_MetData_1994-2024.csv',
    'RithetCreek_raw_MetData_1995-2014.csv'
]

dfs = []

for file in file_names:
    path = os.path.join(meta_path, file)

    df = pd.read_csv(
        path,
        header=[0, 1]   # read two header rows
    )

    # ---- Combine header levels (e.g. Temp + C → Temp_C)
    df.columns = [
        f"{c1}_{c2}".strip("_")
        for c1, c2 in df.columns
    ]

    df['DateTime_DateTime'] = pd.to_datetime(
        df['DateTime_DateTime'],
        format='%d/%m/%Y %H:%M',
        errors='coerce'
    )


    dfs.append(df)

df_judge = dfs[0]
df_rithet = dfs[1]

# %%
df_judge
# Out:
#        StationName_Unnamed: 0_level_1   DateTime_DateTime  Prec_1_mm   Rh_%  \
# 0                         Judge Creek 1994-10-28 15:00:00        0.0   76.0
# 1                         Judge Creek 1994-10-28 16:00:00        0.0   76.0
# 2                         Judge Creek 1994-10-28 17:00:00        0.0   99.0
# 3                         Judge Creek 1994-10-28 18:00:00        0.0  100.0
# 4                         Judge Creek 1994-10-28 19:00:00        0.0  100.0
# ...                               ...                 ...        ...    ...
# 262970                    Judge Creek 2024-12-31 20:00:00        0.0   98.0
# 262971                    Judge Creek 2024-12-31 21:00:00        0.0   98.0
# 262972                    Judge Creek 2024-12-31 22:00:00        0.0   98.0
# 262973                    Judge Creek 2024-12-31 23:00:00        0.0   98.0
# 262974                    Judge Creek 2025-01-01 00:00:00        0.0   98.0
#
#         RhMax_%  RhMin_%  TMax_C  TMin_C  Temp_C
# 0           NaN      NaN     NaN     NaN     9.5
# 1           NaN      NaN     NaN     NaN     8.1
# 2           NaN      NaN     NaN     NaN     4.1
# 3           NaN      NaN     NaN     NaN     1.6
# 4           NaN      NaN     NaN     NaN     0.6
# ...         ...      ...     ...     ...     ...
# 262970     98.0     98.0     2.5     2.4     2.4
# 262971     98.0     98.0     2.4     2.2     2.2
# 262972     98.0     98.0     2.5     2.2     2.5
# 262973     98.0     98.0     2.6     2.5     2.6
# 262974     98.0     98.0     2.8     2.6     2.8
#
# [262975 rows x 9 columns]

# %%
from sqlalchemy import text
import pandas as pd

SQL_VARS_INFO = text("""
SELECT  *
FROM meta_vars 
WHERE network_id = :network_id
""")

net_vars = pd.read_sql(
    SQL_VARS_INFO,
    engine,
    params={"network_id": 36}
)

net_vars
# Out:
#     vars_id  network_id     unit precision  \
# 0       745          36      kph      None
# 1       744          36     W/m2      None
# 2       742          36       mm      None
# 3       743          36      hPa      None
# 4       737          36       mm      None
# 5       738          36       mm      None
# 6       740          36  percent      None
# 7       741          36        m      None
# 8       746          36  degrees      None
# 9       739          36  celsius      None
# 10     1313          36  celsius      None
# 11     1314          36  celsius      None
# 12     1315          36  percent      None
# 13     1316          36  percent      None
# 14     1317          36       mm      None
# 15     1318          36      kph      None
# 16     1319          36      kph      None
#
#                             standard_name    cell_method  \
# 0                              wind_speed    time: point
# 1                        solar_irradiance    time: point
# 2    lwe_thickness_of_surface_snow_amount    time: point
# 3                            air_pressure    time: point
# 4                         rainfall_amount      time: sum
# 5   lwe_thickness_of_precipitation_amount      time: sum
# 6                       relative_humidity    time: point
# 7                  surface_snow_thickness    time: point
# 8                     wind_from_direction    time: point
# 9                         air_temperature    time: point
# 10                        air_temperature  time: maximum
# 11                        air_temperature  time: minimum
# 12                      relative_humidity  time: maximum
# 13                      relative_humidity  time: minimum
# 14                        rainfall_amount      time: sum
# 15                             wind_speed     time: mean
# 16                             wind_speed  time: maximum
#
#                                  long_description          net_var_name  \
# 0                                            None             WindSpeed
# 1                                            None        SolarRadiation
# 2                                            None   SnowWaterEquivalent
# 3                                            None    BarometricPressure
# 4                                            None                  Rain
# 5                                            None         Precipitation
# 6                                            None      RelativeHumidity
# 7                                            None             SnowDepth
# 8                                            None         WindDirection
# 9                                            None        AirTemperature
# 10                     Maximum hourly temperature            MAX_TEMP_h
# 11                     Minimum hourly temperature            MIN_TEMP_h
# 12                                           None  RelativeHumidity_Max
# 13                                           None  RelativeHumidity_Min
# 14                    Hourly accumulated rainfall                Rain_h
# 15                      Hourly average wind speed        WindSpeed_mean
# 16  maximum wind speed (gusts) over the last hour         WindSpeed_Max
#
#                   display_name                 short_name  \
# 0                   Wind Speed                       Wspd
# 1              Solar Radiation                     PYRavg
# 2        Snow Water Equivalent                    SSG_SWE
# 3                 Air Pressure                         BP
# 4                         Rain                       Rn15
# 5                Precipitation                     Prec_1
# 6            Relative Humidity                         Rh
# 7                   Snow Depth                    SnowDep
# 8               Wind Direction                        Dir
# 9              Air temperature                       Temp
# 10        Temperature (Max. h)  air_temperature_maximum_h
# 11        Temperature (Min. h)  air_temperature_minimum_h
# 12  Relative Humidity (Max. h)                     Rh_Max
# 13  Relative Humidity (Min. h)                     Rh_Min
# 14             Hourly Rainfall                       Rn_1
# 15           Wind Speed (mean)                  Wspd_mean
# 16         Wind Speed (Max. h)                   WSpd_Max
#
#                      mod_time    mod_user
# 0  2025-02-11 16:03:39.747374        crmp
# 1  2025-02-11 16:03:39.747374        crmp
# 2  2025-02-11 16:03:39.747374        crmp
# 3  2025-02-11 16:03:39.747374        crmp
# 4  2025-02-11 16:03:39.747374        crmp
# 5  2025-02-11 16:03:39.747374        crmp
# 6  2025-02-11 16:03:39.747374        crmp
# 7  2025-02-11 16:03:39.747374        crmp
# 8  2025-02-11 16:03:39.747374        crmp
# 9  2025-02-11 16:03:39.747374        crmp
# 10 2026-02-24 15:07:54.533395  tongli1997
# 11 2026-02-24 15:07:54.533395  tongli1997
# 12 2026-02-24 15:07:54.533395  tongli1997
# 13 2026-02-24 15:07:54.533395  tongli1997
# 14 2026-02-24 15:07:54.533395  tongli1997
# 15 2026-02-24 15:07:54.533395  tongli1997
# 16 2026-02-24 15:07:54.533395  tongli1997

# %%
mapping_id = {
    'Prec_1_mm': 738,
    'Rh_%': 740,
    'WSpd_Unnamed: 9_level_1': 745,
    'Temp_C': 739,
    'Dir_deg': 746,

    'TMax_C': 1313,
    'TMin_C': 1314,
    'RhMax_%': 1315,
    'RhMin_%': 1316,
    'Rn_1_mm': 1317,
    'WSpd_1_kph': 1318,
    'Mx_Spd_kph': 1319
}


from sqlalchemy import text

SQL_vars = text("""
    SELECT v.vars_id, v.net_var_name, v.unit
    FROM meta_vars v
    WHERE v.vars_id IN :vars_ids
""")

vars_ids = tuple(mapping_id.values())

with engine.connect() as conn:
    df_vars = pd.read_sql(
        SQL_vars,
        conn,
        params={"vars_ids": vars_ids}
    )

df_mapping = pd.DataFrame(
    list(mapping_id.items()),
    columns=["var_name_raw", "vars_id"]
)

df_var = df_mapping.merge(df_vars, on="vars_id", how="left")

df_var
# Out:
#                var_name_raw  vars_id          net_var_name     unit
# 0                 Prec_1_mm      738         Precipitation       mm
# 1                      Rh_%      740      RelativeHumidity  percent
# 2   WSpd_Unnamed: 9_level_1      745             WindSpeed      kph
# 3                    Temp_C      739        AirTemperature  celsius
# 4                   Dir_deg      746         WindDirection  degrees
# 5                    TMax_C     1313            MAX_TEMP_h  celsius
# 6                    TMin_C     1314            MIN_TEMP_h  celsius
# 7                   RhMax_%     1315  RelativeHumidity_Max  percent
# 8                   RhMin_%     1316  RelativeHumidity_Min  percent
# 9                   Rn_1_mm     1317                Rain_h       mm
# 10               WSpd_1_kph     1318        WindSpeed_mean      kph
# 11               Mx_Spd_kph     1319         WindSpeed_Max      kph

# %%
df_rithet
# Out:
#        StationName_Unnamed: 0_level_1   DateTime_DateTime  TMax_C  TMin_C  \
# 0                    FWx Rithet Creek 1995-11-22 00:00:00     NaN     NaN
# 1                    FWx Rithet Creek 1995-11-22 01:00:00     NaN     NaN
# 2                    FWx Rithet Creek 1995-11-22 02:00:00     NaN     NaN
# 3                    FWx Rithet Creek 1995-11-22 03:00:00     NaN     NaN
# 4                    FWx Rithet Creek 1995-11-22 04:00:00     NaN     NaN
# ...                               ...                 ...     ...     ...
# 160630               FWx Rithet Creek 2014-03-20 20:00:00     2.4     1.4
# 160631               FWx Rithet Creek 2014-03-20 21:00:00     1.4     0.6
# 160632               FWx Rithet Creek 2014-03-20 22:00:00     0.6    -0.5
# 160633               FWx Rithet Creek 2014-03-20 23:00:00    -0.5    -1.4
# 160634               FWx Rithet Creek 2014-03-21 00:00:00    -1.3    -1.6
#
#         Temp_C  RhMax_%  RhMin_%  Rh_%  Rn_1_mm  WSpd_Unnamed: 9_level_1  \
# 0          NaN      0.0      0.0   0.0      0.0                      1.8
# 1          NaN      0.0      0.0   0.0      0.0                      1.8
# 2          NaN      0.0      0.0   0.0      0.3                      3.2
# 3          NaN      0.0      0.0   0.0      0.0                      5.3
# 4          NaN      0.0      0.0   0.0      0.0                      3.4
# ...        ...      ...      ...   ...      ...                      ...
# 160630     1.4     94.0     89.0  94.0      0.0                      0.0
# 160631     0.6     94.0     93.0  94.0      0.0                      0.0
# 160632    -0.5     95.0     94.0  95.0      0.0                      0.0
# 160633    -1.4     95.0     95.0  95.0      0.0                      0.0
# 160634    -1.3     96.0     95.0  96.0      0.0                      0.0
#
#         WSpd_1_kph  Dir_deg  Mx_Spd_kph
# 0              NaN    333.0         5.0
# 1              NaN    323.0         3.3
# 2              NaN    164.0         5.6
# 3              NaN    356.0         9.0
# 4              NaN      6.0         5.0
# ...            ...      ...         ...
# 160630         0.0      2.0         0.0
# 160631         0.0     23.0         0.0
# 160632         0.0     16.0         0.0
# 160633         0.0      4.0         0.0
# 160634         0.0    353.0         0.0
#
# [160635 rows x 13 columns]

# %% [markdown]
# ### The first station

# %%
from crmprtd import Row

### for the station Rithet Creek

df_station_1 = df_station_network.loc[
    df_station_network['station_name'] == 'Rithet Creek'
]

time_col = df_rithet['DateTime_DateTime']
variable_name = df_var['var_name_raw']
variable_name_db = df_var['net_var_name']
unit_db = df_var['unit']
network_name = df_station_1['network_name']
native_id = df_station_1['native_id']
lat = float(df_station_1['lat'].iloc[0])
lon = float(df_station_1['lon'].iloc[0])

time_col
variable_name


all_rows = []

# station metadata (extract scalar values!)
network_name = df_station_1['network_name'].iloc[0]
native_id = df_station_1['native_id'].iloc[0]
lat = df_station_1['lat'].iloc[0]
lon = df_station_1['lon'].iloc[0]

# loop over each time row
for _, row_i in df_rithet.iterrows():
    
    time_value = row_i['DateTime_DateTime']
    
    # loop over each variable mapping
    for _, var_row in df_var.iterrows():
        
        raw_name = var_row['var_name_raw']
        db_name = var_row['net_var_name']
        unit_db = var_row['unit']
        
        val = row_i.get(raw_name)
        
        if pd.notna(val):   # optional: skip NaNs
            all_rows.append(
                Row(
                    time=time_value,
                    val=val,
                    variable_name=db_name,
                    unit=unit_db,
                    network_name=network_name,
                    station_id=native_id,
                    lat=lat,
                    lon=lon
                )
            )

# %%
len(all_rows)
# Out:
# 1672856

# %%
import sys
sys.path.append("/workspaces/crmprtd/fern/FERNNorth2025_insert")

from auto_insert_func import *

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"

output_folder = '/workspaces/crmprtd/update_round2/output_tables/'

statin_name = df_station_1['station_name']


safe_insert_rows(
    all_rows,
    log_file_path=output_folder + str(statin_name) +'insert.log',
    db_url=db_url,
    chunk_size=5000,        # SAFE starting point
    bulk_chunk_size=1000,   # internal DB bulk insert size
)
# Out:
# 🚀 Starting insert: 1672856 rows in 335 chunks
# ➡️  Processing rows 0–4999
# {"asctime": "2026-02-24 23:19:15,785", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:16,263", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:16,731", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:17,203", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:17,632", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:18,082", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:18,084", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:18,086", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 0–4999
# ➡️  Processing rows 5000–9999
# {"asctime": "2026-02-24 23:19:18,148", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:18,643", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:19,079", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:19,591", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:20,005", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:20,440", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:20,442", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:20,444", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 5000–9999
# ➡️  Processing rows 10000–14999
# {"asctime": "2026-02-24 23:19:20,496", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:21,017", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:21,432", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:21,886", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:22,318", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:22,755", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:22,757", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:22,758", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 10000–14999
# ➡️  Processing rows 15000–19999
# {"asctime": "2026-02-24 23:19:22,814", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:23,318", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:23,786", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:24,301", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:24,861", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:25,449", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:25,450", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:25,451", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 15000–19999
# ➡️  Processing rows 20000–24999
# {"asctime": "2026-02-24 23:19:25,498", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:26,067", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:26,591", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:27,023", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:27,483", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:27,896", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:27,897", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:27,898", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 20000–24999
# ➡️  Processing rows 25000–29999
# {"asctime": "2026-02-24 23:19:27,950", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:28,459", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:28,893", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:29,334", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:29,742", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:30,103", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:30,104", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:30,105", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 25000–29999
# ➡️  Processing rows 30000–34999
# {"asctime": "2026-02-24 23:19:30,144", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:30,580", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:30,957", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:31,372", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:31,842", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:32,253", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:32,255", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:32,256", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 30000–34999
# ➡️  Processing rows 35000–39999
# {"asctime": "2026-02-24 23:19:32,315", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:32,870", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:33,239", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:33,728", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:34,140", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:34,555", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:34,556", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:34,558", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 35000–39999
# ➡️  Processing rows 40000–44999
# {"asctime": "2026-02-24 23:19:34,596", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:35,099", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:35,659", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:36,071", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:36,521", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:37,051", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:37,053", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:37,054", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 40000–44999
# ➡️  Processing rows 45000–49999
# {"asctime": "2026-02-24 23:19:37,106", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:37,656", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:38,082", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:38,444", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:38,821", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:39,258", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:39,260", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:39,261", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 45000–49999
# ➡️  Processing rows 50000–54999
# {"asctime": "2026-02-24 23:19:39,324", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:39,746", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:40,170", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:40,595", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:40,999", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:41,413", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:41,415", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:41,416", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 50000–54999
# ➡️  Processing rows 55000–59999
# {"asctime": "2026-02-24 23:19:41,475", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:41,892", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:42,280", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:42,643", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:43,003", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:43,416", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:43,419", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:43,420", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 55000–59999
# ➡️  Processing rows 60000–64999
# {"asctime": "2026-02-24 23:19:43,485", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:43,946", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:44,361", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:44,744", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:45,137", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:45,502", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:45,503", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:45,503", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 60000–64999
# ➡️  Processing rows 65000–69999
# {"asctime": "2026-02-24 23:19:45,545", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:45,944", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:46,350", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:46,800", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:47,217", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:47,685", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:47,687", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:47,688", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 65000–69999
# ➡️  Processing rows 70000–74999
# {"asctime": "2026-02-24 23:19:47,737", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:48,149", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:48,677", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:49,110", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:50,021", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:50,601", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:50,604", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:50,605", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 70000–74999
# ➡️  Processing rows 75000–79999
# {"asctime": "2026-02-24 23:19:50,668", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:51,108", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:51,496", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:51,925", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:52,334", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:52,762", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:52,765", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:52,766", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 75000–79999
# ➡️  Processing rows 80000–84999
# {"asctime": "2026-02-24 23:19:52,819", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:53,226", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:53,676", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:54,164", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:54,610", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:55,056", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:55,057", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:55,058", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 80000–84999
# ➡️  Processing rows 85000–89999
# {"asctime": "2026-02-24 23:19:55,102", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:55,548", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:55,965", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:56,398", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:56,803", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:57,196", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:57,197", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:57,198", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 85000–89999
# ➡️  Processing rows 90000–94999
# {"asctime": "2026-02-24 23:19:57,251", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:57,686", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:58,086", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:58,450", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:58,892", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:59,328", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:19:59,329", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:19:59,330", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 90000–94999
# ➡️  Processing rows 95000–99999
# {"asctime": "2026-02-24 23:19:59,375", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:19:59,762", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:00,132", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:00,501", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:00,870", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:01,308", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:01,309", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:01,309", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 95000–99999
# ➡️  Processing rows 100000–104999
# {"asctime": "2026-02-24 23:20:01,356", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:01,742", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:02,203", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:02,635", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:03,061", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:03,472", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:03,473", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:03,474", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 100000–104999
# ➡️  Processing rows 105000–109999
# {"asctime": "2026-02-24 23:20:03,514", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:03,936", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:04,309", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:04,755", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:05,136", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:05,545", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:05,546", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:05,547", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 105000–109999
# ➡️  Processing rows 110000–114999
# {"asctime": "2026-02-24 23:20:05,791", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:06,219", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:06,628", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:07,035", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:07,425", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:07,800", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:07,802", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:07,803", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 110000–114999
# ➡️  Processing rows 115000–119999
# {"asctime": "2026-02-24 23:20:07,849", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:08,257", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:08,623", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:08,994", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:09,424", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:09,836", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:09,837", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:09,838", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 115000–119999
# ➡️  Processing rows 120000–124999
# {"asctime": "2026-02-24 23:20:09,873", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:10,374", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:10,814", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:11,196", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:11,605", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:12,076", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:12,078", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:12,079", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 120000–124999
# ➡️  Processing rows 125000–129999
# {"asctime": "2026-02-24 23:20:12,138", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:12,585", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:12,976", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:13,347", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:13,764", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:14,148", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:14,149", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:14,150", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 125000–129999
# ➡️  Processing rows 130000–134999
# {"asctime": "2026-02-24 23:20:14,191", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:14,596", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:15,151", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:15,827", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:16,270", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:16,656", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:16,657", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:16,657", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 130000–134999
# ➡️  Processing rows 135000–139999
# {"asctime": "2026-02-24 23:20:16,695", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:17,124", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:17,539", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:17,923", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:18,363", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:18,782", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:18,785", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:18,787", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 135000–139999
# ➡️  Processing rows 140000–144999
# {"asctime": "2026-02-24 23:20:18,853", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:19,316", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:19,782", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:20,192", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:20,710", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:21,149", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:21,150", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:21,152", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 140000–144999
# ➡️  Processing rows 145000–149999
# {"asctime": "2026-02-24 23:20:21,420", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:21,880", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:22,274", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:22,762", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:23,257", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:23,706", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:23,706", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:23,707", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 145000–149999
# ➡️  Processing rows 150000–154999
# {"asctime": "2026-02-24 23:20:23,749", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:24,206", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:24,664", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:25,045", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:25,454", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:26,108", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:26,109", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:26,110", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 150000–154999
# ➡️  Processing rows 155000–159999
# {"asctime": "2026-02-24 23:20:26,159", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:26,764", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:27,256", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:27,728", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:28,186", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:28,588", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:28,589", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:28,589", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 155000–159999
# ➡️  Processing rows 160000–164999
# {"asctime": "2026-02-24 23:20:28,626", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:29,098", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:29,528", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:29,953", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:30,384", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:30,796", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:30,797", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:30,798", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 160000–164999
# ➡️  Processing rows 165000–169999
# {"asctime": "2026-02-24 23:20:30,845", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:31,304", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:31,695", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:32,111", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:32,490", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:32,943", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:32,944", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:32,946", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 165000–169999
# ➡️  Processing rows 170000–174999
# {"asctime": "2026-02-24 23:20:33,002", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:33,463", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:33,851", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:34,256", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:34,738", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:35,278", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:35,279", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:35,280", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 170000–174999
# ➡️  Processing rows 175000–179999
# {"asctime": "2026-02-24 23:20:35,343", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:35,926", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:36,610", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:37,108", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:37,501", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:38,012", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:38,015", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:38,017", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 175000–179999
# ➡️  Processing rows 180000–184999
# {"asctime": "2026-02-24 23:20:38,463", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:38,953", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:39,427", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:39,804", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:40,217", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:40,648", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:40,649", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:40,650", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 180000–184999
# ➡️  Processing rows 185000–189999
# {"asctime": "2026-02-24 23:20:40,707", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:41,177", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:41,626", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:42,118", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:42,602", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:43,083", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:43,084", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:20:43,084", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 185000–189999
# ➡️  Processing rows 190000–194999
# {"asctime": "2026-02-24 23:20:43,133", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:20:43,577", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:44,016", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:44,424", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:20:44,903", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# ...
# ✅ Inserted rows 1605000–1609999
# ➡️  Processing rows 1610000–1614999
# {"asctime": "2026-02-24 23:32:13,834", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:14,277", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:14,640", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:15,008", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:15,426", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:15,915", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:15,916", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:15,917", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1610000–1614999
# ➡️  Processing rows 1615000–1619999
# {"asctime": "2026-02-24 23:32:16,127", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:16,688", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:17,159", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:17,744", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:18,204", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:18,693", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:18,696", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:18,697", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1615000–1619999
# ➡️  Processing rows 1620000–1624999
# {"asctime": "2026-02-24 23:32:18,756", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:19,230", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:19,687", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:20,172", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:20,680", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:21,121", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:21,124", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:21,125", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1620000–1624999
# ➡️  Processing rows 1625000–1629999
# {"asctime": "2026-02-24 23:32:21,180", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:21,659", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:22,104", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:22,602", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:22,992", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:23,399", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:23,413", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:23,413", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1625000–1629999
# ➡️  Processing rows 1630000–1634999
# {"asctime": "2026-02-24 23:32:23,457", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:23,971", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:24,379", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:24,853", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:25,348", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:25,832", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:25,835", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:25,836", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1630000–1634999
# ➡️  Processing rows 1635000–1639999
# {"asctime": "2026-02-24 23:32:25,934", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:26,547", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:26,949", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:27,338", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:27,768", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:28,305", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:28,306", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:28,307", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1635000–1639999
# ➡️  Processing rows 1640000–1644999
# {"asctime": "2026-02-24 23:32:28,346", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:28,765", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:29,187", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:29,634", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:30,039", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:30,464", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:30,464", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:30,465", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1640000–1644999
# ➡️  Processing rows 1645000–1649999
# {"asctime": "2026-02-24 23:32:30,505", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:30,968", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:31,339", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:31,771", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:32,240", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:32,650", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:32,651", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:32,652", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1645000–1649999
# ➡️  Processing rows 1650000–1654999
# {"asctime": "2026-02-24 23:32:32,884", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:33,360", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:33,860", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:34,322", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:34,789", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:35,230", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:35,235", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:35,236", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1650000–1654999
# ➡️  Processing rows 1655000–1659999
# {"asctime": "2026-02-24 23:32:35,278", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:35,683", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:36,075", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:36,447", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:36,880", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:37,342", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:37,343", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:37,343", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1655000–1659999
# ➡️  Processing rows 1660000–1664999
# {"asctime": "2026-02-24 23:32:37,389", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:37,869", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:38,426", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:38,885", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:39,338", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:39,745", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:39,746", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:39,746", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1660000–1664999
# ➡️  Processing rows 1665000–1669999
# {"asctime": "2026-02-24 23:32:39,790", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:40,195", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:40,610", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:41,023", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:41,441", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:41,842", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:41,843", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:32:41,844", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1665000–1669999
# ➡️  Processing rows 1670000–1672855
# {"asctime": "2026-02-24 23:32:41,883", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:32:42,370", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:42,867", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:43,259", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2856 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:32:43,260", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 2856"}
# {"asctime": "2026-02-24 23:32:43,260", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1670000–1672855

# %% [markdown]
# ### For the second station

# %%
from crmprtd import Row

### for the station Rithet Creek

df_station_2 = df_station_network.loc[
    df_station_network['station_name'] == 'Judge Creek'
]

time_col = df_judge['DateTime_DateTime']
variable_name = df_var['var_name_raw']
variable_name_db = df_var['net_var_name']
unit_db = df_var['unit']
network_name = df_station_2['network_name']
native_id = df_station_2['native_id']
lat = float(df_station_2['lat'].iloc[0])
lon = float(df_station_2['lon'].iloc[0])

time_col
variable_name


all_rows = []

# station metadata (extract scalar values!)
network_name = df_station_2['network_name'].iloc[0]
native_id = df_station_2['native_id'].iloc[0]
lat = df_station_2['lat'].iloc[0]
lon = df_station_2['lon'].iloc[0]

# loop over each time row
for _, row_i in df_judge.iterrows():
    
    time_value = row_i['DateTime_DateTime']
    
    # loop over each variable mapping
    for _, var_row in df_var.iterrows():
        
        raw_name = var_row['var_name_raw']
        db_name = var_row['net_var_name']
        unit_db = var_row['unit']
        
        val = row_i.get(raw_name)
        
        if pd.notna(val):   # optional: skip NaNs
            all_rows.append(
                Row(
                    time=time_value,
                    val=val,
                    variable_name=db_name,
                    unit=unit_db,
                    network_name=network_name,
                    station_id=native_id,
                    lat=lat,
                    lon=lon
                )
            )

# %%
all_rows
# Out:
# [Row(time=Timestamp('1994-10-28 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 15:00:00'), val=76.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 15:00:00'), val=9.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 16:00:00'), val=76.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 16:00:00'), val=8.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 17:00:00'), val=99.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 17:00:00'), val=4.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 18:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 18:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 18:00:00'), val=1.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 19:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 19:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 19:00:00'), val=0.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 20:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 20:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 20:00:00'), val=1.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 21:00:00'), val=1.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 22:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 22:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 22:00:00'), val=0.4, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 23:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 23:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-28 23:00:00'), val=-0.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 00:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 00:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 00:00:00'), val=-0.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 01:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 01:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 01:00:00'), val=-1.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 02:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 02:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 02:00:00'), val=-1.3, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 03:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 03:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 03:00:00'), val=-0.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 04:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 04:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 04:00:00'), val=-0.3, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 05:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 05:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 05:00:00'), val=-0.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 06:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 06:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 06:00:00'), val=-0.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 07:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 07:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 07:00:00'), val=-0.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 08:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 08:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 08:00:00'), val=0.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 09:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 09:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 09:00:00'), val=2.0, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 10:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 10:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 10:00:00'), val=5.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 11:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 11:00:00'), val=96.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 11:00:00'), val=7.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 12:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 12:00:00'), val=80.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 12:00:00'), val=9.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 13:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 13:00:00'), val=77.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 13:00:00'), val=9.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 14:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 14:00:00'), val=77.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 14:00:00'), val=9.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 15:00:00'), val=80.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 15:00:00'), val=8.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 16:00:00'), val=85.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 16:00:00'), val=7.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 17:00:00'), val=97.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 17:00:00'), val=6.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 18:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 18:00:00'), val=99.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 18:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 19:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 19:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 19:00:00'), val=5.4, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 20:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 20:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 20:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 21:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 21:00:00'), val=5.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 22:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 22:00:00'), val=99.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 22:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 23:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 23:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-29 23:00:00'), val=5.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 00:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 00:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 00:00:00'), val=5.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 01:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 01:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 01:00:00'), val=5.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 02:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 02:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 02:00:00'), val=3.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 03:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 03:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 03:00:00'), val=2.3, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 04:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 04:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 04:00:00'), val=1.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 05:00:00'), val=-1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 05:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 05:00:00'), val=-0.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 06:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 06:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 06:00:00'), val=-0.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 07:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 07:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 07:00:00'), val=-0.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 08:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 08:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 08:00:00'), val=0.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 09:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 09:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 09:00:00'), val=2.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 10:00:00'), val=-1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 10:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 10:00:00'), val=5.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 11:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 11:00:00'), val=91.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 11:00:00'), val=8.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 12:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 12:00:00'), val=95.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 12:00:00'), val=7.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 13:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 13:00:00'), val=88.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 13:00:00'), val=8.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 14:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 14:00:00'), val=88.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 14:00:00'), val=8.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 15:00:00'), val=88.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 15:00:00'), val=8.3, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 16:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 16:00:00'), val=7.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 17:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 17:00:00'), val=6.0, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 18:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 18:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 18:00:00'), val=5.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 19:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 19:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 19:00:00'), val=4.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 20:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 20:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 20:00:00'), val=4.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 21:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 21:00:00'), val=5.0, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 22:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 22:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 22:00:00'), val=5.3, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 23:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 23:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-30 23:00:00'), val=6.0, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 00:00:00'), val=4.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 00:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 00:00:00'), val=5.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 01:00:00'), val=3.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 01:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 01:00:00'), val=5.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 02:00:00'), val=5.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 02:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 02:00:00'), val=5.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 03:00:00'), val=5.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 03:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 03:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 04:00:00'), val=5.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 04:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 04:00:00'), val=5.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 05:00:00'), val=6.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 05:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 05:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 06:00:00'), val=4.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 06:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 06:00:00'), val=5.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 07:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 07:00:00'), val=91.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 07:00:00'), val=10.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 08:00:00'), val=-1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 08:00:00'), val=90.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 08:00:00'), val=9.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 09:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 09:00:00'), val=90.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 09:00:00'), val=8.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 10:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 10:00:00'), val=87.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 10:00:00'), val=8.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 11:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 11:00:00'), val=86.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 11:00:00'), val=8.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 12:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 12:00:00'), val=93.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 12:00:00'), val=7.5, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 13:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 13:00:00'), val=85.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 13:00:00'), val=8.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 14:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 14:00:00'), val=93.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 14:00:00'), val=7.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 15:00:00'), val=94.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 15:00:00'), val=7.4, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 16:00:00'), val=84.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 16:00:00'), val=7.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 17:00:00'), val=77.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 17:00:00'), val=7.3, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 18:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 18:00:00'), val=77.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 18:00:00'), val=7.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 19:00:00'), val=2.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 19:00:00'), val=86.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 19:00:00'), val=5.6, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 20:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 20:00:00'), val=89.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 20:00:00'), val=5.3, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 21:00:00'), val=-1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 21:00:00'), val=3.0, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 22:00:00'), val=1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 22:00:00'), val=83.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 22:00:00'), val=5.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 23:00:00'), val=-1.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 23:00:00'), val=83.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-10-31 23:00:00'), val=4.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-01 00:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
# ...
#  Row(time=Timestamp('1994-11-10 09:00:00'), val=2.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 10:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 10:00:00'), val=87.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 10:00:00'), val=3.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 11:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 11:00:00'), val=97.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 11:00:00'), val=7.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 12:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 12:00:00'), val=91.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 12:00:00'), val=7.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 13:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 13:00:00'), val=80.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 13:00:00'), val=9.7, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 14:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 14:00:00'), val=93.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 14:00:00'), val=8.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 15:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 15:00:00'), val=99.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 15:00:00'), val=7.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 16:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 16:00:00'), val=97.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 16:00:00'), val=6.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 17:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 17:00:00'), val=98.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 17:00:00'), val=6.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 18:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 18:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 18:00:00'), val=5.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 19:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 19:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 19:00:00'), val=5.3, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 20:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 20:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 20:00:00'), val=5.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 21:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 21:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 21:00:00'), val=4.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 22:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 22:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 22:00:00'), val=5.0, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 23:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 23:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-10 23:00:00'), val=5.0, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 00:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 00:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 00:00:00'), val=4.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 01:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 01:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 01:00:00'), val=4.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 02:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 02:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 02:00:00'), val=4.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 03:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 03:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 03:00:00'), val=4.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 04:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 04:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 04:00:00'), val=4.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 05:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 05:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 05:00:00'), val=4.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 06:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 06:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 06:00:00'), val=4.9, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 07:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 07:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 07:00:00'), val=5.0, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 08:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 08:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 08:00:00'), val=5.1, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 09:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 09:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 09:00:00'), val=5.8, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 10:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 10:00:00'), val=96.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 10:00:00'), val=6.3, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 11:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 11:00:00'), val=96.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 11:00:00'), val=6.2, variable_name='AirTemperature', unit='celsius', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 12:00:00'), val=0.0, variable_name='Precipitation', unit='mm', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  Row(time=Timestamp('1994-11-11 12:00:00'), val=100.0, variable_name='RelativeHumidity', unit='percent', network_name='CRD', station_id='HY002', lat=np.float64(48.585278), lon=np.float64(-123.673611)),
#  ...]

# %%
import sys
sys.path.append("/workspaces/crmprtd/fern/FERNNorth2025_insert")

from auto_insert_func import *

db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"

output_folder = '/workspaces/crmprtd/update_round2/output_tables/'

statin_name = df_station_2['station_name']


safe_insert_rows(
    all_rows,
    log_file_path=output_folder + str(statin_name) +'insert.log',
    db_url=db_url,
    chunk_size=5000,        # SAFE starting point
    bulk_chunk_size=1000,   # internal DB bulk insert size
)
# Out:
# 🚀 Starting insert: 1782308 rows in 357 chunks
# ➡️  Processing rows 0–4999
# {"asctime": "2026-02-24 23:40:04,670", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:05,233", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:05,798", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:06,327", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:06,827", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:07,306", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:07,307", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:07,307", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 0–4999
# ➡️  Processing rows 5000–9999
# {"asctime": "2026-02-24 23:40:07,354", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:07,883", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:08,335", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:08,847", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:09,413", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:09,893", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:09,896", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:09,897", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 5000–9999
# ➡️  Processing rows 10000–14999
# {"asctime": "2026-02-24 23:40:09,955", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:10,538", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:11,034", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:11,487", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:11,935", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:12,399", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:12,402", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:12,406", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 10000–14999
# ➡️  Processing rows 15000–19999
# {"asctime": "2026-02-24 23:40:12,468", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:12,995", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:13,463", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:13,977", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:14,492", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:15,121", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:15,123", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:15,124", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 15000–19999
# ➡️  Processing rows 20000–24999
# {"asctime": "2026-02-24 23:40:15,182", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:15,851", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:16,480", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:17,145", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:17,773", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:18,824", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:18,825", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:18,826", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 20000–24999
# ➡️  Processing rows 25000–29999
# {"asctime": "2026-02-24 23:40:18,890", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:19,584", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:20,154", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:20,641", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:21,100", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:21,593", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:21,595", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:21,596", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 25000–29999
# ➡️  Processing rows 30000–34999
# {"asctime": "2026-02-24 23:40:21,652", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:22,225", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:22,729", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:23,214", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:23,769", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:24,265", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:24,268", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:24,269", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 30000–34999
# ➡️  Processing rows 35000–39999
# {"asctime": "2026-02-24 23:40:24,327", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:24,808", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:25,401", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:25,937", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:26,502", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:27,021", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:27,024", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:27,025", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 35000–39999
# ➡️  Processing rows 40000–44999
# {"asctime": "2026-02-24 23:40:27,089", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:27,747", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:28,304", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:29,008", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:29,505", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:30,041", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:30,042", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:30,043", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 40000–44999
# ➡️  Processing rows 45000–49999
# {"asctime": "2026-02-24 23:40:30,090", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:30,521", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:30,964", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:31,404", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:31,862", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:32,290", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:32,291", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:32,292", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 45000–49999
# ➡️  Processing rows 50000–54999
# {"asctime": "2026-02-24 23:40:32,351", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:32,849", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:33,326", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:33,792", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:34,260", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:34,712", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:34,715", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:34,717", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 50000–54999
# ➡️  Processing rows 55000–59999
# {"asctime": "2026-02-24 23:40:34,787", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:35,231", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:35,631", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:36,068", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:36,492", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:36,936", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:36,941", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:36,943", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 55000–59999
# ➡️  Processing rows 60000–64999
# {"asctime": "2026-02-24 23:40:37,012", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:37,491", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:37,979", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:38,513", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:38,970", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:39,411", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:39,414", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:39,415", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 60000–64999
# ➡️  Processing rows 65000–69999
# {"asctime": "2026-02-24 23:40:39,481", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:39,976", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:40,430", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:40,983", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:41,561", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:42,111", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:42,113", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:42,114", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 65000–69999
# ➡️  Processing rows 70000–74999
# {"asctime": "2026-02-24 23:40:42,172", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:42,585", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:43,094", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:43,522", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:43,956", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:44,373", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:44,374", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:44,374", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 70000–74999
# ➡️  Processing rows 75000–79999
# {"asctime": "2026-02-24 23:40:44,414", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:44,869", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:45,321", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:45,725", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:46,174", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:46,592", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:46,593", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:46,593", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 75000–79999
# ➡️  Processing rows 80000–84999
# {"asctime": "2026-02-24 23:40:46,641", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:47,068", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:47,450", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:47,893", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:48,365", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:48,808", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:48,810", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:48,811", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 80000–84999
# ➡️  Processing rows 85000–89999
# {"asctime": "2026-02-24 23:40:48,873", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:49,301", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:49,765", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:50,258", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:50,649", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:51,080", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:51,081", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:51,081", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 85000–89999
# ➡️  Processing rows 90000–94999
# {"asctime": "2026-02-24 23:40:51,119", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:51,576", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:52,029", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:52,501", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:52,926", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:53,353", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:53,355", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:53,356", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 90000–94999
# ➡️  Processing rows 95000–99999
# {"asctime": "2026-02-24 23:40:53,411", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:53,862", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:54,289", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:54,837", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:55,348", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:55,827", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:55,830", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:55,832", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 95000–99999
# ➡️  Processing rows 100000–104999
# {"asctime": "2026-02-24 23:40:55,892", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:56,574", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:56,968", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:57,515", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:57,954", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:58,414", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:58,416", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:40:58,418", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 100000–104999
# ➡️  Processing rows 105000–109999
# {"asctime": "2026-02-24 23:40:58,476", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:40:58,919", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:59,395", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:40:59,864", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:00,348", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:00,747", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:00,748", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:00,748", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 105000–109999
# ➡️  Processing rows 110000–114999
# {"asctime": "2026-02-24 23:41:00,809", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:01,311", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:01,852", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:02,360", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:02,813", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:03,252", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:03,255", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:03,257", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 110000–114999
# ➡️  Processing rows 115000–119999
# {"asctime": "2026-02-24 23:41:03,320", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:03,759", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:04,181", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:04,569", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:04,954", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:05,393", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:05,394", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:05,395", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 115000–119999
# ➡️  Processing rows 120000–124999
# {"asctime": "2026-02-24 23:41:05,433", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:05,910", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:06,376", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:06,853", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:07,337", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:07,975", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:07,978", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:07,980", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 120000–124999
# ➡️  Processing rows 125000–129999
# {"asctime": "2026-02-24 23:41:08,043", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:08,491", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:08,920", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:09,374", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:09,854", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:10,264", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:10,267", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:10,268", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 125000–129999
# ➡️  Processing rows 130000–134999
# {"asctime": "2026-02-24 23:41:10,326", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:10,753", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:11,141", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:11,517", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:11,941", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:12,439", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:12,442", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:12,443", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 130000–134999
# ➡️  Processing rows 135000–139999
# {"asctime": "2026-02-24 23:41:12,500", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:12,945", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:13,420", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:13,838", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:14,260", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:14,693", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:14,694", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:14,696", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 135000–139999
# ➡️  Processing rows 140000–144999
# {"asctime": "2026-02-24 23:41:14,749", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:15,598", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:16,019", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:16,496", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:16,939", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:17,460", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:17,465", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:17,467", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 140000–144999
# ➡️  Processing rows 145000–149999
# {"asctime": "2026-02-24 23:41:17,519", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:17,925", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:18,343", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:18,786", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:19,174", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:19,534", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:19,535", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:19,535", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 145000–149999
# ➡️  Processing rows 150000–154999
# {"asctime": "2026-02-24 23:41:19,578", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:19,977", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:20,357", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:20,804", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:21,269", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:21,713", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:21,714", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:21,714", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 150000–154999
# ➡️  Processing rows 155000–159999
# {"asctime": "2026-02-24 23:41:21,757", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:22,380", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:22,933", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:23,451", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:23,927", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:24,404", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:24,405", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:24,407", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 155000–159999
# ➡️  Processing rows 160000–164999
# {"asctime": "2026-02-24 23:41:24,460", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:24,933", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:25,439", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:25,981", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:26,469", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:26,945", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:26,947", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:26,949", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 160000–164999
# ➡️  Processing rows 165000–169999
# {"asctime": "2026-02-24 23:41:27,000", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:27,484", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:27,933", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:28,403", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:28,905", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:29,341", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:29,344", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:29,345", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 165000–169999
# ➡️  Processing rows 170000–174999
# {"asctime": "2026-02-24 23:41:29,403", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:29,912", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:30,419", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:30,929", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:31,497", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:31,941", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:31,942", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:31,943", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 170000–174999
# ➡️  Processing rows 175000–179999
# {"asctime": "2026-02-24 23:41:31,986", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:32,560", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:33,170", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:33,749", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:34,220", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:34,668", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:34,669", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:34,671", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 175000–179999
# ➡️  Processing rows 180000–184999
# {"asctime": "2026-02-24 23:41:34,722", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:35,332", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:35,762", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:36,161", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:36,620", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:37,043", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:37,044", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:37,046", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 180000–184999
# ➡️  Processing rows 185000–189999
# {"asctime": "2026-02-24 23:41:37,103", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:37,547", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:37,992", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:38,371", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:38,981", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:39,402", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:39,405", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:41:39,406", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 185000–189999
# ➡️  Processing rows 190000–194999
# {"asctime": "2026-02-24 23:41:39,476", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:41:39,956", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:40,392", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:40,835", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:41:41,239", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# ...
# ✅ Inserted rows 1715000–1719999
# ➡️  Processing rows 1720000–1724999
# {"asctime": "2026-02-24 23:55:57,893", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:55:58,530", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:55:58,970", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:55:59,477", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:55:59,968", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:00,508", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:00,516", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:00,517", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1720000–1724999
# ➡️  Processing rows 1725000–1729999
# {"asctime": "2026-02-24 23:56:00,582", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:01,165", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:01,774", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:02,418", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:02,937", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:03,496", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:03,496", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:03,497", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1725000–1729999
# ➡️  Processing rows 1730000–1734999
# {"asctime": "2026-02-24 23:56:03,540", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:04,128", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:04,848", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:05,529", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:06,266", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:06,871", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:06,873", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:06,874", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1730000–1734999
# ➡️  Processing rows 1735000–1739999
# {"asctime": "2026-02-24 23:56:06,920", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:07,486", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:08,014", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:08,634", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:09,213", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:09,759", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:09,760", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:09,760", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1735000–1739999
# ➡️  Processing rows 1740000–1744999
# {"asctime": "2026-02-24 23:56:09,810", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:10,335", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:10,817", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:11,349", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:11,804", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:12,269", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:12,270", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:12,270", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1740000–1744999
# ➡️  Processing rows 1745000–1749999
# {"asctime": "2026-02-24 23:56:12,304", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:12,813", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:13,339", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:13,822", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:14,338", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:14,939", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:14,941", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:14,942", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1745000–1749999
# ➡️  Processing rows 1750000–1754999
# {"asctime": "2026-02-24 23:56:15,001", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:15,828", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:16,315", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:16,870", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:17,403", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:17,978", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:17,979", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:17,980", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1750000–1754999
# ➡️  Processing rows 1755000–1759999
# {"asctime": "2026-02-24 23:56:18,039", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:18,568", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:19,016", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:19,560", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:19,996", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:20,608", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:20,609", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:20,609", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1755000–1759999
# ➡️  Processing rows 1760000–1764999
# {"asctime": "2026-02-24 23:56:20,650", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:21,291", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:22,037", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:22,847", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:23,645", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:24,524", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:24,526", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:24,527", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1760000–1764999
# ➡️  Processing rows 1765000–1769999
# {"asctime": "2026-02-24 23:56:24,588", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:25,515", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:26,331", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:27,255", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:28,482", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:29,382", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:29,382", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:29,383", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1765000–1769999
# ➡️  Processing rows 1770000–1774999
# {"asctime": "2026-02-24 23:56:29,427", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:30,150", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:30,759", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:31,377", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:32,007", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:32,653", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:32,654", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:32,654", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1770000–1774999
# ➡️  Processing rows 1775000–1779999
# {"asctime": "2026-02-24 23:56:32,702", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:33,420", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:33,989", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:34,490", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 3000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:35,005", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 4000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:35,473", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 5000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:35,476", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 5000"}
# {"asctime": "2026-02-24 23:56:35,478", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1775000–1779999
# ➡️  Processing rows 1780000–1782307
# {"asctime": "2026-02-24 23:56:35,522", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-24 23:56:36,017", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 1000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:36,499", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2000 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:36,688", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 2308 inserted, 0 skipped, 0 failed"}
# {"asctime": "2026-02-24 23:56:36,690", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 2308"}
# {"asctime": "2026-02-24 23:56:36,692", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 1780000–1782307
