# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa
import os
from row_generate_func import *
from auto_insert_func import *

from sqlalchemy.orm import Session

engine = sa.create_engine("postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass", echo=False)
session = Session(engine)

# %%
# --- Main workflow ---
output_folder = '/workspaces/crmprtd/fern/v5_after_metadata_update_rerun_testnode/output/'
file_name = 'Fern_raw_db_station_matched.csv'

df_match = pd.read_csv(output_folder + file_name)

df_match
# Out:
#         station_name native_id_raw     station_file_name        lat  \
# 0       Atlin School        AtlSch          Atlin school  59.574000
# 1       Atlin School        AtlSch          Atlin school  59.574000
# 2       Atlin School        AtlSch          Atlin school  59.574000
# 3       Atlin School        AtlSch          Atlin school  59.574000
# 4       Atlin School        AtlSch          Atlin school  59.574000
# ..               ...           ...                   ...        ...
# 422  Willow-BowronWx        PGTIS2  WillowBowron PGTIS 2  53.772577
# 423  Willow-BowronWx        PGTIS2  WillowBowron PGTIS 2  53.772577
# 424  Willow-BowronWx        PGTIS2  WillowBowron PGTIS 2  53.772577
# 425  Willow-BowronWx        PGTIS2  WillowBowron PGTIS 2  53.772577
# 426  Willow-BowronWx        PGTIS2  WillowBowron PGTIS 2  53.772577
#
#             lon  elev         variable unit_raw    earliest_time_raw  \
# 0   -133.687000   705         Air Temp       °C  2010-08-20 19:00:00
# 1   -133.687000   705       Air Temp 2       °C  2010-08-20 19:00:00
# 2   -133.687000   705            DewPt       °C  2011-07-28 09:00:00
# 3   -133.687000   705    Gd Temp 25 cm       °C  2010-08-20 19:00:00
# 4   -133.687000   705    Gd Temp 50 cm       °C  2010-08-20 19:00:00
# ..          ...   ...              ...      ...                  ...
# 422 -122.724634   596  Solar Radiation     W/m²  2007-07-31 15:00:00
# 423 -122.724634   596             Temp       °C  2007-07-31 15:00:00
# 424 -122.724634   596          Wetness        %  2008-06-12 13:00:00
# 425 -122.724634   596   Wind Direction        ø  2007-07-31 15:00:00
# 426 -122.724634   596       Wind Speed      m/s  2007-07-31 15:00:00
#
#          latest_time_raw      db_var_match  unit_db     earliest_time_db  \
# 0    2024-08-10 19:00:00             TempC  celsius                  NaN
# 1    2024-08-10 19:00:00               NaN      NaN                  NaN
# 2    2024-08-10 19:00:00            DewPtC  celsius  2011-07-28 09:00:00
# 3    2024-08-10 19:00:00    Soil_Temp_25cm  celsius                  NaN
# 4    2024-08-10 19:00:00    Soil_Temp_50cm  celsius                  NaN
# ..                   ...               ...      ...                  ...
# 422  2024-10-24 09:00:00  SolarRadiationWm    W m-2  2007-07-31 15:00:00
# 423  2024-10-24 09:00:00             TempC  celsius  2007-07-31 15:00:00
# 424  2024-10-24 09:00:00           Wetness        %  2008-06-12 13:00:00
# 425  2024-10-24 09:00:00     WindDirection   degree  2007-07-31 15:00:00
# 426  2024-10-24 09:00:00       WindSpeedms    m s-1  2007-07-31 15:00:00
#
#           latest_time_db  earliest_diff_days  latest_diff_days   batch
# 0                    NaN                 NaN               NaN  batch4
# 1                    NaN                 NaN               NaN  batch5
# 2    2024-08-10 19:00:00                 0.0               0.0  batch1
# 3                    NaN                 NaN               NaN  batch4
# 4                    NaN                 NaN               NaN  batch4
# ..                   ...                 ...               ...     ...
# 422  2024-10-24 09:00:00                 0.0               0.0  batch1
# 423  2024-10-24 09:00:00                 0.0               0.0  batch1
# 424  2024-10-24 09:00:00                 0.0               0.0  batch1
# 425  2024-10-24 09:00:00                 0.0               0.0  batch1
# 426  2024-10-24 09:00:00                 0.0               0.0  batch1
#
# [427 rows x 17 columns]

# %%
station_names = df_match['station_name'].tolist()

query = sa.text("""
    SELECT DISTINCT m.station_name, s.native_id, m.lat, m.lon, m.elev
    FROM meta_history AS m
    JOIN meta_station AS s ON m.station_id = s.station_id
    WHERE s.network_id = 11
      AND m.station_name = ANY(:station_names)
""")

with engine.connect() as conn:
    db_stations = pd.read_sql(query, conn, params={"station_names": station_names})

# %%
merged = df_match.merge(
    db_stations,
    on='station_name',
    how='left'
)

match_info = merged.rename(
    columns={
        'native_id': 'native_id_db',
        'lat_y': 'lat_db',
        'lon_y': 'lon_db',
        'elev_y': 'elev_db'
    }
)

match_info = match_info.drop(columns=['native_id_raw', 'lat_x', 'lon_x', 'elev_x'])

match_info
# Out:
#         station_name     station_file_name         variable unit_raw  \
# 0       Atlin School          Atlin school         Air Temp       °C
# 1       Atlin School          Atlin school       Air Temp 2       °C
# 2       Atlin School          Atlin school            DewPt       °C
# 3       Atlin School          Atlin school    Gd Temp 25 cm       °C
# 4       Atlin School          Atlin school    Gd Temp 50 cm       °C
# ..               ...                   ...              ...      ...
# 422  Willow-BowronWx  WillowBowron PGTIS 2  Solar Radiation     W/m²
# 423  Willow-BowronWx  WillowBowron PGTIS 2             Temp       °C
# 424  Willow-BowronWx  WillowBowron PGTIS 2          Wetness        %
# 425  Willow-BowronWx  WillowBowron PGTIS 2   Wind Direction        ø
# 426  Willow-BowronWx  WillowBowron PGTIS 2       Wind Speed      m/s
#
#        earliest_time_raw      latest_time_raw      db_var_match  unit_db  \
# 0    2010-08-20 19:00:00  2024-08-10 19:00:00             TempC  celsius
# 1    2010-08-20 19:00:00  2024-08-10 19:00:00               NaN      NaN
# 2    2011-07-28 09:00:00  2024-08-10 19:00:00            DewPtC  celsius
# 3    2010-08-20 19:00:00  2024-08-10 19:00:00    Soil_Temp_25cm  celsius
# 4    2010-08-20 19:00:00  2024-08-10 19:00:00    Soil_Temp_50cm  celsius
# ..                   ...                  ...               ...      ...
# 422  2007-07-31 15:00:00  2024-10-24 09:00:00  SolarRadiationWm    W m-2
# 423  2007-07-31 15:00:00  2024-10-24 09:00:00             TempC  celsius
# 424  2008-06-12 13:00:00  2024-10-24 09:00:00           Wetness        %
# 425  2007-07-31 15:00:00  2024-10-24 09:00:00     WindDirection   degree
# 426  2007-07-31 15:00:00  2024-10-24 09:00:00       WindSpeedms    m s-1
#
#         earliest_time_db       latest_time_db  earliest_diff_days  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2    2011-07-28 09:00:00  2024-08-10 19:00:00                 0.0
# 3                    NaN                  NaN                 NaN
# 4                    NaN                  NaN                 NaN
# ..                   ...                  ...                 ...
# 422  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 423  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 424  2008-06-12 13:00:00  2024-10-24 09:00:00                 0.0
# 425  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 426  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
#
#      latest_diff_days   batch native_id_db     lat_db      lon_db  elev_db
# 0                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# 1                 NaN  batch5       AtlSch  59.574000 -133.687000    705.0
# 2                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 3                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# 4                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# ..                ...     ...          ...        ...         ...      ...
# 422               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 423               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 424               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 425               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 426               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
#
# [427 rows x 17 columns]

# %% [markdown]
# ### Batch 1, for the unique variables (only one sensor)

# %%
match_info_uniq_var = match_info[match_info['db_var_match'].notna()]
match_info_uniq_var
# Out:
#         station_name     station_file_name         variable unit_raw  \
# 0       Atlin School          Atlin school         Air Temp       °C
# 2       Atlin School          Atlin school            DewPt       °C
# 3       Atlin School          Atlin school    Gd Temp 25 cm       °C
# 4       Atlin School          Atlin school    Gd Temp 50 cm       °C
# 5       Atlin School          Atlin school    Gd Temp 75 cm       °C
# ..               ...                   ...              ...      ...
# 422  Willow-BowronWx  WillowBowron PGTIS 2  Solar Radiation     W/m²
# 423  Willow-BowronWx  WillowBowron PGTIS 2             Temp       °C
# 424  Willow-BowronWx  WillowBowron PGTIS 2          Wetness        %
# 425  Willow-BowronWx  WillowBowron PGTIS 2   Wind Direction        ø
# 426  Willow-BowronWx  WillowBowron PGTIS 2       Wind Speed      m/s
#
#        earliest_time_raw      latest_time_raw      db_var_match  unit_db  \
# 0    2010-08-20 19:00:00  2024-08-10 19:00:00             TempC  celsius
# 2    2011-07-28 09:00:00  2024-08-10 19:00:00            DewPtC  celsius
# 3    2010-08-20 19:00:00  2024-08-10 19:00:00    Soil_Temp_25cm  celsius
# 4    2010-08-20 19:00:00  2024-08-10 19:00:00    Soil_Temp_50cm  celsius
# 5    2010-08-20 19:00:00  2024-08-10 19:00:00    Soil_Temp_75cm  celsius
# ..                   ...                  ...               ...      ...
# 422  2007-07-31 15:00:00  2024-10-24 09:00:00  SolarRadiationWm    W m-2
# 423  2007-07-31 15:00:00  2024-10-24 09:00:00             TempC  celsius
# 424  2008-06-12 13:00:00  2024-10-24 09:00:00           Wetness        %
# 425  2007-07-31 15:00:00  2024-10-24 09:00:00     WindDirection   degree
# 426  2007-07-31 15:00:00  2024-10-24 09:00:00       WindSpeedms    m s-1
#
#         earliest_time_db       latest_time_db  earliest_diff_days  \
# 0                    NaN                  NaN                 NaN
# 2    2011-07-28 09:00:00  2024-08-10 19:00:00                 0.0
# 3                    NaN                  NaN                 NaN
# 4                    NaN                  NaN                 NaN
# 5                    NaN                  NaN                 NaN
# ..                   ...                  ...                 ...
# 422  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 423  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 424  2008-06-12 13:00:00  2024-10-24 09:00:00                 0.0
# 425  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
# 426  2007-07-31 15:00:00  2024-10-24 09:00:00                 0.0
#
#      latest_diff_days   batch native_id_db     lat_db      lon_db  elev_db
# 0                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# 2                 0.0  batch1       AtlSch  59.574000 -133.687000    705.0
# 3                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# 4                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# 5                 NaN  batch4       AtlSch  59.574000 -133.687000    705.0
# ..                ...     ...          ...        ...         ...      ...
# 422               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 423               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 424               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 425               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
# 426               0.0  batch1       PGTIS2  53.772577 -122.724634    596.0
#
# [401 rows x 17 columns]

# %%
data_path = '/fern_data/FERNNorth2024_VF/WxData24'

all_rows = []

for i, row in match_info_uniq_var.iterrows():
    station = row["station_name"]
    variable = row["variable"]

    print(f"\n🔍 [{i+1}/{len(match_info_uniq_var)}] Processing {station} — {variable}")

    new_rows = extract_new_data_rows(row, data_path)
    all_rows.extend(new_rows)

    if len(new_rows) > 0:
        print(f"  ✅ {len(new_rows)} new records found outside DB time range.")
    else:
        print("  ⚠️ No new records found (matches DB time range exactly).")
# Out:
# 🔍 [1/401] Processing Atlin School — Air Temp
#   ✅ 119237 new records found outside DB time range.
#
# 🔍 [3/401] Processing Atlin School — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [4/401] Processing Atlin School — Gd Temp 25 cm
#   ✅ 119237 new records found outside DB time range.
#
# 🔍 [5/401] Processing Atlin School — Gd Temp 50 cm
#   ✅ 119237 new records found outside DB time range.
#
# 🔍 [6/401] Processing Atlin School — Gd Temp 75 cm
#   ✅ 119237 new records found outside DB time range.
#
# 🔍 [7/401] Processing Atlin School — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [8/401] Processing Atlin School — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [9/401] Processing Atlin School — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [10/401] Processing Atlin School — Sfc Temp
#   ✅ 119237 new records found outside DB time range.
#
# 🔍 [11/401] Processing Atlin School — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [12/401] Processing Atlin School — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [13/401] Processing Atlin School — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [14/401] Processing BarrenWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [15/401] Processing BarrenWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [16/401] Processing BarrenWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [17/401] Processing BarrenWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [18/401] Processing BarrenWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [19/401] Processing BarrenWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [20/401] Processing BarrenWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [21/401] Processing BarrenWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [22/401] Processing BarrenWx — WC_cal
#   ✅ 28367 new records found outside DB time range.
#
# 🔍 [23/401] Processing BarrenWx — Water Content
#   ✅ 28367 new records found outside DB time range.
#
# 🔍 [24/401] Processing BarrenWx — Water Content
#   ✅ 24376 new records found outside DB time range.
#
# 🔍 [25/401] Processing BarrenWx — Water Content
#   ✅ 28367 new records found outside DB time range.
#
# 🔍 [26/401] Processing BarrenWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [27/401] Processing BarrenWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [28/401] Processing BlackhawkWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [29/401] Processing BlackhawkWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [30/401] Processing BlackhawkWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [31/401] Processing BlackhawkWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [32/401] Processing BlackhawkWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [33/401] Processing BlackhawkWx — Snow depth
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [34/401] Processing BlackhawkWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [35/401] Processing BlackhawkWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [36/401] Processing BlackhawkWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [37/401] Processing BlackhawkWx — WC_cal
#   ✅ 53150 new records found outside DB time range.
#
# 🔍 [38/401] Processing BlackhawkWx — Water Content
#   ✅ 62899 new records found outside DB time range.
#
# 🔍 [39/401] Processing BlackhawkWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [40/401] Processing BlackhawkWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [41/401] Processing BoulderWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [42/401] Processing BoulderWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [43/401] Processing BoulderWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [44/401] Processing BoulderWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [45/401] Processing BoulderWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [46/401] Processing BoulderWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [47/401] Processing BoulderWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [48/401] Processing BoulderWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [49/401] Processing BoulderWx — WC_cal
#   ✅ 54183 new records found outside DB time range.
#
# 🔍 [50/401] Processing BoulderWx — Water Content
#   ✅ 62214 new records found outside DB time range.
#
# 🔍 [51/401] Processing BoulderWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [52/401] Processing BoulderWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [53/401] Processing BoulderWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [54/401] Processing BowronPit — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [56/401] Processing BowronPit — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [57/401] Processing BowronPit — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [58/401] Processing BowronPit — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [60/401] Processing BowronPit — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [61/401] Processing BowronPit — Snow depth
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [62/401] Processing BowronPit — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [63/401] Processing BowronPit — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [64/401] Processing BowronPit — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [66/401] Processing BowronPit — WC_cal
#   ✅ 55387 new records found outside DB time range.
#
# 🔍 [67/401] Processing BowronPit — Water Content
#   ✅ 55387 new records found outside DB time range.
#
# 🔍 [68/401] Processing BowronPit — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [69/401] Processing BowronPit — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [70/401] Processing BulkleyWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [71/401] Processing BulkleyWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [72/401] Processing BulkleyWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [73/401] Processing BulkleyWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [74/401] Processing BulkleyWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [75/401] Processing BulkleyWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [76/401] Processing BulkleyWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [77/401] Processing BulkleyWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [78/401] Processing BulkleyWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [79/401] Processing BulkleyWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [80/401] Processing CPFWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [81/401] Processing CPFWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [82/401] Processing CPFWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [83/401] Processing CPFWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [84/401] Processing CPFWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [85/401] Processing CPFWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [86/401] Processing CPFWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [87/401] Processing CPFWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [88/401] Processing CPFWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [89/401] Processing CPFWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [90/401] Processing Canoe Mountain Stn — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [91/401] Processing Canoe Mountain Stn — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [92/401] Processing Canoe Mountain Stn — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [93/401] Processing Canoe Mountain Stn — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [94/401] Processing Canoe Mountain Stn — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [95/401] Processing Canoe Mountain Stn — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [96/401] Processing Canoe Mountain Stn — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [97/401] Processing Canoe Mountain Stn — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [98/401] Processing Canoe Mountain Stn — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [99/401] Processing Caribou Pass — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [101/401] Processing Caribou Pass — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [102/401] Processing Caribou Pass — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [103/401] Processing Caribou Pass — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [105/401] Processing Caribou Pass — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [106/401] Processing Caribou Pass — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [107/401] Processing Caribou Pass — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [109/401] Processing Caribou Pass — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [110/401] Processing Caribou Pass — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [111/401] Processing ChapmanWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [112/401] Processing ChapmanWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [113/401] Processing ChapmanWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [114/401] Processing ChapmanWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [115/401] Processing ChapmanWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [116/401] Processing ChapmanWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [117/401] Processing ChapmanWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [118/401] Processing ChapmanWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [119/401] Processing ChapmanWx — WC_cal
#   ✅ 28393 new records found outside DB time range.
#
# 🔍 [120/401] Processing ChapmanWx — Water Content
#   ✅ 28393 new records found outside DB time range.
#
# 🔍 [121/401] Processing ChapmanWx — Water Content
#   ✅ 22668 new records found outside DB time range.
#
# 🔍 [122/401] Processing ChapmanWx — Water Content
#   ✅ 22223 new records found outside DB time range.
#
# 🔍 [123/401] Processing ChapmanWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [124/401] Processing ChapmanWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [125/401] Processing ChiefLakeWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [126/401] Processing ChiefLakeWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [127/401] Processing ChiefLakeWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [128/401] Processing ChiefLakeWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [129/401] Processing ChiefLakeWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [130/401] Processing ChiefLakeWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [131/401] Processing ChiefLakeWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [132/401] Processing ChiefLakeWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [133/401] Processing ChiefLakeWx — WC_cal
#   ✅ 45629 new records found outside DB time range.
#
# 🔍 [134/401] Processing ChiefLakeWx — Water Content
#   ✅ 45629 new records found outside DB time range.
#
# 🔍 [135/401] Processing ChiefLakeWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [136/401] Processing ChiefLakeWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [137/401] Processing ChiefLakeWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [138/401] Processing CoalmineWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [140/401] Processing CoalmineWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [141/401] Processing CoalmineWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [142/401] Processing CoalmineWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [144/401] Processing CoalmineWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [145/401] Processing CoalmineWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [146/401] Processing CoalmineWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [148/401] Processing CoalmineWx — WC_cal
#   ✅ 39838 new records found outside DB time range.
#
# 🔍 [149/401] Processing CoalmineWx — Water Content
#   ✅ 39838 new records found outside DB time range.
#
# 🔍 [150/401] Processing CoalmineWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [151/401] Processing CoalmineWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [152/401] Processing CrookedLk — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [153/401] Processing CrookedLk — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [154/401] Processing CrookedLk — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [155/401] Processing CrookedLk — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [156/401] Processing CrookedLk — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [157/401] Processing CrookedLk — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [158/401] Processing CrookedLk — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [159/401] Processing CrookedLk — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [160/401] Processing CrookedLk — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [161/401] Processing CrystalWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [162/401] Processing CrystalWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [163/401] Processing CrystalWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [164/401] Processing CrystalWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [165/401] Processing CrystalWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [166/401] Processing CrystalWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [167/401] Processing CrystalWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [168/401] Processing CrystalWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [169/401] Processing CrystalWx — WC_cal
#   ✅ 59134 new records found outside DB time range.
#
# 🔍 [170/401] Processing CrystalWx — Water Content
#   ✅ 59134 new records found outside DB time range.
#
# 🔍 [171/401] Processing CrystalWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [172/401] Processing CrystalWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [173/401] Processing CrystalWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [174/401] Processing Dennis — DewPt
#   ✅ 9140 new records found outside DB time range.
#
# 🔍 [175/401] Processing Dennis — Gust Speed
#   ✅ 9140 new records found outside DB time range.
#
# 🔍 [176/401] Processing Dennis — Pressure
#   ✅ 9140 new records found outside DB time range.
#
# 🔍 [177/401] Processing Dennis — RH
#   ✅ 9140 new records found outside DB time range.
#
# 🔍 [178/401] Processing Dennis — Rain
#   ✅ 9139 new records found outside DB time range.
#
# 🔍 [179/401] Processing Dennis — Soil Temp
#   ✅ 9140 new records found outside DB time range.
#
# 🔍 [180/401] Processing Dennis — Solar Radiation
#   ✅ 9140 new records found outside DB time range.
#
# 🔍 [181/401] Processing Dennis — Temp
#   ✅ 9140 new records found outside DB time range.
#
# 🔍 [182/401] Processing Dennis — WC_cal
#   ✅ 19701 new records found outside DB time range.
#
# 🔍 [183/401] Processing Dennis — Water Content
#   ✅ 28430 new records found outside DB time range.
#
# 🔍 [184/401] Processing Dennis — Water Content
#   ✅ 15982 new records found outside DB time range.
#
# 🔍 [185/401] Processing Dennis — Water Content
#   ✅ 27386 new records found outside DB time range.
#
# 🔍 [186/401] Processing Dennis — Wind Direction
#   ✅ 9140 new records found outside DB time range.
#
# 🔍 [187/401] Processing Dennis — Wind Speed
#   ✅ 9140 new records found outside DB time range.
#
# 🔍 [188/401] Processing DunsterWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [189/401] Processing DunsterWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [190/401] Processing DunsterWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [191/401] Processing DunsterWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [192/401] Processing DunsterWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [194/401] Processing DunsterWx — Snow depth
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [195/401] Processing DunsterWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [196/401] Processing DunsterWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [197/401] Processing DunsterWx — WC_cal
#   ✅ 58227 new records found outside DB time range.
#
# 🔍 [198/401] Processing DunsterWx — Water Content
#   ✅ 64503 new records found outside DB time range.
#
# 🔍 [199/401] Processing DunsterWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [200/401] Processing DunsterWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [201/401] Processing EndakoWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [202/401] Processing EndakoWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [203/401] Processing EndakoWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [204/401] Processing EndakoWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [205/401] Processing EndakoWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [206/401] Processing EndakoWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [207/401] Processing EndakoWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [208/401] Processing EndakoWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [209/401] Processing EndakoWx — WC_cal
#   ✅ 56658 new records found outside DB time range.
#
# 🔍 [210/401] Processing EndakoWx — Water Content
#   ✅ 60842 new records found outside DB time range.
#
# 🔍 [211/401] Processing EndakoWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [212/401] Processing EndakoWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [213/401] Processing EndakoWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [214/401] Processing GeorgeWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [215/401] Processing GeorgeWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [216/401] Processing GeorgeWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [217/401] Processing GeorgeWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [218/401] Processing GeorgeWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [219/401] Processing GeorgeWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [220/401] Processing GeorgeWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [221/401] Processing GeorgeWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [222/401] Processing GeorgeWx — WC_cal
#   ✅ 49100 new records found outside DB time range.
#
# 🔍 [223/401] Processing GeorgeWx — Water Content
#   ✅ 49993 new records found outside DB time range.
#
# 🔍 [224/401] Processing GeorgeWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [225/401] Processing GeorgeWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [226/401] Processing GeorgeWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [227/401] Processing GunnelWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [228/401] Processing GunnelWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [229/401] Processing GunnelWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [230/401] Processing GunnelWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [231/401] Processing GunnelWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [232/401] Processing GunnelWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [233/401] Processing GunnelWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [234/401] Processing GunnelWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [235/401] Processing GunnelWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [236/401] Processing HourglassWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [237/401] Processing HourglassWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [238/401] Processing HourglassWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [239/401] Processing HourglassWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [240/401] Processing HourglassWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [241/401] Processing HourglassWx — Snow depth
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [242/401] Processing HourglassWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [243/401] Processing HourglassWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [244/401] Processing HourglassWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [245/401] Processing HourglassWx — WC_cal
#   ✅ 50245 new records found outside DB time range.
#
# 🔍 [246/401] Processing HourglassWx — Water Content
#   ✅ 50245 new records found outside DB time range.
#
# 🔍 [247/401] Processing HourglassWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [248/401] Processing HourglassWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [249/401] Processing Hudson Bay Mtn2 — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [250/401] Processing Hudson Bay Mtn2 — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [251/401] Processing Hudson Bay Mtn2 — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [252/401] Processing Hudson Bay Mtn2 — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [253/401] Processing Hudson Bay Mtn2 — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [254/401] Processing Hudson Bay Mtn2 — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [255/401] Processing Hudson Bay Mtn2 — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [256/401] Processing Hudson Bay Mtn2 — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [257/401] Processing Hudson Bay Mtn2 — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [258/401] Processing IBB2Wx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [259/401] Processing IBB2Wx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [260/401] Processing IBB2Wx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [261/401] Processing IBB2Wx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [262/401] Processing IBB2Wx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [263/401] Processing IBB2Wx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [264/401] Processing IBB2Wx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [265/401] Processing IBB2Wx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [266/401] Processing IBB2Wx — Water Content
#   ✅ 1274 new records found outside DB time range.
#
# 🔍 [267/401] Processing IBB2Wx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [268/401] Processing IBB2Wx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [269/401] Processing IBB2Wx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [270/401] Processing IBB3Wx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [271/401] Processing IBB3Wx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [272/401] Processing IBB3Wx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [273/401] Processing IBB3Wx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [274/401] Processing IBB3Wx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [275/401] Processing IBB3Wx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [276/401] Processing IBB3Wx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [277/401] Processing IBB3Wx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [278/401] Processing IBB3Wx — Water Content
#   ✅ 8686 new records found outside DB time range.
#
# 🔍 [279/401] Processing IBB3Wx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [280/401] Processing IBB3Wx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [281/401] Processing IBB3Wx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [282/401] Processing Inklin — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [283/401] Processing Inklin — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [284/401] Processing Inklin — Pressure
#   ✅ 74 new records found outside DB time range.
#
# 🔍 [285/401] Processing Inklin — RH
#   ✅ 926 new records found outside DB time range.
#
# 🔍 [286/401] Processing Inklin — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [287/401] Processing Inklin — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [288/401] Processing Inklin — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [289/401] Processing Inklin — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [290/401] Processing Inklin — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [291/401] Processing Kluskus — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [293/401] Processing Kluskus — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [294/401] Processing Kluskus — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [295/401] Processing Kluskus — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [297/401] Processing Kluskus — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [298/401] Processing Kluskus — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [299/401] Processing Kluskus — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [300/401] Processing Kluskus — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [302/401] Processing Kluskus — WC_cal
#   ✅ 63042 new records found outside DB time range.
#
# 🔍 [303/401] Processing Kluskus — Water Content
#   ✅ 63682 new records found outside DB time range.
#
# 🔍 [304/401] Processing Kluskus — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [305/401] Processing Kluskus — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [306/401] Processing MacJxnWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [307/401] Processing MacJxnWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [308/401] Processing MacJxnWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [309/401] Processing MacJxnWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [310/401] Processing MacJxnWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [311/401] Processing MacJxnWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [312/401] Processing MacJxnWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [313/401] Processing MacJxnWx — WC_cal
#   ✅ 52904 new records found outside DB time range.
#
# 🔍 [314/401] Processing MacJxnWx — Water Content
#   ✅ 58127 new records found outside DB time range.
#
# 🔍 [315/401] Processing MacJxnWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [316/401] Processing MacJxnWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [317/401] Processing MacJxnWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [318/401] Processing MiddleforkWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [319/401] Processing MiddleforkWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [320/401] Processing MiddleforkWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [321/401] Processing MiddleforkWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [322/401] Processing MiddleforkWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [323/401] Processing MiddleforkWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [324/401] Processing MiddleforkWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [325/401] Processing MiddleforkWx — WC_cal
#   ✅ 43920 new records found outside DB time range.
#
# 🔍 [326/401] Processing MiddleforkWx — Water Content
#   ✅ 43920 new records found outside DB time range.
#
# 🔍 [327/401] Processing MiddleforkWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [328/401] Processing MiddleforkWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [329/401] Processing NondaWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [331/401] Processing NondaWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [332/401] Processing NondaWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [333/401] Processing NondaWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [335/401] Processing NondaWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [336/401] Processing NondaWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [337/401] Processing NondaWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [339/401] Processing NondaWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [340/401] Processing NondaWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [341/401] Processing PinkWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [343/401] Processing PinkWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [344/401] Processing PinkWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [345/401] Processing PinkWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [347/401] Processing PinkWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [348/401] Processing PinkWx — Rain raw
#   ✅ 128491 new records found outside DB time range.
#
# 🔍 [349/401] Processing PinkWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [350/401] Processing PinkWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [352/401] Processing PinkWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [353/401] Processing PinkWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [354/401] Processing SaxtonWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [356/401] Processing SaxtonWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [357/401] Processing SaxtonWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [358/401] Processing SaxtonWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [360/401] Processing SaxtonWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [361/401] Processing SaxtonWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [362/401] Processing SaxtonWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [364/401] Processing SaxtonWx — WC_cal
#   ✅ 58280 new records found outside DB time range.
#
# 🔍 [365/401] Processing SaxtonWx — Water Content
#   ✅ 58280 new records found outside DB time range.
#
# 🔍 [366/401] Processing SaxtonWx — Water Content
#   ✅ 57926 new records found outside DB time range.
#
# 🔍 [367/401] Processing SaxtonWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [368/401] Processing SaxtonWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [369/401] Processing SeebachWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [370/401] Processing SeebachWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [371/401] Processing SeebachWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [372/401] Processing SeebachWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [373/401] Processing SeebachWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [374/401] Processing SeebachWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [375/401] Processing SeebachWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [376/401] Processing SeebachWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [377/401] Processing SeebachWx — Water Content
#   ✅ 10583 new records found outside DB time range.
#
# 🔍 [378/401] Processing SeebachWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [379/401] Processing SeebachWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [380/401] Processing SeebachWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [381/401] Processing Sunbeam — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [383/401] Processing Sunbeam — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [384/401] Processing Sunbeam — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [385/401] Processing Sunbeam — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [387/401] Processing Sunbeam — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [388/401] Processing Sunbeam — Snow depth
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [389/401] Processing Sunbeam — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [390/401] Processing Sunbeam — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [392/401] Processing Sunbeam — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [393/401] Processing Sunbeam — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [394/401] Processing Tamarac — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [395/401] Processing Tamarac — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [396/401] Processing Tamarac — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [397/401] Processing Tamarac — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [398/401] Processing Tamarac — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [399/401] Processing Tamarac — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [400/401] Processing Tamarac — WC_cal
#   ✅ 24854 new records found outside DB time range.
#
# 🔍 [401/401] Processing Tamarac — Water Content
#   ✅ 24854 new records found outside DB time range.
#
# 🔍 [402/401] Processing Tamarac — Water Content
#   ✅ 24855 new records found outside DB time range.
#
# 🔍 [403/401] Processing Tamarac — Water Content
#   ✅ 25717 new records found outside DB time range.
#
# 🔍 [404/401] Processing Tamarac — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [405/401] Processing ThompsonWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [406/401] Processing ThompsonWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [407/401] Processing ThompsonWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [408/401] Processing ThompsonWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [409/401] Processing ThompsonWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [410/401] Processing ThompsonWx — Soil Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [411/401] Processing ThompsonWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [412/401] Processing ThompsonWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [413/401] Processing ThompsonWx — WC_cal
#   ✅ 59331 new records found outside DB time range.
#
# 🔍 [414/401] Processing ThompsonWx — Water Content
#   ✅ 70003 new records found outside DB time range.
#
# 🔍 [415/401] Processing ThompsonWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [416/401] Processing ThompsonWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [417/401] Processing ThompsonWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [418/401] Processing Willow-BowronWx — DewPt
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [419/401] Processing Willow-BowronWx — Gust Speed
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [420/401] Processing Willow-BowronWx — Pressure
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [421/401] Processing Willow-BowronWx — RH
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [422/401] Processing Willow-BowronWx — Rain
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [423/401] Processing Willow-BowronWx — Solar Radiation
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [424/401] Processing Willow-BowronWx — Temp
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [425/401] Processing Willow-BowronWx — Wetness
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [426/401] Processing Willow-BowronWx — Wind Direction
#   ⚠️ No new records found (matches DB time range exactly).
#
# 🔍 [427/401] Processing Willow-BowronWx — Wind Speed
#   ⚠️ No new records found (matches DB time range exactly).

# %% [markdown]
# ### Insert

# %%
len(all_rows)
# Out:
# 2942201

# %%
all_rows[0:2]
# Out:
# [Row(time=Timestamp('2010-08-20 19:00:00'), val=10.271, variable_name='TempC', unit='celsius', network_name='BC-FERN', station_id='AtlSch', lat=59.574, lon=-133.687),
#  Row(time=Timestamp('2010-08-20 20:00:00'), val=9.262, variable_name='TempC', unit='celsius', network_name='BC-FERN', station_id='AtlSch', lat=59.574, lon=-133.687)]

# %%
db_url = "postgresql+psycopg2://tongli1997@/crmp?host=pg01.pcic.uvic.ca,pg02.pcic.uvic.ca&port=5432,5432&target_session_attrs=read-write&passfile=/workspaces/crmprtd/.pgpass"

safe_insert_rows(
    all_rows,
    log_file_path=output_folder + 'fern_all_station_insert.log',
    db_url=db_url,
    chunk_size=5000,        # SAFE starting point
    bulk_chunk_size=1000,   # internal DB bulk insert size
)
# Out:
# 🚀 Starting insert: 2942201 rows in 589 chunks
# ➡️  Processing rows 0–4999
# {"asctime": "2026-02-09 21:52:59,497", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:52:59,575", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:52:59,642", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:52:59,707", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:52:59,769", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:52:59,831", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:52:59,832", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:52:59,833", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 0–4999
# ➡️  Processing rows 5000–9999
# {"asctime": "2026-02-09 21:52:59,866", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:52:59,986", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,051", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,113", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,190", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,254", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,255", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:00,255", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 5000–9999
# ➡️  Processing rows 10000–14999
# {"asctime": "2026-02-09 21:53:00,290", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:00,408", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,472", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,536", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,602", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,669", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,670", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:00,670", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 10000–14999
# ➡️  Processing rows 15000–19999
# {"asctime": "2026-02-09 21:53:00,710", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:00,830", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,896", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:00,960", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,024", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,091", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,091", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:01,092", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 15000–19999
# ➡️  Processing rows 20000–24999
# {"asctime": "2026-02-09 21:53:01,130", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:01,251", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,315", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,380", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,443", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,507", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,508", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:01,508", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 20000–24999
# ➡️  Processing rows 25000–29999
# {"asctime": "2026-02-09 21:53:01,544", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:01,665", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,733", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,797", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,862", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,928", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:01,928", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:01,928", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 25000–29999
# ➡️  Processing rows 30000–34999
# {"asctime": "2026-02-09 21:53:01,963", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:02,084", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,148", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,210", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,271", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,334", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,334", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:02,334", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 30000–34999
# ➡️  Processing rows 35000–39999
# {"asctime": "2026-02-09 21:53:02,376", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:02,497", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,565", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,630", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,693", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,756", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,757", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:02,757", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 35000–39999
# ➡️  Processing rows 40000–44999
# {"asctime": "2026-02-09 21:53:02,794", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:02,916", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:02,982", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:03,046", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:03,109", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:03,175", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:03,175", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:03,176", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 40000–44999
# ➡️  Processing rows 45000–49999
# {"asctime": "2026-02-09 21:53:03,604", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:03,721", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:03,787", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:03,852", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:03,915", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:03,979", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:03,980", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:03,980", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 45000–49999
# ➡️  Processing rows 50000–54999
# {"asctime": "2026-02-09 21:53:04,012", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:04,133", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,197", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,262", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,326", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,390", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,391", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:04,391", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 50000–54999
# ➡️  Processing rows 55000–59999
# {"asctime": "2026-02-09 21:53:04,425", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:04,540", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,605", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,668", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,729", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,793", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:04,793", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:04,794", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 55000–59999
# ➡️  Processing rows 60000–64999
# {"asctime": "2026-02-09 21:53:04,827", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:04,946", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,013", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,076", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,141", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,205", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,205", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:05,206", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 60000–64999
# ➡️  Processing rows 65000–69999
# {"asctime": "2026-02-09 21:53:05,240", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:05,363", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,429", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,492", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,556", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,621", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,621", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:05,622", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 65000–69999
# ➡️  Processing rows 70000–74999
# {"asctime": "2026-02-09 21:53:05,656", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:05,774", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,838", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,901", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:05,964", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,029", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,030", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:06,030", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 70000–74999
# ➡️  Processing rows 75000–79999
# {"asctime": "2026-02-09 21:53:06,068", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:06,194", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,259", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,323", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,388", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,453", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,453", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:06,454", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 75000–79999
# ➡️  Processing rows 80000–84999
# {"asctime": "2026-02-09 21:53:06,488", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:06,607", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,673", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,737", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,804", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,869", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:06,869", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:06,870", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 80000–84999
# ➡️  Processing rows 85000–89999
# {"asctime": "2026-02-09 21:53:06,911", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:07,029", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,092", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,162", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,228", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,291", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,291", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:07,292", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 85000–89999
# ➡️  Processing rows 90000–94999
# {"asctime": "2026-02-09 21:53:07,332", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:07,451", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,515", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,577", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,638", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,699", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,699", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:07,700", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 90000–94999
# ➡️  Processing rows 95000–99999
# {"asctime": "2026-02-09 21:53:07,736", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:07,874", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,936", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:07,998", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,059", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,122", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,122", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:08,123", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 95000–99999
# ➡️  Processing rows 100000–104999
# {"asctime": "2026-02-09 21:53:08,152", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:08,268", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,329", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,391", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,454", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,516", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,517", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:08,517", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 100000–104999
# ➡️  Processing rows 105000–109999
# {"asctime": "2026-02-09 21:53:08,547", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:08,673", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,737", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,800", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,864", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,926", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:08,926", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:08,927", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 105000–109999
# ➡️  Processing rows 110000–114999
# {"asctime": "2026-02-09 21:53:08,960", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:09,079", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,144", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,206", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,269", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,330", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,331", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:09,331", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 110000–114999
# ➡️  Processing rows 115000–119999
# {"asctime": "2026-02-09 21:53:09,433", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:09,499", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,563", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,624", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,687", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,748", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,749", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:09,749", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 115000–119999
# ➡️  Processing rows 120000–124999
# {"asctime": "2026-02-09 21:53:09,790", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:09,909", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:09,979", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,042", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,103", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,164", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,164", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:10,165", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 120000–124999
# ➡️  Processing rows 125000–129999
# {"asctime": "2026-02-09 21:53:10,201", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:10,318", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,380", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,440", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,501", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,562", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,562", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:10,563", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 125000–129999
# ➡️  Processing rows 130000–134999
# {"asctime": "2026-02-09 21:53:10,599", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:10,721", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,785", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,849", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,909", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,969", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:10,970", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:10,970", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 130000–134999
# ➡️  Processing rows 135000–139999
# {"asctime": "2026-02-09 21:53:11,005", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:11,127", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,188", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,249", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,311", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,373", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,374", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:11,374", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 135000–139999
# ➡️  Processing rows 140000–144999
# {"asctime": "2026-02-09 21:53:11,411", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:11,532", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,594", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,657", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,720", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,783", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:11,784", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:11,784", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 140000–144999
# ➡️  Processing rows 145000–149999
# {"asctime": "2026-02-09 21:53:12,162", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:12,286", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,350", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,411", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,484", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,547", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,548", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:12,548", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 145000–149999
# ➡️  Processing rows 150000–154999
# {"asctime": "2026-02-09 21:53:12,586", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:12,716", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,782", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,849", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,927", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,991", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:12,992", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:12,992", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 150000–154999
# ➡️  Processing rows 155000–159999
# {"asctime": "2026-02-09 21:53:13,028", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:13,292", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,357", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,422", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,485", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,546", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,546", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:13,547", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 155000–159999
# ➡️  Processing rows 160000–164999
# {"asctime": "2026-02-09 21:53:13,584", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:13,702", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,765", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,827", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,889", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,950", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:13,951", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:13,951", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 160000–164999
# ➡️  Processing rows 165000–169999
# {"asctime": "2026-02-09 21:53:13,990", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:14,110", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,171", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,233", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,294", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,355", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,356", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:14,356", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 165000–169999
# ➡️  Processing rows 170000–174999
# {"asctime": "2026-02-09 21:53:14,393", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:14,510", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,571", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,632", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,702", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,763", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,763", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:14,764", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 170000–174999
# ➡️  Processing rows 175000–179999
# {"asctime": "2026-02-09 21:53:14,801", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:14,916", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:14,978", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,040", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,100", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,160", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,160", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:15,161", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 175000–179999
# ➡️  Processing rows 180000–184999
# {"asctime": "2026-02-09 21:53:15,201", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:15,326", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,389", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,451", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,510", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,571", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,572", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:15,572", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 180000–184999
# ➡️  Processing rows 185000–189999
# {"asctime": "2026-02-09 21:53:15,611", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:15,729", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,791", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,853", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,913", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,974", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:15,974", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:53:15,975", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 185000–189999
# ➡️  Processing rows 190000–194999
# {"asctime": "2026-02-09 21:53:16,015", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:53:16,133", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:16,195", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:16,258", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:16,320", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:53:16,387", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# ...
# {"asctime": "2026-02-09 21:58:03,672", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2875000–2879999
# ➡️  Processing rows 2880000–2884999
# {"asctime": "2026-02-09 21:58:03,708", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:03,826", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:03,890", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:03,953", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,016", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,081", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,081", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:04,082", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2880000–2884999
# ➡️  Processing rows 2885000–2889999
# {"asctime": "2026-02-09 21:58:04,115", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:04,236", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,300", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,362", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,426", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,487", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,488", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:04,488", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2885000–2889999
# ➡️  Processing rows 2890000–2894999
# {"asctime": "2026-02-09 21:58:04,527", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:04,646", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,709", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,771", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,835", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,899", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:04,900", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:04,900", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2890000–2894999
# ➡️  Processing rows 2895000–2899999
# {"asctime": "2026-02-09 21:58:04,935", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:05,057", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,119", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,181", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,243", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,306", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,307", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:05,307", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2895000–2899999
# ➡️  Processing rows 2900000–2904999
# {"asctime": "2026-02-09 21:58:05,349", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:05,467", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,529", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,591", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,655", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,725", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,726", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:05,726", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2900000–2904999
# ➡️  Processing rows 2905000–2909999
# {"asctime": "2026-02-09 21:58:05,761", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:05,876", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:05,940", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,004", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,066", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,128", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,129", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:06,129", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2905000–2909999
# ➡️  Processing rows 2910000–2914999
# {"asctime": "2026-02-09 21:58:06,165", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:06,285", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,347", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,411", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,472", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,535", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,536", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:06,536", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2910000–2914999
# ➡️  Processing rows 2915000–2919999
# {"asctime": "2026-02-09 21:58:06,571", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:06,690", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,753", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,817", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,880", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,943", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:06,944", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:06,944", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2915000–2919999
# ➡️  Processing rows 2920000–2924999
# {"asctime": "2026-02-09 21:58:06,979", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:07,096", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:07,562", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:07,624", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:07,687", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:07,748", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:07,749", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:07,750", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2920000–2924999
# ➡️  Processing rows 2925000–2929999
# {"asctime": "2026-02-09 21:58:07,786", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:07,947", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,012", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,075", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,139", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,201", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,202", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:08,202", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2925000–2929999
# ➡️  Processing rows 2930000–2934999
# {"asctime": "2026-02-09 21:58:08,239", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:08,363", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,427", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,489", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,552", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,615", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,615", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:08,616", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2930000–2934999
# ➡️  Processing rows 2935000–2939999
# {"asctime": "2026-02-09 21:58:08,654", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:08,787", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,851", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,911", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 3000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:08,973", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 4000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:09,036", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 5000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:09,037", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:09,037", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2935000–2939999
# ➡️  Processing rows 2940000–2942200
# {"asctime": "2026-02-09 21:58:09,061", "levelname": "INFO", "name": "crmprtd.insert", "message": "Using Bulk Insert Strategy"}
# {"asctime": "2026-02-09 21:58:09,185", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 1000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:09,251", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2000 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:09,270", "levelname": "INFO", "name": "crmprtd.insert", "message": "Bulk insert progress: 0 inserted, 2201 skipped, 0 failed"}
# {"asctime": "2026-02-09 21:58:09,271", "levelname": "INFO", "name": "crmprtd.insert", "message": "Successfully inserted observations: 0"}
# {"asctime": "2026-02-09 21:58:09,271", "levelname": "INFO", "name": "crmprtd.insert", "message": "Data insertion complete"}
# ✅ Inserted rows 2940000–2942200
